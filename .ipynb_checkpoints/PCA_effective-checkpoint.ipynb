# %% [markdown]
# # Spurious Correlations of Highly Dimensional Big Data

# %% [markdown]
# This Notebook aims at showing how PCA and random projection can solve the problem of spurious correlations in Big Data.

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.utils import shuffle

# %% [markdown]
# ## DataFrame Creation

# %%
# User defined parameters

# Number of rows for df1
x = 10000

# Number of columns for df1
y = 100000

# Number of rows for df2
z = 100

# %%
np.random.seed(0)

# %%
# Creating a dataframe with x number of rows and y number of columns
df = pd.DataFrame(np.random.random_sample((x,y)))

# Shuffle rows of dataframe
df = df.sample(frac=1)

# %% [markdown]
# In order to assess the correlations of the different parameters, correlations between the column with index 0 and the 999 other first columns is assessed.

# %%
# Assigning X to all columns except 0
X_df = df.drop(columns=0)
X_df.head()

# Assigning Y to column 0
Y_df = df[0]
print(Y_df)

# The following line makes Y become a list
Y_df = np.array(Y_df).reshape(-1)
print(X_df.shape,Y_df.shape)

# Calculate correlations between selected column and column 0
list_titles = X_df.columns
list_corr_df1 = []
for i in list_titles[0:z]:
    list_corr_df1.append(abs(np.corrcoef(Y_df, X_df[i])[0][1]))
# Out:
# 5777    0.013107
# 3783    0.960434
# 1295    0.145563
# 838     0.415516
# 1786    0.838305
#           ...
# 3408    0.998848
# 6336    0.662911
# 1880    0.416949
# 763     0.647500
# 2631    0.795114
# Name: 0, Length: 10000, dtype: float64
# (10000, 99999) (10000,)

# %% [markdown]
# To see if indeed the correlations between the different parameters increases with the data size, the original dataframe is compared to a sub-set dataframe which only takes the first z rows of the original dataframe. If the correlations in the original dataframe are higher than in the smaller dataframe this would prove that the bigger the data size the more frequent the number of spurious correlations.

# %%
# Creating smaller dataframe taking z number of rows from original dataframe
df2 = df.iloc[:z]
df2
# Out:
#          0         1         2         3         4         5         6      \
# 5777  0.013107  0.470582  0.782615  0.356561  0.713228  0.001639  0.531202
# 3783  0.960434  0.443701  0.571535  0.813105  0.448731  0.292695  0.378250
# 1295  0.145563  0.462142  0.170783  0.475111  0.200657  0.647372  0.260204
# 838   0.415516  0.027677  0.297519  0.258756  0.415945  0.530397  0.204964
# 1786  0.838305  0.187315  0.668331  0.625653  0.694821  0.305795  0.505483
# ...        ...       ...       ...       ...       ...       ...       ...
# 1206  0.034008  0.384476  0.955847  0.017472  0.794494  0.203768  0.840669
# 3166  0.970882  0.217768  0.846741  0.774417  0.425300  0.366696  0.320553
# 7007  0.536753  0.235460  0.386641  0.627114  0.757405  0.824510  0.304211
# 231   0.453526  0.221772  0.356402  0.693289  0.388062  0.727092  0.152799
# 7824  0.467103  0.391480  0.258068  0.293616  0.933281  0.427195  0.132386
#
#          7         8         9      ...     99990     99991     99992  \
# 5777  0.149542  0.238533  0.156730  ...  0.014578  0.703602  0.121921
# 3783  0.988330  0.737386  0.240126  ...  0.865072  0.048426  0.556778
# 1295  0.386845  0.420123  0.275254  ...  0.038677  0.744098  0.731141
# 838   0.330645  0.675209  0.114403  ...  0.305023  0.463645  0.621614
# 1786  0.220637  0.973320  0.472144  ...  0.863375  0.903354  0.090747
# ...        ...       ...       ...  ...       ...       ...       ...
# 1206  0.235905  0.451264  0.652585  ...  0.543415  0.567987  0.648657
# 3166  0.725521  0.691172  0.997096  ...  0.743677  0.513415  0.185774
# 7007  0.478996  0.601915  0.469792  ...  0.371762  0.180812  0.551398
# 231   0.823869  0.241612  0.032454  ...  0.914891  0.290496  0.041678
# 7824  0.028883  0.788388  0.016230  ...  0.865755  0.817536  0.658653
#
#          99993     99994     99995     99996     99997     99998     99999
# 5777  0.809777  0.141529  0.051837  0.615442  0.598923  0.463951  0.278275
# 3783  0.939422  0.430007  0.304750  0.629446  0.784474  0.027791  0.411822
# 1295  0.329909  0.280043  0.441809  0.997663  0.531609  0.461333  0.930565
# 838   0.614746  0.401539  0.840944  0.074929  0.523992  0.074633  0.005774
# 1786  0.823878  0.833744  0.254442  0.854606  0.282577  0.124343  0.716000
# ...        ...       ...       ...       ...       ...       ...       ...
# 1206  0.374993  0.781972  0.816703  0.173999  0.779997  0.079036  0.773980
# 3166  0.593170  0.729660  0.288874  0.085996  0.673181  0.571513  0.732731
# 7007  0.731789  0.660825  0.301559  0.690867  0.735730  0.899302  0.432162
# 231   0.685290  0.540991  0.279267  0.791828  0.520694  0.033079  0.731138
# 7824  0.292141  0.345956  0.435087  0.135645  0.057249  0.057284  0.933701
#
# [100 rows x 100000 columns]

# %%
# Assigning X to all columns except 0
X_df2 = df2.drop(columns=0)
X_df2.head()

# Assigning Y to column 0
Y_df2 = df2[0]
print(Y_df2)

# The following line makes Y become a list
Y_df2 = np.array(Y_df2).reshape(-1)
print(X_df2.shape,Y_df2.shape)

list_titles = X_df2.columns

# Calculate correlations between selected column and column 0
list_corr_df2 = []
for i in list_titles[0:z]:
    list_corr_df2.append(abs(np.corrcoef(Y_df2, X_df2[i])[0][1]))
# Out:
# 5777    0.013107
# 3783    0.960434
# 1295    0.145563
# 838     0.415516
# 1786    0.838305
#           ...
# 1206    0.034008
# 3166    0.970882
# 7007    0.536753
# 231     0.453526
# 7824    0.467103
# Name: 0, Length: 100, dtype: float64
# (100, 99999) (100,)

# %% [markdown]
# We now compare which of the correlation lists has the highest numbers of every parameter

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df2)):
    if abs(list_corr_df2[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df2:",(b/len(list_corr_df2)*100),"%")
# Out:
# Percentage of correlations in df1: 35.0 %
# Percentage of correlations in df2: 95.0 %

# %% [markdown]
# Clearly it is seen that the lower the number of observations, the higher the frequency of spurious correlations. However the number of spurious correlations present in the bigger DataFrame is still very significant.

# %% [markdown]
# To counter spurious correlations, Principal Component Analysis and Random Projection can be used.

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# In PCA, it is up to the user to choose how many dimension the final data has. This is because the explained variance tells you how much information (variance) can be attributed to each of the principal components. This is important as while you can convert a y dimensional space to 2 dimensional space, you lose some of the variance (information) when you do this. It is up to the user to decide how much variance he is ready to lose.

# %%
# Here we pass the daframe of y columns in 2 dimensions
pca = PCA(n_components=2)
df_pca = pd.DataFrame(pca.fit_transform(df))
# Out:
#              0         1
# 0     3.489677  1.333001
# 1     2.754372 -0.844385
# 2     0.623227 -2.537519
# 3     0.537976  0.929133
# 4    -0.267142 -0.585531
# ...        ...       ...
# 9995 -1.180457 -0.505802
# 9996 -0.366358  1.050017
# 9997 -0.703431 -0.940164
# 9998  0.725669 -1.621737
# 9999 -0.827070  0.694288
#
# [10000 rows x 2 columns]

# %%
# How much of the information is kept by the new dataframe?
print(pca.explained_variance_ratio_)
# Out:
# array([0.00016026, 0.00015946])

# %% [markdown]
# The new dataframe is not useful as it almost does not capture any variance. Thus we need more dimensionss.

# %%
# Here we pass the daframe of y columns in 2 dimensions
pca = PCA(n_components=1000)
df_pca = pd.DataFrame(pca.fit_transform(df))
print(pca.explained_variance_ratio_)

# %%
df_new = df_pca
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]
print(Y_df_new)

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

# Calculate correlations between selected column and column 0
list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")
# Out:
# 0       3.489677
# 1       2.754372
# 2       0.623227
# 3       0.537976
# 4      -0.267142
#           ...
# 9995   -1.180457
# 9996   -0.366358
# 9997   -0.703431
# 9998    0.725669
# 9999   -0.827070
# Name: 0, Length: 10000, dtype: float64
# (10000, 1) (10000,)
# 1
# Correlation matrix for column 0 and and column1: 4.267451745825037e-17
# Percentage of correlations in df1: 35.0 %
# Percentage of correlations in df_new: 0.0 %

# %% [markdown]
# ## Random Projection

# %% [markdown]
# In Random Projection, the parameter eps defines how much the Random Projection can deviate from original DataFrame.
# The lower the percentage of the parameter the higher the fidelity of the transformed data.
# However the higher the fidelity the less the reduction of dimensions.

# %%
transformer = random_projection.GaussianRandomProjection(eps = 0.1)
df_rp = pd.DataFrame(transformer.fit_transform(df))
df_rp
# Out:
#           0         1         2         3         4         5         6     \
# 0    -1.065171 -2.995992 -2.089320 -2.099279 -1.845437 -0.324604 -3.404616
# 1    -0.385895 -1.801724 -1.797421 -3.293098 -0.687212  0.507298 -0.773589
# 2    -0.418647 -1.787895 -0.621267 -1.745061 -0.210410 -0.711057 -0.976609
# 3    -1.221595 -0.488927 -2.063268 -3.089680 -1.500593  1.708293 -1.252196
# 4    -0.726137 -1.509496 -2.540422 -4.012834 -1.153815  0.528685 -1.139813
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -2.108472 -0.473873 -0.719751 -4.236844 -2.174455  0.274223 -1.584417
# 9996 -0.115898 -2.536814 -1.051227 -3.718890  0.047188 -1.162188 -0.519333
# 9997  0.421128 -0.158143 -3.312280 -2.973501 -0.179981 -1.195781 -1.124617
# 9998  0.351580 -1.213253 -2.140968 -5.686912 -1.062430  0.514025 -3.970652
# 9999 -0.081828 -1.166170 -2.961146 -0.879005 -2.421925  1.651297 -0.921941
#
#           7         8         9     ...      7884      7885      7886  \
# 0    -4.107494 -0.053100 -0.332333  ... -0.943849  0.139202  0.392004
# 1    -2.944505 -2.270239 -1.632081  ... -0.175455 -0.307618 -0.950719
# 2    -1.365674 -0.600333 -0.503523  ...  0.808576  1.078265 -1.432039
# 3    -1.746754 -1.859046 -1.657892  ... -1.885928 -1.501214 -0.971320
# 4    -2.283626  1.272111 -0.769261  ... -0.838658 -0.353893 -2.806067
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -2.582362 -1.277590 -1.455722  ...  1.551948  0.166605 -0.680626
# 9996 -2.980986 -0.647016 -0.837035  ... -1.829839  1.303674 -3.401701
# 9997 -2.059188 -0.606050 -1.206387  ... -0.758668  2.347899 -1.306924
# 9998  0.268105 -1.281245 -2.182091  ... -0.417638 -0.913639 -0.886946
# 9999 -1.365103 -1.710098 -0.249466  ...  0.944160  0.481008  0.137552
#
#           7887      7888      7889      7890      7891      7892      7893
# 0     2.402662  0.777589  0.446667  0.128100 -3.848460 -1.705434 -1.828247
# 1     3.730785  0.130190  0.056837  0.148003 -3.057238 -0.412806 -1.182247
# 2     2.765225  1.934319  0.442529 -1.473505 -2.532592  0.257621 -2.628619
# 3     1.868761 -0.818324 -0.460472 -0.824017 -1.925590 -1.842852 -1.747831
# 4     2.338738  0.712653  0.274454 -0.772017 -1.924188 -2.405850  0.769224
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.964170 -0.325588 -0.829252 -0.507893 -2.943830  0.326356 -1.620861
# 9996  4.359526  0.499929  0.497433  0.954959 -2.382946 -1.027271  0.596993
# 9997  2.217031 -0.328944  1.290079  0.205446 -2.794713 -0.276964 -2.046912
# 9998  2.123830 -1.319631  0.742418  0.358243 -2.608131  0.615273  0.240094
# 9999  3.546756 -0.922829  1.049338 -1.479821 -3.251476 -1.001819 -1.109263
#
# [10000 rows x 7894 columns]

# %%
df_new = df_rp
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]
print(Y_df_new)

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    print(i)
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
# Out:
# 0      -1.065171
# 1      -0.385895
# 2      -0.418647
# 3      -1.221595
# 4      -0.726137
#           ...
# 9995   -2.108472
# 9996   -0.115898
# 9997    0.421128
# 9998    0.351580
# 9999   -0.081828
# Name: 0, Length: 10000, dtype: float64
# (10000, 7893) (10000,)
# 1
# Correlation matrix for column 0 and and column1: 0.002933361300677142
# 2
# Correlation matrix for column 0 and and column2: 0.009975699694125194
# 3
# Correlation matrix for column 0 and and column3: 0.0009664925705303054
# 4
# Correlation matrix for column 0 and and column4: -0.018583716701759817
# 5
# Correlation matrix for column 0 and and column5: -0.006737009442109067
# 6
# Correlation matrix for column 0 and and column6: 0.005040145364998269
# 7
# Correlation matrix for column 0 and and column7: -0.0017476222491390487
# 8
# Correlation matrix for column 0 and and column8: 0.000776276651315675
# 9
# Correlation matrix for column 0 and and column9: -0.0046113792801520835
# 10
# Correlation matrix for column 0 and and column10: 0.005502110639484078
# 11
# Correlation matrix for column 0 and and column11: -0.010144184030436626
# 12
# Correlation matrix for column 0 and and column12: 0.018505477895656267
# 13
# Correlation matrix for column 0 and and column13: -0.004220754951196558
# 14
# Correlation matrix for column 0 and and column14: -0.005462107904508697
# 15
# Correlation matrix for column 0 and and column15: -0.004221119085066523
# 16
# Correlation matrix for column 0 and and column16: -0.0005222832191158248
# 17
# Correlation matrix for column 0 and and column17: 0.015337743256757701
# 18
# Correlation matrix for column 0 and and column18: 0.0162531854212264
# 19
# Correlation matrix for column 0 and and column19: -0.004632631776014492
# 20
# Correlation matrix for column 0 and and column20: 0.008569600852046007
# 21
# Correlation matrix for column 0 and and column21: -0.01634851147823867
# 22
# Correlation matrix for column 0 and and column22: 0.013330794633617481
# 23
# Correlation matrix for column 0 and and column23: -0.00197579159903216
# 24
# Correlation matrix for column 0 and and column24: -0.00281014291717025
# 25
# Correlation matrix for column 0 and and column25: 0.014568688308446364
# 26
# Correlation matrix for column 0 and and column26: 0.020606729081532712
# 27
# Correlation matrix for column 0 and and column27: -0.015331050344834988
# 28
# Correlation matrix for column 0 and and column28: -0.0054128450329186725
# 29
# Correlation matrix for column 0 and and column29: 0.006007990125663708
# 30
# Correlation matrix for column 0 and and column30: 0.0034229008391362396
# 31
# Correlation matrix for column 0 and and column31: 0.010306153765177146
# 32
# Correlation matrix for column 0 and and column32: 0.007423231130895581
# 33
# Correlation matrix for column 0 and and column33: -0.00486889118063879
# 34
# Correlation matrix for column 0 and and column34: -0.0069956403814101726
# 35
# Correlation matrix for column 0 and and column35: -0.0010473884101334574
# 36
# Correlation matrix for column 0 and and column36: 0.01504784071241553
# 37
# Correlation matrix for column 0 and and column37: 0.011529098923544437
# 38
# Correlation matrix for column 0 and and column38: -0.0022724751776306315
# 39
# Correlation matrix for column 0 and and column39: 0.0015029628451653334
# 40
# Correlation matrix for column 0 and and column40: -0.0016472046932962039
# 41
# Correlation matrix for column 0 and and column41: -0.008362797151202488
# 42
# Correlation matrix for column 0 and and column42: -0.006038521130713286
# 43
# Correlation matrix for column 0 and and column43: -0.0006449932059364802
# 44
# Correlation matrix for column 0 and and column44: -0.0015324273759681816
# 45
# Correlation matrix for column 0 and and column45: -0.00016819576128047098
# 46
# Correlation matrix for column 0 and and column46: 0.0011354337596108082
# 47
# Correlation matrix for column 0 and and column47: 0.016695139837015562
# 48
# Correlation matrix for column 0 and and column48: 0.009409139767441363
# 49
# Correlation matrix for column 0 and and column49: 0.0016489250221289958
# 50
# Correlation matrix for column 0 and and column50: -0.009750336951156863
# 51
# Correlation matrix for column 0 and and column51: -0.013514734797483696
# 52
# Correlation matrix for column 0 and and column52: 0.0029312563306959543
# 53
# Correlation matrix for column 0 and and column53: -0.004299563824537926
# 54
# Correlation matrix for column 0 and and column54: -0.007235292036099786
# 55
# Correlation matrix for column 0 and and column55: -0.009376475169372334
# 56
# Correlation matrix for column 0 and and column56: -0.0028766779793628185
# 57
# Correlation matrix for column 0 and and column57: 0.013411230276534724
# 58
# Correlation matrix for column 0 and and column58: -0.006578027618887614
# 59
# Correlation matrix for column 0 and and column59: 0.005723080859789958
# 60
# Correlation matrix for column 0 and and column60: -0.010258324525132258
# 61
# Correlation matrix for column 0 and and column61: 0.007552329009777076
# 62
# Correlation matrix for column 0 and and column62: -0.019712980584632278
# 63
# Correlation matrix for column 0 and and column63: 0.0058933183555135325
# 64
# Correlation matrix for column 0 and and column64: 0.015208333258891801
# 65
# Correlation matrix for column 0 and and column65: -0.002962344689572103
# 66
# Correlation matrix for column 0 and and column66: -0.004774291504766658
# 67
# Correlation matrix for column 0 and and column67: -0.00715223974751756
# 68
# Correlation matrix for column 0 and and column68: -0.009640146723447592
# 69
# Correlation matrix for column 0 and and column69: 0.0002928531898650065
# 70
# Correlation matrix for column 0 and and column70: -0.00044224124615459693
# 71
# Correlation matrix for column 0 and and column71: 0.001542240509182571
# 72
# Correlation matrix for column 0 and and column72: -0.0018793531446015235
# 73
# Correlation matrix for column 0 and and column73: 0.006775536786114061
# 74
# Correlation matrix for column 0 and and column74: -0.006194186078574686
# 75
# Correlation matrix for column 0 and and column75: 0.00429698570148501
# 76
# Correlation matrix for column 0 and and column76: 0.019679103851296915
# 77
# Correlation matrix for column 0 and and column77: -0.009937361505097208
# 78
# Correlation matrix for column 0 and and column78: -0.01026906254010187
# 79
# Correlation matrix for column 0 and and column79: 0.0022252451277640526
# 80
# Correlation matrix for column 0 and and column80: 0.013458405142649631
# 81
# Correlation matrix for column 0 and and column81: -0.0012226475812100249
# 82
# Correlation matrix for column 0 and and column82: -0.011368016782441663
# 83
# Correlation matrix for column 0 and and column83: 0.017211899798025027
# 84
# Correlation matrix for column 0 and and column84: -0.018738100595254138
# 85
# Correlation matrix for column 0 and and column85: 0.0028202225134275507
# 86
# Correlation matrix for column 0 and and column86: 0.013795639771816047
# 87
# Correlation matrix for column 0 and and column87: 0.012145276227952655
# 88
# Correlation matrix for column 0 and and column88: 0.012283819068028322
# 89
# Correlation matrix for column 0 and and column89: -0.013255760476985626
# 90
# Correlation matrix for column 0 and and column90: -0.0011551282348954742
# 91
# Correlation matrix for column 0 and and column91: 0.006269786260110057
# 92
# Correlation matrix for column 0 and and column92: -0.000860210087963827
# 93
# Correlation matrix for column 0 and and column93: 0.01642076152696815
# 94
# Correlation matrix for column 0 and and column94: 0.011641500342653002
# 95
# Correlation matrix for column 0 and and column95: 0.00300495217382778
# 96
# Correlation matrix for column 0 and and column96: -0.014134683233710296
# 97
# Correlation matrix for column 0 and and column97: 0.013045798695180714
# 98
# Correlation matrix for column 0 and and column98: -0.013568329218873586
# 99
# Correlation matrix for column 0 and and column99: -0.00214951143390262
# 100
# Correlation matrix for column 0 and and column100: 0.005561754251576339
# 101
# Correlation matrix for column 0 and and column101: 0.006350739341167176
# 102
# Correlation matrix for column 0 and and column102: 0.009476212647435603
# 103
# Correlation matrix for column 0 and and column103: 0.010619037412312841
# 104
# Correlation matrix for column 0 and and column104: 0.0022482143595757395
# 105
# Correlation matrix for column 0 and and column105: -0.006517976799121424
# 106
# Correlation matrix for column 0 and and column106: -0.0066397159207469665
# 107
# Correlation matrix for column 0 and and column107: 0.0007780218675337503
# 108
# Correlation matrix for column 0 and and column108: 0.016132937369296163
# 109
# Correlation matrix for column 0 and and column109: 0.008139144744554726
# 110
# Correlation matrix for column 0 and and column110: 0.006059781410095445
# 111
# Correlation matrix for column 0 and and column111: -0.010322477974508037
# 112
# Correlation matrix for column 0 and and column112: 0.01810123401422513
# 113
# Correlation matrix for column 0 and and column113: -0.002899920761475116
# 114
# Correlation matrix for column 0 and and column114: 0.02744649226635664
# 115
# Correlation matrix for column 0 and and column115: -0.014194268184583246
# 116
# Correlation matrix for column 0 and and column116: 0.013877405976858949
# 117
# Correlation matrix for column 0 and and column117: -0.0015118684572792203
# 118
# Correlation matrix for column 0 and and column118: 0.0038194780910800414
# 119
# Correlation matrix for column 0 and and column119: 0.0034485189325150754
# 120
# Correlation matrix for column 0 and and column120: 0.0031230070927727956
# 121
# Correlation matrix for column 0 and and column121: 0.0013666207998165026
# 122
# Correlation matrix for column 0 and and column122: -0.008892171281461535
# 123
# Correlation matrix for column 0 and and column123: -0.009071484145866412
# 124
# Correlation matrix for column 0 and and column124: 0.018293304327012778
# 125
# Correlation matrix for column 0 and and column125: -0.009606330371755066
# 126
# Correlation matrix for column 0 and and column126: 0.00018183367251812165
# 127
# Correlation matrix for column 0 and and column127: 0.01892070646896763
# 128
# Correlation matrix for column 0 and and column128: 0.009157996052917273
# 129
# Correlation matrix for column 0 and and column129: -0.002437736101714066
# 130
# Correlation matrix for column 0 and and column130: -0.0016649581071824793
# 131
# Correlation matrix for column 0 and and column131: -0.005928769251568842
# 132
# Correlation matrix for column 0 and and column132: 0.015999136391307973
# 133
# Correlation matrix for column 0 and and column133: 0.016357285575587573
# 134
# Correlation matrix for column 0 and and column134: 0.008478385980896525
# 135
# Correlation matrix for column 0 and and column135: -0.007764507688140632
# 136
# Correlation matrix for column 0 and and column136: 0.01455829548288387
# 137
# Correlation matrix for column 0 and and column137: -0.0019052243231981326
# 138
# Correlation matrix for column 0 and and column138: 0.0024729246963317076
# 139
# Correlation matrix for column 0 and and column139: 0.00046930240958502405
# 140
# Correlation matrix for column 0 and and column140: 0.0036379744224996585
# 141
# Correlation matrix for column 0 and and column141: -0.0004643635893199137
# 142
# Correlation matrix for column 0 and and column142: 0.011190272637609194
# 143
# Correlation matrix for column 0 and and column143: -0.004098459700561242
# 144
# Correlation matrix for column 0 and and column144: -0.00010050486582809081
# 145
# Correlation matrix for column 0 and and column145: 0.0024229271031569245
# 146
# Correlation matrix for column 0 and and column146: -0.010627922044208732
# 147
# Correlation matrix for column 0 and and column147: -0.0024580897123239213
# 148
# Correlation matrix for column 0 and and column148: -0.008947436669355479
# 149
# Correlation matrix for column 0 and and column149: -0.00462125694101395
# 150
# Correlation matrix for column 0 and and column150: -0.0012464324828114213
# 151
# Correlation matrix for column 0 and and column151: 0.005640183460447813
# 152
# Correlation matrix for column 0 and and column152: 0.0006924050907839763
# 153
# Correlation matrix for column 0 and and column153: -0.009588091025325152
# 154
# Correlation matrix for column 0 and and column154: 0.004894233191198454
# 155
# Correlation matrix for column 0 and and column155: 0.03161015234477087
# 156
# Correlation matrix for column 0 and and column156: 0.009069459271216251
# 157
# Correlation matrix for column 0 and and column157: 0.012695151155552057
# 158
# Correlation matrix for column 0 and and column158: -0.0032126827915581802
# 159
# Correlation matrix for column 0 and and column159: -0.009193547848172844
# 160
# Correlation matrix for column 0 and and column160: 0.003270869209073375
# 161
# Correlation matrix for column 0 and and column161: -0.002907833768833514
# 162
# Correlation matrix for column 0 and and column162: -0.01164813123388959
# 163
# Correlation matrix for column 0 and and column163: -0.012617030143260495
# 164
# Correlation matrix for column 0 and and column164: -0.0007952230003296384
# 165
# Correlation matrix for column 0 and and column165: -0.00555937833553873
# 166
# Correlation matrix for column 0 and and column166: -0.004774808897018006
# 167
# Correlation matrix for column 0 and and column167: -0.013608955276299588
# 168
# Correlation matrix for column 0 and and column168: -0.013360813019289914
# 169
# Correlation matrix for column 0 and and column169: -0.007475716671176682
# 170
# Correlation matrix for column 0 and and column170: 0.013771834304070966
# 171
# Correlation matrix for column 0 and and column171: 0.004856283449207217
# 172
# Correlation matrix for column 0 and and column172: 0.006597670161688108
# 173
# Correlation matrix for column 0 and and column173: 0.006350326819823541
# 174
# Correlation matrix for column 0 and and column174: 0.004308825830816463
# 175
# Correlation matrix for column 0 and and column175: -0.0018950285579613522
# 176
# Correlation matrix for column 0 and and column176: 0.00033688430948408037
# 177
# Correlation matrix for column 0 and and column177: 0.014909274915228157
# 178
# Correlation matrix for column 0 and and column178: -0.01863079524608786
# 179
# Correlation matrix for column 0 and and column179: -0.009278164979437849
# 180
# Correlation matrix for column 0 and and column180: 0.009935637716730141
# 181
# Correlation matrix for column 0 and and column181: 0.009352826980867056
# 182
# Correlation matrix for column 0 and and column182: -0.0019153324436906474
# 183
# Correlation matrix for column 0 and and column183: -0.004205684461113248
# 184
# Correlation matrix for column 0 and and column184: -0.006700170088947669
# 185
# Correlation matrix for column 0 and and column185: 0.002608822734337175
# 186
# Correlation matrix for column 0 and and column186: -0.003036318673421858
# 187
# Correlation matrix for column 0 and and column187: -0.005532578174616938
# 188
# Correlation matrix for column 0 and and column188: 0.0024042138318345545
# 189
# Correlation matrix for column 0 and and column189: -0.003876459952429673
# 190
# Correlation matrix for column 0 and and column190: 0.026038855324195632
# 191
# Correlation matrix for column 0 and and column191: 0.0002086400665649823
# 192
# Correlation matrix for column 0 and and column192: 0.007457802913385302
# 193
# Correlation matrix for column 0 and and column193: -0.00036233117975401443
# 194
# Correlation matrix for column 0 and and column194: -0.010636010927893095
# 195
# Correlation matrix for column 0 and and column195: 0.010043746904053599
# 196
# Correlation matrix for column 0 and and column196: 0.006215705752829812
# 197
# Correlation matrix for column 0 and and column197: -0.011240248824000675
# 198
# Correlation matrix for column 0 and and column198: 0.026775645932305428
# 199
# Correlation matrix for column 0 and and column199: -0.0006502185270272659
# 200
# Correlation matrix for column 0 and and column200: -0.012092215574025922
# 201
# Correlation matrix for column 0 and and column201: 0.01190911257322359
# 202
# Correlation matrix for column 0 and and column202: 0.015031492471775949
# 203
# Correlation matrix for column 0 and and column203: -0.000653600274147628
# 204
# Correlation matrix for column 0 and and column204: 0.013511643498920317
# 205
# Correlation matrix for column 0 and and column205: 0.009449259847773915
# 206
# Correlation matrix for column 0 and and column206: -0.0038038320986207054
# 207
# Correlation matrix for column 0 and and column207: 0.004635041970921545
# 208
# Correlation matrix for column 0 and and column208: -0.006249660712685623
# 209
# Correlation matrix for column 0 and and column209: 0.005414989965064567
# 210
# Correlation matrix for column 0 and and column210: 0.00901326520347473
# 211
# Correlation matrix for column 0 and and column211: -0.00844255181226036
# 212
# Correlation matrix for column 0 and and column212: -0.00536421599433714
# 213
# Correlation matrix for column 0 and and column213: 0.0008915083957596585
# 214
# Correlation matrix for column 0 and and column214: 0.003871553364007856
# 215
# Correlation matrix for column 0 and and column215: 0.005934852052417018
# 216
# Correlation matrix for column 0 and and column216: 0.01846689597307471
# 217
# Correlation matrix for column 0 and and column217: -0.007329917625068088
# 218
# Correlation matrix for column 0 and and column218: -0.004775662598108133
# 219
# Correlation matrix for column 0 and and column219: 0.009334444033287577
# 220
# Correlation matrix for column 0 and and column220: -0.004088625267564806
# 221
# Correlation matrix for column 0 and and column221: -0.006751603811633528
# 222
# Correlation matrix for column 0 and and column222: 0.0046512328030457375
# 223
# Correlation matrix for column 0 and and column223: -0.01082746096938739
# 224
# Correlation matrix for column 0 and and column224: -0.01324322451518985
# 225
# Correlation matrix for column 0 and and column225: 0.008444935254002096
# 226
# Correlation matrix for column 0 and and column226: 0.006139943377753629
# 227
# Correlation matrix for column 0 and and column227: 0.016865284475834498
# 228
# Correlation matrix for column 0 and and column228: 0.015257704876473252
# 229
# Correlation matrix for column 0 and and column229: 0.0073377149124877455
# 230
# Correlation matrix for column 0 and and column230: 0.0009475360480738072
# 231
# Correlation matrix for column 0 and and column231: -0.002825645354967837
# 232
# Correlation matrix for column 0 and and column232: -0.0065318703530452575
# 233
# Correlation matrix for column 0 and and column233: -0.01990468415616775
# 234
# Correlation matrix for column 0 and and column234: -0.0004190086951346881
# 235
# Correlation matrix for column 0 and and column235: -0.006729819920092359
# 236
# Correlation matrix for column 0 and and column236: 0.002805741241251063
# 237
# Correlation matrix for column 0 and and column237: -0.009368674293053122
# 238
# Correlation matrix for column 0 and and column238: -0.011483837738016981
# 239
# Correlation matrix for column 0 and and column239: 0.01810434982865397
# 240
# Correlation matrix for column 0 and and column240: -0.016329885298886147
# 241
# Correlation matrix for column 0 and and column241: 0.024323592947253975
# 242
# Correlation matrix for column 0 and and column242: -0.0034807412888059087
# 243
# Correlation matrix for column 0 and and column243: -0.008645120896792011
# 244
# Correlation matrix for column 0 and and column244: 0.002106176217151609
# 245
# Correlation matrix for column 0 and and column245: 0.009399612824304765
# 246
# Correlation matrix for column 0 and and column246: 0.008155430401817898
# 247
# Correlation matrix for column 0 and and column247: 0.0069487860609315204
# 248
# Correlation matrix for column 0 and and column248: 0.011890532344285751
# 249
# Correlation matrix for column 0 and and column249: -0.0038972372743145333
# 250
# Correlation matrix for column 0 and and column250: -0.014036650674432691
# 251
# Correlation matrix for column 0 and and column251: -0.010100632967407944
# 252
# Correlation matrix for column 0 and and column252: -0.0034656710433885103
# 253
# Correlation matrix for column 0 and and column253: 0.02302834915451692
# 254
# Correlation matrix for column 0 and and column254: 0.015535846081328889
# 255
# Correlation matrix for column 0 and and column255: 0.0005059033193104578
# 256
# Correlation matrix for column 0 and and column256: -0.0007500459744690282
# 257
# Correlation matrix for column 0 and and column257: 0.008301807780172565
# 258
# Correlation matrix for column 0 and and column258: -0.0017171940613446208
# 259
# Correlation matrix for column 0 and and column259: -0.010238703627669111
# 260
# Correlation matrix for column 0 and and column260: -0.016719147940354676
# 261
# Correlation matrix for column 0 and and column261: 0.0023053760423258443
# 262
# Correlation matrix for column 0 and and column262: -0.019286072309168647
# 263
# Correlation matrix for column 0 and and column263: -0.006924962219264485
# 264
# Correlation matrix for column 0 and and column264: 0.0014036681981256993
# 265
# Correlation matrix for column 0 and and column265: 0.009342423507980282
# 266
# Correlation matrix for column 0 and and column266: 0.00716280011847398
# 267
# Correlation matrix for column 0 and and column267: -0.0171595300308987
# 268
# Correlation matrix for column 0 and and column268: -0.0044026285162946065
# 269
# Correlation matrix for column 0 and and column269: 0.007546082909825114
# 270
# Correlation matrix for column 0 and and column270: 0.00987802603411434
# 271
# Correlation matrix for column 0 and and column271: 0.0020823450601806437
# 272
# Correlation matrix for column 0 and and column272: -0.02300162217865838
# 273
# Correlation matrix for column 0 and and column273: 0.005890878050904897
# 274
# Correlation matrix for column 0 and and column274: -0.0036221157125578803
# 275
# Correlation matrix for column 0 and and column275: 0.005649996832101804
# 276
# Correlation matrix for column 0 and and column276: 0.015586089962496835
# 277
# Correlation matrix for column 0 and and column277: -0.005404713228937501
# 278
# Correlation matrix for column 0 and and column278: 0.0027118400975910846
# 279
# Correlation matrix for column 0 and and column279: 0.003624704528504031
# 280
# Correlation matrix for column 0 and and column280: -0.009223870050628446
# 281
# Correlation matrix for column 0 and and column281: -0.0022586727758160995
# 282
# Correlation matrix for column 0 and and column282: 0.014219869199311733
# 283
# Correlation matrix for column 0 and and column283: -0.006033329816600938
# 284
# Correlation matrix for column 0 and and column284: 0.006619005238285755
# 285
# Correlation matrix for column 0 and and column285: -0.000833845256352746
# 286
# Correlation matrix for column 0 and and column286: -0.0044804204872795576
# 287
# Correlation matrix for column 0 and and column287: -0.005993923886542186
# 288
# Correlation matrix for column 0 and and column288: -0.007814130546641948
# 289
# Correlation matrix for column 0 and and column289: 0.01054972057884459
# 290
# Correlation matrix for column 0 and and column290: 0.0074119209997498235
# 291
# Correlation matrix for column 0 and and column291: -0.0007364741229358684
# 292
# Correlation matrix for column 0 and and column292: -0.0005211030966887494
# 293
# Correlation matrix for column 0 and and column293: 0.01623551064740171
# 294
# Correlation matrix for column 0 and and column294: 0.0080310326348248
# 295
# Correlation matrix for column 0 and and column295: -0.008634381711069528
# 296
# Correlation matrix for column 0 and and column296: -0.0031799309475569575
# 297
# Correlation matrix for column 0 and and column297: -0.01238667348199872
# 298
# Correlation matrix for column 0 and and column298: -0.011302986302974855
# 299
# Correlation matrix for column 0 and and column299: -0.0033448520469276464
# 300
# Correlation matrix for column 0 and and column300: 0.011225939868123678
# 301
# Correlation matrix for column 0 and and column301: -0.0037053961272285165
# 302
# Correlation matrix for column 0 and and column302: 0.013401697048033987
# 303
# Correlation matrix for column 0 and and column303: 0.0031368200387673585
# 304
# Correlation matrix for column 0 and and column304: -0.0007862426047651678
# 305
# Correlation matrix for column 0 and and column305: 0.0020558315378510416
# 306
# Correlation matrix for column 0 and and column306: -0.008020952506811329
# 307
# Correlation matrix for column 0 and and column307: -0.005783816795110515
# 308
# Correlation matrix for column 0 and and column308: -0.006494361120444081
# 309
# Correlation matrix for column 0 and and column309: 0.006106319100654464
# 310
# Correlation matrix for column 0 and and column310: 0.002190766310666659
# 311
# Correlation matrix for column 0 and and column311: -0.009825240416135032
# 312
# Correlation matrix for column 0 and and column312: -0.0064247681547828775
# 313
# Correlation matrix for column 0 and and column313: 0.018646992822782947
# 314
# Correlation matrix for column 0 and and column314: 0.004377404811448819
# 315
# Correlation matrix for column 0 and and column315: 0.0063182871201933445
# 316
# Correlation matrix for column 0 and and column316: -0.004062512322363246
# 317
# Correlation matrix for column 0 and and column317: -0.0030991097479051775
# 318
# Correlation matrix for column 0 and and column318: 0.0035553075236226203
# 319
# Correlation matrix for column 0 and and column319: 0.003092130106831868
# 320
# Correlation matrix for column 0 and and column320: 0.00878545069989922
# 321
# Correlation matrix for column 0 and and column321: -0.0032166762955986696
# 322
# Correlation matrix for column 0 and and column322: -0.0006961791730657072
# 323
# Correlation matrix for column 0 and and column323: -0.0002835576462358762
# 324
# Correlation matrix for column 0 and and column324: 0.007851411672327327
# 325
# Correlation matrix for column 0 and and column325: -0.0009737746815345027
# 326
# Correlation matrix for column 0 and and column326: 0.009948609050646205
# 327
# Correlation matrix for column 0 and and column327: 0.0027423389432262475
# 328
# Correlation matrix for column 0 and and column328: 0.005357598150248547
# 329
# Correlation matrix for column 0 and and column329: 0.003316356620216431
# 330
# Correlation matrix for column 0 and and column330: -0.0020493523528471794
# 331
# Correlation matrix for column 0 and and column331: 0.005131453987658897
# 332
# Correlation matrix for column 0 and and column332: 0.00519549731073107
# 333
# Correlation matrix for column 0 and and column333: 0.0035928306066548674
# 334
# Correlation matrix for column 0 and and column334: -0.032230590489937046
# 335
# Correlation matrix for column 0 and and column335: -0.001378966539498959
# 336
# Correlation matrix for column 0 and and column336: 0.01988763825299479
# 337
# Correlation matrix for column 0 and and column337: -0.004364296156696131
# 338
# Correlation matrix for column 0 and and column338: 0.013359073334429305
# 339
# Correlation matrix for column 0 and and column339: 0.00823289307985897
# 340
# Correlation matrix for column 0 and and column340: -0.006063248044325857
# 341
# Correlation matrix for column 0 and and column341: 0.0016886025935705525
# 342
# Correlation matrix for column 0 and and column342: -0.008678554811015494
# 343
# Correlation matrix for column 0 and and column343: -0.007390073316145973
# 344
# Correlation matrix for column 0 and and column344: -0.003765246666995297
# 345
# Correlation matrix for column 0 and and column345: -0.0006023446919227457
# 346
# Correlation matrix for column 0 and and column346: 0.00869815235471158
# 347
# Correlation matrix for column 0 and and column347: -0.0027024205186635154
# 348
# Correlation matrix for column 0 and and column348: 0.008472141256132902
# 349
# Correlation matrix for column 0 and and column349: -0.002818381381645716
# 350
# Correlation matrix for column 0 and and column350: -0.0012375166438177718
# 351
# Correlation matrix for column 0 and and column351: -0.006409354056956153
# 352
# Correlation matrix for column 0 and and column352: 0.002513095766058393
# 353
# Correlation matrix for column 0 and and column353: 0.0002792549362805204
# 354
# Correlation matrix for column 0 and and column354: -0.005359849268796056
# 355
# Correlation matrix for column 0 and and column355: 0.006716800898866139
# 356
# Correlation matrix for column 0 and and column356: 0.01899243277752216
# 357
# Correlation matrix for column 0 and and column357: 0.017173478830292535
# 358
# Correlation matrix for column 0 and and column358: -0.0056882850069546
# 359
# Correlation matrix for column 0 and and column359: -0.01898961399612876
# 360
# Correlation matrix for column 0 and and column360: -0.003206513279979657
# 361
# Correlation matrix for column 0 and and column361: 0.00432830488225882
# 362
# Correlation matrix for column 0 and and column362: -0.0029841276703361005
# 363
# Correlation matrix for column 0 and and column363: -0.00847008283957247
# 364
# Correlation matrix for column 0 and and column364: 0.002678229913667859
# 365
# Correlation matrix for column 0 and and column365: -0.017235695784161318
# 366
# Correlation matrix for column 0 and and column366: 0.004500582252178613
# 367
# Correlation matrix for column 0 and and column367: -0.0076332635870997
# 368
# Correlation matrix for column 0 and and column368: 0.0022806742109578266
# 369
# Correlation matrix for column 0 and and column369: 0.01379319979837805
# 370
# Correlation matrix for column 0 and and column370: -0.012082867973679185
# 371
# Correlation matrix for column 0 and and column371: -0.009204707959131343
# 372
# Correlation matrix for column 0 and and column372: 0.009364548560943467
# 373
# Correlation matrix for column 0 and and column373: 0.02001477639338076
# 374
# Correlation matrix for column 0 and and column374: -0.008776170207825673
# 375
# Correlation matrix for column 0 and and column375: 0.013465323085165317
# 376
# Correlation matrix for column 0 and and column376: 0.01586544889136377
# 377
# Correlation matrix for column 0 and and column377: 0.001253626513440372
# 378
# Correlation matrix for column 0 and and column378: -0.0142285729707613
# 379
# Correlation matrix for column 0 and and column379: 0.0033588107619535916
# 380
# Correlation matrix for column 0 and and column380: 0.0018998832955848376
# 381
# Correlation matrix for column 0 and and column381: -0.011840100200595442
# 382
# Correlation matrix for column 0 and and column382: 0.0061256632461462596
# 383
# Correlation matrix for column 0 and and column383: 0.012614111894048848
# 384
# Correlation matrix for column 0 and and column384: 0.014135094454976604
# 385
# Correlation matrix for column 0 and and column385: -0.0032103123587348893
# 386
# Correlation matrix for column 0 and and column386: 0.001584340671007842
# 387
# Correlation matrix for column 0 and and column387: -0.005232379258059544
# 388
# Correlation matrix for column 0 and and column388: -0.005697129902263221
# 389
# Correlation matrix for column 0 and and column389: -0.011893858894582622
# 390
# Correlation matrix for column 0 and and column390: -0.0023547707199203047
# 391
# Correlation matrix for column 0 and and column391: -0.0021692619113001686
# 392
# Correlation matrix for column 0 and and column392: 0.016563502944970197
# 393
# Correlation matrix for column 0 and and column393: 0.004689748226176358
# 394
# Correlation matrix for column 0 and and column394: 0.004495187879117588
# 395
# Correlation matrix for column 0 and and column395: 0.015205982895254083
# 396
# Correlation matrix for column 0 and and column396: 0.006992354548763176
# 397
# Correlation matrix for column 0 and and column397: 0.007680429203014334
# 398
# Correlation matrix for column 0 and and column398: -0.003038876803537095
# 399
# Correlation matrix for column 0 and and column399: 0.0038155862519999627
# 400
# Correlation matrix for column 0 and and column400: -0.0032661233329604
# 401
# Correlation matrix for column 0 and and column401: 0.002780124927048905
# 402
# Correlation matrix for column 0 and and column402: 0.006267797600513565
# 403
# Correlation matrix for column 0 and and column403: -0.002594076393011888
# 404
# Correlation matrix for column 0 and and column404: 0.009208160352926247
# 405
# Correlation matrix for column 0 and and column405: 0.001410008586536249
# 406
# Correlation matrix for column 0 and and column406: 0.014025226545694203
# 407
# Correlation matrix for column 0 and and column407: -0.001156884791230497
# 408
# Correlation matrix for column 0 and and column408: 0.0038202457455120556
# 409
# Correlation matrix for column 0 and and column409: -0.008775472328408194
# 410
# Correlation matrix for column 0 and and column410: 0.008299879030590169
# 411
# Correlation matrix for column 0 and and column411: 0.0064129936746008115
# 412
# Correlation matrix for column 0 and and column412: -0.017806623119401656
# 413
# Correlation matrix for column 0 and and column413: -0.0021268181927532747
# 414
# Correlation matrix for column 0 and and column414: -0.0003302437102978285
# 415
# Correlation matrix for column 0 and and column415: -0.0021531582215703953
# 416
# Correlation matrix for column 0 and and column416: -0.0004814966719096243
# 417
# Correlation matrix for column 0 and and column417: 0.008395340477085695
# 418
# Correlation matrix for column 0 and and column418: -0.016617057398133687
# 419
# Correlation matrix for column 0 and and column419: 0.012610486901116467
# 420
# Correlation matrix for column 0 and and column420: 0.00016889989202932424
# 421
# Correlation matrix for column 0 and and column421: 0.00807636705920546
# 422
# Correlation matrix for column 0 and and column422: 0.0009658934505046739
# 423
# Correlation matrix for column 0 and and column423: 0.010213126492156206
# 424
# Correlation matrix for column 0 and and column424: 0.0009419586606823707
# 425
# Correlation matrix for column 0 and and column425: 0.0047820909993269165
# 426
# Correlation matrix for column 0 and and column426: -0.002302425821662896
# 427
# Correlation matrix for column 0 and and column427: -0.006410098275652275
# 428
# Correlation matrix for column 0 and and column428: -0.02384788151913122
# 429
# Correlation matrix for column 0 and and column429: 0.00910405372852584
# 430
# Correlation matrix for column 0 and and column430: -0.006746255614686828
# 431
# Correlation matrix for column 0 and and column431: 0.004828968355620451
# 432
# Correlation matrix for column 0 and and column432: -0.013386865892984871
# 433
# Correlation matrix for column 0 and and column433: -0.0005652999126431723
# 434
# Correlation matrix for column 0 and and column434: 0.0062477072969429805
# 435
# Correlation matrix for column 0 and and column435: -0.00397542636664606
# 436
# Correlation matrix for column 0 and and column436: -0.009842684890096437
# 437
# Correlation matrix for column 0 and and column437: 0.012819127262948232
# 438
# Correlation matrix for column 0 and and column438: 0.019571883713451855
# 439
# Correlation matrix for column 0 and and column439: 0.015271464658466022
# 440
# Correlation matrix for column 0 and and column440: 0.00032737155696013477
# 441
# Correlation matrix for column 0 and and column441: -0.00375712076744974
# 442
# Correlation matrix for column 0 and and column442: 0.003700877719367653
# 443
# Correlation matrix for column 0 and and column443: 0.0015335122077820278
# 444
# Correlation matrix for column 0 and and column444: -0.012239860418798274
# 445
# Correlation matrix for column 0 and and column445: 0.007777679176212603
# 446
# Correlation matrix for column 0 and and column446: -0.0036760308853366675
# 447
# Correlation matrix for column 0 and and column447: 0.006903924268444387
# 448
# Correlation matrix for column 0 and and column448: -0.0059367153077040154
# 449
# Correlation matrix for column 0 and and column449: -0.004713626480811458
# 450
# Correlation matrix for column 0 and and column450: 2.688070314664593e-05
# 451
# Correlation matrix for column 0 and and column451: 0.02266208628689598
# 452
# Correlation matrix for column 0 and and column452: -0.0031164912760406694
# 453
# Correlation matrix for column 0 and and column453: -0.0036768818391393
# 454
# Correlation matrix for column 0 and and column454: -0.019478199189138987
# 455
# Correlation matrix for column 0 and and column455: 0.004749296192600126
# 456
# Correlation matrix for column 0 and and column456: -0.020162301731945723
# 457
# Correlation matrix for column 0 and and column457: -0.005929778291688567
# 458
# Correlation matrix for column 0 and and column458: -0.009746082071352984
# 459
# Correlation matrix for column 0 and and column459: -0.022358807947507105
# 460
# Correlation matrix for column 0 and and column460: 0.0020479175293874638
# 461
# Correlation matrix for column 0 and and column461: 0.004227070549846803
# 462
# Correlation matrix for column 0 and and column462: 0.0054766778013195724
# 463
# Correlation matrix for column 0 and and column463: -0.0065363254901919755
# 464
# Correlation matrix for column 0 and and column464: 0.008787375714588356
# 465
# Correlation matrix for column 0 and and column465: -0.003274273542197303
# 466
# Correlation matrix for column 0 and and column466: 0.008647052814937623
# 467
# Correlation matrix for column 0 and and column467: 0.00025906893307968214
# 468
# Correlation matrix for column 0 and and column468: -0.00011076103130531363
# 469
# Correlation matrix for column 0 and and column469: 0.016584279186168283
# 470
# Correlation matrix for column 0 and and column470: -0.017105474642951066
# 471
# Correlation matrix for column 0 and and column471: 0.013763093952914654
# 472
# Correlation matrix for column 0 and and column472: 0.011469222949096126
# 473
# Correlation matrix for column 0 and and column473: -0.001228332613037159
# 474
# Correlation matrix for column 0 and and column474: 0.008836349565371155
# 475
# Correlation matrix for column 0 and and column475: 0.009218370387669057
# 476
# Correlation matrix for column 0 and and column476: 0.0016587504740681813
# 477
# Correlation matrix for column 0 and and column477: 0.010973872746980782
# 478
# Correlation matrix for column 0 and and column478: -0.01777524751184116
# 479
# Correlation matrix for column 0 and and column479: -0.005004579327868647
# 480
# Correlation matrix for column 0 and and column480: -0.0028283955935661576
# 481
# Correlation matrix for column 0 and and column481: -0.020974494275009782
# 482
# Correlation matrix for column 0 and and column482: -0.008105076827021397
# 483
# Correlation matrix for column 0 and and column483: 0.0024134359728720735
# 484
# Correlation matrix for column 0 and and column484: 0.008054807421184652
# 485
# Correlation matrix for column 0 and and column485: -0.015665968173261026
# 486
# Correlation matrix for column 0 and and column486: -0.007838249044137503
# 487
# Correlation matrix for column 0 and and column487: -0.008043294927291843
# 488
# Correlation matrix for column 0 and and column488: -0.004697931660462144
# 489
# Correlation matrix for column 0 and and column489: -0.005906333471673965
# 490
# Correlation matrix for column 0 and and column490: 0.010285960453260072
# 491
# Correlation matrix for column 0 and and column491: 0.0022172487846816203
# 492
# Correlation matrix for column 0 and and column492: -0.008630301076954994
# 493
# Correlation matrix for column 0 and and column493: 0.0006222645561301755
# 494
# Correlation matrix for column 0 and and column494: 0.010406011918837721
# 495
# Correlation matrix for column 0 and and column495: 0.005924663956195104
# 496
# Correlation matrix for column 0 and and column496: 0.007279658252725087
# 497
# Correlation matrix for column 0 and and column497: 0.007786173417939701
# 498
# Correlation matrix for column 0 and and column498: -0.0008426592853672227
# 499
# Correlation matrix for column 0 and and column499: -0.004519737756613255
# 500
# Correlation matrix for column 0 and and column500: -0.009476205363023795
# 501
# Correlation matrix for column 0 and and column501: 0.007036287730875366
# 502
# Correlation matrix for column 0 and and column502: 0.0058721193694363915
# 503
# Correlation matrix for column 0 and and column503: -0.017326606082547286
# 504
# Correlation matrix for column 0 and and column504: -0.003267772369838577
# 505
# Correlation matrix for column 0 and and column505: -0.01365652135927854
# 506
# Correlation matrix for column 0 and and column506: 0.010298841198366554
# 507
# Correlation matrix for column 0 and and column507: -0.021870117003819307
# 508
# Correlation matrix for column 0 and and column508: 0.007820610682371224
# 509
# Correlation matrix for column 0 and and column509: 0.00605589847808708
# 510
# Correlation matrix for column 0 and and column510: 0.0009375427723451344
# 511
# Correlation matrix for column 0 and and column511: 0.006726666668549589
# 512
# Correlation matrix for column 0 and and column512: -0.0029336848575410527
# 513
# Correlation matrix for column 0 and and column513: -0.0032635036943008135
# 514
# Correlation matrix for column 0 and and column514: 0.005891541950479686
# 515
# Correlation matrix for column 0 and and column515: 0.01329709076112969
# 516
# Correlation matrix for column 0 and and column516: -0.0060091308465660435
# 517
# Correlation matrix for column 0 and and column517: -0.00019254872545251462
# 518
# Correlation matrix for column 0 and and column518: -0.011737015674074609
# 519
# Correlation matrix for column 0 and and column519: 0.0010776194754542278
# 520
# Correlation matrix for column 0 and and column520: -0.0014712509697956554
# 521
# Correlation matrix for column 0 and and column521: -0.005656614115774538
# 522
# Correlation matrix for column 0 and and column522: 0.0009871182775634897
# 523
# Correlation matrix for column 0 and and column523: 0.004530900205737925
# 524
# Correlation matrix for column 0 and and column524: 0.00859462304865913
# 525
# Correlation matrix for column 0 and and column525: 0.005710509963050084
# 526
# Correlation matrix for column 0 and and column526: 0.0034017836275136285
# 527
# Correlation matrix for column 0 and and column527: -0.011489858744956002
# 528
# Correlation matrix for column 0 and and column528: 0.011816060478520492
# 529
# Correlation matrix for column 0 and and column529: 0.0007724053715225317
# 530
# Correlation matrix for column 0 and and column530: 0.00786486360847689
# 531
# Correlation matrix for column 0 and and column531: 0.01579718416841228
# 532
# Correlation matrix for column 0 and and column532: 0.004118522886385122
# 533
# Correlation matrix for column 0 and and column533: 0.004242860043475933
# 534
# Correlation matrix for column 0 and and column534: 0.00223764413629556
# 535
# Correlation matrix for column 0 and and column535: 9.28396812401253e-05
# 536
# Correlation matrix for column 0 and and column536: 0.0015661403272711634
# 537
# Correlation matrix for column 0 and and column537: 0.004356026593594038
# 538
# Correlation matrix for column 0 and and column538: -0.0001369659031608809
# 539
# Correlation matrix for column 0 and and column539: 0.029465123041222268
# 540
# Correlation matrix for column 0 and and column540: 0.006223422391073907
# 541
# Correlation matrix for column 0 and and column541: 0.0001403149514279946
# 542
# Correlation matrix for column 0 and and column542: 0.011605049977540425
# 543
# Correlation matrix for column 0 and and column543: -0.003290022230928922
# 544
# Correlation matrix for column 0 and and column544: 0.0018892369175707215
# 545
# Correlation matrix for column 0 and and column545: -0.01668591166500181
# 546
# Correlation matrix for column 0 and and column546: -0.0026833546703605594
# 547
# Correlation matrix for column 0 and and column547: -0.013522690990951873
# 548
# Correlation matrix for column 0 and and column548: -0.0032268740855513375
# 549
# Correlation matrix for column 0 and and column549: 0.004864283220278604
# 550
# Correlation matrix for column 0 and and column550: -0.01352783667449477
# 551
# Correlation matrix for column 0 and and column551: -0.0010084302712433984
# 552
# Correlation matrix for column 0 and and column552: 0.0032896490104532767
# 553
# Correlation matrix for column 0 and and column553: -0.009406123749419895
# 554
# Correlation matrix for column 0 and and column554: 0.010487511819754448
# 555
# Correlation matrix for column 0 and and column555: 0.00024270039356964987
# 556
# Correlation matrix for column 0 and and column556: 0.014807571167262347
# 557
# Correlation matrix for column 0 and and column557: 0.011920367821841731
# 558
# Correlation matrix for column 0 and and column558: -0.012942621324633979
# 559
# Correlation matrix for column 0 and and column559: -0.005888959583954125
# 560
# Correlation matrix for column 0 and and column560: 0.0013002386475083878
# 561
# Correlation matrix for column 0 and and column561: 0.0037803788363567114
# 562
# Correlation matrix for column 0 and and column562: -0.005196991058998562
# 563
# Correlation matrix for column 0 and and column563: 0.00742404692156965
# 564
# Correlation matrix for column 0 and and column564: 0.0036052406717877487
# 565
# Correlation matrix for column 0 and and column565: -0.0017085376364132613
# 566
# Correlation matrix for column 0 and and column566: 0.024927823543522132
# 567
# Correlation matrix for column 0 and and column567: -0.006028306816010008
# 568
# Correlation matrix for column 0 and and column568: 0.0018687496163130952
# 569
# Correlation matrix for column 0 and and column569: -0.011407232886190336
# 570
# Correlation matrix for column 0 and and column570: 0.008134664207208877
# 571
# Correlation matrix for column 0 and and column571: 0.012030114034988132
# 572
# Correlation matrix for column 0 and and column572: -0.0038982463131734947
# 573
# Correlation matrix for column 0 and and column573: -0.006495558981930055
# 574
# Correlation matrix for column 0 and and column574: 0.0023943162307057553
# 575
# Correlation matrix for column 0 and and column575: 0.0055568029518698785
# 576
# Correlation matrix for column 0 and and column576: 0.002413614301629894
# 577
# Correlation matrix for column 0 and and column577: -0.008497905977368799
# 578
# Correlation matrix for column 0 and and column578: -0.005343450805681726
# 579
# Correlation matrix for column 0 and and column579: 0.007452926058985865
# 580
# Correlation matrix for column 0 and and column580: 0.004960439736592105
# 581
# Correlation matrix for column 0 and and column581: 0.010297696792398536
# 582
# Correlation matrix for column 0 and and column582: 0.01569356877670521
# 583
# Correlation matrix for column 0 and and column583: -0.001614434921084806
# 584
# Correlation matrix for column 0 and and column584: -0.012179194135984039
# 585
# Correlation matrix for column 0 and and column585: 0.009982858911228971
# 586
# Correlation matrix for column 0 and and column586: 0.0025178796492441487
# 587
# Correlation matrix for column 0 and and column587: -0.0019222439470859632
# 588
# Correlation matrix for column 0 and and column588: 0.009227582682295543
# 589
# Correlation matrix for column 0 and and column589: 0.0031848307358561707
# 590
# Correlation matrix for column 0 and and column590: -0.012188238601185784
# 591
# Correlation matrix for column 0 and and column591: -0.005418283390824323
# 592
# Correlation matrix for column 0 and and column592: 0.006922273424531889
# 593
# Correlation matrix for column 0 and and column593: -0.004366503904792315
# 594
# Correlation matrix for column 0 and and column594: 0.0052315490876706046
# 595
# Correlation matrix for column 0 and and column595: -0.01593345004868827
# 596
# Correlation matrix for column 0 and and column596: -0.004886042437179595
# 597
# Correlation matrix for column 0 and and column597: -0.005744036792414666
# 598
# Correlation matrix for column 0 and and column598: -0.009325968968617942
# 599
# Correlation matrix for column 0 and and column599: -0.008940097752443206
# 600
# Correlation matrix for column 0 and and column600: 0.0031643904914303196
# 601
# Correlation matrix for column 0 and and column601: 0.0010359176192440884
# 602
# Correlation matrix for column 0 and and column602: 0.0010005189097683782
# 603
# Correlation matrix for column 0 and and column603: -0.0009418874170338827
# 604
# Correlation matrix for column 0 and and column604: 0.002977439287382247
# 605
# Correlation matrix for column 0 and and column605: 0.0008424278214497038
# 606
# Correlation matrix for column 0 and and column606: -0.020856688976386723
# 607
# Correlation matrix for column 0 and and column607: 0.005392443869908147
# 608
# Correlation matrix for column 0 and and column608: -0.0031110048628498936
# 609
# Correlation matrix for column 0 and and column609: -0.02636109761957955
# 610
# Correlation matrix for column 0 and and column610: 0.0025831410174810246
# 611
# Correlation matrix for column 0 and and column611: -0.008792912391634275
# 612
# Correlation matrix for column 0 and and column612: 0.020838870242827028
# 613
# Correlation matrix for column 0 and and column613: 0.003092421984530319
# 614
# Correlation matrix for column 0 and and column614: 0.004070849647098811
# 615
# Correlation matrix for column 0 and and column615: 0.003528703396454605
# 616
# Correlation matrix for column 0 and and column616: -0.017649273893394525
# 617
# Correlation matrix for column 0 and and column617: 0.00324151790738866
# 618
# Correlation matrix for column 0 and and column618: -0.0004908934418487415
# 619
# Correlation matrix for column 0 and and column619: 0.004749029070799327
# 620
# Correlation matrix for column 0 and and column620: 0.007158713361685231
# 621
# Correlation matrix for column 0 and and column621: -0.00678241962317421
# 622
# Correlation matrix for column 0 and and column622: 0.008981572183124748
# 623
# Correlation matrix for column 0 and and column623: -0.000375539838501711
# 624
# Correlation matrix for column 0 and and column624: 0.012768893228503398
# 625
# Correlation matrix for column 0 and and column625: 0.004481198195467794
# 626
# ...
# 7691
# Correlation matrix for column 0 and and column7691: 0.005333981519155595
# 7692
# Correlation matrix for column 0 and and column7692: -0.002372345775679632
# 7693
# Correlation matrix for column 0 and and column7693: 0.004596138626812482
# 7694
# Correlation matrix for column 0 and and column7694: -0.009737470905187109
# 7695
# Correlation matrix for column 0 and and column7695: 0.00043823348093381177
# 7696
# Correlation matrix for column 0 and and column7696: -0.0011432734479050945
# 7697
# Correlation matrix for column 0 and and column7697: 0.0069471702258196485
# 7698
# Correlation matrix for column 0 and and column7698: -0.012226554475850552
# 7699
# Correlation matrix for column 0 and and column7699: 0.009503029133533526
# 7700
# Correlation matrix for column 0 and and column7700: -0.0002499309237507809
# 7701
# Correlation matrix for column 0 and and column7701: -0.010489289082072405
# 7702
# Correlation matrix for column 0 and and column7702: -0.0034636366310784395
# 7703
# Correlation matrix for column 0 and and column7703: 0.014364204831535067
# 7704
# Correlation matrix for column 0 and and column7704: 0.0018241952218070877
# 7705
# Correlation matrix for column 0 and and column7705: 0.008914537733679388
# 7706
# Correlation matrix for column 0 and and column7706: 0.005952244958698115
# 7707
# Correlation matrix for column 0 and and column7707: 0.010602984954716555
# 7708
# Correlation matrix for column 0 and and column7708: -0.02076641164319712
# 7709
# Correlation matrix for column 0 and and column7709: -0.007902856778416106
# 7710
# Correlation matrix for column 0 and and column7710: 0.006084772080351983
# 7711
# Correlation matrix for column 0 and and column7711: -0.006324272789660871
# 7712
# Correlation matrix for column 0 and and column7712: -0.0034542547383278064
# 7713
# Correlation matrix for column 0 and and column7713: -0.011510607945630361
# 7714
# Correlation matrix for column 0 and and column7714: 0.011795035931259978
# 7715
# Correlation matrix for column 0 and and column7715: 0.011339925132732742
# 7716
# Correlation matrix for column 0 and and column7716: -0.009442811506905333
# 7717
# Correlation matrix for column 0 and and column7717: -0.00029613677574388543
# 7718
# Correlation matrix for column 0 and and column7718: -0.02133266925794521
# 7719
# Correlation matrix for column 0 and and column7719: -0.0006190360005501281
# 7720
# Correlation matrix for column 0 and and column7720: -0.0023299070842784735
# 7721
# Correlation matrix for column 0 and and column7721: -0.000815032103477896
# 7722
# Correlation matrix for column 0 and and column7722: 0.0008420215564004375
# 7723
# Correlation matrix for column 0 and and column7723: 0.012132196913811727
# 7724
# Correlation matrix for column 0 and and column7724: 0.002998624833284131
# 7725
# Correlation matrix for column 0 and and column7725: 0.018223639396494615
# 7726
# Correlation matrix for column 0 and and column7726: 0.02088651223579997
# 7727
# Correlation matrix for column 0 and and column7727: -0.010891212463431376
# 7728
# Correlation matrix for column 0 and and column7728: 0.01386657910069079
# 7729
# Correlation matrix for column 0 and and column7729: -0.016200380535107767
# 7730
# Correlation matrix for column 0 and and column7730: -0.009898350703468428
# 7731
# Correlation matrix for column 0 and and column7731: -0.006985923683519265
# 7732
# Correlation matrix for column 0 and and column7732: 0.007579990166952894
# 7733
# Correlation matrix for column 0 and and column7733: 0.01931187506714142
# 7734
# Correlation matrix for column 0 and and column7734: 0.012010692170206168
# 7735
# Correlation matrix for column 0 and and column7735: -0.020355880449890507
# 7736
# Correlation matrix for column 0 and and column7736: -0.01944954818796402
# 7737
# Correlation matrix for column 0 and and column7737: -0.013142070865215136
# 7738
# Correlation matrix for column 0 and and column7738: 0.005537512036812598
# 7739
# Correlation matrix for column 0 and and column7739: -0.0038557684792793327
# 7740
# Correlation matrix for column 0 and and column7740: 0.03625504711682384
# 7741
# Correlation matrix for column 0 and and column7741: 0.0073963711709601945
# 7742
# Correlation matrix for column 0 and and column7742: 0.003670784279476227
# 7743
# Correlation matrix for column 0 and and column7743: -0.021699348194748527
# 7744
# Correlation matrix for column 0 and and column7744: 0.011650974422199822
# 7745
# Correlation matrix for column 0 and and column7745: 0.018278979941601537
# 7746
# Correlation matrix for column 0 and and column7746: 0.0053996026924993615
# 7747
# Correlation matrix for column 0 and and column7747: -0.010932608976592277
# 7748
# Correlation matrix for column 0 and and column7748: -0.013810071016713533
# 7749
# Correlation matrix for column 0 and and column7749: -0.010133278737618944
# 7750
# Correlation matrix for column 0 and and column7750: 0.008334013096488796
# 7751
# Correlation matrix for column 0 and and column7751: 0.0055041095374258695
# 7752
# Correlation matrix for column 0 and and column7752: -0.014127322529865293
# 7753
# Correlation matrix for column 0 and and column7753: -0.00042497439272569436
# 7754
# Correlation matrix for column 0 and and column7754: -0.01441196207426227
# 7755
# Correlation matrix for column 0 and and column7755: 0.0040090242097556685
# 7756
# Correlation matrix for column 0 and and column7756: -0.012494195800017665
# 7757
# Correlation matrix for column 0 and and column7757: -0.011650948129213886
# 7758
# Correlation matrix for column 0 and and column7758: 0.008664734916118667
# 7759
# Correlation matrix for column 0 and and column7759: -0.00847514792078878
# 7760
# Correlation matrix for column 0 and and column7760: 0.005971827769258135
# 7761
# Correlation matrix for column 0 and and column7761: 0.01730778319721172
# 7762
# Correlation matrix for column 0 and and column7762: -0.0031450298479448486
# 7763
# Correlation matrix for column 0 and and column7763: 0.007293841027040038
# 7764
# Correlation matrix for column 0 and and column7764: 0.0006470011765835486
# 7765
# Correlation matrix for column 0 and and column7765: -0.005694078169645557
# 7766
# Correlation matrix for column 0 and and column7766: -0.007370597115288736
# 7767
# Correlation matrix for column 0 and and column7767: -0.0011286557770721012
# 7768
# Correlation matrix for column 0 and and column7768: 0.006492227370127492
# 7769
# Correlation matrix for column 0 and and column7769: -0.015144665161707808
# 7770
# Correlation matrix for column 0 and and column7770: -0.008894547102937576
# 7771
# Correlation matrix for column 0 and and column7771: -0.012449985681227725
# 7772
# Correlation matrix for column 0 and and column7772: 0.008034643054480513
# 7773
# Correlation matrix for column 0 and and column7773: -0.00010074939174344617
# 7774
# Correlation matrix for column 0 and and column7774: 0.009102597250899578
# 7775
# Correlation matrix for column 0 and and column7775: 0.015422125445673994
# 7776
# Correlation matrix for column 0 and and column7776: 0.01428018073076646
# 7777
# Correlation matrix for column 0 and and column7777: 0.01586018547569382
# 7778
# Correlation matrix for column 0 and and column7778: 0.0009252832687251655
# 7779
# Correlation matrix for column 0 and and column7779: 0.007306756705458199
# 7780
# Correlation matrix for column 0 and and column7780: -0.005019996014298382
# 7781
# Correlation matrix for column 0 and and column7781: -0.012813878058580593
# 7782
# Correlation matrix for column 0 and and column7782: 0.015338603276287019
# 7783
# Correlation matrix for column 0 and and column7783: 0.007579357137732768
# 7784
# Correlation matrix for column 0 and and column7784: 0.008334377376165146
# 7785
# Correlation matrix for column 0 and and column7785: 0.022810716240409108
# 7786
# Correlation matrix for column 0 and and column7786: -0.0016907174824077299
# 7787
# Correlation matrix for column 0 and and column7787: -0.018417286983137323
# 7788
# Correlation matrix for column 0 and and column7788: 0.010576372672658377
# 7789
# Correlation matrix for column 0 and and column7789: -0.004613215159188712
# 7790
# Correlation matrix for column 0 and and column7790: -0.00937330385552901
# 7791
# Correlation matrix for column 0 and and column7791: 0.00201372554015627
# 7792
# Correlation matrix for column 0 and and column7792: 0.0016844269947322913
# 7793
# Correlation matrix for column 0 and and column7793: -0.013399659466672934
# 7794
# Correlation matrix for column 0 and and column7794: -0.00824123342868998
# 7795
# Correlation matrix for column 0 and and column7795: 0.005097503778874399
# 7796
# Correlation matrix for column 0 and and column7796: 0.006519224506532601
# 7797
# Correlation matrix for column 0 and and column7797: 0.006153736574743161
# 7798
# Correlation matrix for column 0 and and column7798: -0.0037120889697591936
# 7799
# Correlation matrix for column 0 and and column7799: 0.022738010903536277
# 7800
# Correlation matrix for column 0 and and column7800: 0.0229232588023196
# 7801
# Correlation matrix for column 0 and and column7801: -0.00561846502335481
# 7802
# Correlation matrix for column 0 and and column7802: 0.011181855071559362
# 7803
# Correlation matrix for column 0 and and column7803: 0.010457190783404223
# 7804
# Correlation matrix for column 0 and and column7804: 0.004347448390119192
# 7805
# Correlation matrix for column 0 and and column7805: -0.0020405302217839814
# 7806
# Correlation matrix for column 0 and and column7806: 0.013140103381245504
# 7807
# Correlation matrix for column 0 and and column7807: 0.012278600555373746
# 7808
# Correlation matrix for column 0 and and column7808: 0.015124797198772405
# 7809
# Correlation matrix for column 0 and and column7809: -0.01070535917218929
# 7810
# Correlation matrix for column 0 and and column7810: 0.0044422818644333515
# 7811
# Correlation matrix for column 0 and and column7811: 0.005426643088250485
# 7812
# Correlation matrix for column 0 and and column7812: 0.01980476410248669
# 7813
# Correlation matrix for column 0 and and column7813: -0.0010602891756587634
# 7814
# Correlation matrix for column 0 and and column7814: -0.006907629377157768
# 7815
# Correlation matrix for column 0 and and column7815: 0.022114734251326047
# 7816
# Correlation matrix for column 0 and and column7816: 0.002901834222850724
# 7817
# Correlation matrix for column 0 and and column7817: 0.00033145274480464703
# 7818
# Correlation matrix for column 0 and and column7818: 0.013348081916994402
# 7819
# Correlation matrix for column 0 and and column7819: 0.01347683419952076
# 7820
# Correlation matrix for column 0 and and column7820: -0.0072613637241778235
# 7821
# Correlation matrix for column 0 and and column7821: -0.007446956977692786
# 7822
# Correlation matrix for column 0 and and column7822: -0.005001695015560936
# 7823
# Correlation matrix for column 0 and and column7823: -0.008184004768114985
# 7824
# Correlation matrix for column 0 and and column7824: -0.002764727487037863
# 7825
# Correlation matrix for column 0 and and column7825: -0.014111801795042896
# 7826
# Correlation matrix for column 0 and and column7826: -0.0011762701209541845
# 7827
# Correlation matrix for column 0 and and column7827: -0.005749639303153907
# 7828
# Correlation matrix for column 0 and and column7828: 0.0029044386815660476
# 7829
# Correlation matrix for column 0 and and column7829: -0.019705704207623277
# 7830
# Correlation matrix for column 0 and and column7830: -0.01745230865026516
# 7831
# Correlation matrix for column 0 and and column7831: 0.01100061063642163
# 7832
# Correlation matrix for column 0 and and column7832: -0.0035367080299235493
# 7833
# Correlation matrix for column 0 and and column7833: -0.017228963386480965
# 7834
# Correlation matrix for column 0 and and column7834: 0.0015272844628449302
# 7835
# Correlation matrix for column 0 and and column7835: -0.005791959159673538
# 7836
# Correlation matrix for column 0 and and column7836: -0.008329848645884676
# 7837
# Correlation matrix for column 0 and and column7837: 0.012673455886524427
# 7838
# Correlation matrix for column 0 and and column7838: -0.002805318612664491
# 7839
# Correlation matrix for column 0 and and column7839: -0.005279339546127923
# 7840
# Correlation matrix for column 0 and and column7840: -0.004235208789374015
# 7841
# Correlation matrix for column 0 and and column7841: -0.00029369678782527217
# 7842
# Correlation matrix for column 0 and and column7842: -0.014245501266502652
# 7843
# Correlation matrix for column 0 and and column7843: 0.005044028608197017
# 7844
# Correlation matrix for column 0 and and column7844: 0.006529268534670331
# 7845
# Correlation matrix for column 0 and and column7845: -0.005930045415509002
# 7846
# Correlation matrix for column 0 and and column7846: 0.005993130099236237
# 7847
# Correlation matrix for column 0 and and column7847: 0.010314892540421243
# 7848
# Correlation matrix for column 0 and and column7848: -7.171926288088128e-06
# 7849
# Correlation matrix for column 0 and and column7849: 0.007333951470966011
# 7850
# Correlation matrix for column 0 and and column7850: -0.008624267338694114
# 7851
# Correlation matrix for column 0 and and column7851: 0.0072301760298872225
# 7852
# Correlation matrix for column 0 and and column7852: 0.0060165594939970025
# 7853
# Correlation matrix for column 0 and and column7853: 0.02430643379143548
# 7854
# Correlation matrix for column 0 and and column7854: -0.005429846695423893
# 7855
# Correlation matrix for column 0 and and column7855: -0.011026169848839567
# 7856
# Correlation matrix for column 0 and and column7856: 0.01185341613269927
# 7857
# Correlation matrix for column 0 and and column7857: -0.002301272006972427
# 7858
# Correlation matrix for column 0 and and column7858: 0.004819905685063403
# 7859
# Correlation matrix for column 0 and and column7859: -0.00031309987547345974
# 7860
# Correlation matrix for column 0 and and column7860: 0.012112125047210104
# 7861
# Correlation matrix for column 0 and and column7861: -0.0006449289389111919
# 7862
# Correlation matrix for column 0 and and column7862: 0.0023567639682045105
# 7863
# Correlation matrix for column 0 and and column7863: 0.008410783216967654
# 7864
# Correlation matrix for column 0 and and column7864: 0.012415919531227912
# 7865
# Correlation matrix for column 0 and and column7865: -0.021351617624754207
# 7866
# Correlation matrix for column 0 and and column7866: -0.0063558220863668925
# 7867
# Correlation matrix for column 0 and and column7867: -0.005993523163533179
# 7868
# Correlation matrix for column 0 and and column7868: 0.005517221446925989
# 7869
# Correlation matrix for column 0 and and column7869: -0.013150343163497658
# 7870
# Correlation matrix for column 0 and and column7870: 0.011632972652448002
# 7871
# Correlation matrix for column 0 and and column7871: -0.019991256611941087
# 7872
# Correlation matrix for column 0 and and column7872: 0.009336370691898
# 7873
# Correlation matrix for column 0 and and column7873: 0.011356509502786641
# 7874
# Correlation matrix for column 0 and and column7874: 0.023048038171486793
# 7875
# Correlation matrix for column 0 and and column7875: 0.011096327950920066
# 7876
# Correlation matrix for column 0 and and column7876: -0.023288035655881556
# 7877
# Correlation matrix for column 0 and and column7877: 0.0015118305102189546
# 7878
# Correlation matrix for column 0 and and column7878: 0.012768234089924235
# 7879
# Correlation matrix for column 0 and and column7879: -0.009224203879787295
# 7880
# Correlation matrix for column 0 and and column7880: 0.01830689540135782
# 7881
# Correlation matrix for column 0 and and column7881: 0.007665962291651063
# 7882
# Correlation matrix for column 0 and and column7882: -0.02154233184256354
# 7883
# Correlation matrix for column 0 and and column7883: -0.011152939542403999
# 7884
# Correlation matrix for column 0 and and column7884: 0.004801672975280782
# 7885
# Correlation matrix for column 0 and and column7885: 0.022396266487861225
# 7886
# Correlation matrix for column 0 and and column7886: 0.012971109725231517
# 7887
# Correlation matrix for column 0 and and column7887: 0.013015671744205596
# 7888
# Correlation matrix for column 0 and and column7888: -0.0070325924233133556
# 7889
# Correlation matrix for column 0 and and column7889: -0.004229477619832163
# 7890
# Correlation matrix for column 0 and and column7890: -0.008973562048595158
# 7891
# Correlation matrix for column 0 and and column7891: 0.013507210985490086
# 7892
# Correlation matrix for column 0 and and column7892: -0.002467783667174103
# 7893
# Correlation matrix for column 0 and and column7893: -0.0069881088580706794

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")
# Out:
# Percentage of correlations in df1: 35.0 %
# Percentage of correlations in df_new: 33.612061320157096 %
