# %% [markdown]
# # Spurious Correlations of Highly Dimensional Big Data

# %% [markdown]
# This Notebook aims at showing how PCA and random projection can solve the problem of spurious correlations in Big Data.

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.utils import shuffle

# %% [markdown]
# ## DataFrame Creation

# %%
# Number of rows for df
x = 10000 

# Number of columns for df1
y = 100000

# Number of rows for df2
z = 100

# We fix the seed so that random number do not change everytime the script is launched
np.random.seed(0)

# Creating a dataframe with x number of rows and y number of columns
df = pd.DataFrame(np.random.random_sample((x,y)))

# Shuffle rows of dataframe
df = df.sample(frac=1)
df
# Out:
#          0         1         2         3         4         5         6      \
# 5777  0.013107  0.470582  0.782615  0.356561  0.713228  0.001639  0.531202
# 3783  0.960434  0.443701  0.571535  0.813105  0.448731  0.292695  0.378250
# 1295  0.145563  0.462142  0.170783  0.475111  0.200657  0.647372  0.260204
# 838   0.415516  0.027677  0.297519  0.258756  0.415945  0.530397  0.204964
# 1786  0.838305  0.187315  0.668331  0.625653  0.694821  0.305795  0.505483
# ...        ...       ...       ...       ...       ...       ...       ...
# 3408  0.998848  0.085800  0.471002  0.409039  0.700793  0.540194  0.107416
# 6336  0.662911  0.213004  0.723441  0.183560  0.722360  0.145670  0.330431
# 1880  0.416949  0.271127  0.791953  0.508140  0.039867  0.257467  0.701436
# 763   0.647500  0.127408  0.799678  0.626792  0.124441  0.137988  0.041683
# 2631  0.795114  0.455362  0.362424  0.136987  0.434703  0.682724  0.324495
#
#          7         8         9      ...     99990     99991     99992  \
# 5777  0.149542  0.238533  0.156730  ...  0.014578  0.703602  0.121921
# 3783  0.988330  0.737386  0.240126  ...  0.865072  0.048426  0.556778
# 1295  0.386845  0.420123  0.275254  ...  0.038677  0.744098  0.731141
# 838   0.330645  0.675209  0.114403  ...  0.305023  0.463645  0.621614
# 1786  0.220637  0.973320  0.472144  ...  0.863375  0.903354  0.090747
# ...        ...       ...       ...  ...       ...       ...       ...
# 3408  0.102830  0.798725  0.773601  ...  0.026062  0.044855  0.712999
# 6336  0.135678  0.996597  0.220519  ...  0.144963  0.446426  0.148142
# 1880  0.249736  0.430972  0.918784  ...  0.435077  0.629779  0.088950
# 763   0.283041  0.592727  0.516547  ...  0.854014  0.113504  0.449887
# 2631  0.025517  0.901961  0.915626  ...  0.546081  0.614907  0.510145
#
#          99993     99994     99995     99996     99997     99998     99999
# 5777  0.809777  0.141529  0.051837  0.615442  0.598923  0.463951  0.278275
# 3783  0.939422  0.430007  0.304750  0.629446  0.784474  0.027791  0.411822
# 1295  0.329909  0.280043  0.441809  0.997663  0.531609  0.461333  0.930565
# 838   0.614746  0.401539  0.840944  0.074929  0.523992  0.074633  0.005774
# 1786  0.823878  0.833744  0.254442  0.854606  0.282577  0.124343  0.716000
# ...        ...       ...       ...       ...       ...       ...       ...
# 3408  0.918720  0.893730  0.286155  0.116346  0.535174  0.483603  0.914082
# 6336  0.398983  0.215387  0.081686  0.622973  0.427959  0.442991  0.751608
# 1880  0.311274  0.453839  0.558268  0.585202  0.938641  0.548909  0.466086
# 763   0.768145  0.033564  0.712753  0.263060  0.514465  0.901452  0.073480
# 2631  0.875002  0.102243  0.572923  0.600667  0.118417  0.279194  0.612196
#
# [10000 rows x 100000 columns]

# %% [markdown]
# In order to assess the correlations of the different parameters, correlations between the column with index 0 and the 999 other first columns is assessed.

# %%
# Assigning X to all columns except 0
X_df = df.drop(columns=0)
X_df.head()

# Assigning Y to column 0
Y_df = df[0]

# The following line makes Y become a list
Y_df = np.array(Y_df).reshape(-1)
print(X_df.shape,Y_df.shape)

# Calculate correlations between selected column and column 0
list_titles = X_df.columns
list_corr_df1 = []
for i in list_titles[0:z]:
    list_corr_df1.append(abs(np.corrcoef(Y_df, X_df[i])[0][1]))
# Out:
# (10000, 99999) (10000,)

# %% [markdown]
# To see if indeed the correlations between the different parameters increases with the data size, the original dataframe is compared to a sub-set dataframe which only takes the first z rows of the original dataframe. If the correlations in the original dataframe are higher than in the smaller dataframe this would prove that the bigger the data size the more frequent the number of spurious correlations.

# %%
# Creating smaller dataframe taking z number of rows from original dataframe
df2 = df.iloc[:z]
df2

# Assigning X to all columns except 0
X_df2 = df2.drop(columns=0)
X_df2.head()

# Assigning Y to column 0
Y_df2 = df2[0]

# The following line makes Y become a list
Y_df2 = np.array(Y_df2).reshape(-1)
print(X_df2.shape,Y_df2.shape)

list_titles = X_df2.columns

# Calculate correlations between selected column and column 0
list_corr_df2 = []
for i in list_titles[0:z]:
    list_corr_df2.append(abs(np.corrcoef(Y_df2, X_df2[i])[0][1]))
# Out:
# (100, 99999) (100,)

# %% [markdown]
# We now compare which of the dataframes has the highest proportions of correlations.

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df2)):
    if abs(list_corr_df2[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df2:",(b/len(list_corr_df2)*100),"%")
# Out:
# Percentage of correlations in df1: 35.0 %
# Percentage of correlations in df2: 95.0 %

# %% [markdown]
# Clearly it is seen that the lower the number of observations, the higher the frequency of spurious correlations. However the number of spurious correlations present in the bigger DataFrame is still very significant.

# %% [markdown]
# To counter spurious correlations, Principal Component Analysis and Random Projection can be used.

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# In PCA, it is up to the user to choose how many dimension the final data has. This is because the explained variance tells you how much information (variance) can be attributed to each of the principal components. This is important as while you can convert a y dimensional space to 2 dimensional space, you lose some of the variance (information) when you do this. It is up to the user to decide how much variance he is ready to lose.

# %%
# Here we pass the daframe of y columns in 2 dimensions
pca = PCA(n_components=2)
df_pca = pd.DataFrame(pca.fit_transform(df))

# How much of the information is kept by the new dataframe?
print(pca.explained_variance_ratio_)

# %% [markdown]
# The new dataframe is not useful as it almost does not capture any variance. Thus we need more dimensionss.

# %%
# Here we pass the daframe of y columns in 2 dimensions
pca = PCA(n_components=100)
df_pca = pd.DataFrame(pca.fit_transform(df))
print(pca.explained_variance_ratio_)

# %%
# Here we pass the daframe of y columns in 2 dimensions
pca = PCA(n_components=1000)
df_pca = pd.DataFrame(pca.fit_transform(df))
print(pca.explained_variance_ratio_)

# %%
pca.explained_variance_ratio_[0]

# %% [markdown]
# With 1000 Columns, the sum of all the variances is close to 100%, therefore appplying PCA on data with dimension 1000000 and changing it to 1000 dimensions is effective.

# %%
df_new = df_pca
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

# Calculate correlations between selected column and column 0
list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")

# %% [markdown]
# The correlation of the original DataFrame is close to 0 when transformed through PCA.

# %% [markdown]
# ## Random Projection

# %% [markdown]
# In Random Projection, the parameter eps defines how much the Random Projection can deviate from original DataFrame.
# The lower the percentage of the parameter the higher the fidelity of the transformed data.
# However the higher the fidelity the less the reduction of dimensions.

# %%
# Pass df1 in the random projection to create a new reduced DataFrame
transformer = random_projection.GaussianRandomProjection(eps = 0.1)
df_new = pd.DataFrame(transformer.fit_transform(df))
df_new
# Out:
#           0         1         2         3         4         5         6     \
# 0    -0.302008 -0.068082 -2.166533 -1.586556  3.510537 -2.421297  3.879346
# 1     1.085679 -0.621856 -2.965446 -1.289220  1.607926 -1.067674  3.181879
# 2     2.036863  0.810359 -1.578479 -1.842556  4.341481 -0.939813  2.496344
# 3     0.853745  0.209489 -0.653894 -1.438213  4.008682 -1.809010  3.742473
# 4    -0.159262 -0.706281 -1.174776 -2.489145  2.734029 -2.368186  5.093136
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.785027  1.599259 -1.158546 -4.318470  3.890277 -0.086400  3.337646
# 9996  0.287730 -0.654357 -0.580357 -2.476720  1.883245 -1.857241  3.788790
# 9997 -0.231346  0.441176 -1.393993 -1.232085  1.748469 -2.726565  2.460113
# 9998  2.160462 -0.746765  0.152266 -2.963119  3.092495 -1.738957  2.788696
# 9999 -0.279601  0.572601 -2.454676 -2.340935  4.013656 -1.296355  1.855094
#
#           7         8         9     ...      7884      7885      7886  \
# 0    -0.302644 -0.041499 -2.723630  ... -0.526081 -1.870555 -0.515048
# 1    -0.332075 -0.627533 -1.647495  ... -0.389697 -0.407165 -1.061195
# 2    -1.479995 -0.010654 -1.368587  ... -0.836032 -2.663172 -1.463469
# 3    -0.741538  0.730524 -3.445020  ... -0.986869 -2.378565 -0.051288
# 4    -2.298969  0.974940 -2.009920  ...  0.194942 -0.256983  0.133863
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.181822 -1.099291 -2.106602  ... -0.397556 -0.188547 -0.292251
# 9996  0.127083 -0.756120 -1.320422  ...  0.334685 -2.676578 -0.910316
# 9997 -1.598314 -1.596900 -2.540504  ... -0.734830 -0.157428 -0.363285
# 9998 -4.040584 -1.815706 -3.396164  ... -1.344430 -1.284020 -1.864767
# 9999 -1.460061 -1.786897 -2.305595  ...  2.364886 -0.397213 -0.744895
#
#           7887      7888      7889      7890      7891      7892      7893
# 0     0.418709  0.155676  0.913438 -0.137671 -3.233703  1.908510 -0.569964
# 1    -0.578337  0.758631 -0.507895 -1.746763 -2.337331  0.945448 -0.851532
# 2     1.097604  1.839424  1.041087  0.052026 -2.945125  1.497522 -0.118119
# 3     1.374595  0.452994  1.046057 -1.582592 -0.549707  0.856490 -0.122405
# 4     1.448755  2.124376  1.519730  0.872593 -1.599972  0.613540 -1.755886
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.881339  0.798065  1.866085 -1.619263  0.483374  2.026052 -0.395025
# 9996  0.718175  1.226792 -0.783091  0.791722 -2.558282  1.897154 -2.681029
# 9997  1.313989 -0.015197  0.103351 -0.522323 -0.394032  1.189327 -1.506372
# 9998  1.216307  0.866234  0.888831 -1.280773 -3.071721  0.902930 -2.393207
# 9999  1.336309  0.560102  0.652312 -2.175519 -0.767835  3.967625 -0.324088
#
# [10000 rows x 7894 columns]

# %%
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]


# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
# Out:
# 0      -0.302008
# 1       1.085679
# 2       2.036863
# 3       0.853745
# 4      -0.159262
#           ...
# 9995   -0.785027
# 9996    0.287730
# 9997   -0.231346
# 9998    2.160462
# 9999   -0.279601
# Name: 0, Length: 10000, dtype: float64
# (10000, 7893) (10000,)
# 1
# Correlation matrix for column 0 and and column1: -0.005242318414090562
# 2
# Correlation matrix for column 0 and and column2: 0.003941437850269528
# 3
# Correlation matrix for column 0 and and column3: -0.01749704766151873
# 4
# Correlation matrix for column 0 and and column4: -0.007227892357628483
# 5
# Correlation matrix for column 0 and and column5: -0.007569666739016499
# 6
# Correlation matrix for column 0 and and column6: 0.0026103184704149938
# 7
# Correlation matrix for column 0 and and column7: -0.006272080011699586
# 8
# Correlation matrix for column 0 and and column8: 0.0023326459181834155
# 9
# Correlation matrix for column 0 and and column9: -0.003976298936861743
# 10
# Correlation matrix for column 0 and and column10: 0.003188739822555378
# 11
# Correlation matrix for column 0 and and column11: 0.0037497934558032913
# 12
# Correlation matrix for column 0 and and column12: -0.00022447631336313902
# 13
# Correlation matrix for column 0 and and column13: -0.004176201972855902
# 14
# Correlation matrix for column 0 and and column14: 0.005741018415556548
# 15
# Correlation matrix for column 0 and and column15: -0.014142602481670104
# 16
# Correlation matrix for column 0 and and column16: -0.0013263703507694247
# 17
# Correlation matrix for column 0 and and column17: 0.011550419175380779
# 18
# Correlation matrix for column 0 and and column18: 0.021812616000778356
# 19
# Correlation matrix for column 0 and and column19: -0.010357043021415937
# 20
# Correlation matrix for column 0 and and column20: 0.003910813658642487
# 21
# Correlation matrix for column 0 and and column21: 0.006002477593797812
# 22
# Correlation matrix for column 0 and and column22: -0.018280567982411487
# 23
# Correlation matrix for column 0 and and column23: 0.006300585125204447
# 24
# Correlation matrix for column 0 and and column24: -0.009358432316213871
# 25
# Correlation matrix for column 0 and and column25: -0.012502786492110066
# 26
# Correlation matrix for column 0 and and column26: 0.0016661747025570502
# 27
# Correlation matrix for column 0 and and column27: -0.010003749824298162
# 28
# Correlation matrix for column 0 and and column28: 0.004925961456095904
# 29
# Correlation matrix for column 0 and and column29: -0.011855028710438089
# 30
# Correlation matrix for column 0 and and column30: 0.0018652260671997124
# 31
# Correlation matrix for column 0 and and column31: 0.010570227370804663
# 32
# Correlation matrix for column 0 and and column32: 0.009021996493221128
# 33
# Correlation matrix for column 0 and and column33: 0.012753719084412547
# 34
# Correlation matrix for column 0 and and column34: -0.003406423326312209
# 35
# Correlation matrix for column 0 and and column35: 0.0028805006472469347
# 36
# Correlation matrix for column 0 and and column36: 0.02004041012455783
# 37
# Correlation matrix for column 0 and and column37: -0.002766028630745515
# 38
# Correlation matrix for column 0 and and column38: 0.005312635485166279
# 39
# Correlation matrix for column 0 and and column39: -0.0002307796043830702
# 40
# Correlation matrix for column 0 and and column40: 0.008292838360745429
# 41
# Correlation matrix for column 0 and and column41: 0.006290915463307088
# 42
# Correlation matrix for column 0 and and column42: 0.0016432300581037595
# 43
# Correlation matrix for column 0 and and column43: -0.014215688775415451
# 44
# Correlation matrix for column 0 and and column44: -0.00010098688577555227
# 45
# Correlation matrix for column 0 and and column45: 0.008695519887146267
# 46
# Correlation matrix for column 0 and and column46: 0.007865101058441452
# 47
# Correlation matrix for column 0 and and column47: -0.015813894865316484
# 48
# Correlation matrix for column 0 and and column48: 0.003472412115433603
# 49
# Correlation matrix for column 0 and and column49: 0.009574590707282182
# 50
# Correlation matrix for column 0 and and column50: 0.005680515753114052
# 51
# Correlation matrix for column 0 and and column51: -0.013087064081940448
# 52
# Correlation matrix for column 0 and and column52: 0.008202517054639367
# 53
# Correlation matrix for column 0 and and column53: 0.024786622730794215
# 54
# Correlation matrix for column 0 and and column54: -0.001617229823823637
# 55
# Correlation matrix for column 0 and and column55: -0.0016586147293014858
# 56
# Correlation matrix for column 0 and and column56: 0.006367846796350629
# 57
# Correlation matrix for column 0 and and column57: -0.0053244099020759855
# 58
# Correlation matrix for column 0 and and column58: -0.007266616330406179
# 59
# Correlation matrix for column 0 and and column59: -0.003100322507258484
# 60
# Correlation matrix for column 0 and and column60: -0.00946215497955775
# 61
# Correlation matrix for column 0 and and column61: -0.00892613875803227
# 62
# Correlation matrix for column 0 and and column62: 0.008738227955423998
# 63
# Correlation matrix for column 0 and and column63: -0.008404887027830753
# 64
# Correlation matrix for column 0 and and column64: 0.001513277338401103
# 65
# Correlation matrix for column 0 and and column65: 0.0010934691579742757
# 66
# Correlation matrix for column 0 and and column66: -0.003968743194897498
# 67
# Correlation matrix for column 0 and and column67: 0.004986615609874176
# 68
# Correlation matrix for column 0 and and column68: -0.006258303803710597
# 69
# Correlation matrix for column 0 and and column69: 0.0023965833276800345
# 70
# Correlation matrix for column 0 and and column70: 0.003156348445852545
# 71
# Correlation matrix for column 0 and and column71: -0.005639949777064546
# 72
# Correlation matrix for column 0 and and column72: -0.013095523802116975
# 73
# Correlation matrix for column 0 and and column73: 0.024609867475625068
# 74
# Correlation matrix for column 0 and and column74: -0.020266210070483733
# 75
# Correlation matrix for column 0 and and column75: -0.004810339551425604
# 76
# Correlation matrix for column 0 and and column76: -0.02030974767672205
# 77
# Correlation matrix for column 0 and and column77: 0.0046340394192281665
# 78
# Correlation matrix for column 0 and and column78: -0.002244689400162656
# 79
# Correlation matrix for column 0 and and column79: 0.0013425875229180362
# 80
# Correlation matrix for column 0 and and column80: 0.015282191368750133
# 81
# Correlation matrix for column 0 and and column81: 0.002346258895627011
# 82
# Correlation matrix for column 0 and and column82: -0.005081389813185916
# 83
# Correlation matrix for column 0 and and column83: 0.008043494249504235
# 84
# Correlation matrix for column 0 and and column84: 0.003358775161626819
# 85
# Correlation matrix for column 0 and and column85: -0.014004757088441856
# 86
# Correlation matrix for column 0 and and column86: -0.009259086839158564
# 87
# Correlation matrix for column 0 and and column87: -0.0026289110848324534
# 88
# Correlation matrix for column 0 and and column88: 0.030249267257434025
# 89
# Correlation matrix for column 0 and and column89: 0.019193746826248904
# 90
# Correlation matrix for column 0 and and column90: -0.007767741811456566
# 91
# Correlation matrix for column 0 and and column91: -0.008307904519049645
# 92
# Correlation matrix for column 0 and and column92: 0.0022734750098198156
# 93
# Correlation matrix for column 0 and and column93: 0.003927065678267527
# 94
# Correlation matrix for column 0 and and column94: -0.008202436168539324
# 95
# Correlation matrix for column 0 and and column95: -0.0035095926543154514
# 96
# Correlation matrix for column 0 and and column96: 0.013483687604195726
# 97
# Correlation matrix for column 0 and and column97: 0.0009055490792353066
# 98
# Correlation matrix for column 0 and and column98: -0.011470600508219925
# 99
# Correlation matrix for column 0 and and column99: -0.001851062256662993
# 100
# Correlation matrix for column 0 and and column100: -0.01654249663247656
# 101
# Correlation matrix for column 0 and and column101: -0.013321033350294095
# 102
# Correlation matrix for column 0 and and column102: -0.002558290225118957
# 103
# Correlation matrix for column 0 and and column103: 0.0020661035156405556
# 104
# Correlation matrix for column 0 and and column104: 0.006517615527194967
# 105
# Correlation matrix for column 0 and and column105: 0.0021676605901472185
# 106
# Correlation matrix for column 0 and and column106: -0.005667966382446411
# 107
# Correlation matrix for column 0 and and column107: -0.013993418841825018
# 108
# Correlation matrix for column 0 and and column108: 0.01744067328970817
# 109
# Correlation matrix for column 0 and and column109: -0.012431893563392034
# 110
# Correlation matrix for column 0 and and column110: 0.012547317002172091
# 111
# Correlation matrix for column 0 and and column111: 0.01616558028810081
# 112
# Correlation matrix for column 0 and and column112: -0.0076261573037572595
# 113
# Correlation matrix for column 0 and and column113: 0.015011501381467921
# 114
# Correlation matrix for column 0 and and column114: 0.007371694036998987
# 115
# Correlation matrix for column 0 and and column115: 0.01683981843997274
# 116
# Correlation matrix for column 0 and and column116: -0.013146065215487755
# 117
# Correlation matrix for column 0 and and column117: 0.008903493785651537
# 118
# Correlation matrix for column 0 and and column118: 0.017812466350091132
# 119
# Correlation matrix for column 0 and and column119: 0.0095923630209377
# 120
# Correlation matrix for column 0 and and column120: -0.0061699428472815725
# 121
# Correlation matrix for column 0 and and column121: -0.0015576342845013526
# 122
# Correlation matrix for column 0 and and column122: -0.004293770054753004
# 123
# Correlation matrix for column 0 and and column123: 0.0024966769610370635
# 124
# Correlation matrix for column 0 and and column124: -0.00319300838083464
# 125
# Correlation matrix for column 0 and and column125: -0.006091040934047897
# 126
# Correlation matrix for column 0 and and column126: 0.00855455958679307
# 127
# Correlation matrix for column 0 and and column127: 0.0025340377217584536
# 128
# Correlation matrix for column 0 and and column128: -0.01592061736619674
# 129
# Correlation matrix for column 0 and and column129: -0.01202314733282993
# 130
# Correlation matrix for column 0 and and column130: -0.01125703711337096
# 131
# Correlation matrix for column 0 and and column131: 0.005191682087204099
# 132
# Correlation matrix for column 0 and and column132: 0.022994805215672796
# 133
# Correlation matrix for column 0 and and column133: 0.0015238521803969008
# 134
# Correlation matrix for column 0 and and column134: -0.0056107900633261525
# 135
# Correlation matrix for column 0 and and column135: 0.00950600975493538
# 136
# Correlation matrix for column 0 and and column136: -0.00938671944121522
# 137
# Correlation matrix for column 0 and and column137: 0.004493284862554712
# 138
# Correlation matrix for column 0 and and column138: 0.009494641667178089
# 139
# Correlation matrix for column 0 and and column139: -0.013742568736286624
# 140
# Correlation matrix for column 0 and and column140: 0.019740669916385137
# 141
# Correlation matrix for column 0 and and column141: 0.010742567054302014
# 142
# Correlation matrix for column 0 and and column142: 0.005098953558336109
# 143
# Correlation matrix for column 0 and and column143: -0.006206980012178184
# 144
# Correlation matrix for column 0 and and column144: -0.005630272815768948
# 145
# Correlation matrix for column 0 and and column145: 0.01583022606407772
# 146
# Correlation matrix for column 0 and and column146: 0.0001444880258482209
# 147
# Correlation matrix for column 0 and and column147: 0.005715197002232696
# 148
# Correlation matrix for column 0 and and column148: -0.015151215962754264
# 149
# Correlation matrix for column 0 and and column149: 0.002610060290184721
# 150
# Correlation matrix for column 0 and and column150: 0.010005492480774142
# 151
# Correlation matrix for column 0 and and column151: -0.00014462422265204653
# 152
# Correlation matrix for column 0 and and column152: -0.013585654257517775
# 153
# Correlation matrix for column 0 and and column153: -0.00016129919267917427
# 154
# Correlation matrix for column 0 and and column154: -0.027497685762821758
# 155
# Correlation matrix for column 0 and and column155: 0.003473680636473613
# 156
# Correlation matrix for column 0 and and column156: 0.0006814592620307176
# 157
# Correlation matrix for column 0 and and column157: 0.018560482890524796
# 158
# Correlation matrix for column 0 and and column158: -0.008678008503713013
# 159
# Correlation matrix for column 0 and and column159: -0.015271862361934651
# 160
# Correlation matrix for column 0 and and column160: 0.0015921412061708049
# 161
# Correlation matrix for column 0 and and column161: 0.001549824967116507
# 162
# Correlation matrix for column 0 and and column162: -0.0035894052552033003
# 163
# Correlation matrix for column 0 and and column163: 0.006825827952023625
# 164
# Correlation matrix for column 0 and and column164: 0.012413407518920588
# 165
# Correlation matrix for column 0 and and column165: 0.01572056909357497
# 166
# Correlation matrix for column 0 and and column166: 0.01097693327091488
# 167
# Correlation matrix for column 0 and and column167: -0.0158205040279267
# 168
# Correlation matrix for column 0 and and column168: 0.009887177577762979
# 169
# Correlation matrix for column 0 and and column169: -0.0031913146557171527
# 170
# Correlation matrix for column 0 and and column170: -0.019406384328202124
# 171
# Correlation matrix for column 0 and and column171: 0.005107529468513804
# 172
# Correlation matrix for column 0 and and column172: 0.012243336837497659
# 173
# Correlation matrix for column 0 and and column173: -0.004124367486108576
# 174
# Correlation matrix for column 0 and and column174: -0.0006191841638696591
# 175
# Correlation matrix for column 0 and and column175: -0.002894334914772231
# 176
# Correlation matrix for column 0 and and column176: -0.001831611551859657
# 177
# Correlation matrix for column 0 and and column177: -0.00939917734369646
# 178
# Correlation matrix for column 0 and and column178: -0.0023717682188767694
# 179
# Correlation matrix for column 0 and and column179: 0.016674277721811022
# 180
# Correlation matrix for column 0 and and column180: -0.018896251130499548
# 181
# Correlation matrix for column 0 and and column181: 0.003309214165114646
# 182
# Correlation matrix for column 0 and and column182: 0.013472898552414007
# 183
# Correlation matrix for column 0 and and column183: -0.0062599740849364404
# 184
# Correlation matrix for column 0 and and column184: 0.006628481522320483
# 185
# Correlation matrix for column 0 and and column185: -0.01812617744641335
# 186
# Correlation matrix for column 0 and and column186: 0.00974720602807174
# 187
# Correlation matrix for column 0 and and column187: -0.010251575716553963
# 188
# Correlation matrix for column 0 and and column188: 0.00461783337405509
# 189
# Correlation matrix for column 0 and and column189: -0.000672503309002264
# 190
# Correlation matrix for column 0 and and column190: -0.006242371472506423
# 191
# Correlation matrix for column 0 and and column191: -0.010724426873406637
# 192
# Correlation matrix for column 0 and and column192: 0.001140390301428043
# 193
# Correlation matrix for column 0 and and column193: 0.011633225859005976
# 194
# Correlation matrix for column 0 and and column194: -0.002146479164749293
# 195
# Correlation matrix for column 0 and and column195: -0.0015499361334531182
# 196
# Correlation matrix for column 0 and and column196: 0.004880747338075621
# 197
# Correlation matrix for column 0 and and column197: -0.008492523923289285
# 198
# Correlation matrix for column 0 and and column198: 0.010571361011317117
# 199
# Correlation matrix for column 0 and and column199: 0.0005356567948870332
# 200
# Correlation matrix for column 0 and and column200: -0.00352582117460532
# 201
# Correlation matrix for column 0 and and column201: -0.0092951333753237
# 202
# Correlation matrix for column 0 and and column202: 0.0005085369230198478
# 203
# Correlation matrix for column 0 and and column203: 0.012437157265846169
# 204
# Correlation matrix for column 0 and and column204: 0.009093112339791959
# 205
# Correlation matrix for column 0 and and column205: -0.006329916929646593
# 206
# Correlation matrix for column 0 and and column206: 0.016411111801944833
# 207
# Correlation matrix for column 0 and and column207: -0.009628589934077931
# 208
# Correlation matrix for column 0 and and column208: 0.00472638735009737
# 209
# Correlation matrix for column 0 and and column209: -0.0028733157575020363
# 210
# Correlation matrix for column 0 and and column210: 0.013600399009775284
# 211
# Correlation matrix for column 0 and and column211: 0.01929536139699438
# 212
# Correlation matrix for column 0 and and column212: -0.0002854481606687549
# 213
# Correlation matrix for column 0 and and column213: 0.034259879441885
# 214
# Correlation matrix for column 0 and and column214: 0.013391246815168534
# 215
# Correlation matrix for column 0 and and column215: 0.001218330701894477
# 216
# Correlation matrix for column 0 and and column216: 0.00695184200052698
# 217
# Correlation matrix for column 0 and and column217: -0.005371880032073016
# 218
# Correlation matrix for column 0 and and column218: -0.0016782247184054376
# 219
# Correlation matrix for column 0 and and column219: -0.0055764179077030665
# 220
# Correlation matrix for column 0 and and column220: 0.0031837349485810194
# 221
# Correlation matrix for column 0 and and column221: 0.015139025940545607
# 222
# Correlation matrix for column 0 and and column222: -0.006620428059538667
# 223
# Correlation matrix for column 0 and and column223: -0.004337706872902354
# 224
# Correlation matrix for column 0 and and column224: -0.01467170770385432
# 225
# Correlation matrix for column 0 and and column225: 0.0036834843894696765
# 226
# Correlation matrix for column 0 and and column226: 0.012124958795233974
# 227
# Correlation matrix for column 0 and and column227: 0.006016773357852536
# 228
# Correlation matrix for column 0 and and column228: -0.0036241441629364323
# 229
# Correlation matrix for column 0 and and column229: 0.016237997483055332
# 230
# Correlation matrix for column 0 and and column230: -0.0039035414018104135
# 231
# Correlation matrix for column 0 and and column231: -0.0034842012932570386
# 232
# Correlation matrix for column 0 and and column232: 0.009726219949883085
# 233
# Correlation matrix for column 0 and and column233: 0.004801931760642618
# 234
# Correlation matrix for column 0 and and column234: 0.005215083983989083
# 235
# Correlation matrix for column 0 and and column235: 0.01469740416874134
# 236
# Correlation matrix for column 0 and and column236: 0.008357113240730582
# 237
# Correlation matrix for column 0 and and column237: -0.00395773570775009
# 238
# Correlation matrix for column 0 and and column238: -0.01007095521988841
# 239
# Correlation matrix for column 0 and and column239: 0.008681252618646836
# 240
# Correlation matrix for column 0 and and column240: 0.03106875393728612
# 241
# Correlation matrix for column 0 and and column241: -0.007502750835642053
# 242
# Correlation matrix for column 0 and and column242: 0.000967825071638777
# 243
# Correlation matrix for column 0 and and column243: 0.008344316541959324
# 244
# Correlation matrix for column 0 and and column244: 0.008330666642903776
# 245
# Correlation matrix for column 0 and and column245: 0.008004688773304996
# 246
# Correlation matrix for column 0 and and column246: 0.009814888170991298
# 247
# Correlation matrix for column 0 and and column247: 0.009887587396262467
# 248
# Correlation matrix for column 0 and and column248: -0.0055229220099069845
# 249
# Correlation matrix for column 0 and and column249: -0.012338997870408644
# 250
# Correlation matrix for column 0 and and column250: -0.005546605089402353
# 251
# Correlation matrix for column 0 and and column251: 0.001047059000449625
# 252
# Correlation matrix for column 0 and and column252: -0.0051478866873816784
# 253
# Correlation matrix for column 0 and and column253: 0.0008540252992060537
# 254
# Correlation matrix for column 0 and and column254: 0.012707032107609916
# 255
# Correlation matrix for column 0 and and column255: -0.01413311389448144
# 256
# Correlation matrix for column 0 and and column256: 0.0009904006569311206
# 257
# Correlation matrix for column 0 and and column257: 0.013079549065381958
# 258
# Correlation matrix for column 0 and and column258: -0.01177865434501829
# 259
# Correlation matrix for column 0 and and column259: 0.0013936102907010487
# 260
# Correlation matrix for column 0 and and column260: -0.004007191299536429
# 261
# Correlation matrix for column 0 and and column261: -0.01005360743986408
# 262
# Correlation matrix for column 0 and and column262: 0.005065562264509799
# 263
# Correlation matrix for column 0 and and column263: -0.005402354148363608
# 264
# Correlation matrix for column 0 and and column264: -0.009593323034429628
# 265
# Correlation matrix for column 0 and and column265: 0.01453655634237321
# 266
# Correlation matrix for column 0 and and column266: -0.0013999120551826613
# 267
# Correlation matrix for column 0 and and column267: -0.029008772166615862
# 268
# Correlation matrix for column 0 and and column268: -0.009423530186071507
# 269
# Correlation matrix for column 0 and and column269: 0.021331098694077323
# 270
# Correlation matrix for column 0 and and column270: -0.00027463733453863604
# 271
# Correlation matrix for column 0 and and column271: -0.008599547167681227
# 272
# Correlation matrix for column 0 and and column272: 0.00823849825299531
# 273
# Correlation matrix for column 0 and and column273: 0.0058717374961221105
# 274
# Correlation matrix for column 0 and and column274: -0.012259660023794052
# 275
# Correlation matrix for column 0 and and column275: -0.01556975558743918
# 276
# Correlation matrix for column 0 and and column276: -0.00567925194126928
# 277
# Correlation matrix for column 0 and and column277: -0.00455099404762451
# 278
# Correlation matrix for column 0 and and column278: 0.006958103054731154
# 279
# Correlation matrix for column 0 and and column279: 0.004456047185271456
# 280
# Correlation matrix for column 0 and and column280: -0.005834149895404834
# 281
# Correlation matrix for column 0 and and column281: 0.0015015012638682913
# 282
# Correlation matrix for column 0 and and column282: -0.015450445239950822
# 283
# Correlation matrix for column 0 and and column283: 0.004628052433726668
# 284
# Correlation matrix for column 0 and and column284: -0.0018999820536643197
# 285
# Correlation matrix for column 0 and and column285: -0.00019404114980060274
# 286
# Correlation matrix for column 0 and and column286: 0.0020633736385469183
# 287
# Correlation matrix for column 0 and and column287: 0.016712537334870093
# 288
# Correlation matrix for column 0 and and column288: -0.005136335571750194
# 289
# Correlation matrix for column 0 and and column289: -0.001996597363944823
# 290
# Correlation matrix for column 0 and and column290: -0.006876620198619132
# 291
# Correlation matrix for column 0 and and column291: 0.003065698155425754
# 292
# Correlation matrix for column 0 and and column292: -0.0016530162546970865
# 293
# Correlation matrix for column 0 and and column293: -0.0069872410563146066
# 294
# Correlation matrix for column 0 and and column294: -0.0025374721841952726
# 295
# Correlation matrix for column 0 and and column295: 0.02857682261864502
# 296
# Correlation matrix for column 0 and and column296: 0.0014747026429338392
# 297
# Correlation matrix for column 0 and and column297: 0.01539190021516336
# 298
# Correlation matrix for column 0 and and column298: -0.004025724668082045
# 299
# Correlation matrix for column 0 and and column299: -0.007142878633397499
# 300
# Correlation matrix for column 0 and and column300: 0.006163019393416787
# 301
# Correlation matrix for column 0 and and column301: -0.016986982636636446
# 302
# Correlation matrix for column 0 and and column302: 0.0017035894305297027
# 303
# Correlation matrix for column 0 and and column303: 0.02008405715389854
# 304
# Correlation matrix for column 0 and and column304: -0.006540361682824012
# 305
# Correlation matrix for column 0 and and column305: -0.01070667375346851
# 306
# Correlation matrix for column 0 and and column306: -0.006176992991279911
# 307
# Correlation matrix for column 0 and and column307: 0.0011681941274209902
# 308
# Correlation matrix for column 0 and and column308: -0.004239086207110456
# 309
# Correlation matrix for column 0 and and column309: -0.008348314643068221
# 310
# Correlation matrix for column 0 and and column310: -0.0007058649026113742
# 311
# Correlation matrix for column 0 and and column311: -0.010532499069985012
# 312
# Correlation matrix for column 0 and and column312: -0.015107036034289123
# 313
# Correlation matrix for column 0 and and column313: 0.0003397054506028821
# 314
# Correlation matrix for column 0 and and column314: -0.003071497312826801
# 315
# Correlation matrix for column 0 and and column315: 0.0021789676547457368
# 316
# Correlation matrix for column 0 and and column316: -0.0005945064129130487
# 317
# Correlation matrix for column 0 and and column317: -0.0010812740819033883
# 318
# Correlation matrix for column 0 and and column318: -0.017553254064276477
# 319
# Correlation matrix for column 0 and and column319: -0.001801445320319325
# 320
# Correlation matrix for column 0 and and column320: 0.004540452043859675
# 321
# Correlation matrix for column 0 and and column321: 0.00690325703406342
# 322
# Correlation matrix for column 0 and and column322: 0.013602409462370433
# 323
# Correlation matrix for column 0 and and column323: 0.01614797168677918
# 324
# Correlation matrix for column 0 and and column324: -0.0032198852996717054
# 325
# Correlation matrix for column 0 and and column325: -0.007414140308475192
# 326
# Correlation matrix for column 0 and and column326: -0.006598250272150751
# 327
# Correlation matrix for column 0 and and column327: 0.007304798589491361
# 328
# Correlation matrix for column 0 and and column328: 0.01648266471423888
# 329
# Correlation matrix for column 0 and and column329: -0.006943516267780339
# 330
# Correlation matrix for column 0 and and column330: -0.0047677192181130035
# 331
# Correlation matrix for column 0 and and column331: 0.0060745915322780114
# 332
# Correlation matrix for column 0 and and column332: 3.8815126588728724e-05
# 333
# Correlation matrix for column 0 and and column333: 0.004243884308706372
# 334
# Correlation matrix for column 0 and and column334: 0.0025058409301373227
# 335
# Correlation matrix for column 0 and and column335: -0.009610399111764924
# 336
# Correlation matrix for column 0 and and column336: 0.013629710680228774
# 337
# Correlation matrix for column 0 and and column337: 0.004091352063263329
# 338
# Correlation matrix for column 0 and and column338: 0.003484252490179148
# 339
# Correlation matrix for column 0 and and column339: 0.006829038021926178
# 340
# Correlation matrix for column 0 and and column340: 0.0008372992598530239
# 341
# Correlation matrix for column 0 and and column341: 0.020190961731375932
# 342
# Correlation matrix for column 0 and and column342: -0.0007334707262891092
# 343
# Correlation matrix for column 0 and and column343: 0.003359431545266395
# 344
# Correlation matrix for column 0 and and column344: 0.005970616989325296
# 345
# Correlation matrix for column 0 and and column345: -0.009459967226997731
# 346
# Correlation matrix for column 0 and and column346: 0.00443116294902605
# 347
# Correlation matrix for column 0 and and column347: 0.0003429227964377979
# 348
# Correlation matrix for column 0 and and column348: 0.010324430356355585
# 349
# Correlation matrix for column 0 and and column349: -0.0065030983317493195
# 350
# Correlation matrix for column 0 and and column350: 0.0014721112268997068
# 351
# Correlation matrix for column 0 and and column351: 0.012372864882348164
# 352
# Correlation matrix for column 0 and and column352: -0.015001287584372575
# 353
# Correlation matrix for column 0 and and column353: 0.01423243555035959
# 354
# Correlation matrix for column 0 and and column354: -0.00018399836753452343
# 355
# Correlation matrix for column 0 and and column355: -0.003835306955203212
# 356
# Correlation matrix for column 0 and and column356: 0.00013609125190930748
# 357
# Correlation matrix for column 0 and and column357: 0.0015124901549840618
# 358
# Correlation matrix for column 0 and and column358: 0.001150911157363808
# 359
# Correlation matrix for column 0 and and column359: -0.006365514460754745
# 360
# Correlation matrix for column 0 and and column360: -0.006544558613265467
# 361
# Correlation matrix for column 0 and and column361: -0.011814369927153281
# 362
# Correlation matrix for column 0 and and column362: -0.013463795943815218
# 363
# Correlation matrix for column 0 and and column363: 0.0021984173855533087
# 364
# Correlation matrix for column 0 and and column364: 0.002330109133316466
# 365
# Correlation matrix for column 0 and and column365: -0.0006566194471994872
# 366
# Correlation matrix for column 0 and and column366: -0.00566825916814465
# 367
# Correlation matrix for column 0 and and column367: 0.0271500670750182
# 368
# Correlation matrix for column 0 and and column368: 0.00425187224828478
# 369
# Correlation matrix for column 0 and and column369: -0.002215760678374372
# 370
# Correlation matrix for column 0 and and column370: 0.016364613976348783
# 371
# Correlation matrix for column 0 and and column371: -0.007599035977347462
# 372
# Correlation matrix for column 0 and and column372: 0.004246240955387416
# 373
# Correlation matrix for column 0 and and column373: -0.008428665976464812
# 374
# Correlation matrix for column 0 and and column374: 0.0072301601132077125
# 375
# Correlation matrix for column 0 and and column375: 0.0029976011352083123
# 376
# Correlation matrix for column 0 and and column376: -0.003657040979696466
# 377
# Correlation matrix for column 0 and and column377: 0.006913108832191417
# 378
# Correlation matrix for column 0 and and column378: -0.013862781688616205
# 379
# Correlation matrix for column 0 and and column379: 0.005894139994852567
# 380
# Correlation matrix for column 0 and and column380: 0.002340155879108686
# 381
# Correlation matrix for column 0 and and column381: -0.010161327908717481
# 382
# Correlation matrix for column 0 and and column382: -0.006941923561535233
# 383
# Correlation matrix for column 0 and and column383: -0.012886314126423305
# 384
# Correlation matrix for column 0 and and column384: -0.005811205657954935
# 385
# Correlation matrix for column 0 and and column385: -0.018782096117326046
# 386
# Correlation matrix for column 0 and and column386: 0.009538161805171188
# 387
# Correlation matrix for column 0 and and column387: 0.009341222303915299
# 388
# Correlation matrix for column 0 and and column388: 0.014638367014576143
# 389
# Correlation matrix for column 0 and and column389: -0.00039474223898741944
# 390
# Correlation matrix for column 0 and and column390: 0.011728477321350435
# 391
# Correlation matrix for column 0 and and column391: 0.01038311782600407
# 392
# Correlation matrix for column 0 and and column392: 0.028965019540910703
# 393
# Correlation matrix for column 0 and and column393: -0.002396062080512184
# 394
# Correlation matrix for column 0 and and column394: -0.02451819002508398
# 395
# Correlation matrix for column 0 and and column395: 0.0100048111084692
# 396
# Correlation matrix for column 0 and and column396: -0.008946357421226075
# 397
# Correlation matrix for column 0 and and column397: 0.012311353451691879
# 398
# Correlation matrix for column 0 and and column398: -0.019355030320112373
# 399
# Correlation matrix for column 0 and and column399: -0.0158276620868478
# 400
# Correlation matrix for column 0 and and column400: -0.006637083722588362
# 401
# Correlation matrix for column 0 and and column401: 0.022576894194453998
# 402
# Correlation matrix for column 0 and and column402: -0.005996427776401083
# 403
# Correlation matrix for column 0 and and column403: 0.015127447124992793
# 404
# Correlation matrix for column 0 and and column404: 0.01936067718986295
# 405
# Correlation matrix for column 0 and and column405: -0.024835192921375728
# 406
# Correlation matrix for column 0 and and column406: -0.014677585093474211
# 407
# Correlation matrix for column 0 and and column407: 0.0017957644492028442
# 408
# Correlation matrix for column 0 and and column408: -0.0017146646120095158
# 409
# Correlation matrix for column 0 and and column409: -0.005353468216588875
# 410
# Correlation matrix for column 0 and and column410: 0.004376722470478454
# 411
# Correlation matrix for column 0 and and column411: 0.01415664614503458
# 412
# Correlation matrix for column 0 and and column412: 0.014305325977723082
# 413
# Correlation matrix for column 0 and and column413: -0.004341371520953009
# 414
# Correlation matrix for column 0 and and column414: -0.0008569894956524623
# 415
# Correlation matrix for column 0 and and column415: -0.0031726586347760703
# 416
# Correlation matrix for column 0 and and column416: -0.0038048984902847582
# 417
# Correlation matrix for column 0 and and column417: 0.00694723741370112
# 418
# Correlation matrix for column 0 and and column418: 0.006742624229626593
# 419
# Correlation matrix for column 0 and and column419: -0.012431363179550405
# 420
# Correlation matrix for column 0 and and column420: -0.00960588410530373
# 421
# Correlation matrix for column 0 and and column421: -0.017270258113784936
# 422
# Correlation matrix for column 0 and and column422: -0.023478503157536537
# 423
# Correlation matrix for column 0 and and column423: -0.0005728629679464536
# 424
# Correlation matrix for column 0 and and column424: 0.0073842121324435555
# 425
# Correlation matrix for column 0 and and column425: 0.014534291260819385
# 426
# Correlation matrix for column 0 and and column426: 0.020142806605415037
# 427
# Correlation matrix for column 0 and and column427: -0.020627386592387893
# 428
# Correlation matrix for column 0 and and column428: 0.00895215637230773
# 429
# Correlation matrix for column 0 and and column429: 0.007235414542528271
# 430
# Correlation matrix for column 0 and and column430: 0.008689553217929571
# 431
# Correlation matrix for column 0 and and column431: 0.0019261183932095683
# 432
# Correlation matrix for column 0 and and column432: -0.006343990829695494
# 433
# Correlation matrix for column 0 and and column433: -0.011763425619855382
# 434
# Correlation matrix for column 0 and and column434: -0.0020730742515538535
# 435
# Correlation matrix for column 0 and and column435: -0.01735049469729483
# 436
# Correlation matrix for column 0 and and column436: -0.0034415181551941607
# 437
# Correlation matrix for column 0 and and column437: 0.005805306961278926
# 438
# Correlation matrix for column 0 and and column438: -0.0008882209812340342
# 439
# Correlation matrix for column 0 and and column439: 0.007889470357557332
# 440
# Correlation matrix for column 0 and and column440: 0.015349614640753104
# 441
# Correlation matrix for column 0 and and column441: -0.0024005367278347733
# 442
# Correlation matrix for column 0 and and column442: -0.006750618392421646
# 443
# Correlation matrix for column 0 and and column443: 0.00416186696966281
# 444
# Correlation matrix for column 0 and and column444: -0.006177384509446668
# 445
# Correlation matrix for column 0 and and column445: 0.0006944294078516034
# 446
# Correlation matrix for column 0 and and column446: 0.004509025724367896
# 447
# Correlation matrix for column 0 and and column447: -0.01514726924042875
# 448
# Correlation matrix for column 0 and and column448: 0.007143292191052892
# 449
# Correlation matrix for column 0 and and column449: -0.006318409990171647
# 450
# Correlation matrix for column 0 and and column450: 0.007180838723018215
# 451
# Correlation matrix for column 0 and and column451: 0.002800308584554661
# 452
# Correlation matrix for column 0 and and column452: 0.004890022162835917
# 453
# Correlation matrix for column 0 and and column453: -0.016435117038698682
# 454
# Correlation matrix for column 0 and and column454: 0.012746371974165411
# 455
# Correlation matrix for column 0 and and column455: 0.004700826582657602
# 456
# Correlation matrix for column 0 and and column456: -0.0036588764371448786
# 457
# Correlation matrix for column 0 and and column457: -0.011277643710902473
# 458
# Correlation matrix for column 0 and and column458: -0.011939990880856116
# 459
# Correlation matrix for column 0 and and column459: 0.00026667697650944
# 460
# Correlation matrix for column 0 and and column460: 0.021667694873465936
# 461
# Correlation matrix for column 0 and and column461: -0.019010000762080974
# 462
# Correlation matrix for column 0 and and column462: -0.003797725492080645
# 463
# Correlation matrix for column 0 and and column463: 0.006679812340919178
# 464
# Correlation matrix for column 0 and and column464: -0.000640271335540944
# 465
# Correlation matrix for column 0 and and column465: 0.006141907776621124
# 466
# Correlation matrix for column 0 and and column466: 0.01489768072579358
# 467
# Correlation matrix for column 0 and and column467: -0.015432163283320597
# 468
# Correlation matrix for column 0 and and column468: -0.008055047727709203
# 469
# Correlation matrix for column 0 and and column469: 0.015702568664699348
# 470
# Correlation matrix for column 0 and and column470: -0.028596376050677146
# 471
# Correlation matrix for column 0 and and column471: -0.00807715379324031
# 472
# Correlation matrix for column 0 and and column472: 0.0005515967353428948
# 473
# Correlation matrix for column 0 and and column473: 0.014616287453040023
# 474
# Correlation matrix for column 0 and and column474: -0.005676744530637859
# 475
# Correlation matrix for column 0 and and column475: 0.0026075937703269754
# 476
# Correlation matrix for column 0 and and column476: -0.00669573454173472
# 477
# Correlation matrix for column 0 and and column477: -0.021075519443480316
# 478
# Correlation matrix for column 0 and and column478: 0.02097768153141964
# 479
# Correlation matrix for column 0 and and column479: 0.015152059738657466
# 480
# Correlation matrix for column 0 and and column480: 0.01253332040794092
# 481
# Correlation matrix for column 0 and and column481: 0.007310354295640769
# 482
# Correlation matrix for column 0 and and column482: -0.0063133077242527825
# 483
# Correlation matrix for column 0 and and column483: -0.004718889896614058
# 484
# Correlation matrix for column 0 and and column484: 0.00036311030227198786
# 485
# Correlation matrix for column 0 and and column485: 0.013780707357449394
# 486
# Correlation matrix for column 0 and and column486: -0.01422921084088685
# 487
# Correlation matrix for column 0 and and column487: 0.006083846363522242
# 488
# Correlation matrix for column 0 and and column488: 0.011020649931905645
# 489
# Correlation matrix for column 0 and and column489: -0.007911442667113694
# 490
# Correlation matrix for column 0 and and column490: 0.008075657223525491
# 491
# Correlation matrix for column 0 and and column491: 0.01784785742721656
# 492
# Correlation matrix for column 0 and and column492: -0.007121281572364532
# 493
# Correlation matrix for column 0 and and column493: 0.004179232366439015
# 494
# Correlation matrix for column 0 and and column494: 0.011080485454056982
# 495
# Correlation matrix for column 0 and and column495: -0.011418112407041459
# 496
# Correlation matrix for column 0 and and column496: -0.009817093945226738
# 497
# Correlation matrix for column 0 and and column497: -0.004440601145520568
# 498
# Correlation matrix for column 0 and and column498: -0.020833125803351952
# 499
# Correlation matrix for column 0 and and column499: 0.004493517973543259
# 500
# Correlation matrix for column 0 and and column500: 0.00874659864476489
# 501
# Correlation matrix for column 0 and and column501: 0.010691999681820755
# 502
# Correlation matrix for column 0 and and column502: 0.008772175554687367
# 503
# Correlation matrix for column 0 and and column503: 0.0029683534749809096
# 504
# Correlation matrix for column 0 and and column504: -0.011007474827126534
# 505
# Correlation matrix for column 0 and and column505: -0.013597770239615156
# 506
# Correlation matrix for column 0 and and column506: 0.01738421113642737
# 507
# Correlation matrix for column 0 and and column507: -0.02626887630721892
# 508
# Correlation matrix for column 0 and and column508: 0.0017917784175605414
# 509
# Correlation matrix for column 0 and and column509: 0.02118872400387274
# 510
# Correlation matrix for column 0 and and column510: 0.013291511503109664
# 511
# Correlation matrix for column 0 and and column511: 0.0016964563870191527
# 512
# Correlation matrix for column 0 and and column512: -0.004742504106653654
# 513
# Correlation matrix for column 0 and and column513: 0.007603976042801537
# 514
# Correlation matrix for column 0 and and column514: 0.010923680396427072
# 515
# Correlation matrix for column 0 and and column515: 0.00018618105232301837
# 516
# Correlation matrix for column 0 and and column516: -0.006663790497554621
# 517
# Correlation matrix for column 0 and and column517: 0.016306543625380764
# 518
# Correlation matrix for column 0 and and column518: -0.016392229722196835
# 519
# Correlation matrix for column 0 and and column519: 0.005092926475010837
# 520
# Correlation matrix for column 0 and and column520: 0.0035514177258585016
# 521
# Correlation matrix for column 0 and and column521: -0.004313517992072281
# 522
# Correlation matrix for column 0 and and column522: -0.005396465631918113
# 523
# Correlation matrix for column 0 and and column523: 0.005083363884202312
# 524
# Correlation matrix for column 0 and and column524: -0.008524604769729601
# 525
# Correlation matrix for column 0 and and column525: -0.0042718541882696415
# 526
# Correlation matrix for column 0 and and column526: -0.0021828701534354197
# 527
# Correlation matrix for column 0 and and column527: 0.005279455036522712
# 528
# Correlation matrix for column 0 and and column528: 0.005180302373778304
# 529
# Correlation matrix for column 0 and and column529: 0.013454878549949967
# 530
# Correlation matrix for column 0 and and column530: -0.00313044287225595
# 531
# Correlation matrix for column 0 and and column531: -0.009976458728043936
# 532
# Correlation matrix for column 0 and and column532: 0.007672012882501194
# 533
# Correlation matrix for column 0 and and column533: -0.008484063893615577
# 534
# Correlation matrix for column 0 and and column534: -0.010842536651086332
# 535
# Correlation matrix for column 0 and and column535: 0.0049453871241377945
# 536
# Correlation matrix for column 0 and and column536: 0.0030735661566225316
# 537
# Correlation matrix for column 0 and and column537: -0.01892333539940668
# 538
# Correlation matrix for column 0 and and column538: 0.005771682690129904
# 539
# Correlation matrix for column 0 and and column539: 0.006980034185247444
# 540
# Correlation matrix for column 0 and and column540: -0.005736463553929958
# 541
# Correlation matrix for column 0 and and column541: -0.009927020757339618
# 542
# Correlation matrix for column 0 and and column542: 0.02108653428465633
# 543
# Correlation matrix for column 0 and and column543: -0.004427646542026295
# 544
# Correlation matrix for column 0 and and column544: -0.013429734934505421
# 545
# Correlation matrix for column 0 and and column545: 0.008852042969374722
# 546
# Correlation matrix for column 0 and and column546: 0.005380068790511733
# 547
# Correlation matrix for column 0 and and column547: 0.028800101525892473
# 548
# Correlation matrix for column 0 and and column548: 0.011134357155078583
# 549
# Correlation matrix for column 0 and and column549: 0.00860717377803287
# 550
# Correlation matrix for column 0 and and column550: -0.017898568359347892
# 551
# Correlation matrix for column 0 and and column551: -0.00242617905555853
# 552
# Correlation matrix for column 0 and and column552: 0.014086973961621743
# 553
# Correlation matrix for column 0 and and column553: 0.0018004025481793387
# 554
# Correlation matrix for column 0 and and column554: 0.0014682128839870233
# 555
# Correlation matrix for column 0 and and column555: 0.009412429591194467
# 556
# Correlation matrix for column 0 and and column556: 0.0006980793832656083
# 557
# Correlation matrix for column 0 and and column557: -0.010306395959094564
# 558
# Correlation matrix for column 0 and and column558: 0.0014893344389082608
# 559
# Correlation matrix for column 0 and and column559: -0.004218483647312959
# 560
# Correlation matrix for column 0 and and column560: -0.0016511485577791868
# 561
# Correlation matrix for column 0 and and column561: 0.002412798763334793
# 562
# Correlation matrix for column 0 and and column562: -0.01165776946634611
# 563
# Correlation matrix for column 0 and and column563: 0.0007354021077737138
# 564
# Correlation matrix for column 0 and and column564: 0.009680598996475926
# 565
# Correlation matrix for column 0 and and column565: 0.010173901831316499
# 566
# Correlation matrix for column 0 and and column566: 0.005098713568874754
# 567
# Correlation matrix for column 0 and and column567: 0.009430270029799022
# 568
# Correlation matrix for column 0 and and column568: 0.001624188940919218
# 569
# Correlation matrix for column 0 and and column569: 0.007975328215963013
# 570
# Correlation matrix for column 0 and and column570: 0.004910287739092901
# 571
# Correlation matrix for column 0 and and column571: -2.587979692367145e-05
# 572
# Correlation matrix for column 0 and and column572: 0.004564194176343486
# 573
# Correlation matrix for column 0 and and column573: 0.007118729047658821
# 574
# Correlation matrix for column 0 and and column574: 0.00542404740619474
# 575
# Correlation matrix for column 0 and and column575: -0.012924706928613259
# 576
# Correlation matrix for column 0 and and column576: -0.007693367962320552
# 577
# Correlation matrix for column 0 and and column577: -0.013674939395325202
# 578
# Correlation matrix for column 0 and and column578: 0.0023044963367390443
# 579
# Correlation matrix for column 0 and and column579: -0.0011748971111175265
# 580
# Correlation matrix for column 0 and and column580: -0.002107259970904671
# 581
# Correlation matrix for column 0 and and column581: -0.008261961139455057
# 582
# Correlation matrix for column 0 and and column582: -0.03677052110331598
# 583
# Correlation matrix for column 0 and and column583: 0.004358528277004444
# 584
# Correlation matrix for column 0 and and column584: 0.01236169029384031
# 585
# Correlation matrix for column 0 and and column585: -0.0031896992165956774
# 586
# Correlation matrix for column 0 and and column586: -0.010661317812551268
# 587
# Correlation matrix for column 0 and and column587: -0.0014720247234162698
# 588
# Correlation matrix for column 0 and and column588: -0.003309125762847481
# 589
# Correlation matrix for column 0 and and column589: 0.0007703446246574739
# 590
# Correlation matrix for column 0 and and column590: 0.01378630574334077
# 591
# Correlation matrix for column 0 and and column591: 0.00024056912073485134
# 592
# Correlation matrix for column 0 and and column592: 0.004205625821762679
# 593
# Correlation matrix for column 0 and and column593: 0.009366232539854498
# 594
# Correlation matrix for column 0 and and column594: -0.02084293281000058
# 595
# Correlation matrix for column 0 and and column595: -0.0001222199938318357
# 596
# Correlation matrix for column 0 and and column596: -0.004472690359536831
# 597
# Correlation matrix for column 0 and and column597: -0.001251231821121204
# 598
# Correlation matrix for column 0 and and column598: -0.00399006010391833
# 599
# Correlation matrix for column 0 and and column599: -0.0008654750736262051
# 600
# Correlation matrix for column 0 and and column600: 0.0009356642588009582
# 601
# Correlation matrix for column 0 and and column601: -0.0003335754521445954
# 602
# Correlation matrix for column 0 and and column602: 0.006854092076463443
# 603
# Correlation matrix for column 0 and and column603: -0.003907684458158129
# 604
# Correlation matrix for column 0 and and column604: -0.004462630685944405
# 605
# Correlation matrix for column 0 and and column605: 0.0039945175029835935
# 606
# Correlation matrix for column 0 and and column606: -0.000594224923559506
# 607
# Correlation matrix for column 0 and and column607: -0.00027819300382866377
# 608
# Correlation matrix for column 0 and and column608: 0.02650618676790542
# 609
# Correlation matrix for column 0 and and column609: -0.022303368999297617
# 610
# Correlation matrix for column 0 and and column610: -0.00725331099439775
# 611
# Correlation matrix for column 0 and and column611: 0.002095160601455718
# 612
# Correlation matrix for column 0 and and column612: -0.0059285259028210744
# 613
# Correlation matrix for column 0 and and column613: -0.0032511389992523347
# 614
# Correlation matrix for column 0 and and column614: -0.0018312632595478503
# 615
# Correlation matrix for column 0 and and column615: 0.0013888308997683793
# 616
# Correlation matrix for column 0 and and column616: -0.008635571892957822
# 617
# Correlation matrix for column 0 and and column617: 0.006061395421806302
# 618
# Correlation matrix for column 0 and and column618: 0.0005702794424046154
# 619
# Correlation matrix for column 0 and and column619: -0.005324756217609452
# 620
# Correlation matrix for column 0 and and column620: 0.016985384151944283
# 621
# Correlation matrix for column 0 and and column621: -0.00107119859349631
# 622
# Correlation matrix for column 0 and and column622: 0.0013154575914755121
# 623
# Correlation matrix for column 0 and and column623: 0.010801230258769402
# 624
# Correlation matrix for column 0 and and column624: -0.005974831372406669
# 625
# Correlation matrix for column 0 and and column625: -0.0009945630130645529
# 626
# Correlation matrix for column 0 and and column626: 0.0023470776082062266
# 627
# ...
# 7691
# Correlation matrix for column 0 and and column7691: -0.006066198630973786
# 7692
# Correlation matrix for column 0 and and column7692: 0.02492880179281682
# 7693
# Correlation matrix for column 0 and and column7693: 0.015834499547455593
# 7694
# Correlation matrix for column 0 and and column7694: 0.0013966768198233853
# 7695
# Correlation matrix for column 0 and and column7695: 0.0036046686028410827
# 7696
# Correlation matrix for column 0 and and column7696: -0.001289607268746396
# 7697
# Correlation matrix for column 0 and and column7697: 0.005793715637215475
# 7698
# Correlation matrix for column 0 and and column7698: 0.003524547059124628
# 7699
# Correlation matrix for column 0 and and column7699: 0.006104779717587573
# 7700
# Correlation matrix for column 0 and and column7700: 0.0024629572784534803
# 7701
# Correlation matrix for column 0 and and column7701: 0.0051335951359244535
# 7702
# Correlation matrix for column 0 and and column7702: 0.010977394279894198
# 7703
# Correlation matrix for column 0 and and column7703: -0.005032710882531684
# 7704
# Correlation matrix for column 0 and and column7704: 0.0003395530540242014
# 7705
# Correlation matrix for column 0 and and column7705: -0.016658836049263954
# 7706
# Correlation matrix for column 0 and and column7706: -0.012494162197492513
# 7707
# Correlation matrix for column 0 and and column7707: -0.0008200634574980728
# 7708
# Correlation matrix for column 0 and and column7708: -0.0004864906367607699
# 7709
# Correlation matrix for column 0 and and column7709: -0.01908947293295528
# 7710
# Correlation matrix for column 0 and and column7710: -0.010460940918955438
# 7711
# Correlation matrix for column 0 and and column7711: 0.0052341317996151705
# 7712
# Correlation matrix for column 0 and and column7712: 0.0017743151888496179
# 7713
# Correlation matrix for column 0 and and column7713: 0.034568666463099244
# 7714
# Correlation matrix for column 0 and and column7714: 0.005786195788491532
# 7715
# Correlation matrix for column 0 and and column7715: -0.005431166504849014
# 7716
# Correlation matrix for column 0 and and column7716: 0.0075340623111437065
# 7717
# Correlation matrix for column 0 and and column7717: -0.009968823059528505
# 7718
# Correlation matrix for column 0 and and column7718: 0.015402781171390885
# 7719
# Correlation matrix for column 0 and and column7719: 0.0054767440234844075
# 7720
# Correlation matrix for column 0 and and column7720: 0.008622023518582267
# 7721
# Correlation matrix for column 0 and and column7721: -0.008397994795025803
# 7722
# Correlation matrix for column 0 and and column7722: -0.007024641591402092
# 7723
# Correlation matrix for column 0 and and column7723: 0.00940003255955902
# 7724
# Correlation matrix for column 0 and and column7724: -0.0005156157882167081
# 7725
# Correlation matrix for column 0 and and column7725: 0.002034958239113575
# 7726
# Correlation matrix for column 0 and and column7726: -0.00068496022322964
# 7727
# Correlation matrix for column 0 and and column7727: 0.00041267805324780854
# 7728
# Correlation matrix for column 0 and and column7728: 0.0006379247276681087
# 7729
# Correlation matrix for column 0 and and column7729: 0.002650924669583081
# 7730
# Correlation matrix for column 0 and and column7730: -0.00772200031708297
# 7731
# Correlation matrix for column 0 and and column7731: 0.00524606234679204
# 7732
# Correlation matrix for column 0 and and column7732: -0.006016900604241153
# 7733
# Correlation matrix for column 0 and and column7733: 0.00810446209055317
# 7734
# Correlation matrix for column 0 and and column7734: 0.007741812307547559
# 7735
# Correlation matrix for column 0 and and column7735: 0.014223585861824673
# 7736
# Correlation matrix for column 0 and and column7736: 0.009283060150287863
# 7737
# Correlation matrix for column 0 and and column7737: -0.006071405380684718
# 7738
# Correlation matrix for column 0 and and column7738: -0.011484627593905828
# 7739
# Correlation matrix for column 0 and and column7739: 0.01397729405380768
# 7740
# Correlation matrix for column 0 and and column7740: 0.0047357020018685345
# 7741
# Correlation matrix for column 0 and and column7741: 0.018187207402319393
# 7742
# Correlation matrix for column 0 and and column7742: -0.005259523960556007
# 7743
# Correlation matrix for column 0 and and column7743: -0.0016093885207414148
# 7744
# Correlation matrix for column 0 and and column7744: -0.017836198951796698
# 7745
# Correlation matrix for column 0 and and column7745: 0.013592265094655722
# 7746
# Correlation matrix for column 0 and and column7746: -0.002070332579516767
# 7747
# Correlation matrix for column 0 and and column7747: 0.021328703868852446
# 7748
# Correlation matrix for column 0 and and column7748: 0.0034552742709929884
# 7749
# Correlation matrix for column 0 and and column7749: -0.01650134759161376
# 7750
# Correlation matrix for column 0 and and column7750: -0.015331930498295242
# 7751
# Correlation matrix for column 0 and and column7751: -0.0032716793236763652
# 7752
# Correlation matrix for column 0 and and column7752: -0.037302285986810756
# 7753
# Correlation matrix for column 0 and and column7753: -0.00799106094128041
# 7754
# Correlation matrix for column 0 and and column7754: 0.006626239896872439
# 7755
# Correlation matrix for column 0 and and column7755: -0.005778569770558531
# 7756
# Correlation matrix for column 0 and and column7756: -0.006658380486876683
# 7757
# Correlation matrix for column 0 and and column7757: -0.009602293676182979
# 7758
# Correlation matrix for column 0 and and column7758: -0.02638225844949275
# 7759
# Correlation matrix for column 0 and and column7759: -0.006837086163712168
# 7760
# Correlation matrix for column 0 and and column7760: 0.014162294208616087
# 7761
# Correlation matrix for column 0 and and column7761: -0.0016017248240301804
# 7762
# Correlation matrix for column 0 and and column7762: 0.0020041865809656213
# 7763
# Correlation matrix for column 0 and and column7763: 0.0017289818241603742
# 7764
# Correlation matrix for column 0 and and column7764: -0.012902339098983502
# 7765
# Correlation matrix for column 0 and and column7765: 0.006888987145777934
# 7766
# Correlation matrix for column 0 and and column7766: -0.002547754803604668
# 7767
# Correlation matrix for column 0 and and column7767: 0.013885609646089876
# 7768
# Correlation matrix for column 0 and and column7768: -0.0029168457228776956
# 7769
# Correlation matrix for column 0 and and column7769: -0.006297497769105496
# 7770
# Correlation matrix for column 0 and and column7770: -0.0014431835885444942
# 7771
# Correlation matrix for column 0 and and column7771: -0.006736169071564591
# 7772
# Correlation matrix for column 0 and and column7772: -0.01569253948188754
# 7773
# Correlation matrix for column 0 and and column7773: -0.0005475340035618045
# 7774
# Correlation matrix for column 0 and and column7774: 0.01723436852548017
# 7775
# Correlation matrix for column 0 and and column7775: -0.0035863644291850953
# 7776
# Correlation matrix for column 0 and and column7776: -0.003842491377204429
# 7777
# Correlation matrix for column 0 and and column7777: -0.004468348089224126
# 7778
# Correlation matrix for column 0 and and column7778: 0.003345414008876987
# 7779
# Correlation matrix for column 0 and and column7779: -0.005819854536103054
# 7780
# Correlation matrix for column 0 and and column7780: 0.020208410320866167
# 7781
# Correlation matrix for column 0 and and column7781: 0.026025373531174553
# 7782
# Correlation matrix for column 0 and and column7782: 0.009694381027212736
# 7783
# Correlation matrix for column 0 and and column7783: 0.012834305597065339
# 7784
# Correlation matrix for column 0 and and column7784: -0.005485544341253286
# 7785
# Correlation matrix for column 0 and and column7785: 0.001643202229175073
# 7786
# Correlation matrix for column 0 and and column7786: 0.016448550827351915
# 7787
# Correlation matrix for column 0 and and column7787: -0.008898164512467112
# 7788
# Correlation matrix for column 0 and and column7788: -0.004135161949855608
# 7789
# Correlation matrix for column 0 and and column7789: -0.007110385305566186
# 7790
# Correlation matrix for column 0 and and column7790: -0.003841037836071361
# 7791
# Correlation matrix for column 0 and and column7791: 0.008875485296427179
# 7792
# Correlation matrix for column 0 and and column7792: -0.0018820678301102005
# 7793
# Correlation matrix for column 0 and and column7793: -0.018825708107457217
# 7794
# Correlation matrix for column 0 and and column7794: -0.00817066626280244
# 7795
# Correlation matrix for column 0 and and column7795: -0.01432123061681611
# 7796
# Correlation matrix for column 0 and and column7796: 0.014270053206221645
# 7797
# Correlation matrix for column 0 and and column7797: -0.011960329640227045
# 7798
# Correlation matrix for column 0 and and column7798: -0.007732260815787365
# 7799
# Correlation matrix for column 0 and and column7799: 0.004334857406337343
# 7800
# Correlation matrix for column 0 and and column7800: 0.005959209412842067
# 7801
# Correlation matrix for column 0 and and column7801: 0.0017397537548532644
# 7802
# Correlation matrix for column 0 and and column7802: 0.011460342649926542
# 7803
# Correlation matrix for column 0 and and column7803: 0.0009760450052845004
# 7804
# Correlation matrix for column 0 and and column7804: -0.018991658339907864
# 7805
# Correlation matrix for column 0 and and column7805: -0.00041723597874469327
# 7806
# Correlation matrix for column 0 and and column7806: -0.005991057184729795
# 7807
# Correlation matrix for column 0 and and column7807: -0.0033157102177800287
# 7808
# Correlation matrix for column 0 and and column7808: 0.0036202388982451415
# 7809
# Correlation matrix for column 0 and and column7809: 0.005833785555805727
# 7810
# Correlation matrix for column 0 and and column7810: -0.0024340319223992352
# 7811
# Correlation matrix for column 0 and and column7811: -0.0030749604695289004
# 7812
# Correlation matrix for column 0 and and column7812: -0.022308364344999287
# 7813
# Correlation matrix for column 0 and and column7813: 0.015416508644445812
# 7814
# Correlation matrix for column 0 and and column7814: -0.0005795754259348497
# 7815
# Correlation matrix for column 0 and and column7815: 0.004411654119223322
# 7816
# Correlation matrix for column 0 and and column7816: 0.0077001193602296136
# 7817
# Correlation matrix for column 0 and and column7817: -0.01060302559692012
# 7818
# Correlation matrix for column 0 and and column7818: 0.004819168855796484
# 7819
# Correlation matrix for column 0 and and column7819: 0.01644269123008061
# 7820
# Correlation matrix for column 0 and and column7820: -0.00026629133870470473
# 7821
# Correlation matrix for column 0 and and column7821: -0.010132265553231127
# 7822
# Correlation matrix for column 0 and and column7822: 0.0034368115925149582
# 7823
# Correlation matrix for column 0 and and column7823: 0.021938243607321974
# 7824
# Correlation matrix for column 0 and and column7824: 0.0045668627732151305
# 7825
# Correlation matrix for column 0 and and column7825: 0.00471496516911527
# 7826
# Correlation matrix for column 0 and and column7826: -0.016213282678784607
# 7827
# Correlation matrix for column 0 and and column7827: -0.0207277004984472
# 7828
# Correlation matrix for column 0 and and column7828: -0.002411538470070074
# 7829
# Correlation matrix for column 0 and and column7829: -0.013368553954096378
# 7830
# Correlation matrix for column 0 and and column7830: -0.0007322368811804556
# 7831
# Correlation matrix for column 0 and and column7831: -0.005811858392652612
# 7832
# Correlation matrix for column 0 and and column7832: -0.016917982277129297
# 7833
# Correlation matrix for column 0 and and column7833: -0.014369997927203539
# 7834
# Correlation matrix for column 0 and and column7834: 0.0008479467558260707
# 7835
# Correlation matrix for column 0 and and column7835: 0.010794604196417725
# 7836
# Correlation matrix for column 0 and and column7836: 0.013345701836955397
# 7837
# Correlation matrix for column 0 and and column7837: 0.0037497016406686503
# 7838
# Correlation matrix for column 0 and and column7838: -0.0035790561535377356
# 7839
# Correlation matrix for column 0 and and column7839: -0.00805656523536945
# 7840
# Correlation matrix for column 0 and and column7840: 0.00867929291976624
# 7841
# Correlation matrix for column 0 and and column7841: 0.007888099703087306
# 7842
# Correlation matrix for column 0 and and column7842: 0.021919383394668864
# 7843
# Correlation matrix for column 0 and and column7843: 0.003980226385619234
# 7844
# Correlation matrix for column 0 and and column7844: 0.010578194676651654
# 7845
# Correlation matrix for column 0 and and column7845: 0.008344077753887168
# 7846
# Correlation matrix for column 0 and and column7846: 0.018470910703045622
# 7847
# Correlation matrix for column 0 and and column7847: -0.013942869580253654
# 7848
# Correlation matrix for column 0 and and column7848: 0.0027596677079232725
# 7849
# Correlation matrix for column 0 and and column7849: 0.0027867659111363604
# 7850
# Correlation matrix for column 0 and and column7850: -0.00222273825655646
# 7851
# Correlation matrix for column 0 and and column7851: 0.016836475877631193
# 7852
# Correlation matrix for column 0 and and column7852: 0.03206327597119265
# 7853
# Correlation matrix for column 0 and and column7853: -0.0023262914986579013
# 7854
# Correlation matrix for column 0 and and column7854: 0.009099053285938331
# 7855
# Correlation matrix for column 0 and and column7855: -0.0010022899637978095
# 7856
# Correlation matrix for column 0 and and column7856: -0.013941179208433557
# 7857
# Correlation matrix for column 0 and and column7857: 0.009904940264777288
# 7858
# Correlation matrix for column 0 and and column7858: 0.0017525603763938664
# 7859
# Correlation matrix for column 0 and and column7859: -0.021775356064814955
# 7860
# Correlation matrix for column 0 and and column7860: 0.0012619837484256252
# 7861
# Correlation matrix for column 0 and and column7861: 0.002457719999079591
# 7862
# Correlation matrix for column 0 and and column7862: -0.009989012533101178
# 7863
# Correlation matrix for column 0 and and column7863: 0.006385252929257394
# 7864
# Correlation matrix for column 0 and and column7864: 0.014586176864287882
# 7865
# Correlation matrix for column 0 and and column7865: -0.0072115374177342565
# 7866
# Correlation matrix for column 0 and and column7866: 0.0002516235929231569
# 7867
# Correlation matrix for column 0 and and column7867: 0.025009854366480448
# 7868
# Correlation matrix for column 0 and and column7868: -0.005966268453996611
# 7869
# Correlation matrix for column 0 and and column7869: 0.010391098212299289
# 7870
# Correlation matrix for column 0 and and column7870: 0.0013957079749594814
# 7871
# Correlation matrix for column 0 and and column7871: 0.01267955120441031
# 7872
# Correlation matrix for column 0 and and column7872: 0.002460636601812333
# 7873
# Correlation matrix for column 0 and and column7873: -0.009388008579711097
# 7874
# Correlation matrix for column 0 and and column7874: 0.00532694597317165
# 7875
# Correlation matrix for column 0 and and column7875: 0.009386317549407854
# 7876
# Correlation matrix for column 0 and and column7876: 0.005862388628795057
# 7877
# Correlation matrix for column 0 and and column7877: -0.0020870196108530217
# 7878
# Correlation matrix for column 0 and and column7878: -0.00010776033577485588
# 7879
# Correlation matrix for column 0 and and column7879: -0.00635515646858084
# 7880
# Correlation matrix for column 0 and and column7880: 0.013980825634889487
# 7881
# Correlation matrix for column 0 and and column7881: -0.0058018223201107095
# 7882
# Correlation matrix for column 0 and and column7882: -0.0004514137138615086
# 7883
# Correlation matrix for column 0 and and column7883: 0.002841334718561578
# 7884
# Correlation matrix for column 0 and and column7884: 0.007162945842851689
# 7885
# Correlation matrix for column 0 and and column7885: 0.008584188552622572
# 7886
# Correlation matrix for column 0 and and column7886: -0.012960555976537455
# 7887
# Correlation matrix for column 0 and and column7887: 0.014866301641323505
# 7888
# Correlation matrix for column 0 and and column7888: 0.009113785738710143
# 7889
# Correlation matrix for column 0 and and column7889: 0.000835846672282431
# 7890
# Correlation matrix for column 0 and and column7890: -0.015765042025570143
# 7891
# Correlation matrix for column 0 and and column7891: 0.006538120274103588
# 7892
# Correlation matrix for column 0 and and column7892: -0.009391340427431618
# 7893
# Correlation matrix for column 0 and and column7893: -0.003001259047900565

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")
# Out:
# Percentage of correlations in df1: 39.0 %
# Percentage of correlations in df_new: 34.01748384644622 %

# %% [markdown]
# Random Projection seems to have a slight effect on the correlations, however the number of spurious correlations is still significant which would mean that either the number of dimensions has to be increased to augment the efficiency of the method. Otherwise sacrificing some data fidelity through a higher distortion defined in the parameter eps is another possibility.
