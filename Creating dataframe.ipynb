# %% [markdown]
# # Spurious Correlations of Highly Dimensional Big Data

# %% [markdown]
# This Notebook aims at showing how PCA and random projection can solve the problem of spurious correlations in Big Data.

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.utils import shuffle

# %%
# User defined parameters

# Number of rows for df1
x = 10000
print(x)

# Number of columns for df1
y = 200000

# Number of rows for df2
z = 1000
# Out:
# 10000

# %%
# Creating a dataframe with x number of rows and y number of columns
df = pd.DataFrame(np.random.random_sample((x,y)))
df
# Out:
#         0         1         2         3         4         5         6       \
# 0     0.683541  0.018479  0.357882  0.681310  0.447448  0.598510  0.124120
# 1     0.827127  0.473744  0.547709  0.097834  0.480502  0.960953  0.667213
# 2     0.929321  0.373383  0.937262  0.279188  0.898340  0.396706  0.395249
# 3     0.669256  0.761206  0.647999  0.893389  0.087763  0.398732  0.699660
# 4     0.153948  0.006564  0.293203  0.002775  0.026068  0.006733  0.999795
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.741071  0.019029  0.726753  0.045537  0.636693  0.836929  0.093999
# 9996  0.685906  0.602061  0.585465  0.409683  0.720429  0.850826  0.618792
# 9997  0.056428  0.032820  0.501168  0.791639  0.725606  0.565231  0.828117
# 9998  0.968585  0.287188  0.518795  0.353105  0.819224  0.899140  0.735084
# 9999  0.959810  0.211951  0.839366  0.208443  0.129852  0.051106  0.456479
#
#         7         8         9       ...    199990    199991    199992  \
# 0     0.026100  0.892880  0.790828  ...  0.785743  0.987288  0.587592
# 1     0.029142  0.544869  0.029782  ...  0.147390  0.316055  0.891719
# 2     0.085978  0.535766  0.352000  ...  0.372708  0.331071  0.823048
# 3     0.116835  0.825984  0.666978  ...  0.774387  0.791663  0.092473
# 4     0.351303  0.612944  0.640485  ...  0.444889  0.689587  0.771937
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.314873  0.654295  0.301487  ...  0.478707  0.315784  0.983865
# 9996  0.318580  0.570577  0.920668  ...  0.213659  0.924116  0.411273
# 9997  0.597243  0.007799  0.331962  ...  0.216443  0.145054  0.951711
# 9998  0.302363  0.593943  0.153128  ...  0.630912  0.062861  0.266355
# 9999  0.350714  0.425154  0.742259  ...  0.497373  0.280164  0.898522
#
#         199993    199994    199995    199996    199997    199998    199999
# 0     0.546459  0.181415  0.818808  0.184176  0.668079  0.347183  0.707497
# 1     0.825268  0.782924  0.101897  0.650957  0.081078  0.441026  0.386312
# 2     0.698590  0.825034  0.672430  0.670454  0.542668  0.040608  0.398071
# 3     0.203856  0.140118  0.459813  0.687499  0.229563  0.706178  0.919847
# 4     0.902576  0.301864  0.389987  0.739029  0.607980  0.586038  0.148765
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.113627  0.419265  0.209850  0.296888  0.764054  0.570778  0.936255
# 9996  0.638701  0.433407  0.526492  0.612638  0.148246  0.185502  0.203919
# 9997  0.482814  0.676325  0.616729  0.444121  0.248416  0.777552  0.403724
# 9998  0.701662  0.445077  0.107632  0.429528  0.886163  0.737584  0.839082
# 9999  0.983063  0.662837  0.621518  0.905277  0.487128  0.106873  0.838766
#
# [10000 rows x 200000 columns]

# %% [markdown]
# In order to assess the correlations of the different parameters, correlations between the column with index 0 and the 99 other first columns is assessed.

# %%
# Assigning X to all columns except 0
X_df = df.drop(columns=0)
X_df.head()

# Assigning Y to column 0
Y_df = df[0]
print(Y_df)

# The following line makes Y become a list
Y_df = np.array(Y_df).reshape(-1)
print(X_df.shape,Y_df.shape)

list_titles = X_df.columns
list_corr_df1 = []
for i in list_titles[0:1000]:
    print(i)
    list_corr_df1.append(abs(np.corrcoef(Y_df, X_df[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df, X_df[i])[0][1]))
# Out:
# 0       0.683541
# 1       0.827127
# 2       0.929321
# 3       0.669256
# 4       0.153948
#           ...
# 9995    0.741071
# 9996    0.685906
# 9997    0.056428
# 9998    0.968585
# 9999    0.959810
# Name: 0, Length: 10000, dtype: float64
# (10000, 199999) (10000,)
# 1
# Correlation matrix for column 0 and and column1: 0.005204561553717579
# 2
# Correlation matrix for column 0 and and column2: 0.005883334136098834
# 3
# Correlation matrix for column 0 and and column3: -0.0011400525660891913
# 4
# Correlation matrix for column 0 and and column4: -0.013393150349447307
# 5
# Correlation matrix for column 0 and and column5: -0.004535673138091676
# 6
# Correlation matrix for column 0 and and column6: -0.0007679309042347035
# 7
# Correlation matrix for column 0 and and column7: 0.012319691810831751
# 8
# Correlation matrix for column 0 and and column8: 0.02196116383262485
# 9
# Correlation matrix for column 0 and and column9: -0.009096636271847714
# 10
# Correlation matrix for column 0 and and column10: -0.002522116763103136
# 11
# Correlation matrix for column 0 and and column11: 0.01883894934567572
# 12
# Correlation matrix for column 0 and and column12: 0.005309017329950307
# 13
# Correlation matrix for column 0 and and column13: -0.013886493521853834
# 14
# Correlation matrix for column 0 and and column14: 0.0014615919986913555
# 15
# Correlation matrix for column 0 and and column15: 0.012100984653274445
# 16
# Correlation matrix for column 0 and and column16: -0.013730127425687572
# 17
# Correlation matrix for column 0 and and column17: 0.011519083233550808
# 18
# Correlation matrix for column 0 and and column18: 0.0034155264535926937
# 19
# Correlation matrix for column 0 and and column19: 0.00022486052130187776
# 20
# Correlation matrix for column 0 and and column20: -0.008745266276776444
# 21
# Correlation matrix for column 0 and and column21: -0.005312911184061991
# 22
# Correlation matrix for column 0 and and column22: 0.004327578478431187
# 23
# Correlation matrix for column 0 and and column23: 0.012223054359544717
# 24
# Correlation matrix for column 0 and and column24: -0.004214246493634305
# 25
# Correlation matrix for column 0 and and column25: -0.003395929715348676
# 26
# Correlation matrix for column 0 and and column26: 0.004155682578634106
# 27
# Correlation matrix for column 0 and and column27: -0.012168371056205253
# 28
# Correlation matrix for column 0 and and column28: 0.015241039596256176
# 29
# Correlation matrix for column 0 and and column29: 0.00462266868772282
# 30
# Correlation matrix for column 0 and and column30: 0.007825658370037977
# 31
# Correlation matrix for column 0 and and column31: 0.005612597984764268
# 32
# Correlation matrix for column 0 and and column32: 0.0036354745097923573
# 33
# Correlation matrix for column 0 and and column33: -0.00238393386232938
# 34
# Correlation matrix for column 0 and and column34: -0.015474576822961628
# 35
# Correlation matrix for column 0 and and column35: -0.013103208575638577
# 36
# Correlation matrix for column 0 and and column36: 0.0014234740475626074
# 37
# Correlation matrix for column 0 and and column37: 0.0005690029940987813
# 38
# Correlation matrix for column 0 and and column38: -0.005070570609372165
# 39
# Correlation matrix for column 0 and and column39: 0.007463005138885923
# 40
# Correlation matrix for column 0 and and column40: 0.008214725756492671
# 41
# Correlation matrix for column 0 and and column41: -0.005841114934953062
# 42
# Correlation matrix for column 0 and and column42: -0.00027043254109764746
# 43
# Correlation matrix for column 0 and and column43: 0.006955328721029525
# 44
# Correlation matrix for column 0 and and column44: 0.00107848754190296
# 45
# Correlation matrix for column 0 and and column45: -0.008191468994195168
# 46
# Correlation matrix for column 0 and and column46: 0.0009300881216619774
# 47
# Correlation matrix for column 0 and and column47: 0.004747178777059277
# 48
# Correlation matrix for column 0 and and column48: 0.0005079010802308297
# 49
# Correlation matrix for column 0 and and column49: 0.0022042167377483894
# 50
# Correlation matrix for column 0 and and column50: 0.007217315093915815
# 51
# Correlation matrix for column 0 and and column51: 0.0010990735501004692
# 52
# Correlation matrix for column 0 and and column52: 0.007250374907080764
# 53
# Correlation matrix for column 0 and and column53: 0.004186687023527271
# 54
# Correlation matrix for column 0 and and column54: -0.014187684571576785
# 55
# Correlation matrix for column 0 and and column55: 0.02221846472629319
# 56
# Correlation matrix for column 0 and and column56: 0.0075068179996633415
# 57
# Correlation matrix for column 0 and and column57: -0.01173472995221654
# 58
# Correlation matrix for column 0 and and column58: 0.0025961032257338225
# 59
# Correlation matrix for column 0 and and column59: 0.001982438697227604
# 60
# Correlation matrix for column 0 and and column60: 0.0005354037749525104
# 61
# Correlation matrix for column 0 and and column61: -0.004268776755480191
# 62
# Correlation matrix for column 0 and and column62: 0.003489144018646257
# 63
# Correlation matrix for column 0 and and column63: 0.023712029139546197
# 64
# Correlation matrix for column 0 and and column64: 0.010404868243020754
# 65
# Correlation matrix for column 0 and and column65: -0.005740656617610177
# 66
# Correlation matrix for column 0 and and column66: 0.015925271953564458
# 67
# Correlation matrix for column 0 and and column67: -0.008487296180416971
# 68
# Correlation matrix for column 0 and and column68: 0.016246969877147344
# 69
# Correlation matrix for column 0 and and column69: -0.009652188294800898
# 70
# Correlation matrix for column 0 and and column70: 0.006533645584520187
# 71
# Correlation matrix for column 0 and and column71: 0.0001287463017113474
# 72
# Correlation matrix for column 0 and and column72: 0.0043590384684458845
# 73
# Correlation matrix for column 0 and and column73: -0.0060769479071262796
# 74
# Correlation matrix for column 0 and and column74: 0.01314514568834492
# 75
# Correlation matrix for column 0 and and column75: 0.003143213574837109
# 76
# Correlation matrix for column 0 and and column76: -0.0087901575690092
# 77
# Correlation matrix for column 0 and and column77: -0.0039082398693892914
# 78
# Correlation matrix for column 0 and and column78: -0.010871167048393198
# 79
# Correlation matrix for column 0 and and column79: 0.019756370636980308
# 80
# Correlation matrix for column 0 and and column80: 0.013726858447503123
# 81
# Correlation matrix for column 0 and and column81: 0.020382304926251094
# 82
# Correlation matrix for column 0 and and column82: -0.016941040869665334
# 83
# Correlation matrix for column 0 and and column83: -0.012968268731196992
# 84
# Correlation matrix for column 0 and and column84: 0.013367599962826968
# 85
# Correlation matrix for column 0 and and column85: -0.0033974400183974887
# 86
# Correlation matrix for column 0 and and column86: -0.009509734308379897
# 87
# Correlation matrix for column 0 and and column87: -0.006521316136969584
# 88
# Correlation matrix for column 0 and and column88: 8.94111180916901e-05
# 89
# Correlation matrix for column 0 and and column89: 0.0024080552989222456
# 90
# Correlation matrix for column 0 and and column90: -0.0042204471516501425
# 91
# Correlation matrix for column 0 and and column91: 0.0009203742484970925
# 92
# Correlation matrix for column 0 and and column92: -0.0009909966965467893
# 93
# Correlation matrix for column 0 and and column93: 0.0036496658438164935
# 94
# Correlation matrix for column 0 and and column94: 0.0133935334330169
# 95
# Correlation matrix for column 0 and and column95: 0.004533215843768843
# 96
# Correlation matrix for column 0 and and column96: 0.0073002828982456705
# 97
# Correlation matrix for column 0 and and column97: -0.005280188324298846
# 98
# Correlation matrix for column 0 and and column98: -0.012933562984638354
# 99
# Correlation matrix for column 0 and and column99: -0.0013743872055306616
# 100
# Correlation matrix for column 0 and and column100: 0.005782894150237711
# 101
# Correlation matrix for column 0 and and column101: -0.010400057288530827
# 102
# Correlation matrix for column 0 and and column102: 0.002961923326049581
# 103
# Correlation matrix for column 0 and and column103: 0.005361512790375979
# 104
# Correlation matrix for column 0 and and column104: -0.0013444330571812158
# 105
# Correlation matrix for column 0 and and column105: -0.002304168612782408
# 106
# Correlation matrix for column 0 and and column106: 0.010374634133387947
# 107
# Correlation matrix for column 0 and and column107: -0.007452253075108113
# 108
# Correlation matrix for column 0 and and column108: -0.0027775973120361796
# 109
# Correlation matrix for column 0 and and column109: -0.005430607244502901
# 110
# Correlation matrix for column 0 and and column110: -0.002788059848933885
# 111
# Correlation matrix for column 0 and and column111: -0.0004960072818456525
# 112
# Correlation matrix for column 0 and and column112: -0.006432009252790235
# 113
# Correlation matrix for column 0 and and column113: -0.012000259237111864
# 114
# Correlation matrix for column 0 and and column114: 0.025010885894845625
# 115
# Correlation matrix for column 0 and and column115: -0.010205197906129348
# 116
# Correlation matrix for column 0 and and column116: -0.00931650001513144
# 117
# Correlation matrix for column 0 and and column117: 0.0037030801832600552
# 118
# Correlation matrix for column 0 and and column118: -0.00768869567718495
# 119
# Correlation matrix for column 0 and and column119: 7.86142363329614e-05
# 120
# Correlation matrix for column 0 and and column120: -0.007723210586679989
# 121
# Correlation matrix for column 0 and and column121: 0.0014309697005428085
# 122
# Correlation matrix for column 0 and and column122: -0.008637684617373973
# 123
# Correlation matrix for column 0 and and column123: -0.022904523300391937
# 124
# Correlation matrix for column 0 and and column124: -0.0006407550209063088
# 125
# Correlation matrix for column 0 and and column125: 0.004735101116302653
# 126
# Correlation matrix for column 0 and and column126: 0.004992089934344456
# 127
# Correlation matrix for column 0 and and column127: 0.001586927367302704
# 128
# Correlation matrix for column 0 and and column128: -0.004595721064631615
# 129
# Correlation matrix for column 0 and and column129: 0.002648138761150019
# 130
# Correlation matrix for column 0 and and column130: 0.012017704451079124
# 131
# Correlation matrix for column 0 and and column131: -0.011085281476286686
# 132
# Correlation matrix for column 0 and and column132: 0.003860586001041451
# 133
# Correlation matrix for column 0 and and column133: -0.01917947917662832
# 134
# Correlation matrix for column 0 and and column134: 0.018786426067370923
# 135
# Correlation matrix for column 0 and and column135: 0.006084954520176833
# 136
# Correlation matrix for column 0 and and column136: 0.003567258697232728
# 137
# Correlation matrix for column 0 and and column137: -0.002607494361008733
# 138
# Correlation matrix for column 0 and and column138: -0.0034171653372238346
# 139
# Correlation matrix for column 0 and and column139: 0.011401806572031076
# 140
# Correlation matrix for column 0 and and column140: 0.0028418389672685905
# 141
# Correlation matrix for column 0 and and column141: -0.0023230493342666883
# 142
# Correlation matrix for column 0 and and column142: -0.014155076015407728
# 143
# Correlation matrix for column 0 and and column143: -0.007301278706167281
# 144
# Correlation matrix for column 0 and and column144: 0.0070557416007049545
# 145
# Correlation matrix for column 0 and and column145: 0.0023104904642659045
# 146
# Correlation matrix for column 0 and and column146: 0.01959379483686055
# 147
# Correlation matrix for column 0 and and column147: -0.018777425536203717
# 148
# Correlation matrix for column 0 and and column148: 0.010768975229854504
# 149
# Correlation matrix for column 0 and and column149: -7.968438767438767e-05
# 150
# Correlation matrix for column 0 and and column150: -0.014418514179945172
# 151
# Correlation matrix for column 0 and and column151: -0.009395396492063493
# 152
# Correlation matrix for column 0 and and column152: -0.005228113310072149
# 153
# Correlation matrix for column 0 and and column153: -0.006075561520663785
# 154
# Correlation matrix for column 0 and and column154: 0.005125996683776873
# 155
# Correlation matrix for column 0 and and column155: 0.0032509414210847533
# 156
# Correlation matrix for column 0 and and column156: -0.014405672660538337
# 157
# Correlation matrix for column 0 and and column157: 0.011075522795563092
# 158
# Correlation matrix for column 0 and and column158: -0.005724610195134747
# 159
# Correlation matrix for column 0 and and column159: 0.016972629676368194
# 160
# Correlation matrix for column 0 and and column160: -0.013953309379836461
# 161
# Correlation matrix for column 0 and and column161: -0.007398538025602568
# 162
# Correlation matrix for column 0 and and column162: -0.013394843040710395
# 163
# Correlation matrix for column 0 and and column163: -0.011766595038521864
# 164
# Correlation matrix for column 0 and and column164: 0.0038994071577098666
# 165
# Correlation matrix for column 0 and and column165: -0.0007308104904993155
# 166
# Correlation matrix for column 0 and and column166: 0.0035323771673644957
# 167
# Correlation matrix for column 0 and and column167: 0.004266584030887776
# 168
# Correlation matrix for column 0 and and column168: 0.012276023899673685
# 169
# Correlation matrix for column 0 and and column169: 0.010888581593837661
# 170
# Correlation matrix for column 0 and and column170: 0.00032465398614747845
# 171
# Correlation matrix for column 0 and and column171: 0.010155625070276175
# 172
# Correlation matrix for column 0 and and column172: 0.014337216255187166
# 173
# Correlation matrix for column 0 and and column173: 0.0098003082223538
# 174
# Correlation matrix for column 0 and and column174: -0.006364278926424817
# 175
# Correlation matrix for column 0 and and column175: -0.007414983797596353
# 176
# Correlation matrix for column 0 and and column176: 0.0054802425141811835
# 177
# Correlation matrix for column 0 and and column177: 0.002917942332544273
# 178
# Correlation matrix for column 0 and and column178: 0.012760844577211402
# 179
# Correlation matrix for column 0 and and column179: 0.015489018883467341
# 180
# Correlation matrix for column 0 and and column180: 0.0039952698452149745
# 181
# Correlation matrix for column 0 and and column181: -0.008552017618756066
# 182
# Correlation matrix for column 0 and and column182: -0.008078531385299077
# 183
# Correlation matrix for column 0 and and column183: 0.007238419792699871
# 184
# Correlation matrix for column 0 and and column184: 0.014615692856561956
# 185
# Correlation matrix for column 0 and and column185: 0.0024574124959225716
# 186
# Correlation matrix for column 0 and and column186: -0.017363722257370814
# 187
# Correlation matrix for column 0 and and column187: -0.011584604600872146
# 188
# Correlation matrix for column 0 and and column188: 0.0008833666321029296
# 189
# Correlation matrix for column 0 and and column189: 0.008014009890885907
# 190
# Correlation matrix for column 0 and and column190: -0.014427060919717564
# 191
# Correlation matrix for column 0 and and column191: -0.00036173160773924175
# 192
# Correlation matrix for column 0 and and column192: 0.0019233775544475874
# 193
# Correlation matrix for column 0 and and column193: 0.007798247075103127
# 194
# Correlation matrix for column 0 and and column194: 0.017056313416915107
# 195
# Correlation matrix for column 0 and and column195: -0.009931838087435887
# 196
# Correlation matrix for column 0 and and column196: 0.01367935147449089
# 197
# Correlation matrix for column 0 and and column197: -0.002290625369965571
# 198
# Correlation matrix for column 0 and and column198: 0.01619502017552495
# 199
# Correlation matrix for column 0 and and column199: 0.005107980947479667
# 200
# Correlation matrix for column 0 and and column200: -0.01299009417494279
# 201
# Correlation matrix for column 0 and and column201: 0.006597656596989464
# 202
# Correlation matrix for column 0 and and column202: 0.007040647648695917
# 203
# Correlation matrix for column 0 and and column203: 0.001714673856079637
# 204
# Correlation matrix for column 0 and and column204: 0.006436024886842977
# 205
# Correlation matrix for column 0 and and column205: 0.01220426646001929
# 206
# Correlation matrix for column 0 and and column206: 0.0038656818434850957
# 207
# Correlation matrix for column 0 and and column207: 0.00061308934201281
# 208
# Correlation matrix for column 0 and and column208: -0.0011335630926201223
# 209
# Correlation matrix for column 0 and and column209: -0.015996474785095263
# 210
# Correlation matrix for column 0 and and column210: 0.007147318399941533
# 211
# Correlation matrix for column 0 and and column211: 0.01641231139211549
# 212
# Correlation matrix for column 0 and and column212: -0.00889660295266345
# 213
# Correlation matrix for column 0 and and column213: 0.004072643576662462
# 214
# Correlation matrix for column 0 and and column214: 0.006546225106120337
# 215
# Correlation matrix for column 0 and and column215: 0.0013285364910053505
# 216
# Correlation matrix for column 0 and and column216: -0.0070851805359017596
# 217
# Correlation matrix for column 0 and and column217: -0.007303102856605338
# 218
# Correlation matrix for column 0 and and column218: -0.009731449991840106
# 219
# Correlation matrix for column 0 and and column219: 0.010592256058445186
# 220
# Correlation matrix for column 0 and and column220: -0.00603733543951083
# 221
# Correlation matrix for column 0 and and column221: 0.008276225260574751
# 222
# Correlation matrix for column 0 and and column222: -0.0016398200070948826
# 223
# Correlation matrix for column 0 and and column223: -0.0027348382475205894
# 224
# Correlation matrix for column 0 and and column224: 0.004248638612214498
# 225
# Correlation matrix for column 0 and and column225: -0.011803572120136396
# 226
# Correlation matrix for column 0 and and column226: -0.0017847495350704673
# 227
# Correlation matrix for column 0 and and column227: -0.0008211983990762821
# 228
# Correlation matrix for column 0 and and column228: 0.009382108875134486
# 229
# Correlation matrix for column 0 and and column229: 0.00975029920001189
# 230
# Correlation matrix for column 0 and and column230: 0.008378134105153602
# 231
# Correlation matrix for column 0 and and column231: 0.010275314122046297
# 232
# Correlation matrix for column 0 and and column232: 0.004000660474909227
# 233
# Correlation matrix for column 0 and and column233: 0.00509127294230283
# 234
# Correlation matrix for column 0 and and column234: -0.005440691531417265
# 235
# Correlation matrix for column 0 and and column235: -0.004361331588515272
# 236
# Correlation matrix for column 0 and and column236: 0.0058424997065688045
# 237
# Correlation matrix for column 0 and and column237: -0.005279954078303295
# 238
# Correlation matrix for column 0 and and column238: 0.003821208706442398
# 239
# Correlation matrix for column 0 and and column239: 0.010824059860641912
# 240
# Correlation matrix for column 0 and and column240: 0.0017039092593223522
# 241
# Correlation matrix for column 0 and and column241: 0.004154205545166176
# 242
# Correlation matrix for column 0 and and column242: 0.01789231595663138
# 243
# Correlation matrix for column 0 and and column243: 0.009909817333817628
# 244
# Correlation matrix for column 0 and and column244: -0.003349178055210816
# 245
# Correlation matrix for column 0 and and column245: -0.004755466633778439
# 246
# Correlation matrix for column 0 and and column246: -0.004034128885546748
# 247
# Correlation matrix for column 0 and and column247: -0.006826453182048199
# 248
# Correlation matrix for column 0 and and column248: 0.002295666516020529
# 249
# Correlation matrix for column 0 and and column249: -0.00015248272843102983
# 250
# Correlation matrix for column 0 and and column250: 0.013746131041285754
# 251
# Correlation matrix for column 0 and and column251: -0.009683676023886619
# 252
# Correlation matrix for column 0 and and column252: 0.015566808988908675
# 253
# Correlation matrix for column 0 and and column253: -0.004320813579412617
# 254
# Correlation matrix for column 0 and and column254: 0.007765241678607151
# 255
# Correlation matrix for column 0 and and column255: -0.005964287854641582
# 256
# Correlation matrix for column 0 and and column256: 0.009445218855316512
# 257
# Correlation matrix for column 0 and and column257: -0.0006232293631885659
# 258
# Correlation matrix for column 0 and and column258: -0.0037394652898197532
# 259
# Correlation matrix for column 0 and and column259: 0.01729550988805307
# 260
# Correlation matrix for column 0 and and column260: 0.003178016254790861
# 261
# Correlation matrix for column 0 and and column261: 0.0002647200853559823
# 262
# Correlation matrix for column 0 and and column262: -0.0017806083628232458
# 263
# Correlation matrix for column 0 and and column263: -0.0019457171157038116
# 264
# Correlation matrix for column 0 and and column264: 0.0033276234165906505
# 265
# Correlation matrix for column 0 and and column265: 0.00024344533642461447
# 266
# Correlation matrix for column 0 and and column266: -0.00021475800593261966
# 267
# Correlation matrix for column 0 and and column267: -0.009867528969083097
# 268
# Correlation matrix for column 0 and and column268: 0.0032553604323793434
# 269
# Correlation matrix for column 0 and and column269: -0.008422617263472876
# 270
# Correlation matrix for column 0 and and column270: 0.015483669618998058
# 271
# Correlation matrix for column 0 and and column271: 0.013790522850408209
# 272
# Correlation matrix for column 0 and and column272: 0.017439978636434244
# 273
# Correlation matrix for column 0 and and column273: 0.006197184809055646
# 274
# Correlation matrix for column 0 and and column274: -0.010003956057227113
# 275
# Correlation matrix for column 0 and and column275: 0.0029710759978885232
# 276
# Correlation matrix for column 0 and and column276: -0.003594705791293236
# 277
# Correlation matrix for column 0 and and column277: -0.005798086159092371
# 278
# Correlation matrix for column 0 and and column278: 0.00861161390078305
# 279
# Correlation matrix for column 0 and and column279: 0.00026725748119359595
# 280
# Correlation matrix for column 0 and and column280: 0.004149990285855063
# 281
# Correlation matrix for column 0 and and column281: -0.019796114142898166
# 282
# Correlation matrix for column 0 and and column282: 0.008367760524580633
# 283
# Correlation matrix for column 0 and and column283: 0.007367928417301898
# 284
# Correlation matrix for column 0 and and column284: 0.016105862347267356
# 285
# Correlation matrix for column 0 and and column285: -1.5490179584378454e-05
# 286
# Correlation matrix for column 0 and and column286: -0.004327068579235848
# 287
# Correlation matrix for column 0 and and column287: -0.0033089353682022268
# 288
# Correlation matrix for column 0 and and column288: -0.0004024452317930906
# 289
# Correlation matrix for column 0 and and column289: 0.0011703419962954353
# 290
# Correlation matrix for column 0 and and column290: 0.006554471526622515
# 291
# Correlation matrix for column 0 and and column291: 0.019087214136695493
# 292
# Correlation matrix for column 0 and and column292: 0.002654825365708758
# 293
# Correlation matrix for column 0 and and column293: 0.010708381525697776
# 294
# Correlation matrix for column 0 and and column294: 0.00018787412361578724
# 295
# Correlation matrix for column 0 and and column295: -0.007143709624349608
# 296
# Correlation matrix for column 0 and and column296: 0.008791675429052771
# 297
# Correlation matrix for column 0 and and column297: -0.006767523404661592
# 298
# Correlation matrix for column 0 and and column298: 0.016972124367960317
# 299
# Correlation matrix for column 0 and and column299: -0.010531240498791205
# 300
# Correlation matrix for column 0 and and column300: -0.007511659913393355
# 301
# Correlation matrix for column 0 and and column301: -0.0022948059400670676
# 302
# Correlation matrix for column 0 and and column302: 0.014503094217254467
# 303
# Correlation matrix for column 0 and and column303: -0.010588154122453394
# 304
# Correlation matrix for column 0 and and column304: -0.01238217478944979
# 305
# Correlation matrix for column 0 and and column305: 0.0042066024002651164
# 306
# Correlation matrix for column 0 and and column306: -0.0011533781419381653
# 307
# Correlation matrix for column 0 and and column307: 0.0011981261819356782
# 308
# Correlation matrix for column 0 and and column308: 0.0009153612340249826
# 309
# Correlation matrix for column 0 and and column309: -9.229287670858728e-05
# 310
# Correlation matrix for column 0 and and column310: 0.006116537151752709
# 311
# Correlation matrix for column 0 and and column311: -0.007406463821922028
# 312
# Correlation matrix for column 0 and and column312: -0.006033598635430022
# 313
# Correlation matrix for column 0 and and column313: 0.0004407118850570419
# 314
# Correlation matrix for column 0 and and column314: -0.01093702915382615
# 315
# Correlation matrix for column 0 and and column315: -0.014589829551440493
# 316
# Correlation matrix for column 0 and and column316: 0.004697306294517434
# 317
# Correlation matrix for column 0 and and column317: 0.016383042822620958
# 318
# Correlation matrix for column 0 and and column318: 0.012338372295554291
# 319
# Correlation matrix for column 0 and and column319: 0.008258743000286289
# 320
# Correlation matrix for column 0 and and column320: 0.0071024519267683245
# 321
# Correlation matrix for column 0 and and column321: -0.020431975783403156
# 322
# Correlation matrix for column 0 and and column322: 0.002131525180399782
# 323
# Correlation matrix for column 0 and and column323: -0.010293371082340658
# 324
# Correlation matrix for column 0 and and column324: 0.010717101711548053
# 325
# Correlation matrix for column 0 and and column325: -0.011655134306130245
# 326
# Correlation matrix for column 0 and and column326: -0.008821828793584842
# 327
# Correlation matrix for column 0 and and column327: 0.00092185703047191
# 328
# Correlation matrix for column 0 and and column328: -0.005146949454179453
# 329
# Correlation matrix for column 0 and and column329: 0.0008537369878569553
# 330
# Correlation matrix for column 0 and and column330: -0.010078501647586991
# 331
# Correlation matrix for column 0 and and column331: -0.011515727987154261
# 332
# Correlation matrix for column 0 and and column332: 0.008434252980561949
# 333
# Correlation matrix for column 0 and and column333: 0.006426541245116804
# 334
# Correlation matrix for column 0 and and column334: -0.0039473104843812225
# 335
# Correlation matrix for column 0 and and column335: 0.013485008598874767
# 336
# Correlation matrix for column 0 and and column336: 0.008649798142840134
# 337
# Correlation matrix for column 0 and and column337: -0.008627282374692864
# 338
# Correlation matrix for column 0 and and column338: -0.01718562273651598
# 339
# Correlation matrix for column 0 and and column339: -0.0064614822974037745
# 340
# Correlation matrix for column 0 and and column340: -0.018340946426483394
# 341
# Correlation matrix for column 0 and and column341: 0.002921124134935686
# 342
# Correlation matrix for column 0 and and column342: -0.0020028316312545934
# 343
# Correlation matrix for column 0 and and column343: -0.005753984837504914
# 344
# Correlation matrix for column 0 and and column344: 0.015590621267163273
# 345
# Correlation matrix for column 0 and and column345: 0.0074312910715804235
# 346
# Correlation matrix for column 0 and and column346: -0.011325343396228416
# 347
# Correlation matrix for column 0 and and column347: 0.017286526812975354
# 348
# Correlation matrix for column 0 and and column348: 0.0017181678305820982
# 349
# Correlation matrix for column 0 and and column349: -0.0010403039996355564
# 350
# Correlation matrix for column 0 and and column350: -0.0014825159920800837
# 351
# Correlation matrix for column 0 and and column351: 0.017309344142099496
# 352
# Correlation matrix for column 0 and and column352: -0.009828066597625576
# 353
# Correlation matrix for column 0 and and column353: 0.012740828742690197
# 354
# Correlation matrix for column 0 and and column354: 0.0036499965505251706
# 355
# Correlation matrix for column 0 and and column355: 0.003620542763047323
# 356
# Correlation matrix for column 0 and and column356: -0.004387198887141541
# 357
# Correlation matrix for column 0 and and column357: -0.0015570184120910532
# 358
# Correlation matrix for column 0 and and column358: 0.002330428658002128
# 359
# Correlation matrix for column 0 and and column359: -0.014567191514875589
# 360
# Correlation matrix for column 0 and and column360: -0.003905027490814176
# 361
# Correlation matrix for column 0 and and column361: 0.005145651498661435
# 362
# Correlation matrix for column 0 and and column362: 0.003385872562468213
# 363
# Correlation matrix for column 0 and and column363: 0.0029263672523880575
# 364
# Correlation matrix for column 0 and and column364: 0.008324759021597208
# 365
# Correlation matrix for column 0 and and column365: -0.0028175415105342848
# 366
# Correlation matrix for column 0 and and column366: 0.007218539152582845
# 367
# Correlation matrix for column 0 and and column367: 0.005266139172130818
# 368
# Correlation matrix for column 0 and and column368: -0.01918893434315815
# 369
# Correlation matrix for column 0 and and column369: 0.02475502294689316
# 370
# Correlation matrix for column 0 and and column370: 0.002619555484468617
# 371
# Correlation matrix for column 0 and and column371: -0.02275738691408003
# 372
# Correlation matrix for column 0 and and column372: -0.004649194158322727
# 373
# Correlation matrix for column 0 and and column373: -0.005985387996583505
# 374
# Correlation matrix for column 0 and and column374: 0.008648673847028936
# 375
# Correlation matrix for column 0 and and column375: 0.00757189022431656
# 376
# Correlation matrix for column 0 and and column376: 0.011080999449469282
# 377
# Correlation matrix for column 0 and and column377: -9.832003863575679e-06
# 378
# Correlation matrix for column 0 and and column378: 0.0007939514905395186
# 379
# Correlation matrix for column 0 and and column379: 0.004458332426489771
# 380
# Correlation matrix for column 0 and and column380: -0.00605701017405202
# 381
# Correlation matrix for column 0 and and column381: 0.003744020507923995
# 382
# Correlation matrix for column 0 and and column382: -0.0009340391061673121
# 383
# Correlation matrix for column 0 and and column383: 0.018727347948514106
# 384
# Correlation matrix for column 0 and and column384: 0.0027136838927972573
# 385
# Correlation matrix for column 0 and and column385: -0.01736247260693527
# 386
# Correlation matrix for column 0 and and column386: -0.01611332550733818
# 387
# Correlation matrix for column 0 and and column387: -0.022771870527079904
# 388
# Correlation matrix for column 0 and and column388: 0.002843512790062142
# 389
# Correlation matrix for column 0 and and column389: -0.005882718189885484
# 390
# Correlation matrix for column 0 and and column390: 0.009591784169021662
# 391
# Correlation matrix for column 0 and and column391: -0.005945814746730667
# 392
# Correlation matrix for column 0 and and column392: 0.007531186061962207
# 393
# Correlation matrix for column 0 and and column393: 0.008837229089140364
# 394
# Correlation matrix for column 0 and and column394: -0.0065290953490065575
# 395
# Correlation matrix for column 0 and and column395: 0.003607355491926476
# 396
# Correlation matrix for column 0 and and column396: -0.0036520268472465833
# 397
# Correlation matrix for column 0 and and column397: -0.012733892377335718
# 398
# Correlation matrix for column 0 and and column398: 0.015321411091183611
# 399
# Correlation matrix for column 0 and and column399: 0.010969981494871198
# 400
# Correlation matrix for column 0 and and column400: -0.01690709220444977
# 401
# Correlation matrix for column 0 and and column401: 0.0008091838399417122
# 402
# Correlation matrix for column 0 and and column402: -0.016635191672011274
# 403
# Correlation matrix for column 0 and and column403: 0.002581574024897992
# 404
# Correlation matrix for column 0 and and column404: 0.004173563551223161
# 405
# Correlation matrix for column 0 and and column405: -0.010470211818766693
# 406
# Correlation matrix for column 0 and and column406: -0.003238550076642745
# 407
# Correlation matrix for column 0 and and column407: 0.0006686871701155522
# 408
# Correlation matrix for column 0 and and column408: 0.022323186026147756
# 409
# Correlation matrix for column 0 and and column409: 0.0004884339243718681
# 410
# Correlation matrix for column 0 and and column410: -0.0025925865710349945
# 411
# Correlation matrix for column 0 and and column411: -0.007884315628150543
# 412
# Correlation matrix for column 0 and and column412: -0.020777090833952037
# 413
# Correlation matrix for column 0 and and column413: -0.0059783406660915955
# 414
# Correlation matrix for column 0 and and column414: -0.0190010107849435
# 415
# Correlation matrix for column 0 and and column415: -0.00030071236594850296
# 416
# Correlation matrix for column 0 and and column416: -0.025640737412889414
# 417
# Correlation matrix for column 0 and and column417: -0.00377577552770936
# 418
# Correlation matrix for column 0 and and column418: 0.00813902245324277
# 419
# Correlation matrix for column 0 and and column419: 0.019213481370251896
# 420
# Correlation matrix for column 0 and and column420: -0.01528318424428699
# 421
# Correlation matrix for column 0 and and column421: 0.017821953018236036
# 422
# Correlation matrix for column 0 and and column422: 0.008866536230157809
# 423
# Correlation matrix for column 0 and and column423: -0.008496094561503251
# 424
# Correlation matrix for column 0 and and column424: -0.008586415374555297
# 425
# Correlation matrix for column 0 and and column425: 0.0017799437811761567
# 426
# Correlation matrix for column 0 and and column426: 0.0008797794341367858
# 427
# Correlation matrix for column 0 and and column427: -0.0008606927496463072
# 428
# Correlation matrix for column 0 and and column428: 0.0052243586840658865
# 429
# Correlation matrix for column 0 and and column429: 0.004572287840689624
# 430
# Correlation matrix for column 0 and and column430: 0.017896232404265768
# 431
# Correlation matrix for column 0 and and column431: 0.0001887104598366445
# 432
# Correlation matrix for column 0 and and column432: -0.0048035453072317455
# 433
# Correlation matrix for column 0 and and column433: 0.0006337724905107651
# 434
# Correlation matrix for column 0 and and column434: 0.0021111434732945813
# 435
# Correlation matrix for column 0 and and column435: 0.003920532052492805
# 436
# Correlation matrix for column 0 and and column436: -0.0044040054631015995
# 437
# Correlation matrix for column 0 and and column437: -0.01480167924020928
# 438
# Correlation matrix for column 0 and and column438: 0.007200036284663228
# 439
# Correlation matrix for column 0 and and column439: -1.4201258524112003e-05
# 440
# Correlation matrix for column 0 and and column440: 0.00248518348598611
# 441
# Correlation matrix for column 0 and and column441: 0.00724097475814488
# 442
# Correlation matrix for column 0 and and column442: 0.00869403162087842
# 443
# Correlation matrix for column 0 and and column443: 0.004036621120496169
# 444
# Correlation matrix for column 0 and and column444: 0.008908526656041185
# 445
# Correlation matrix for column 0 and and column445: 0.01475239781149146
# 446
# Correlation matrix for column 0 and and column446: -0.011434814327617424
# 447
# Correlation matrix for column 0 and and column447: 0.015128760093537152
# 448
# Correlation matrix for column 0 and and column448: -0.0005217355183575216
# 449
# Correlation matrix for column 0 and and column449: -0.005169323141325131
# 450
# Correlation matrix for column 0 and and column450: -0.0004855434982503485
# 451
# Correlation matrix for column 0 and and column451: -0.001375454322964366
# 452
# Correlation matrix for column 0 and and column452: -0.007310620582642143
# 453
# Correlation matrix for column 0 and and column453: -0.015163651709130171
# 454
# Correlation matrix for column 0 and and column454: -0.0015181310198929664
# 455
# Correlation matrix for column 0 and and column455: 0.013022446401883905
# 456
# Correlation matrix for column 0 and and column456: -0.007229599888263058
# 457
# Correlation matrix for column 0 and and column457: 0.007022379395738686
# 458
# Correlation matrix for column 0 and and column458: -0.02564591869052366
# 459
# Correlation matrix for column 0 and and column459: -0.004947349439152944
# 460
# Correlation matrix for column 0 and and column460: 0.015831490280371698
# 461
# Correlation matrix for column 0 and and column461: 0.00452652903793335
# 462
# Correlation matrix for column 0 and and column462: -0.0016342640728156908
# 463
# Correlation matrix for column 0 and and column463: -0.012066746780218091
# 464
# Correlation matrix for column 0 and and column464: -0.008530710446740792
# 465
# Correlation matrix for column 0 and and column465: -0.004169489006413769
# 466
# Correlation matrix for column 0 and and column466: -0.0008339943596350527
# 467
# Correlation matrix for column 0 and and column467: 0.003600597863046008
# 468
# Correlation matrix for column 0 and and column468: -0.008154223113532439
# 469
# Correlation matrix for column 0 and and column469: -0.00449630707732079
# 470
# Correlation matrix for column 0 and and column470: -0.0007523211226446687
# 471
# Correlation matrix for column 0 and and column471: 0.003355961547800661
# 472
# Correlation matrix for column 0 and and column472: -0.0077241633129377495
# 473
# Correlation matrix for column 0 and and column473: -0.00062404423562417
# 474
# Correlation matrix for column 0 and and column474: -0.023041956164341622
# 475
# Correlation matrix for column 0 and and column475: 0.0008374514527623772
# 476
# Correlation matrix for column 0 and and column476: -3.4668989426401366e-05
# 477
# Correlation matrix for column 0 and and column477: 0.017937265118550812
# 478
# Correlation matrix for column 0 and and column478: 0.0012660227314578384
# 479
# Correlation matrix for column 0 and and column479: 0.004409491627065935
# 480
# Correlation matrix for column 0 and and column480: -0.0024459373087589303
# 481
# Correlation matrix for column 0 and and column481: -0.002799566799419267
# 482
# Correlation matrix for column 0 and and column482: 0.0009179004373733157
# 483
# Correlation matrix for column 0 and and column483: 0.015793663904988906
# 484
# Correlation matrix for column 0 and and column484: 0.015334789846986052
# 485
# Correlation matrix for column 0 and and column485: -0.002872800812167765
# 486
# Correlation matrix for column 0 and and column486: 0.003781063245376808
# 487
# Correlation matrix for column 0 and and column487: 0.0038833783992493548
# 488
# Correlation matrix for column 0 and and column488: 0.004442240833449362
# 489
# Correlation matrix for column 0 and and column489: -0.014040003245029789
# 490
# Correlation matrix for column 0 and and column490: 0.021993816072847464
# 491
# Correlation matrix for column 0 and and column491: 0.01072288242730271
# 492
# Correlation matrix for column 0 and and column492: -0.0007717683647388617
# 493
# Correlation matrix for column 0 and and column493: 0.025464225726139704
# 494
# Correlation matrix for column 0 and and column494: -0.01348607074890946
# 495
# Correlation matrix for column 0 and and column495: -0.00826556730827177
# 496
# Correlation matrix for column 0 and and column496: 0.010819307093141833
# 497
# Correlation matrix for column 0 and and column497: 0.02071078434309895
# 498
# Correlation matrix for column 0 and and column498: 0.01850499219395276
# 499
# Correlation matrix for column 0 and and column499: 0.0017319999955571343
# 500
# Correlation matrix for column 0 and and column500: -0.002179885902504549
# 501
# Correlation matrix for column 0 and and column501: 0.010231127946833656
# 502
# Correlation matrix for column 0 and and column502: 0.006050215991358533
# 503
# Correlation matrix for column 0 and and column503: 0.007584808362565949
# 504
# Correlation matrix for column 0 and and column504: 0.012529886571084696
# 505
# Correlation matrix for column 0 and and column505: 0.020370887370693057
# 506
# Correlation matrix for column 0 and and column506: 0.01196497525082214
# 507
# Correlation matrix for column 0 and and column507: -0.006625767626478055
# 508
# Correlation matrix for column 0 and and column508: 0.0010727695403123531
# 509
# Correlation matrix for column 0 and and column509: -0.0009586887005740552
# 510
# Correlation matrix for column 0 and and column510: 0.007007869767646924
# 511
# Correlation matrix for column 0 and and column511: 0.011053551627352727
# 512
# Correlation matrix for column 0 and and column512: -0.010002597000307138
# 513
# Correlation matrix for column 0 and and column513: -0.016982686973736196
# 514
# Correlation matrix for column 0 and and column514: 0.015079332468397181
# 515
# Correlation matrix for column 0 and and column515: 0.0071312667708733155
# 516
# Correlation matrix for column 0 and and column516: 0.0057201738001348285
# 517
# Correlation matrix for column 0 and and column517: -0.001907491608029624
# 518
# Correlation matrix for column 0 and and column518: 0.004842848185063271
# 519
# Correlation matrix for column 0 and and column519: -0.0026104746160634453
# 520
# Correlation matrix for column 0 and and column520: 0.013231091365995653
# 521
# Correlation matrix for column 0 and and column521: -0.013781748398630616
# 522
# Correlation matrix for column 0 and and column522: 0.003960535401432295
# 523
# Correlation matrix for column 0 and and column523: 0.00592381904033749
# 524
# Correlation matrix for column 0 and and column524: 0.010603933068080003
# 525
# Correlation matrix for column 0 and and column525: 0.008638690171877262
# 526
# Correlation matrix for column 0 and and column526: -0.004052715589035119
# 527
# Correlation matrix for column 0 and and column527: -0.012289631299922377
# 528
# Correlation matrix for column 0 and and column528: 0.00019554198130606617
# 529
# Correlation matrix for column 0 and and column529: 0.006642973849229614
# 530
# Correlation matrix for column 0 and and column530: -0.010850392941641218
# 531
# Correlation matrix for column 0 and and column531: -0.009109083530347473
# 532
# Correlation matrix for column 0 and and column532: 0.0043500632972352914
# 533
# Correlation matrix for column 0 and and column533: 0.007593442939720563
# 534
# Correlation matrix for column 0 and and column534: 0.011647349547184474
# 535
# Correlation matrix for column 0 and and column535: 0.021274930151346214
# 536
# Correlation matrix for column 0 and and column536: -0.00695405556489567
# 537
# Correlation matrix for column 0 and and column537: 0.003231291513234829
# 538
# Correlation matrix for column 0 and and column538: -0.0037956727583326666
# 539
# Correlation matrix for column 0 and and column539: -0.011537025686357769
# 540
# Correlation matrix for column 0 and and column540: -0.007060483767120377
# 541
# Correlation matrix for column 0 and and column541: -0.006920883810982988
# 542
# Correlation matrix for column 0 and and column542: -0.009486953680225035
# 543
# Correlation matrix for column 0 and and column543: -0.012765872880640511
# 544
# Correlation matrix for column 0 and and column544: -0.006941594003938023
# 545
# Correlation matrix for column 0 and and column545: 0.013979561146896744
# 546
# Correlation matrix for column 0 and and column546: 0.0067245328497539175
# 547
# Correlation matrix for column 0 and and column547: -0.020321558767660924
# 548
# Correlation matrix for column 0 and and column548: 0.013889143060887425
# 549
# Correlation matrix for column 0 and and column549: 0.0068196973952333005
# 550
# Correlation matrix for column 0 and and column550: -0.005677188495529791
# 551
# Correlation matrix for column 0 and and column551: 0.004576504178741755
# 552
# Correlation matrix for column 0 and and column552: 0.00652435671289415
# 553
# Correlation matrix for column 0 and and column553: -0.002464144665747757
# 554
# Correlation matrix for column 0 and and column554: 0.0003605750030369121
# 555
# Correlation matrix for column 0 and and column555: -0.007889572657420576
# 556
# Correlation matrix for column 0 and and column556: 0.011186323790770702
# 557
# Correlation matrix for column 0 and and column557: -0.001444430744973172
# 558
# Correlation matrix for column 0 and and column558: -0.0015943976399879008
# 559
# Correlation matrix for column 0 and and column559: 0.024948516363815957
# 560
# Correlation matrix for column 0 and and column560: -0.015922329690405215
# 561
# Correlation matrix for column 0 and and column561: 0.013302552133397871
# 562
# Correlation matrix for column 0 and and column562: -0.006355273713407755
# 563
# Correlation matrix for column 0 and and column563: -0.010486334464275094
# 564
# Correlation matrix for column 0 and and column564: 0.00033266347547673364
# 565
# Correlation matrix for column 0 and and column565: -0.0010013285288398453
# 566
# Correlation matrix for column 0 and and column566: -0.004381486728426948
# 567
# Correlation matrix for column 0 and and column567: 0.002919223727353432
# 568
# Correlation matrix for column 0 and and column568: -0.0023222361758256428
# 569
# Correlation matrix for column 0 and and column569: -0.011375661227766367
# 570
# Correlation matrix for column 0 and and column570: 0.004061105768137917
# 571
# Correlation matrix for column 0 and and column571: 0.016271380836121146
# 572
# Correlation matrix for column 0 and and column572: 0.008277296375761339
# 573
# Correlation matrix for column 0 and and column573: -0.0035196056343683485
# 574
# Correlation matrix for column 0 and and column574: -0.003487390888826151
# 575
# Correlation matrix for column 0 and and column575: -0.014647644346608722
# 576
# Correlation matrix for column 0 and and column576: -0.006166585030425483
# 577
# Correlation matrix for column 0 and and column577: -0.0005439339068093506
# 578
# Correlation matrix for column 0 and and column578: -0.003973091902090491
# 579
# Correlation matrix for column 0 and and column579: -0.017867114775980006
# 580
# Correlation matrix for column 0 and and column580: 0.01198813380818026
# 581
# Correlation matrix for column 0 and and column581: -0.013530331025280708
# 582
# Correlation matrix for column 0 and and column582: 0.010469047239000712
# 583
# Correlation matrix for column 0 and and column583: -0.006784420007696921
# 584
# Correlation matrix for column 0 and and column584: -0.012002569863703206
# 585
# Correlation matrix for column 0 and and column585: -0.006483064625725035
# 586
# Correlation matrix for column 0 and and column586: -0.02075736515251837
# 587
# Correlation matrix for column 0 and and column587: 0.011248498494554986
# 588
# Correlation matrix for column 0 and and column588: 0.004816702344675643
# 589
# Correlation matrix for column 0 and and column589: -0.004561391297924846
# 590
# Correlation matrix for column 0 and and column590: -0.0036285541803307586
# 591
# Correlation matrix for column 0 and and column591: 0.024064421467872726
# 592
# Correlation matrix for column 0 and and column592: -0.0017848759617885978
# 593
# Correlation matrix for column 0 and and column593: 0.007290331330527439
# 594
# Correlation matrix for column 0 and and column594: -0.0038935435425540284
# 595
# Correlation matrix for column 0 and and column595: 0.009622613052200328
# 596
# Correlation matrix for column 0 and and column596: -0.002614183607971729
# 597
# Correlation matrix for column 0 and and column597: -0.015923079946107196
# 598
# Correlation matrix for column 0 and and column598: 0.014396881255269634
# 599
# Correlation matrix for column 0 and and column599: 0.0026583900252131133
# 600
# Correlation matrix for column 0 and and column600: 0.030463546871361696
# 601
# Correlation matrix for column 0 and and column601: -0.0008868498884179619
# 602
# Correlation matrix for column 0 and and column602: -0.007521188450062126
# 603
# Correlation matrix for column 0 and and column603: 0.004755321558690016
# 604
# Correlation matrix for column 0 and and column604: 0.006136696318170591
# 605
# Correlation matrix for column 0 and and column605: 0.004012959078991821
# 606
# Correlation matrix for column 0 and and column606: -0.002410007090158896
# 607
# Correlation matrix for column 0 and and column607: -0.0037527402679858406
# 608
# Correlation matrix for column 0 and and column608: -0.006229088881481069
# 609
# Correlation matrix for column 0 and and column609: -0.006493249877384997
# 610
# Correlation matrix for column 0 and and column610: 0.006729607024328807
# 611
# Correlation matrix for column 0 and and column611: -0.008342313537871019
# 612
# Correlation matrix for column 0 and and column612: 0.031073729430375677
# 613
# Correlation matrix for column 0 and and column613: -0.00314757893499887
# 614
# Correlation matrix for column 0 and and column614: 0.021487687473180916
# 615
# Correlation matrix for column 0 and and column615: 0.003954708467919317
# 616
# Correlation matrix for column 0 and and column616: -0.0025616313895844224
# 617
# Correlation matrix for column 0 and and column617: -0.017639407393227072
# 618
# Correlation matrix for column 0 and and column618: -0.016489559026926403
# 619
# Correlation matrix for column 0 and and column619: 0.0017503092608604574
# 620
# Correlation matrix for column 0 and and column620: -0.0103691725566723
# 621
# Correlation matrix for column 0 and and column621: 0.0036444939487796377
# 622
# Correlation matrix for column 0 and and column622: -0.007738814852099694
# 623
# Correlation matrix for column 0 and and column623: -0.0001863188035709304
# 624
# Correlation matrix for column 0 and and column624: -0.00041301000472202106
# 625
# Correlation matrix for column 0 and and column625: 0.007889174811771604
# 626
# ...
# 793
# Correlation matrix for column 0 and and column793: 0.009280944884312298
# 794
# Correlation matrix for column 0 and and column794: -0.016688162361853873
# 795
# Correlation matrix for column 0 and and column795: 0.0036826146780112885
# 796
# Correlation matrix for column 0 and and column796: -0.0035022649074339706
# 797
# Correlation matrix for column 0 and and column797: 0.00980093696628055
# 798
# Correlation matrix for column 0 and and column798: 0.009826034480615871
# 799
# Correlation matrix for column 0 and and column799: -0.006695682307691117
# 800
# Correlation matrix for column 0 and and column800: -0.016774835823434486
# 801
# Correlation matrix for column 0 and and column801: -0.0022996398343417494
# 802
# Correlation matrix for column 0 and and column802: -0.017924234286969563
# 803
# Correlation matrix for column 0 and and column803: 0.0003400319702249228
# 804
# Correlation matrix for column 0 and and column804: -0.0022911235769017017
# 805
# Correlation matrix for column 0 and and column805: 0.011098178077472182
# 806
# Correlation matrix for column 0 and and column806: 0.02299579596025582
# 807
# Correlation matrix for column 0 and and column807: 0.019298147389301475
# 808
# Correlation matrix for column 0 and and column808: 0.0034033472338011244
# 809
# Correlation matrix for column 0 and and column809: -0.0038721174766882106
# 810
# Correlation matrix for column 0 and and column810: -0.022221677229355575
# 811
# Correlation matrix for column 0 and and column811: -0.010405308925192477
# 812
# Correlation matrix for column 0 and and column812: 0.013071687292985692
# 813
# Correlation matrix for column 0 and and column813: 0.021446650803646505
# 814
# Correlation matrix for column 0 and and column814: -0.004021133404427573
# 815
# Correlation matrix for column 0 and and column815: 0.0014023029746474238
# 816
# Correlation matrix for column 0 and and column816: -0.021147008923225123
# 817
# Correlation matrix for column 0 and and column817: -0.0011726137976989888
# 818
# Correlation matrix for column 0 and and column818: 0.004916239368820315
# 819
# Correlation matrix for column 0 and and column819: 0.01357915164680897
# 820
# Correlation matrix for column 0 and and column820: -0.000824975266169356
# 821
# Correlation matrix for column 0 and and column821: -0.002599371860037064
# 822
# Correlation matrix for column 0 and and column822: -0.010877868297572502
# 823
# Correlation matrix for column 0 and and column823: 0.007809762242217615
# 824
# Correlation matrix for column 0 and and column824: -0.015830132610208648
# 825
# Correlation matrix for column 0 and and column825: -0.0008360871586768623
# 826
# Correlation matrix for column 0 and and column826: 0.0008788787249645382
# 827
# Correlation matrix for column 0 and and column827: 0.011931259621924437
# 828
# Correlation matrix for column 0 and and column828: 0.005200280935657757
# 829
# Correlation matrix for column 0 and and column829: 0.0100442992050545
# 830
# Correlation matrix for column 0 and and column830: 0.012880038787951595
# 831
# Correlation matrix for column 0 and and column831: 0.032967394641302945
# 832
# Correlation matrix for column 0 and and column832: -0.01018703828545317
# 833
# Correlation matrix for column 0 and and column833: 0.0047932179237240346
# 834
# Correlation matrix for column 0 and and column834: -0.01125090725480867
# 835
# Correlation matrix for column 0 and and column835: -0.008795549051417648
# 836
# Correlation matrix for column 0 and and column836: 0.007558098150830942
# 837
# Correlation matrix for column 0 and and column837: -0.002736024057627703
# 838
# Correlation matrix for column 0 and and column838: -0.024663360208492597
# 839
# Correlation matrix for column 0 and and column839: 0.0008005093018236464
# 840
# Correlation matrix for column 0 and and column840: 0.007002873827841735
# 841
# Correlation matrix for column 0 and and column841: -0.004646984981345894
# 842
# Correlation matrix for column 0 and and column842: 0.02396506074395391
# 843
# Correlation matrix for column 0 and and column843: -0.0034991986901150526
# 844
# Correlation matrix for column 0 and and column844: -0.0023410512169685324
# 845
# Correlation matrix for column 0 and and column845: 0.008747013209677695
# 846
# Correlation matrix for column 0 and and column846: 0.004615033981166336
# 847
# Correlation matrix for column 0 and and column847: -0.0028635390530910684
# 848
# Correlation matrix for column 0 and and column848: -0.00043590614299299257
# 849
# Correlation matrix for column 0 and and column849: 0.011842076822942221
# 850
# Correlation matrix for column 0 and and column850: -0.012519299672446988
# 851
# Correlation matrix for column 0 and and column851: -0.013145022613522453
# 852
# Correlation matrix for column 0 and and column852: 0.003278322647735038
# 853
# Correlation matrix for column 0 and and column853: 0.004535038124286632
# 854
# Correlation matrix for column 0 and and column854: -0.004508007000027381
# 855
# Correlation matrix for column 0 and and column855: 0.005127387595070635
# 856
# Correlation matrix for column 0 and and column856: 0.008973684111057732
# 857
# Correlation matrix for column 0 and and column857: -0.0016057056956109972
# 858
# Correlation matrix for column 0 and and column858: 0.014218066988115867
# 859
# Correlation matrix for column 0 and and column859: 0.0036783990114961783
# 860
# Correlation matrix for column 0 and and column860: -0.017021371710222402
# 861
# Correlation matrix for column 0 and and column861: -0.00615766086797383
# 862
# Correlation matrix for column 0 and and column862: 0.020886315932373486
# 863
# Correlation matrix for column 0 and and column863: 0.024613903088507867
# 864
# Correlation matrix for column 0 and and column864: -0.006063244870837203
# 865
# Correlation matrix for column 0 and and column865: 0.0034356546858886655
# 866
# Correlation matrix for column 0 and and column866: 0.001135863985231968
# 867
# Correlation matrix for column 0 and and column867: -0.005391876492966334
# 868
# Correlation matrix for column 0 and and column868: 0.004906235839509006
# 869
# Correlation matrix for column 0 and and column869: -0.011758007266720742
# 870
# Correlation matrix for column 0 and and column870: -0.007174083267027996
# 871
# Correlation matrix for column 0 and and column871: -0.004204741207659266
# 872
# Correlation matrix for column 0 and and column872: -0.003403981254342799
# 873
# Correlation matrix for column 0 and and column873: -0.0005101218306851052
# 874
# Correlation matrix for column 0 and and column874: 0.0023496776595389227
# 875
# Correlation matrix for column 0 and and column875: -0.010902030518217951
# 876
# Correlation matrix for column 0 and and column876: -0.005971544898014144
# 877
# Correlation matrix for column 0 and and column877: -0.00777267199061405
# 878
# Correlation matrix for column 0 and and column878: 0.005738998952886851
# 879
# Correlation matrix for column 0 and and column879: 0.01084638422790155
# 880
# Correlation matrix for column 0 and and column880: -0.00246627446717586
# 881
# Correlation matrix for column 0 and and column881: 0.004571626251447426
# 882
# Correlation matrix for column 0 and and column882: 0.007466692378176126
# 883
# Correlation matrix for column 0 and and column883: -0.013153301753207993
# 884
# Correlation matrix for column 0 and and column884: -0.02264019078969947
# 885
# Correlation matrix for column 0 and and column885: -0.001884294756320522
# 886
# Correlation matrix for column 0 and and column886: 0.0012098820891406992
# 887
# Correlation matrix for column 0 and and column887: 0.011029719147586695
# 888
# Correlation matrix for column 0 and and column888: -0.007685421821101101
# 889
# Correlation matrix for column 0 and and column889: 0.009744833044281948
# 890
# Correlation matrix for column 0 and and column890: -0.0045901018587400505
# 891
# Correlation matrix for column 0 and and column891: -0.01938584870581547
# 892
# Correlation matrix for column 0 and and column892: -0.004901226638858508
# 893
# Correlation matrix for column 0 and and column893: -0.004584371956057919
# 894
# Correlation matrix for column 0 and and column894: 0.00460004822732082
# 895
# Correlation matrix for column 0 and and column895: 0.008380175006202993
# 896
# Correlation matrix for column 0 and and column896: -0.017077434584331655
# 897
# Correlation matrix for column 0 and and column897: 0.007375391817798329
# 898
# Correlation matrix for column 0 and and column898: -0.010956376513905065
# 899
# Correlation matrix for column 0 and and column899: 0.004164742184661654
# 900
# Correlation matrix for column 0 and and column900: 0.007775463121729253
# 901
# Correlation matrix for column 0 and and column901: -0.011029082690503638
# 902
# Correlation matrix for column 0 and and column902: 0.00020162471679351752
# 903
# Correlation matrix for column 0 and and column903: 0.003553722541753493
# 904
# Correlation matrix for column 0 and and column904: 0.004292197835552925
# 905
# Correlation matrix for column 0 and and column905: -0.015098724676981437
# 906
# Correlation matrix for column 0 and and column906: -0.015424668747218281
# 907
# Correlation matrix for column 0 and and column907: -0.016707526474288432
# 908
# Correlation matrix for column 0 and and column908: -0.0003037222799880626
# 909
# Correlation matrix for column 0 and and column909: -0.009157531695623637
# 910
# Correlation matrix for column 0 and and column910: 0.007624872985952719
# 911
# Correlation matrix for column 0 and and column911: -0.0032976110267626713
# 912
# Correlation matrix for column 0 and and column912: -0.008418027032368745
# 913
# Correlation matrix for column 0 and and column913: 0.0043372229029208535
# 914
# Correlation matrix for column 0 and and column914: -0.00978851994946294
# 915
# Correlation matrix for column 0 and and column915: -0.012059670398451263
# 916
# Correlation matrix for column 0 and and column916: 0.018462221289618733
# 917
# Correlation matrix for column 0 and and column917: 0.004553312285656478
# 918
# Correlation matrix for column 0 and and column918: 0.012748605013046766
# 919
# Correlation matrix for column 0 and and column919: 0.002643144756617551
# 920
# Correlation matrix for column 0 and and column920: 0.0025108865178788695
# 921
# Correlation matrix for column 0 and and column921: 0.007175447453479469
# 922
# Correlation matrix for column 0 and and column922: -0.007599183746770747
# 923
# Correlation matrix for column 0 and and column923: -0.0027745686506990496
# 924
# Correlation matrix for column 0 and and column924: -0.012808167635980288
# 925
# Correlation matrix for column 0 and and column925: -0.01527881205653926
# 926
# Correlation matrix for column 0 and and column926: -0.0037145862305810787
# 927
# Correlation matrix for column 0 and and column927: -0.002487465001514798
# 928
# Correlation matrix for column 0 and and column928: -0.002961360839786459
# 929
# Correlation matrix for column 0 and and column929: 0.012976300228686496
# 930
# Correlation matrix for column 0 and and column930: -0.004130050112512864
# 931
# Correlation matrix for column 0 and and column931: 0.007888543729972199
# 932
# Correlation matrix for column 0 and and column932: -0.0010012118443153263
# 933
# Correlation matrix for column 0 and and column933: 0.009739093347638917
# 934
# Correlation matrix for column 0 and and column934: 0.009551387793530616
# 935
# Correlation matrix for column 0 and and column935: 0.01062524975242507
# 936
# Correlation matrix for column 0 and and column936: 0.014249448758739451
# 937
# Correlation matrix for column 0 and and column937: 0.015325832156840425
# 938
# Correlation matrix for column 0 and and column938: 0.002999258990582652
# 939
# Correlation matrix for column 0 and and column939: 0.006258469428501163
# 940
# Correlation matrix for column 0 and and column940: -0.0022569357049266976
# 941
# Correlation matrix for column 0 and and column941: 0.004361499378757905
# 942
# Correlation matrix for column 0 and and column942: -0.014890429729759075
# 943
# Correlation matrix for column 0 and and column943: -0.015360548759377061
# 944
# Correlation matrix for column 0 and and column944: -0.008465380013142685
# 945
# Correlation matrix for column 0 and and column945: -0.0011555839453130292
# 946
# Correlation matrix for column 0 and and column946: -0.011696399191630541
# 947
# Correlation matrix for column 0 and and column947: 0.003607221999502283
# 948
# Correlation matrix for column 0 and and column948: -0.007990582860813122
# 949
# Correlation matrix for column 0 and and column949: 0.013361116756905319
# 950
# Correlation matrix for column 0 and and column950: 0.012060857022534361
# 951
# Correlation matrix for column 0 and and column951: 0.011470115975999626
# 952
# Correlation matrix for column 0 and and column952: -0.015559596979485777
# 953
# Correlation matrix for column 0 and and column953: -0.019467468989077863
# 954
# Correlation matrix for column 0 and and column954: 0.020000411225745876
# 955
# Correlation matrix for column 0 and and column955: -0.004146486707223743
# 956
# Correlation matrix for column 0 and and column956: -0.0031803782651363384
# 957
# Correlation matrix for column 0 and and column957: -0.003342739374571812
# 958
# Correlation matrix for column 0 and and column958: 0.02068350119934291
# 959
# Correlation matrix for column 0 and and column959: -0.0051543197633107584
# 960
# Correlation matrix for column 0 and and column960: 0.0066447243641069445
# 961
# Correlation matrix for column 0 and and column961: -0.008165942836511921
# 962
# Correlation matrix for column 0 and and column962: -0.021132836122258632
# 963
# Correlation matrix for column 0 and and column963: 0.009970096143602414
# 964
# Correlation matrix for column 0 and and column964: -0.0013526810571893196
# 965
# Correlation matrix for column 0 and and column965: 0.012567910183381327
# 966
# Correlation matrix for column 0 and and column966: 0.013133647741008734
# 967
# Correlation matrix for column 0 and and column967: -0.013146693687219246
# 968
# Correlation matrix for column 0 and and column968: -0.0004964017751123415
# 969
# Correlation matrix for column 0 and and column969: 0.0008851186114633133
# 970
# Correlation matrix for column 0 and and column970: 0.0015658757567702376
# 971
# Correlation matrix for column 0 and and column971: 0.002579059123417923
# 972
# Correlation matrix for column 0 and and column972: 0.0024470879659962076
# 973
# Correlation matrix for column 0 and and column973: -0.004099109238072937
# 974
# Correlation matrix for column 0 and and column974: 0.0011135147271354995
# 975
# Correlation matrix for column 0 and and column975: -0.002459459871889176
# 976
# Correlation matrix for column 0 and and column976: -0.004031253043576573
# 977
# Correlation matrix for column 0 and and column977: -0.025083829933012905
# 978
# Correlation matrix for column 0 and and column978: -0.0004558858465453584
# 979
# Correlation matrix for column 0 and and column979: 0.022354622692316563
# 980
# Correlation matrix for column 0 and and column980: -0.007070130766293175
# 981
# Correlation matrix for column 0 and and column981: -0.01671355631832611
# 982
# Correlation matrix for column 0 and and column982: 0.009694314328468333
# 983
# Correlation matrix for column 0 and and column983: 0.0009375987505307893
# 984
# Correlation matrix for column 0 and and column984: -0.015496801156315803
# 985
# Correlation matrix for column 0 and and column985: -0.015011367403167103
# 986
# Correlation matrix for column 0 and and column986: -0.003969459770892997
# 987
# Correlation matrix for column 0 and and column987: -0.0010545605670274454
# 988
# Correlation matrix for column 0 and and column988: 0.005835074464176421
# 989
# Correlation matrix for column 0 and and column989: -0.012788760560318201
# 990
# Correlation matrix for column 0 and and column990: -0.009293846275775576
# 991
# Correlation matrix for column 0 and and column991: -0.002030420605838964
# 992
# Correlation matrix for column 0 and and column992: -0.004051384819257965
# 993
# Correlation matrix for column 0 and and column993: -0.005500812147689104
# 994
# Correlation matrix for column 0 and and column994: 0.0021973939123680884
# 995
# Correlation matrix for column 0 and and column995: 0.0009946373346821594
# 996
# Correlation matrix for column 0 and and column996: -0.016371159569072355
# 997
# Correlation matrix for column 0 and and column997: -0.0005741759430990011
# 998
# Correlation matrix for column 0 and and column998: 0.002386377322907951
# 999
# Correlation matrix for column 0 and and column999: -0.006198590393999275
# 1000
# Correlation matrix for column 0 and and column1000: -0.012966786524824603

# %%
# See how many correlations are significant

# %% [markdown]
# To see if indeed the correlations between the different parameters increases with the data size, the original dataframe is compared to a sub-set dataframe which only takes the first z rows of the original dataframe. If the correlations in the original dataframe are higher than in the smaller dataframe this would prove that the bigger the data size the more frequent the number of spurious correlations.

# %%
# Creating smaller dataframe taking z number of rows from original dataframe
df2 = df.iloc[:z]
df2.head()
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.683541  0.018479  0.357882  0.681310  0.447448  0.598510  0.124120
# 1  0.827127  0.473744  0.547709  0.097834  0.480502  0.960953  0.667213
# 2  0.929321  0.373383  0.937262  0.279188  0.898340  0.396706  0.395249
# 3  0.669256  0.761206  0.647999  0.893389  0.087763  0.398732  0.699660
# 4  0.153948  0.006564  0.293203  0.002775  0.026068  0.006733  0.999795
#
#      7         8         9       ...    199990    199991    199992    199993  \
# 0  0.026100  0.892880  0.790828  ...  0.785743  0.987288  0.587592  0.546459
# 1  0.029142  0.544869  0.029782  ...  0.147390  0.316055  0.891719  0.825268
# 2  0.085978  0.535766  0.352000  ...  0.372708  0.331071  0.823048  0.698590
# 3  0.116835  0.825984  0.666978  ...  0.774387  0.791663  0.092473  0.203856
# 4  0.351303  0.612944  0.640485  ...  0.444889  0.689587  0.771937  0.902576
#
#      199994    199995    199996    199997    199998    199999
# 0  0.181415  0.818808  0.184176  0.668079  0.347183  0.707497
# 1  0.782924  0.101897  0.650957  0.081078  0.441026  0.386312
# 2  0.825034  0.672430  0.670454  0.542668  0.040608  0.398071
# 3  0.140118  0.459813  0.687499  0.229563  0.706178  0.919847
# 4  0.301864  0.389987  0.739029  0.607980  0.586038  0.148765
#
# [5 rows x 200000 columns]

# %%
# Assigning X to all columns except 0
X_df2 = df2.drop(columns=0)
X_df2.head()

# Assigning Y to column 0
Y_df2 = df2[0]
print(Y_df2)

# The following line makes Y become a list
Y_df2 = np.array(Y_df2).reshape(-1)
print(X_df2.shape,Y_df2.shape)

list_titles = X_df2.columns

list_corr_df2 = []
for i in list_titles[0:1000]:
    print(i)
    list_corr_df2.append(abs(np.corrcoef(Y_df2, X_df2[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df2, X_df2[i])[0][1]))
# Out:
# 0      0.683541
# 1      0.827127
# 2      0.929321
# 3      0.669256
# 4      0.153948
#          ...
# 995    0.808768
# 996    0.474589
# 997    0.573353
# 998    0.644323
# 999    0.210506
# Name: 0, Length: 1000, dtype: float64
# (1000, 199999) (1000,)
# 1
# Correlation matrix for column 0 and and column1: 0.003245390535283828
# 2
# Correlation matrix for column 0 and and column2: 0.0219811816003659
# 3
# Correlation matrix for column 0 and and column3: -0.03974781731436399
# 4
# Correlation matrix for column 0 and and column4: -0.05048746628639718
# 5
# Correlation matrix for column 0 and and column5: -0.02842895054170089
# 6
# Correlation matrix for column 0 and and column6: 0.056251294251095964
# 7
# Correlation matrix for column 0 and and column7: -0.008514544834533837
# 8
# Correlation matrix for column 0 and and column8: 0.01041363358686422
# 9
# Correlation matrix for column 0 and and column9: -0.0251834549326992
# 10
# Correlation matrix for column 0 and and column10: -0.0267516070001874
# 11
# Correlation matrix for column 0 and and column11: -0.022304835674893192
# 12
# Correlation matrix for column 0 and and column12: 0.004362884114895319
# 13
# Correlation matrix for column 0 and and column13: -0.057277511330616135
# 14
# Correlation matrix for column 0 and and column14: -0.013399267993618149
# 15
# Correlation matrix for column 0 and and column15: 0.019180862046550885
# 16
# Correlation matrix for column 0 and and column16: 0.005081687268173062
# 17
# Correlation matrix for column 0 and and column17: 0.03532297270472694
# 18
# Correlation matrix for column 0 and and column18: 0.05054674614526506
# 19
# Correlation matrix for column 0 and and column19: 0.026954810909683997
# 20
# Correlation matrix for column 0 and and column20: 0.052237078273542896
# 21
# Correlation matrix for column 0 and and column21: -0.010785227926255839
# 22
# Correlation matrix for column 0 and and column22: 0.06525377019231442
# 23
# Correlation matrix for column 0 and and column23: -0.006257260482535902
# 24
# Correlation matrix for column 0 and and column24: -0.03610603136572753
# 25
# Correlation matrix for column 0 and and column25: 0.008544619017860789
# 26
# Correlation matrix for column 0 and and column26: -0.005278420124596995
# 27
# Correlation matrix for column 0 and and column27: -0.04513736173548537
# 28
# Correlation matrix for column 0 and and column28: 0.05126818530543022
# 29
# Correlation matrix for column 0 and and column29: -0.045319319437176604
# 30
# Correlation matrix for column 0 and and column30: -0.06386759820462816
# 31
# Correlation matrix for column 0 and and column31: -0.017816591551652425
# 32
# Correlation matrix for column 0 and and column32: -0.007233325745969127
# 33
# Correlation matrix for column 0 and and column33: 0.0007246275485175685
# 34
# Correlation matrix for column 0 and and column34: -0.03965136870435399
# 35
# Correlation matrix for column 0 and and column35: -0.003321435673799206
# 36
# Correlation matrix for column 0 and and column36: 0.016978255440251475
# 37
# Correlation matrix for column 0 and and column37: 0.018969385986591796
# 38
# Correlation matrix for column 0 and and column38: -0.014892698464382004
# 39
# Correlation matrix for column 0 and and column39: 0.0753036297516261
# 40
# Correlation matrix for column 0 and and column40: 0.034317227483227214
# 41
# Correlation matrix for column 0 and and column41: -0.007776134484245708
# 42
# Correlation matrix for column 0 and and column42: 0.008004166656011023
# 43
# Correlation matrix for column 0 and and column43: 0.022934104349470942
# 44
# Correlation matrix for column 0 and and column44: 0.0011005600539632703
# 45
# Correlation matrix for column 0 and and column45: -0.004169926976534808
# 46
# Correlation matrix for column 0 and and column46: -0.036401466662199004
# 47
# Correlation matrix for column 0 and and column47: 0.005108570448059109
# 48
# Correlation matrix for column 0 and and column48: 0.012848294067417365
# 49
# Correlation matrix for column 0 and and column49: 0.03544410478027051
# 50
# Correlation matrix for column 0 and and column50: -0.01587550928385893
# 51
# Correlation matrix for column 0 and and column51: -0.022490594783132374
# 52
# Correlation matrix for column 0 and and column52: -0.004294674010996293
# 53
# Correlation matrix for column 0 and and column53: -0.012705522848281204
# 54
# Correlation matrix for column 0 and and column54: -0.07317616066437255
# 55
# Correlation matrix for column 0 and and column55: 0.03289700197581993
# 56
# Correlation matrix for column 0 and and column56: -0.020363779320514874
# 57
# Correlation matrix for column 0 and and column57: 0.0012499878882574818
# 58
# Correlation matrix for column 0 and and column58: -0.031166909206934757
# 59
# Correlation matrix for column 0 and and column59: 0.0404546244410958
# 60
# Correlation matrix for column 0 and and column60: 0.02007052227659773
# 61
# Correlation matrix for column 0 and and column61: -0.010243080954859563
# 62
# Correlation matrix for column 0 and and column62: 0.009948656493263985
# 63
# Correlation matrix for column 0 and and column63: 0.022441566957989666
# 64
# Correlation matrix for column 0 and and column64: -0.010340194105041355
# 65
# Correlation matrix for column 0 and and column65: -0.05192524231674176
# 66
# Correlation matrix for column 0 and and column66: 0.04120143017148451
# 67
# Correlation matrix for column 0 and and column67: -0.004017144619729295
# 68
# Correlation matrix for column 0 and and column68: 0.03741881572084469
# 69
# Correlation matrix for column 0 and and column69: 0.0018888290735744177
# 70
# Correlation matrix for column 0 and and column70: 0.05895509539907025
# 71
# Correlation matrix for column 0 and and column71: 0.059301983569106737
# 72
# Correlation matrix for column 0 and and column72: -0.044440654424328756
# 73
# Correlation matrix for column 0 and and column73: 0.02399102083971256
# 74
# Correlation matrix for column 0 and and column74: -0.03915020635369714
# 75
# Correlation matrix for column 0 and and column75: -0.022220997021875397
# 76
# Correlation matrix for column 0 and and column76: 0.0022345640906309954
# 77
# Correlation matrix for column 0 and and column77: -0.002951657741389631
# 78
# Correlation matrix for column 0 and and column78: -0.06032617631068965
# 79
# Correlation matrix for column 0 and and column79: 0.028897911261163582
# 80
# Correlation matrix for column 0 and and column80: 0.062117311288516414
# 81
# Correlation matrix for column 0 and and column81: 0.01034065510112935
# 82
# Correlation matrix for column 0 and and column82: -0.029968563530258636
# 83
# Correlation matrix for column 0 and and column83: -0.007178406816675001
# 84
# Correlation matrix for column 0 and and column84: 0.05062719664543749
# 85
# Correlation matrix for column 0 and and column85: -0.009470363475771567
# 86
# Correlation matrix for column 0 and and column86: -0.051995384677734166
# 87
# Correlation matrix for column 0 and and column87: -0.013446833919060826
# 88
# Correlation matrix for column 0 and and column88: -0.013854751036915752
# 89
# Correlation matrix for column 0 and and column89: 0.0039284356034428305
# 90
# Correlation matrix for column 0 and and column90: 0.019937619361241787
# 91
# Correlation matrix for column 0 and and column91: 0.020996966008309803
# 92
# Correlation matrix for column 0 and and column92: -0.009037922254304881
# 93
# Correlation matrix for column 0 and and column93: 0.006438769298349469
# 94
# Correlation matrix for column 0 and and column94: 0.030204710708813073
# 95
# Correlation matrix for column 0 and and column95: -0.00196507349587646
# 96
# Correlation matrix for column 0 and and column96: -0.01789796036709886
# 97
# Correlation matrix for column 0 and and column97: 0.00804301365951665
# 98
# Correlation matrix for column 0 and and column98: -0.0493190264041537
# 99
# Correlation matrix for column 0 and and column99: -0.03850389533445495
# 100
# Correlation matrix for column 0 and and column100: -0.012069180153750107
# 101
# Correlation matrix for column 0 and and column101: 0.010629618162403749
# 102
# Correlation matrix for column 0 and and column102: -0.027714572465619064
# 103
# Correlation matrix for column 0 and and column103: 0.006894941331490552
# 104
# Correlation matrix for column 0 and and column104: -0.06169535848959963
# 105
# Correlation matrix for column 0 and and column105: -0.0037495946481538173
# 106
# Correlation matrix for column 0 and and column106: 0.05511491553131772
# 107
# Correlation matrix for column 0 and and column107: -0.04606041868286714
# 108
# Correlation matrix for column 0 and and column108: 0.025424803940104827
# 109
# Correlation matrix for column 0 and and column109: 0.05040887409042823
# 110
# Correlation matrix for column 0 and and column110: -0.06287110575928234
# 111
# Correlation matrix for column 0 and and column111: -0.03357095897682882
# 112
# Correlation matrix for column 0 and and column112: -0.015156792574285307
# 113
# Correlation matrix for column 0 and and column113: 0.019399568901301838
# 114
# Correlation matrix for column 0 and and column114: 0.023133478239253685
# 115
# Correlation matrix for column 0 and and column115: -0.037597712456082406
# 116
# Correlation matrix for column 0 and and column116: -0.02792949437279248
# 117
# Correlation matrix for column 0 and and column117: 0.01303505680895753
# 118
# Correlation matrix for column 0 and and column118: -0.012840504728137072
# 119
# Correlation matrix for column 0 and and column119: -0.03510363716184813
# 120
# Correlation matrix for column 0 and and column120: -0.04386300527582376
# 121
# Correlation matrix for column 0 and and column121: -0.03567864568312194
# 122
# Correlation matrix for column 0 and and column122: 0.012025602972317716
# 123
# Correlation matrix for column 0 and and column123: -0.01895725851553157
# 124
# Correlation matrix for column 0 and and column124: 0.06216945921370981
# 125
# Correlation matrix for column 0 and and column125: 0.04106181988713937
# 126
# Correlation matrix for column 0 and and column126: -0.08235260777900145
# 127
# Correlation matrix for column 0 and and column127: -0.014930865631984393
# 128
# Correlation matrix for column 0 and and column128: -0.05245934249057532
# 129
# Correlation matrix for column 0 and and column129: 0.01663088228113349
# 130
# Correlation matrix for column 0 and and column130: 0.018565587809408216
# 131
# Correlation matrix for column 0 and and column131: 0.00522407228809864
# 132
# Correlation matrix for column 0 and and column132: 0.0028516528659240908
# 133
# Correlation matrix for column 0 and and column133: -0.03115741816148659
# 134
# Correlation matrix for column 0 and and column134: -0.0011404844975080322
# 135
# Correlation matrix for column 0 and and column135: 0.05402266926567464
# 136
# Correlation matrix for column 0 and and column136: 0.021974907108506657
# 137
# Correlation matrix for column 0 and and column137: 0.03573489229075013
# 138
# Correlation matrix for column 0 and and column138: 0.024682730420597133
# 139
# Correlation matrix for column 0 and and column139: 0.009830175802579295
# 140
# Correlation matrix for column 0 and and column140: 0.03702944642205062
# 141
# Correlation matrix for column 0 and and column141: -0.00428198710235106
# 142
# Correlation matrix for column 0 and and column142: -0.07705823294839145
# 143
# Correlation matrix for column 0 and and column143: -0.0570987641361209
# 144
# Correlation matrix for column 0 and and column144: 0.020752638280760367
# 145
# Correlation matrix for column 0 and and column145: -0.010342096852014532
# 146
# Correlation matrix for column 0 and and column146: 0.026135953407216188
# 147
# Correlation matrix for column 0 and and column147: 0.001820119676246333
# 148
# Correlation matrix for column 0 and and column148: 0.0412222841789383
# 149
# Correlation matrix for column 0 and and column149: -0.0019724799523153746
# 150
# Correlation matrix for column 0 and and column150: 0.010144428351963997
# 151
# Correlation matrix for column 0 and and column151: -0.03133132222900731
# 152
# Correlation matrix for column 0 and and column152: 0.036239003073036596
# 153
# Correlation matrix for column 0 and and column153: 0.011604325110127163
# 154
# Correlation matrix for column 0 and and column154: -0.00028717150895059843
# 155
# Correlation matrix for column 0 and and column155: 0.005256065321232778
# 156
# Correlation matrix for column 0 and and column156: -0.03224748839666379
# 157
# Correlation matrix for column 0 and and column157: -0.028221310398386223
# 158
# Correlation matrix for column 0 and and column158: -0.020793718420887536
# 159
# Correlation matrix for column 0 and and column159: 0.01750665147925093
# 160
# Correlation matrix for column 0 and and column160: -0.027260303855988356
# 161
# Correlation matrix for column 0 and and column161: 0.002623161972230216
# 162
# Correlation matrix for column 0 and and column162: -0.011688033319123435
# 163
# Correlation matrix for column 0 and and column163: -0.015462238124370045
# 164
# Correlation matrix for column 0 and and column164: -0.0057475519450391
# 165
# Correlation matrix for column 0 and and column165: 0.00906863914226844
# 166
# Correlation matrix for column 0 and and column166: 0.03783339172335962
# 167
# Correlation matrix for column 0 and and column167: -0.06205470058364821
# 168
# Correlation matrix for column 0 and and column168: 0.00908057810075534
# 169
# Correlation matrix for column 0 and and column169: 0.027270580097166694
# 170
# Correlation matrix for column 0 and and column170: 0.018597308193863342
# 171
# Correlation matrix for column 0 and and column171: 0.04559777996483177
# 172
# Correlation matrix for column 0 and and column172: 0.02405437467619487
# 173
# Correlation matrix for column 0 and and column173: 0.05666840936896757
# 174
# Correlation matrix for column 0 and and column174: -0.02922515462095002
# 175
# Correlation matrix for column 0 and and column175: 0.009397858632695653
# 176
# Correlation matrix for column 0 and and column176: 0.030509234532290177
# 177
# Correlation matrix for column 0 and and column177: 0.0542274896692124
# 178
# Correlation matrix for column 0 and and column178: 0.01123179885928811
# 179
# Correlation matrix for column 0 and and column179: -0.014967539015247042
# 180
# Correlation matrix for column 0 and and column180: -0.019248203532743233
# 181
# Correlation matrix for column 0 and and column181: -0.04592481429288118
# 182
# Correlation matrix for column 0 and and column182: 0.009358407583303458
# 183
# Correlation matrix for column 0 and and column183: -0.02865584927934702
# 184
# Correlation matrix for column 0 and and column184: -0.005851848636998088
# 185
# Correlation matrix for column 0 and and column185: 0.008522201419476154
# 186
# Correlation matrix for column 0 and and column186: -0.031033681253376258
# 187
# Correlation matrix for column 0 and and column187: -0.03374413517047697
# 188
# Correlation matrix for column 0 and and column188: -0.015276942113249124
# 189
# Correlation matrix for column 0 and and column189: -0.0030144052923933616
# 190
# Correlation matrix for column 0 and and column190: 0.0059802117039752314
# 191
# Correlation matrix for column 0 and and column191: -0.002841880431551115
# 192
# Correlation matrix for column 0 and and column192: -0.022237504352974745
# 193
# Correlation matrix for column 0 and and column193: -0.011458580216004509
# 194
# Correlation matrix for column 0 and and column194: -0.0041146113253033205
# 195
# Correlation matrix for column 0 and and column195: -0.026130122285876193
# 196
# Correlation matrix for column 0 and and column196: -0.02930695219965206
# 197
# Correlation matrix for column 0 and and column197: 0.0578269553909384
# 198
# Correlation matrix for column 0 and and column198: 0.02501753644378731
# 199
# Correlation matrix for column 0 and and column199: 0.004485859498695766
# 200
# Correlation matrix for column 0 and and column200: -0.014624294967593973
# 201
# Correlation matrix for column 0 and and column201: 0.013167682685142006
# 202
# Correlation matrix for column 0 and and column202: 0.03483492668608574
# 203
# Correlation matrix for column 0 and and column203: 0.03959061663527286
# 204
# Correlation matrix for column 0 and and column204: -0.020292706409941384
# 205
# Correlation matrix for column 0 and and column205: -0.0003091949320332934
# 206
# Correlation matrix for column 0 and and column206: 0.021850959019877273
# 207
# Correlation matrix for column 0 and and column207: -0.026499656116265456
# 208
# Correlation matrix for column 0 and and column208: 0.022726127092916062
# 209
# Correlation matrix for column 0 and and column209: -0.004895714504928222
# 210
# Correlation matrix for column 0 and and column210: 0.00015699286668224708
# 211
# Correlation matrix for column 0 and and column211: 0.06462040481214881
# 212
# Correlation matrix for column 0 and and column212: 0.02484251231130407
# 213
# Correlation matrix for column 0 and and column213: -0.012505885803884913
# 214
# Correlation matrix for column 0 and and column214: 0.0262448881420591
# 215
# Correlation matrix for column 0 and and column215: 0.015007749509386296
# 216
# Correlation matrix for column 0 and and column216: -0.010173940684081423
# 217
# Correlation matrix for column 0 and and column217: 0.014469139937794244
# 218
# Correlation matrix for column 0 and and column218: -0.03145862593131497
# 219
# Correlation matrix for column 0 and and column219: -0.0008436600875386323
# 220
# Correlation matrix for column 0 and and column220: -0.06382640534835791
# 221
# Correlation matrix for column 0 and and column221: -0.017188936238852055
# 222
# Correlation matrix for column 0 and and column222: -0.03758851351807898
# 223
# Correlation matrix for column 0 and and column223: 0.063488672065536
# 224
# Correlation matrix for column 0 and and column224: 0.016516838196860777
# 225
# Correlation matrix for column 0 and and column225: 0.013794169451997207
# 226
# Correlation matrix for column 0 and and column226: 0.020743625735012445
# 227
# Correlation matrix for column 0 and and column227: -0.033518652972930864
# 228
# Correlation matrix for column 0 and and column228: 0.004053588079800492
# 229
# Correlation matrix for column 0 and and column229: 0.045421496754142636
# 230
# Correlation matrix for column 0 and and column230: -0.04286864294760641
# 231
# Correlation matrix for column 0 and and column231: -0.02017306423833786
# 232
# Correlation matrix for column 0 and and column232: -0.008881692321169095
# 233
# Correlation matrix for column 0 and and column233: -0.00346202510972628
# 234
# Correlation matrix for column 0 and and column234: 0.008966241016630258
# 235
# Correlation matrix for column 0 and and column235: -0.02586355674634835
# 236
# Correlation matrix for column 0 and and column236: 0.012638012513357944
# 237
# Correlation matrix for column 0 and and column237: -0.0004918500276036411
# 238
# Correlation matrix for column 0 and and column238: 0.012088772259256938
# 239
# Correlation matrix for column 0 and and column239: -0.020270917363548368
# 240
# Correlation matrix for column 0 and and column240: -0.02432618892697268
# 241
# Correlation matrix for column 0 and and column241: -0.01690251313761417
# 242
# Correlation matrix for column 0 and and column242: 0.045359183732433174
# 243
# Correlation matrix for column 0 and and column243: -0.003245935199909019
# 244
# Correlation matrix for column 0 and and column244: -0.0440078291862291
# 245
# Correlation matrix for column 0 and and column245: 0.005819168944349236
# 246
# Correlation matrix for column 0 and and column246: 0.01171822103706911
# 247
# Correlation matrix for column 0 and and column247: 0.03299238251821485
# 248
# Correlation matrix for column 0 and and column248: -0.0205019746945834
# 249
# Correlation matrix for column 0 and and column249: -0.007960157704564062
# 250
# Correlation matrix for column 0 and and column250: 0.00975762919280613
# 251
# Correlation matrix for column 0 and and column251: -0.028629522534049226
# 252
# Correlation matrix for column 0 and and column252: -0.01240113262152229
# 253
# Correlation matrix for column 0 and and column253: 0.023124633434992624
# 254
# Correlation matrix for column 0 and and column254: -0.02332329138265606
# 255
# Correlation matrix for column 0 and and column255: 0.00903630880146608
# 256
# Correlation matrix for column 0 and and column256: -0.020156859127241158
# 257
# Correlation matrix for column 0 and and column257: 0.01159064712409537
# 258
# Correlation matrix for column 0 and and column258: -0.03326574627680795
# 259
# Correlation matrix for column 0 and and column259: -0.010125248198943722
# 260
# Correlation matrix for column 0 and and column260: 0.04591854318999926
# 261
# Correlation matrix for column 0 and and column261: 0.019492622428886504
# 262
# Correlation matrix for column 0 and and column262: 0.05212737330005319
# 263
# Correlation matrix for column 0 and and column263: 0.02679931391424052
# 264
# Correlation matrix for column 0 and and column264: 0.021692449944405046
# 265
# Correlation matrix for column 0 and and column265: 0.03029466631307164
# 266
# Correlation matrix for column 0 and and column266: 0.027311028338516827
# 267
# Correlation matrix for column 0 and and column267: -0.011555581602078716
# 268
# Correlation matrix for column 0 and and column268: 0.003936967203112496
# 269
# Correlation matrix for column 0 and and column269: -0.068747869809149
# 270
# Correlation matrix for column 0 and and column270: -0.00107959922814795
# 271
# Correlation matrix for column 0 and and column271: -0.011439901639160845
# 272
# Correlation matrix for column 0 and and column272: 0.011141884224454427
# 273
# Correlation matrix for column 0 and and column273: 0.04830444346233652
# 274
# Correlation matrix for column 0 and and column274: -0.002169786545903261
# 275
# Correlation matrix for column 0 and and column275: 0.04739314594865651
# 276
# Correlation matrix for column 0 and and column276: -0.019048115562054838
# 277
# Correlation matrix for column 0 and and column277: 0.024500390622054825
# 278
# Correlation matrix for column 0 and and column278: 0.07925139593956594
# 279
# Correlation matrix for column 0 and and column279: -0.05302507345148772
# 280
# Correlation matrix for column 0 and and column280: 0.027680502329924396
# 281
# Correlation matrix for column 0 and and column281: -0.020707048051176746
# 282
# Correlation matrix for column 0 and and column282: 0.04228564504600611
# 283
# Correlation matrix for column 0 and and column283: 0.020651924037533527
# 284
# Correlation matrix for column 0 and and column284: -0.01847679643326182
# 285
# Correlation matrix for column 0 and and column285: -0.03531294693864501
# 286
# Correlation matrix for column 0 and and column286: -0.007090409681406417
# 287
# Correlation matrix for column 0 and and column287: 0.017828567455748512
# 288
# Correlation matrix for column 0 and and column288: 0.02564302182141835
# 289
# Correlation matrix for column 0 and and column289: 0.05200666303020669
# 290
# Correlation matrix for column 0 and and column290: 0.009582620265208433
# 291
# Correlation matrix for column 0 and and column291: -0.0013493356404244094
# 292
# Correlation matrix for column 0 and and column292: -0.0020201401113790624
# 293
# Correlation matrix for column 0 and and column293: 0.06704606265044133
# 294
# Correlation matrix for column 0 and and column294: 0.03488383317402812
# 295
# Correlation matrix for column 0 and and column295: -0.027582421473788934
# 296
# Correlation matrix for column 0 and and column296: 0.03427471936019118
# 297
# Correlation matrix for column 0 and and column297: -0.0534172215141375
# 298
# Correlation matrix for column 0 and and column298: 0.009116556786464338
# 299
# Correlation matrix for column 0 and and column299: 0.017759455720380294
# 300
# Correlation matrix for column 0 and and column300: 0.015359423247671868
# 301
# Correlation matrix for column 0 and and column301: 0.003113322448786208
# 302
# Correlation matrix for column 0 and and column302: -0.010159453858343168
# 303
# Correlation matrix for column 0 and and column303: -0.03202343499327355
# 304
# Correlation matrix for column 0 and and column304: 0.011534259603446204
# 305
# Correlation matrix for column 0 and and column305: -0.032529223626513254
# 306
# Correlation matrix for column 0 and and column306: -0.0014609245729631578
# 307
# Correlation matrix for column 0 and and column307: -0.03942922551332662
# 308
# Correlation matrix for column 0 and and column308: 0.028910740467842526
# 309
# Correlation matrix for column 0 and and column309: 0.018645191013865386
# 310
# Correlation matrix for column 0 and and column310: 0.015941777037967182
# 311
# Correlation matrix for column 0 and and column311: 0.009049417125572843
# 312
# Correlation matrix for column 0 and and column312: -0.07515310632032982
# 313
# Correlation matrix for column 0 and and column313: 0.011270875337861995
# 314
# Correlation matrix for column 0 and and column314: -0.038763060670499054
# 315
# Correlation matrix for column 0 and and column315: -0.04281806970952691
# 316
# Correlation matrix for column 0 and and column316: -0.024496127468056263
# 317
# Correlation matrix for column 0 and and column317: 0.00950992424116837
# 318
# Correlation matrix for column 0 and and column318: 0.042929504197740435
# 319
# Correlation matrix for column 0 and and column319: 0.010459762071649434
# 320
# Correlation matrix for column 0 and and column320: 0.0018690721397387144
# 321
# Correlation matrix for column 0 and and column321: -0.05522968626079675
# 322
# Correlation matrix for column 0 and and column322: 0.0395548576100304
# 323
# Correlation matrix for column 0 and and column323: -0.014403857628334366
# 324
# Correlation matrix for column 0 and and column324: 0.06456966892194879
# 325
# Correlation matrix for column 0 and and column325: -0.015057116196618777
# 326
# Correlation matrix for column 0 and and column326: -0.009818521609884313
# 327
# Correlation matrix for column 0 and and column327: 0.024978825912149106
# 328
# Correlation matrix for column 0 and and column328: 0.01568485327996788
# 329
# Correlation matrix for column 0 and and column329: -0.017944130728204315
# 330
# Correlation matrix for column 0 and and column330: -4.227476433743566e-05
# 331
# Correlation matrix for column 0 and and column331: 0.01682614825798105
# 332
# Correlation matrix for column 0 and and column332: 0.0020739711530354667
# 333
# Correlation matrix for column 0 and and column333: 0.059550668633554044
# 334
# Correlation matrix for column 0 and and column334: -0.019567470819622908
# 335
# Correlation matrix for column 0 and and column335: 0.006182014984133862
# 336
# Correlation matrix for column 0 and and column336: 0.010591685867362945
# 337
# Correlation matrix for column 0 and and column337: -0.0583194423749215
# 338
# Correlation matrix for column 0 and and column338: -0.04348502724365143
# 339
# Correlation matrix for column 0 and and column339: -0.006626231450225576
# 340
# Correlation matrix for column 0 and and column340: -0.07112323714569571
# 341
# Correlation matrix for column 0 and and column341: -0.016186184395072616
# 342
# Correlation matrix for column 0 and and column342: 0.022631647468052195
# 343
# Correlation matrix for column 0 and and column343: -0.055539061280091354
# 344
# Correlation matrix for column 0 and and column344: 0.05706803871817384
# 345
# Correlation matrix for column 0 and and column345: -0.01570823165160348
# 346
# Correlation matrix for column 0 and and column346: -0.05051435947565104
# 347
# Correlation matrix for column 0 and and column347: 0.044267513494208925
# 348
# Correlation matrix for column 0 and and column348: -0.04737224760862579
# 349
# Correlation matrix for column 0 and and column349: -6.287096560722142e-05
# 350
# Correlation matrix for column 0 and and column350: -0.039758826007498436
# 351
# Correlation matrix for column 0 and and column351: -0.014333374164847947
# 352
# Correlation matrix for column 0 and and column352: -0.03209295818638392
# 353
# Correlation matrix for column 0 and and column353: 0.029913859220636108
# 354
# Correlation matrix for column 0 and and column354: 0.04493989915404972
# 355
# Correlation matrix for column 0 and and column355: 0.039866637283027695
# 356
# Correlation matrix for column 0 and and column356: 0.004898964251148894
# 357
# Correlation matrix for column 0 and and column357: -0.009148193252802223
# 358
# Correlation matrix for column 0 and and column358: 0.012922935771594321
# 359
# Correlation matrix for column 0 and and column359: -0.027812136459823906
# 360
# Correlation matrix for column 0 and and column360: 0.02385480523948077
# 361
# Correlation matrix for column 0 and and column361: 0.034721955962619136
# 362
# Correlation matrix for column 0 and and column362: 0.03255573576851043
# 363
# Correlation matrix for column 0 and and column363: -0.03537011041776576
# 364
# Correlation matrix for column 0 and and column364: 0.01577735332461362
# 365
# Correlation matrix for column 0 and and column365: -0.014546820063916954
# 366
# Correlation matrix for column 0 and and column366: 0.020081012425282287
# 367
# Correlation matrix for column 0 and and column367: -0.047083817148310565
# 368
# Correlation matrix for column 0 and and column368: 0.0038970438393923605
# 369
# Correlation matrix for column 0 and and column369: 0.016940978956846348
# 370
# Correlation matrix for column 0 and and column370: 0.011149949788966019
# 371
# Correlation matrix for column 0 and and column371: -0.032812003712706185
# 372
# Correlation matrix for column 0 and and column372: 0.028072088610384117
# 373
# Correlation matrix for column 0 and and column373: 0.03785235075672986
# 374
# Correlation matrix for column 0 and and column374: 0.0001882716991214352
# 375
# Correlation matrix for column 0 and and column375: 0.022334889574183604
# 376
# Correlation matrix for column 0 and and column376: -0.004595626285039566
# 377
# Correlation matrix for column 0 and and column377: -0.02107176265935597
# 378
# Correlation matrix for column 0 and and column378: 0.02873166562696616
# 379
# Correlation matrix for column 0 and and column379: 0.005493042007426797
# 380
# Correlation matrix for column 0 and and column380: 0.04666429870070812
# 381
# Correlation matrix for column 0 and and column381: -0.02459797400966241
# 382
# Correlation matrix for column 0 and and column382: -0.042679431497409055
# 383
# Correlation matrix for column 0 and and column383: 0.012941697071580606
# 384
# Correlation matrix for column 0 and and column384: 0.03736308644727683
# 385
# Correlation matrix for column 0 and and column385: 0.04434988577764298
# 386
# Correlation matrix for column 0 and and column386: -0.03233853066875025
# 387
# Correlation matrix for column 0 and and column387: 0.0009873995172531556
# 388
# Correlation matrix for column 0 and and column388: -0.030574151541202917
# 389
# Correlation matrix for column 0 and and column389: 0.015857296327530652
# 390
# Correlation matrix for column 0 and and column390: 0.05385287427108748
# 391
# Correlation matrix for column 0 and and column391: 0.01089601744331825
# 392
# Correlation matrix for column 0 and and column392: -0.009037516586717913
# 393
# Correlation matrix for column 0 and and column393: 0.03300843817924709
# 394
# Correlation matrix for column 0 and and column394: -0.042374741213600374
# 395
# Correlation matrix for column 0 and and column395: 0.00667539779289172
# 396
# Correlation matrix for column 0 and and column396: 0.003839876374387412
# 397
# Correlation matrix for column 0 and and column397: -0.01004127179251761
# 398
# Correlation matrix for column 0 and and column398: 0.05365036111125495
# 399
# Correlation matrix for column 0 and and column399: -0.001908043675480527
# 400
# Correlation matrix for column 0 and and column400: 0.009767795906535218
# 401
# Correlation matrix for column 0 and and column401: 0.015175495457761992
# 402
# Correlation matrix for column 0 and and column402: -0.024657641607792102
# 403
# Correlation matrix for column 0 and and column403: -0.008857481622094656
# 404
# Correlation matrix for column 0 and and column404: 0.025813828911904608
# 405
# Correlation matrix for column 0 and and column405: -0.04106802329782632
# 406
# Correlation matrix for column 0 and and column406: -0.035757126691172536
# 407
# Correlation matrix for column 0 and and column407: 0.022356723431073176
# 408
# Correlation matrix for column 0 and and column408: 0.02424536733704538
# 409
# Correlation matrix for column 0 and and column409: -0.034933380725599435
# 410
# Correlation matrix for column 0 and and column410: -0.008529879735160124
# 411
# Correlation matrix for column 0 and and column411: 0.020312332779080323
# 412
# Correlation matrix for column 0 and and column412: -0.0038546568493688575
# 413
# Correlation matrix for column 0 and and column413: -0.04100286198316657
# 414
# Correlation matrix for column 0 and and column414: -0.03452450600156487
# 415
# Correlation matrix for column 0 and and column415: 0.012927582690888374
# 416
# Correlation matrix for column 0 and and column416: -0.05055936442791165
# 417
# Correlation matrix for column 0 and and column417: -0.06300012043979121
# 418
# Correlation matrix for column 0 and and column418: -0.03468998468358944
# 419
# Correlation matrix for column 0 and and column419: 0.0682176529752083
# 420
# Correlation matrix for column 0 and and column420: -0.008381818377048808
# 421
# Correlation matrix for column 0 and and column421: 0.043830653869767006
# 422
# Correlation matrix for column 0 and and column422: 0.02533899272540053
# 423
# Correlation matrix for column 0 and and column423: 0.00029394814676223153
# 424
# Correlation matrix for column 0 and and column424: -0.006752523007872064
# 425
# Correlation matrix for column 0 and and column425: -0.012245622575364289
# 426
# Correlation matrix for column 0 and and column426: -0.012158286870464623
# 427
# Correlation matrix for column 0 and and column427: 0.03636536748102473
# 428
# Correlation matrix for column 0 and and column428: -0.045180660056371585
# 429
# Correlation matrix for column 0 and and column429: 0.0045769944154881005
# 430
# Correlation matrix for column 0 and and column430: 0.04847350487959325
# 431
# Correlation matrix for column 0 and and column431: 0.008903377885428112
# 432
# Correlation matrix for column 0 and and column432: 0.02807672831671995
# 433
# Correlation matrix for column 0 and and column433: -0.052136358586656995
# 434
# Correlation matrix for column 0 and and column434: 0.029270571605853772
# 435
# Correlation matrix for column 0 and and column435: 0.018971255558538607
# 436
# Correlation matrix for column 0 and and column436: 0.01609551672342238
# 437
# Correlation matrix for column 0 and and column437: -0.020065694715284146
# 438
# Correlation matrix for column 0 and and column438: 0.011347070590888856
# 439
# Correlation matrix for column 0 and and column439: 0.018595064742521657
# 440
# Correlation matrix for column 0 and and column440: -0.04741365068320275
# 441
# Correlation matrix for column 0 and and column441: 0.07027389526583717
# 442
# Correlation matrix for column 0 and and column442: 0.03652935177753297
# 443
# Correlation matrix for column 0 and and column443: 0.0018268885750617025
# 444
# Correlation matrix for column 0 and and column444: -0.008459065767690262
# 445
# Correlation matrix for column 0 and and column445: -0.011373695394099527
# 446
# Correlation matrix for column 0 and and column446: -0.002702076685615568
# 447
# Correlation matrix for column 0 and and column447: -0.04769650780801634
# 448
# Correlation matrix for column 0 and and column448: -0.005753453276356878
# 449
# Correlation matrix for column 0 and and column449: -0.021404741672528163
# 450
# Correlation matrix for column 0 and and column450: 0.046037054118568746
# 451
# Correlation matrix for column 0 and and column451: 0.024116479301138465
# 452
# Correlation matrix for column 0 and and column452: -0.04303781164034894
# 453
# Correlation matrix for column 0 and and column453: 0.08448148205710158
# 454
# Correlation matrix for column 0 and and column454: -0.017671564658595557
# 455
# Correlation matrix for column 0 and and column455: 0.00029896858339626206
# 456
# Correlation matrix for column 0 and and column456: -0.023961442405407655
# 457
# Correlation matrix for column 0 and and column457: 0.014348231561813115
# 458
# Correlation matrix for column 0 and and column458: -0.019945841848146705
# 459
# Correlation matrix for column 0 and and column459: 0.047463989580795174
# 460
# Correlation matrix for column 0 and and column460: 0.02966937964666284
# 461
# Correlation matrix for column 0 and and column461: -0.0010110072406728887
# 462
# Correlation matrix for column 0 and and column462: 0.029592160424198106
# 463
# Correlation matrix for column 0 and and column463: 0.010922002725831532
# 464
# Correlation matrix for column 0 and and column464: -0.03110021786701308
# 465
# Correlation matrix for column 0 and and column465: -0.05715246385902234
# 466
# Correlation matrix for column 0 and and column466: -0.038253914016739866
# 467
# Correlation matrix for column 0 and and column467: 0.006632332475367807
# 468
# Correlation matrix for column 0 and and column468: -0.015082913454882737
# 469
# Correlation matrix for column 0 and and column469: 0.010951914255475313
# 470
# Correlation matrix for column 0 and and column470: 0.0046814266924246955
# 471
# Correlation matrix for column 0 and and column471: -0.04096667355352821
# 472
# Correlation matrix for column 0 and and column472: 0.039576431516836263
# 473
# Correlation matrix for column 0 and and column473: -0.041167835573146246
# 474
# Correlation matrix for column 0 and and column474: -0.032423180711366205
# 475
# Correlation matrix for column 0 and and column475: -0.00504886923382497
# 476
# Correlation matrix for column 0 and and column476: -0.01715180236847581
# 477
# Correlation matrix for column 0 and and column477: -0.04488760269987353
# 478
# Correlation matrix for column 0 and and column478: -0.005958579253192275
# 479
# Correlation matrix for column 0 and and column479: 0.03406840052709041
# 480
# Correlation matrix for column 0 and and column480: -0.003289839443957107
# 481
# Correlation matrix for column 0 and and column481: -0.01664982186214105
# 482
# Correlation matrix for column 0 and and column482: 0.031852138187119496
# 483
# Correlation matrix for column 0 and and column483: -0.02170262589856085
# 484
# Correlation matrix for column 0 and and column484: 0.028509559128670817
# 485
# Correlation matrix for column 0 and and column485: 0.01771440375447976
# 486
# Correlation matrix for column 0 and and column486: -0.0028918695704126026
# 487
# Correlation matrix for column 0 and and column487: 0.014756810140344693
# 488
# Correlation matrix for column 0 and and column488: 0.0023161468964056553
# 489
# Correlation matrix for column 0 and and column489: -0.017460605443540944
# 490
# Correlation matrix for column 0 and and column490: -0.037249761980961305
# 491
# Correlation matrix for column 0 and and column491: 0.03198002266174744
# 492
# Correlation matrix for column 0 and and column492: -0.0032248067419966154
# 493
# Correlation matrix for column 0 and and column493: 0.01956944198658621
# 494
# Correlation matrix for column 0 and and column494: -0.008764817433839589
# 495
# Correlation matrix for column 0 and and column495: -0.044523990180121785
# 496
# Correlation matrix for column 0 and and column496: 0.01576784833699648
# 497
# Correlation matrix for column 0 and and column497: -0.023405991832547865
# 498
# Correlation matrix for column 0 and and column498: 0.032708561003866585
# 499
# Correlation matrix for column 0 and and column499: 0.029644599246180278
# 500
# Correlation matrix for column 0 and and column500: 0.003976596839875827
# 501
# Correlation matrix for column 0 and and column501: 0.02342303309632284
# 502
# Correlation matrix for column 0 and and column502: 0.01674106172177011
# 503
# Correlation matrix for column 0 and and column503: -0.008062977940370879
# 504
# Correlation matrix for column 0 and and column504: -0.017291920538982812
# 505
# Correlation matrix for column 0 and and column505: 0.056379258745043175
# 506
# Correlation matrix for column 0 and and column506: 0.04519339001905893
# 507
# Correlation matrix for column 0 and and column507: 0.028647290507190646
# 508
# Correlation matrix for column 0 and and column508: -0.013550081931815517
# 509
# Correlation matrix for column 0 and and column509: -0.0443245778096101
# 510
# Correlation matrix for column 0 and and column510: -0.02203288464828064
# 511
# Correlation matrix for column 0 and and column511: 0.0023654204377724568
# 512
# Correlation matrix for column 0 and and column512: -0.023955151330128207
# 513
# Correlation matrix for column 0 and and column513: -0.006375710331583498
# 514
# Correlation matrix for column 0 and and column514: 0.017980603530231568
# 515
# Correlation matrix for column 0 and and column515: -0.013370661719338199
# 516
# Correlation matrix for column 0 and and column516: -0.042094170058982354
# 517
# Correlation matrix for column 0 and and column517: 0.006436268424014204
# 518
# Correlation matrix for column 0 and and column518: 0.030019147239503337
# 519
# Correlation matrix for column 0 and and column519: -0.01856179882133416
# 520
# Correlation matrix for column 0 and and column520: 0.04656031126796782
# 521
# Correlation matrix for column 0 and and column521: 0.006767599985170791
# 522
# Correlation matrix for column 0 and and column522: 0.016299531184463763
# 523
# Correlation matrix for column 0 and and column523: 0.018653336710832823
# 524
# Correlation matrix for column 0 and and column524: -0.00805966888306734
# 525
# Correlation matrix for column 0 and and column525: 0.00231622921265995
# 526
# Correlation matrix for column 0 and and column526: 0.018280301820844294
# 527
# Correlation matrix for column 0 and and column527: -0.029508937512523706
# 528
# Correlation matrix for column 0 and and column528: 0.05538738255912531
# 529
# Correlation matrix for column 0 and and column529: 0.04428031432363375
# 530
# Correlation matrix for column 0 and and column530: 0.014843794361519516
# 531
# Correlation matrix for column 0 and and column531: 0.011896562836260258
# 532
# Correlation matrix for column 0 and and column532: 0.06118894373029318
# 533
# Correlation matrix for column 0 and and column533: -0.007620550411728904
# 534
# Correlation matrix for column 0 and and column534: 0.08508477839280898
# 535
# Correlation matrix for column 0 and and column535: 0.08989201749229284
# 536
# Correlation matrix for column 0 and and column536: 0.032590933398156476
# 537
# Correlation matrix for column 0 and and column537: 0.005896505070577439
# 538
# Correlation matrix for column 0 and and column538: -0.028617342796142524
# 539
# Correlation matrix for column 0 and and column539: 0.023566980471948433
# 540
# Correlation matrix for column 0 and and column540: -0.07890849891759283
# 541
# Correlation matrix for column 0 and and column541: -0.03600218508074304
# 542
# Correlation matrix for column 0 and and column542: -0.010996882200070099
# 543
# Correlation matrix for column 0 and and column543: -0.050689875516495786
# 544
# Correlation matrix for column 0 and and column544: -0.020106245961963937
# 545
# Correlation matrix for column 0 and and column545: 0.013022611848180907
# 546
# Correlation matrix for column 0 and and column546: 0.010684815502925287
# 547
# Correlation matrix for column 0 and and column547: -0.00785963643345209
# 548
# Correlation matrix for column 0 and and column548: 0.03870348734533752
# 549
# Correlation matrix for column 0 and and column549: 0.03888195549777736
# 550
# Correlation matrix for column 0 and and column550: -0.05225282154291587
# 551
# Correlation matrix for column 0 and and column551: 0.014127390683286861
# 552
# Correlation matrix for column 0 and and column552: -0.017086508848458234
# 553
# Correlation matrix for column 0 and and column553: 0.015792683507493865
# 554
# Correlation matrix for column 0 and and column554: -0.06728797912887366
# 555
# Correlation matrix for column 0 and and column555: 0.005121243450735132
# 556
# Correlation matrix for column 0 and and column556: -0.02970897290817035
# 557
# Correlation matrix for column 0 and and column557: -0.022451953707771297
# 558
# Correlation matrix for column 0 and and column558: 0.01107785039041042
# 559
# Correlation matrix for column 0 and and column559: 0.04141683688692112
# 560
# Correlation matrix for column 0 and and column560: 0.0010109518339744676
# 561
# Correlation matrix for column 0 and and column561: 0.04624310350208642
# 562
# Correlation matrix for column 0 and and column562: -0.004163167164358257
# 563
# Correlation matrix for column 0 and and column563: 0.0025608000401895143
# 564
# Correlation matrix for column 0 and and column564: 0.0007484807099197855
# 565
# Correlation matrix for column 0 and and column565: 0.015122321722816572
# 566
# Correlation matrix for column 0 and and column566: 0.028272115963215494
# 567
# Correlation matrix for column 0 and and column567: -0.007572151430425341
# 568
# Correlation matrix for column 0 and and column568: -0.023248322669486905
# 569
# Correlation matrix for column 0 and and column569: -0.011574490251818673
# 570
# Correlation matrix for column 0 and and column570: -0.012367621848358474
# 571
# Correlation matrix for column 0 and and column571: 0.017888896158970154
# 572
# Correlation matrix for column 0 and and column572: 0.015023126307437608
# 573
# Correlation matrix for column 0 and and column573: 0.020296220524671723
# 574
# Correlation matrix for column 0 and and column574: 0.003825321215668278
# 575
# Correlation matrix for column 0 and and column575: 0.002138231902724432
# 576
# Correlation matrix for column 0 and and column576: -0.04238179439366443
# 577
# Correlation matrix for column 0 and and column577: -0.04996127471538376
# 578
# Correlation matrix for column 0 and and column578: -0.010810801430966889
# 579
# Correlation matrix for column 0 and and column579: 0.003302815235447304
# 580
# Correlation matrix for column 0 and and column580: 0.06870026728462332
# 581
# Correlation matrix for column 0 and and column581: -0.08273191285028601
# 582
# Correlation matrix for column 0 and and column582: 0.037827562414963
# 583
# Correlation matrix for column 0 and and column583: -0.015501372747360138
# 584
# Correlation matrix for column 0 and and column584: 0.008862914207237733
# 585
# Correlation matrix for column 0 and and column585: -0.033554421864940044
# 586
# Correlation matrix for column 0 and and column586: -0.028411951018057352
# 587
# Correlation matrix for column 0 and and column587: 0.0071884110017057835
# 588
# Correlation matrix for column 0 and and column588: 0.016890234791029735
# 589
# Correlation matrix for column 0 and and column589: 0.02544385693854725
# 590
# Correlation matrix for column 0 and and column590: 0.005331147151574319
# 591
# Correlation matrix for column 0 and and column591: 0.011017531621513315
# 592
# Correlation matrix for column 0 and and column592: -0.01525986271987862
# 593
# Correlation matrix for column 0 and and column593: -0.028848778100745112
# 594
# Correlation matrix for column 0 and and column594: -0.02892735711753711
# 595
# Correlation matrix for column 0 and and column595: 0.01930268655905942
# 596
# Correlation matrix for column 0 and and column596: 0.0024395699062736698
# 597
# Correlation matrix for column 0 and and column597: -0.059134218010961054
# 598
# Correlation matrix for column 0 and and column598: 0.08625853497984591
# 599
# Correlation matrix for column 0 and and column599: -0.03809342875504254
# 600
# Correlation matrix for column 0 and and column600: -0.035170362376429516
# 601
# Correlation matrix for column 0 and and column601: 0.04119928948393108
# 602
# Correlation matrix for column 0 and and column602: -0.020220107576228812
# 603
# Correlation matrix for column 0 and and column603: -0.08482843842319505
# 604
# Correlation matrix for column 0 and and column604: -0.013259728203296241
# 605
# Correlation matrix for column 0 and and column605: 0.01397928112365018
# 606
# Correlation matrix for column 0 and and column606: 0.00015213015741490844
# 607
# Correlation matrix for column 0 and and column607: -0.04671853555055445
# 608
# Correlation matrix for column 0 and and column608: -0.011422146456331902
# 609
# Correlation matrix for column 0 and and column609: 0.0351891274238866
# 610
# Correlation matrix for column 0 and and column610: 0.0265230830971765
# 611
# Correlation matrix for column 0 and and column611: 0.03986372088977298
# 612
# Correlation matrix for column 0 and and column612: 0.010388462558325049
# 613
# Correlation matrix for column 0 and and column613: -0.01876108676798554
# 614
# Correlation matrix for column 0 and and column614: 0.06980080953808329
# 615
# Correlation matrix for column 0 and and column615: 0.004556932981719047
# 616
# Correlation matrix for column 0 and and column616: 0.002230354497469163
# 617
# Correlation matrix for column 0 and and column617: -0.05597237686880072
# 618
# Correlation matrix for column 0 and and column618: 0.00956254525887392
# 619
# Correlation matrix for column 0 and and column619: 0.028229591732500003
# 620
# Correlation matrix for column 0 and and column620: -0.02274867205448618
# 621
# Correlation matrix for column 0 and and column621: 0.02359396239132107
# 622
# Correlation matrix for column 0 and and column622: -0.009753856627106684
# 623
# Correlation matrix for column 0 and and column623: 0.008238090248798142
# 624
# Correlation matrix for column 0 and and column624: -0.0089265781617878
# 625
# Correlation matrix for column 0 and and column625: 0.07449194405820748
# 626
# Correlation matrix for column 0 and and column626: 0.041026366855957536
# 627
# Correlation matrix for column 0 and and column627: 0.014818493062576666
# 628
# Correlation matrix for column 0 and and column628: 0.0499782098551745
# 629
# Correlation matrix for column 0 and and column629: 0.013248573651032639
# 630
# Correlation matrix for column 0 and and column630: 0.001707657000451598
# 631
# ...
# Correlation matrix for column 0 and and column791: -0.015734241755015966
# 792
# Correlation matrix for column 0 and and column792: 0.01914465996281327
# 793
# Correlation matrix for column 0 and and column793: 0.0397150998175672
# 794
# Correlation matrix for column 0 and and column794: 0.011120425567400474
# 795
# Correlation matrix for column 0 and and column795: -0.012673957595934555
# 796
# Correlation matrix for column 0 and and column796: -0.05512146468172894
# 797
# Correlation matrix for column 0 and and column797: 0.0187418333173712
# 798
# Correlation matrix for column 0 and and column798: 0.04929035647882812
# 799
# Correlation matrix for column 0 and and column799: 0.0071345727353920516
# 800
# Correlation matrix for column 0 and and column800: -0.047441184261077865
# 801
# Correlation matrix for column 0 and and column801: 0.00971655672541502
# 802
# Correlation matrix for column 0 and and column802: -0.03568952138134177
# 803
# Correlation matrix for column 0 and and column803: 0.004693490237373167
# 804
# Correlation matrix for column 0 and and column804: 0.0032049547491529275
# 805
# Correlation matrix for column 0 and and column805: 0.010211443446137057
# 806
# Correlation matrix for column 0 and and column806: -0.022467419413865188
# 807
# Correlation matrix for column 0 and and column807: 0.07943885495866178
# 808
# Correlation matrix for column 0 and and column808: -0.040838121133422195
# 809
# Correlation matrix for column 0 and and column809: -0.04659508371512232
# 810
# Correlation matrix for column 0 and and column810: -0.016550472163323025
# 811
# Correlation matrix for column 0 and and column811: -0.015767599162621115
# 812
# Correlation matrix for column 0 and and column812: -0.005069204032041974
# 813
# Correlation matrix for column 0 and and column813: 0.03716596411532302
# 814
# Correlation matrix for column 0 and and column814: 0.0014159675666988406
# 815
# Correlation matrix for column 0 and and column815: 0.021144288950150858
# 816
# Correlation matrix for column 0 and and column816: 0.015478745675526503
# 817
# Correlation matrix for column 0 and and column817: 0.004064754436215413
# 818
# Correlation matrix for column 0 and and column818: 0.0035216402313369755
# 819
# Correlation matrix for column 0 and and column819: 0.029122676155675733
# 820
# Correlation matrix for column 0 and and column820: 0.020892918769204533
# 821
# Correlation matrix for column 0 and and column821: 0.06162044963125596
# 822
# Correlation matrix for column 0 and and column822: -0.036868100987529295
# 823
# Correlation matrix for column 0 and and column823: 0.011788799760305035
# 824
# Correlation matrix for column 0 and and column824: -0.03388126353491223
# 825
# Correlation matrix for column 0 and and column825: 0.04502412810220308
# 826
# Correlation matrix for column 0 and and column826: 0.030154489348822196
# 827
# Correlation matrix for column 0 and and column827: 0.03555282662372501
# 828
# Correlation matrix for column 0 and and column828: -0.0024368743632167144
# 829
# Correlation matrix for column 0 and and column829: -0.005845212576074837
# 830
# Correlation matrix for column 0 and and column830: 0.006794115526722556
# 831
# Correlation matrix for column 0 and and column831: 0.02524001000253082
# 832
# Correlation matrix for column 0 and and column832: 0.017738582002537147
# 833
# Correlation matrix for column 0 and and column833: -0.015857348676028296
# 834
# Correlation matrix for column 0 and and column834: -0.0374681407307112
# 835
# Correlation matrix for column 0 and and column835: -0.01184566503381294
# 836
# Correlation matrix for column 0 and and column836: -0.007861167942138921
# 837
# Correlation matrix for column 0 and and column837: 0.017115638565769406
# 838
# Correlation matrix for column 0 and and column838: 0.015412454422654737
# 839
# Correlation matrix for column 0 and and column839: 0.030134530776357086
# 840
# Correlation matrix for column 0 and and column840: 0.030791766934635412
# 841
# Correlation matrix for column 0 and and column841: 0.10302948106995377
# 842
# Correlation matrix for column 0 and and column842: -0.012114135985197767
# 843
# Correlation matrix for column 0 and and column843: -0.030981707133945508
# 844
# Correlation matrix for column 0 and and column844: -0.006247547989378246
# 845
# Correlation matrix for column 0 and and column845: -0.010844518817522094
# 846
# Correlation matrix for column 0 and and column846: -0.06047960662756249
# 847
# Correlation matrix for column 0 and and column847: -0.023982193541123104
# 848
# Correlation matrix for column 0 and and column848: 0.015746936522491484
# 849
# Correlation matrix for column 0 and and column849: -0.03820497777736399
# 850
# Correlation matrix for column 0 and and column850: -0.03150984653158595
# 851
# Correlation matrix for column 0 and and column851: 0.06035113391703653
# 852
# Correlation matrix for column 0 and and column852: -0.001465308951631072
# 853
# Correlation matrix for column 0 and and column853: 0.03537214311164019
# 854
# Correlation matrix for column 0 and and column854: -0.023533048958345622
# 855
# Correlation matrix for column 0 and and column855: 0.04129674830960885
# 856
# Correlation matrix for column 0 and and column856: 0.02904204323735591
# 857
# Correlation matrix for column 0 and and column857: 0.0003732244761419217
# 858
# Correlation matrix for column 0 and and column858: 0.021270286992399773
# 859
# Correlation matrix for column 0 and and column859: 0.008834157786231431
# 860
# Correlation matrix for column 0 and and column860: -0.008559350757210765
# 861
# Correlation matrix for column 0 and and column861: -0.04379027440342516
# 862
# Correlation matrix for column 0 and and column862: 0.06275082763377872
# 863
# Correlation matrix for column 0 and and column863: 0.03590727356180451
# 864
# Correlation matrix for column 0 and and column864: 0.0007945885768568491
# 865
# Correlation matrix for column 0 and and column865: 0.02084773332270991
# 866
# Correlation matrix for column 0 and and column866: -0.05800488807059169
# 867
# Correlation matrix for column 0 and and column867: -0.013610991449146813
# 868
# Correlation matrix for column 0 and and column868: -0.014736003002227207
# 869
# Correlation matrix for column 0 and and column869: -0.03923210844516257
# 870
# Correlation matrix for column 0 and and column870: -0.02845049936633071
# 871
# Correlation matrix for column 0 and and column871: -0.02710136943903267
# 872
# Correlation matrix for column 0 and and column872: 0.02594915960878109
# 873
# Correlation matrix for column 0 and and column873: -0.0031609802238771498
# 874
# Correlation matrix for column 0 and and column874: 0.00967965911146182
# 875
# Correlation matrix for column 0 and and column875: -0.045939613906238005
# 876
# Correlation matrix for column 0 and and column876: -0.025878194534840325
# 877
# Correlation matrix for column 0 and and column877: -0.01996690783341959
# 878
# Correlation matrix for column 0 and and column878: 0.0018168859875550844
# 879
# Correlation matrix for column 0 and and column879: -0.04735222097309562
# 880
# Correlation matrix for column 0 and and column880: -0.0015097707411122297
# 881
# Correlation matrix for column 0 and and column881: -0.05415885664562448
# 882
# Correlation matrix for column 0 and and column882: -0.04292439600201472
# 883
# Correlation matrix for column 0 and and column883: -0.029928180474471502
# 884
# Correlation matrix for column 0 and and column884: -0.0043229670762514934
# 885
# Correlation matrix for column 0 and and column885: -0.03291363264337581
# 886
# Correlation matrix for column 0 and and column886: -0.06400483768826332
# 887
# Correlation matrix for column 0 and and column887: 0.02679817138027605
# 888
# Correlation matrix for column 0 and and column888: -0.04964379986515613
# 889
# Correlation matrix for column 0 and and column889: 0.008667023590531033
# 890
# Correlation matrix for column 0 and and column890: -0.039854664889728865
# 891
# Correlation matrix for column 0 and and column891: -0.019653826212915147
# 892
# Correlation matrix for column 0 and and column892: -0.039813750381186085
# 893
# Correlation matrix for column 0 and and column893: -0.024025009677302984
# 894
# Correlation matrix for column 0 and and column894: 0.0370993597833436
# 895
# Correlation matrix for column 0 and and column895: 0.00546281507655023
# 896
# Correlation matrix for column 0 and and column896: 0.0393548974749457
# 897
# Correlation matrix for column 0 and and column897: -0.027796282129465864
# 898
# Correlation matrix for column 0 and and column898: 0.060913665476840274
# 899
# Correlation matrix for column 0 and and column899: 0.000929888013831078
# 900
# Correlation matrix for column 0 and and column900: 0.066651371174623
# 901
# Correlation matrix for column 0 and and column901: -0.027693126226871888
# 902
# Correlation matrix for column 0 and and column902: -0.037378599729872425
# 903
# Correlation matrix for column 0 and and column903: 0.020752665888838943
# 904
# Correlation matrix for column 0 and and column904: 0.0109588762830992
# 905
# Correlation matrix for column 0 and and column905: -0.0050968872519394064
# 906
# Correlation matrix for column 0 and and column906: -0.01655895230306849
# 907
# Correlation matrix for column 0 and and column907: -0.053398630504301416
# 908
# Correlation matrix for column 0 and and column908: 0.05018724364051554
# 909
# Correlation matrix for column 0 and and column909: 0.00874049326047757
# 910
# Correlation matrix for column 0 and and column910: 0.028668643618838193
# 911
# Correlation matrix for column 0 and and column911: 0.010408116128125254
# 912
# Correlation matrix for column 0 and and column912: -0.007800600414968292
# 913
# Correlation matrix for column 0 and and column913: -0.05134948356792881
# 914
# Correlation matrix for column 0 and and column914: -0.015882894502436636
# 915
# Correlation matrix for column 0 and and column915: -0.0013460527296655432
# 916
# Correlation matrix for column 0 and and column916: -0.02832670290378742
# 917
# Correlation matrix for column 0 and and column917: 0.017456282192139426
# 918
# Correlation matrix for column 0 and and column918: 0.018525901430997256
# 919
# Correlation matrix for column 0 and and column919: 0.01694460031989167
# 920
# Correlation matrix for column 0 and and column920: -0.05475584353727281
# 921
# Correlation matrix for column 0 and and column921: -0.0008433821826314337
# 922
# Correlation matrix for column 0 and and column922: -0.008999807543908037
# 923
# Correlation matrix for column 0 and and column923: -0.021102064753157547
# 924
# Correlation matrix for column 0 and and column924: 0.01599729945063608
# 925
# Correlation matrix for column 0 and and column925: -0.04860009544301403
# 926
# Correlation matrix for column 0 and and column926: -0.016571035109767557
# 927
# Correlation matrix for column 0 and and column927: 0.02468230528854097
# 928
# Correlation matrix for column 0 and and column928: 0.004728320481871376
# 929
# Correlation matrix for column 0 and and column929: 0.009557310522674133
# 930
# Correlation matrix for column 0 and and column930: 0.013231721149954821
# 931
# Correlation matrix for column 0 and and column931: 0.024569884594267247
# 932
# Correlation matrix for column 0 and and column932: 0.013396907340238564
# 933
# Correlation matrix for column 0 and and column933: 0.03673809493866684
# 934
# Correlation matrix for column 0 and and column934: 0.06464459089160281
# 935
# Correlation matrix for column 0 and and column935: -0.020836400917739098
# 936
# Correlation matrix for column 0 and and column936: 0.010824530881911812
# 937
# Correlation matrix for column 0 and and column937: 0.028030208101314995
# 938
# Correlation matrix for column 0 and and column938: -0.031880540057421046
# 939
# Correlation matrix for column 0 and and column939: -0.0006070484716643452
# 940
# Correlation matrix for column 0 and and column940: 0.03710254646460318
# 941
# Correlation matrix for column 0 and and column941: 0.010621483493594654
# 942
# Correlation matrix for column 0 and and column942: -0.008878526607998354
# 943
# Correlation matrix for column 0 and and column943: -0.022869699915542413
# 944
# Correlation matrix for column 0 and and column944: 0.014388765774463142
# 945
# Correlation matrix for column 0 and and column945: -0.05415922803902535
# 946
# Correlation matrix for column 0 and and column946: 0.006447344057619554
# 947
# Correlation matrix for column 0 and and column947: 0.03573826377800374
# 948
# Correlation matrix for column 0 and and column948: -0.029490548531610206
# 949
# Correlation matrix for column 0 and and column949: 0.035024252868595264
# 950
# Correlation matrix for column 0 and and column950: -0.005162113836054922
# 951
# Correlation matrix for column 0 and and column951: 0.012347191499477817
# 952
# Correlation matrix for column 0 and and column952: -0.04910647304039879
# 953
# Correlation matrix for column 0 and and column953: -7.970363282988061e-05
# 954
# Correlation matrix for column 0 and and column954: -0.02950035384630936
# 955
# Correlation matrix for column 0 and and column955: -0.011357789282330978
# 956
# Correlation matrix for column 0 and and column956: 0.028070658674589515
# 957
# Correlation matrix for column 0 and and column957: -0.01770543961901837
# 958
# Correlation matrix for column 0 and and column958: -0.0030429587347504295
# 959
# Correlation matrix for column 0 and and column959: -0.017008763126361584
# 960
# Correlation matrix for column 0 and and column960: -0.015251478928295458
# 961
# Correlation matrix for column 0 and and column961: 0.03676776042877946
# 962
# Correlation matrix for column 0 and and column962: -0.01054638053645958
# 963
# Correlation matrix for column 0 and and column963: -0.036423104598866975
# 964
# Correlation matrix for column 0 and and column964: 0.0055763467622627514
# 965
# Correlation matrix for column 0 and and column965: 0.029223273146962665
# 966
# Correlation matrix for column 0 and and column966: -0.0010032492961380328
# 967
# Correlation matrix for column 0 and and column967: -0.03683803278354412
# 968
# Correlation matrix for column 0 and and column968: 0.006818243842167728
# 969
# Correlation matrix for column 0 and and column969: -0.021687313826491104
# 970
# Correlation matrix for column 0 and and column970: 0.06070085022636527
# 971
# Correlation matrix for column 0 and and column971: -0.007848468466702068
# 972
# Correlation matrix for column 0 and and column972: 0.0008198400901795728
# 973
# Correlation matrix for column 0 and and column973: -0.018312672003012925
# 974
# Correlation matrix for column 0 and and column974: -0.004666284515568901
# 975
# Correlation matrix for column 0 and and column975: -0.03466755227468478
# 976
# Correlation matrix for column 0 and and column976: 0.02260003506250112
# 977
# Correlation matrix for column 0 and and column977: -0.020863901974031766
# 978
# Correlation matrix for column 0 and and column978: -0.06829978646213535
# 979
# Correlation matrix for column 0 and and column979: 0.04905309282215146
# 980
# Correlation matrix for column 0 and and column980: 0.024362341693814595
# 981
# Correlation matrix for column 0 and and column981: -0.0612464459740585
# 982
# Correlation matrix for column 0 and and column982: 0.00815608724446988
# 983
# Correlation matrix for column 0 and and column983: -0.022709654073612414
# 984
# Correlation matrix for column 0 and and column984: -0.025501107677875192
# 985
# Correlation matrix for column 0 and and column985: -0.013666823142838258
# 986
# Correlation matrix for column 0 and and column986: -0.03300850710436364
# 987
# Correlation matrix for column 0 and and column987: 0.04523458743222473
# 988
# Correlation matrix for column 0 and and column988: 0.007475249020400493
# 989
# Correlation matrix for column 0 and and column989: 0.022284533509684106
# 990
# Correlation matrix for column 0 and and column990: 0.0022441863664633527
# 991
# Correlation matrix for column 0 and and column991: 0.008056542827038429
# 992
# Correlation matrix for column 0 and and column992: 0.021758197652983865
# 993
# Correlation matrix for column 0 and and column993: 3.6542384436537214e-05
# 994
# Correlation matrix for column 0 and and column994: 0.04670306018197985
# 995
# Correlation matrix for column 0 and and column995: -0.010257861407932342
# 996
# Correlation matrix for column 0 and and column996: -0.003048175152615662
# 997
# Correlation matrix for column 0 and and column997: 0.054119266452923295
# 998
# Correlation matrix for column 0 and and column998: 0.017399813590208677
# 999
# Correlation matrix for column 0 and and column999: 0.003383561058460063
# 1000
# Correlation matrix for column 0 and and column1000: 0.00685938135120644

# %% [markdown]
# We now compare which of the correlation lists has the highest numbers of every parameter

# %%
a = 0
b = 0
for i in range(0,1000):
    if list_corr_df1[i] > list_corr_df2[i]:
        a+=1
    elif list_corr_df1[i] < list_corr_df2[i]:
        b+=1
    else:
        print()
        
print(a)
print(b)
# Out:
# 190
# 810

# %% [markdown]
# Clearly it is seen that the bigger DataFrame has the highest number of spurious correlations.

# %% [markdown]
# To counter spurious correlations, random projection can be used

# %%
# Pass df1 in the random projection to create a new reduced DataFrame
transformer = random_projection.GaussianRandomProjection(eps = 0.1)
df_new = pd.DataFrame(transformer.fit_transform(df))
df_new

# %%
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)
X_df_new.head()

# Assigning Y to column 0
Y_df_new = df_new[0]
print(Y_df_new)

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

list_corr_df_new = []
for i in list_titles[0:1000]:
    print(i)
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        a+=1
    else:
        pass
print(a)
print(b)

# %%
print((a/len(list_corr_df1)*100)

# %%
print((b/len(list_corr_df_new)*100)
