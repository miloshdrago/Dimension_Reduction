# %% [markdown]
# # Spurious Correlations of Highly Dimensional Big Data

# %% [markdown]
# This Notebook aims at showing how PCA and random projection can solve the problem of spurious correlations in Big Data.

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.utils import shuffle

# %% [markdown]
# ## DataFrame Creation

# %%
# User defined parameters

# Number of rows for df1
x = 10000

# Number of columns for df1
y = 200000

# Number of rows for df2
z = 100

# %%
# Creating a dataframe with x number of rows and y number of columns
df = pd.DataFrame(np.random.random_sample((x,y)))
df
# Out:
#         0         1         2         3         4         5         6       \
# 0     0.407963  0.474301  0.914513  0.945734  0.890279  0.229336  0.756325
# 1     0.266604  0.891838  0.326213  0.414000  0.016495  0.678724  0.769021
# 2     0.012947  0.200213  0.104626  0.751361  0.050545  0.358969  0.358193
# 3     0.143612  0.332017  0.204220  0.352314  0.677777  0.986789  0.775544
# 4     0.036490  0.664502  0.070242  0.434057  0.120381  0.191591  0.162851
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.871819  0.241897  0.393195  0.808734  0.336314  0.342002  0.722219
# 9996  0.574667  0.648291  0.386820  0.512158  0.115873  0.861028  0.452934
# 9997  0.151340  0.994866  0.183183  0.062861  0.065738  0.003076  0.555498
# 9998  0.059971  0.222334  0.737692  0.822662  0.517723  0.359236  0.924562
# 9999  0.170995  0.644141  0.072912  0.352917  0.966145  0.190793  0.529946
#
#         7         8         9       ...    199990    199991    199992  \
# 0     0.802745  0.198708  0.070974  ...  0.790681  0.108249  0.993805
# 1     0.275967  0.400031  0.540276  ...  0.323772  0.227763  0.002099
# 2     0.422369  0.363553  0.495734  ...  0.994751  0.794476  0.326189
# 3     0.477414  0.800975  0.117092  ...  0.770246  0.184897  0.337386
# 4     0.080212  0.307039  0.862983  ...  0.480691  0.421116  0.040282
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.227660  0.949949  0.600648  ...  0.144944  0.297414  0.119255
# 9996  0.905635  0.054558  0.614569  ...  0.657768  0.026425  0.646882
# 9997  0.993349  0.954818  0.478832  ...  0.241897  0.523435  0.619811
# 9998  0.712109  0.456856  0.856850  ...  0.228542  0.101134  0.446126
# 9999  0.550845  0.377131  0.988746  ...  0.553924  0.011063  0.540914
#
#         199993    199994    199995    199996    199997    199998    199999
# 0     0.058102  0.951598  0.156123  0.153480  0.678361  0.644528  0.260141
# 1     0.027215  0.545546  0.941441  0.393512  0.948004  0.462694  0.546881
# 2     0.628087  0.242329  0.382629  0.941287  0.618321  0.777962  0.294418
# 3     0.537976  0.754733  0.695631  0.460544  0.155375  0.911842  0.257937
# 4     0.248952  0.499326  0.933375  0.191678  0.411791  0.527633  0.756135
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.709883  0.828140  0.940303  0.677057  0.047723  0.506935  0.218158
# 9996  0.211253  0.053022  0.075468  0.252419  0.612902  0.869790  0.636975
# 9997  0.595720  0.803662  0.176473  0.633499  0.437984  0.752831  0.690303
# 9998  0.642025  0.826221  0.181803  0.227055  0.838175  0.626288  0.734780
# 9999  0.099147  0.883795  0.894429  0.708962  0.083813  0.611057  0.715648
#
# [10000 rows x 200000 columns]

# %% [markdown]
# In order to assess the correlations of the different parameters, correlations between the column with index 0 and the 999 other first columns is assessed.

# %%
# Assigning X to all columns except 0
X_df = df.drop(columns=0)
X_df.head()

# Assigning Y to column 0
Y_df = df[0]
print(Y_df)

# The following line makes Y become a list
Y_df = np.array(Y_df).reshape(-1)
print(X_df.shape,Y_df.shape)

list_titles = X_df.columns
list_corr_df1 = []
for i in list_titles[0:x]:
    print(i)
    list_corr_df1.append(abs(np.corrcoef(Y_df, X_df[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df, X_df[i])[0][1]))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-e480b7f817ed> in <module>
#       1 # Assigning X to all columns except 0
# ----> 2 X_df = df.drop(columns=0)
#       3 X_df.head()
#       4
#       5 # Assigning Y to column 0
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3969             else:
#    3970                 new_axis = axis.drop(labels, errors=errors)
# -> 3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#    3973         # Case for non-unique axis
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     225         @wraps(func)
#     226         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 227             return func(*args, **kwargs)
#     228
#     229         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3854         kwargs.pop("axis", None)
#    3855         kwargs.pop("labels", None)
# -> 3856         return self._ensure_type(super().reindex(**kwargs))
#    3857
#    3858     def drop(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4542         # perform the reindex on the axes
#    4543         return self._reindex_axes(
# -> 4544             axes, level, limit, tolerance, method, fill_value, copy
#    4545         ).__finalize__(self)
#    4546
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3736         if columns is not None:
#    3737             frame = frame._reindex_columns(
# -> 3738                 columns, method, copy, level, fill_value, limit, tolerance
#    3739             )
#    3740
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3784             copy=copy,
#    3785             fill_value=fill_value,
# -> 3786             allow_dups=False,
#    3787         )
#    3788
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4611                 fill_value=fill_value,
#    4612                 allow_dups=allow_dups,
# -> 4613                 copy=copy,
#    4614             )
#    4615
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1352                             axis=0,
#    1353                             new_mgr_locs=mgr_locs,
# -> 1354                             fill_tuple=None,
#    1355                         )
#    1356                     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1289
#    1290         new_values = algos.take_nd(
# -> 1291             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1292         )
#    1293
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1655             out = np.empty(out_shape, dtype=dtype, order="F")
#    1656         else:
# -> 1657             out = np.empty(out_shape, dtype=dtype)
#    1658
#    1659     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 14.9 GiB for an array with shape (10000, 199999) and data type float64

# %% [markdown]
# To see if indeed the correlations between the different parameters increases with the data size, the original dataframe is compared to a sub-set dataframe which only takes the first z rows of the original dataframe. If the correlations in the original dataframe are higher than in the smaller dataframe this would prove that the bigger the data size the more frequent the number of spurious correlations.

# %%
# Creating smaller dataframe taking z number of rows from original dataframe
df2 = df.iloc[:z]
df2
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.407963  0.474301  0.914513  0.945734  0.890279  0.229336  0.756325
# 1   0.266604  0.891838  0.326213  0.414000  0.016495  0.678724  0.769021
# 2   0.012947  0.200213  0.104626  0.751361  0.050545  0.358969  0.358193
# 3   0.143612  0.332017  0.204220  0.352314  0.677777  0.986789  0.775544
# 4   0.036490  0.664502  0.070242  0.434057  0.120381  0.191591  0.162851
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.917452  0.744051  0.238972  0.254169  0.190358  0.440512  0.690596
# 96  0.424941  0.996347  0.224406  0.423946  0.210579  0.463526  0.962147
# 97  0.287480  0.121949  0.730155  0.645828  0.634625  0.287823  0.680536
# 98  0.967958  0.828583  0.421419  0.737181  0.107403  0.954604  0.929338
# 99  0.961049  0.834440  0.775057  0.494283  0.412841  0.642848  0.425313
#
#       7         8         9       ...    199990    199991    199992    199993  \
# 0   0.802745  0.198708  0.070974  ...  0.790681  0.108249  0.993805  0.058102
# 1   0.275967  0.400031  0.540276  ...  0.323772  0.227763  0.002099  0.027215
# 2   0.422369  0.363553  0.495734  ...  0.994751  0.794476  0.326189  0.628087
# 3   0.477414  0.800975  0.117092  ...  0.770246  0.184897  0.337386  0.537976
# 4   0.080212  0.307039  0.862983  ...  0.480691  0.421116  0.040282  0.248952
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.922669  0.590341  0.867127  ...  0.473398  0.681050  0.904653  0.550374
# 96  0.603950  0.769794  0.531726  ...  0.215319  0.601649  0.671480  0.725062
# 97  0.386376  0.331841  0.038838  ...  0.678618  0.649602  0.092574  0.745161
# 98  0.886695  0.707572  0.217950  ...  0.140828  0.035136  0.071781  0.324461
# 99  0.958586  0.424584  0.482583  ...  0.573979  0.843070  0.692842  0.243074
#
#       199994    199995    199996    199997    199998    199999
# 0   0.951598  0.156123  0.153480  0.678361  0.644528  0.260141
# 1   0.545546  0.941441  0.393512  0.948004  0.462694  0.546881
# 2   0.242329  0.382629  0.941287  0.618321  0.777962  0.294418
# 3   0.754733  0.695631  0.460544  0.155375  0.911842  0.257937
# 4   0.499326  0.933375  0.191678  0.411791  0.527633  0.756135
# ..       ...       ...       ...       ...       ...       ...
# 95  0.805353  0.500888  0.916740  0.588384  0.873342  0.515684
# 96  0.054036  0.837277  0.729312  0.792405  0.944136  0.893257
# 97  0.656989  0.114554  0.860985  0.559947  0.414666  0.920162
# 98  0.409897  0.308449  0.146352  0.043716  0.102074  0.613195
# 99  0.218842  0.901457  0.311545  0.989286  0.727796  0.253849
#
# [100 rows x 200000 columns]

# %%
# Assigning X to all columns except 0
X_df2 = df2.drop(columns=0)
X_df2.head()

# Assigning Y to column 0
Y_df2 = df2[0]
print(Y_df2)

# The following line makes Y become a list
Y_df2 = np.array(Y_df2).reshape(-1)
print(X_df2.shape,Y_df2.shape)

list_titles = X_df2.columns

list_corr_df2 = []
for i in list_titles[0:z]:
    print(i)
    list_corr_df2.append(abs(np.corrcoef(Y_df2, X_df2[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df2, X_df2[i])[0][1]))
# Out:
# 0     0.407963
# 1     0.266604
# 2     0.012947
# 3     0.143612
# 4     0.036490
#         ...
# 95    0.917452
# 96    0.424941
# 97    0.287480
# 98    0.967958
# 99    0.961049
# Name: 0, Length: 100, dtype: float64
# (100, 199999) (100,)
# 1
# Correlation matrix for column 0 and and column1: 0.21394182521052013
# 2
# Correlation matrix for column 0 and and column2: 0.18448416211393862
# 3
# Correlation matrix for column 0 and and column3: -0.004417706220055239
# 4
# Correlation matrix for column 0 and and column4: -0.03521844856713025
# 5
# Correlation matrix for column 0 and and column5: -0.05295914303931865
# 6
# Correlation matrix for column 0 and and column6: 0.09434493451606289
# 7
# Correlation matrix for column 0 and and column7: 0.10621829592416787
# 8
# Correlation matrix for column 0 and and column8: 0.007801123879485116
# 9
# Correlation matrix for column 0 and and column9: 0.005140916145243733
# 10
# Correlation matrix for column 0 and and column10: -0.04763589188544659
# 11
# Correlation matrix for column 0 and and column11: 0.04712844436486648
# 12
# Correlation matrix for column 0 and and column12: 0.03809941177006938
# 13
# Correlation matrix for column 0 and and column13: -0.23952664097134765
# 14
# Correlation matrix for column 0 and and column14: 0.009121832950961703
# 15
# Correlation matrix for column 0 and and column15: 0.05440686372138028
# 16
# Correlation matrix for column 0 and and column16: -0.11494112057299909
# 17
# Correlation matrix for column 0 and and column17: 0.017204112814400836
# 18
# Correlation matrix for column 0 and and column18: 0.026429203966012088
# 19
# Correlation matrix for column 0 and and column19: 0.031884429866627824
# 20
# Correlation matrix for column 0 and and column20: 0.1352061939675029
# 21
# Correlation matrix for column 0 and and column21: 0.28368646628092414
# 22
# Correlation matrix for column 0 and and column22: -0.20552563979334315
# 23
# Correlation matrix for column 0 and and column23: -0.025561796012051198
# 24
# Correlation matrix for column 0 and and column24: -0.000497740342575653
# 25
# Correlation matrix for column 0 and and column25: -0.03551811526913462
# 26
# Correlation matrix for column 0 and and column26: 0.009530475994740233
# 27
# Correlation matrix for column 0 and and column27: -0.059314161292305705
# 28
# Correlation matrix for column 0 and and column28: 0.10710845657914467
# 29
# Correlation matrix for column 0 and and column29: 0.019436253863991452
# 30
# Correlation matrix for column 0 and and column30: 0.03685447102700451
# 31
# Correlation matrix for column 0 and and column31: -0.04696718886597697
# 32
# Correlation matrix for column 0 and and column32: -0.01718467842511735
# 33
# Correlation matrix for column 0 and and column33: 0.0970289540079218
# 34
# Correlation matrix for column 0 and and column34: -0.17725009338511621
# 35
# Correlation matrix for column 0 and and column35: -0.045997548393346174
# 36
# Correlation matrix for column 0 and and column36: 0.02033868579008008
# 37
# Correlation matrix for column 0 and and column37: -0.12105087460907483
# 38
# Correlation matrix for column 0 and and column38: 0.16504420472354459
# 39
# Correlation matrix for column 0 and and column39: 0.04730158756841443
# 40
# Correlation matrix for column 0 and and column40: -0.07546298157312951
# 41
# Correlation matrix for column 0 and and column41: 0.03179602910371743
# 42
# Correlation matrix for column 0 and and column42: -0.11578713403470967
# 43
# Correlation matrix for column 0 and and column43: -0.017788482748292315
# 44
# Correlation matrix for column 0 and and column44: 0.04898849174488697
# 45
# Correlation matrix for column 0 and and column45: 0.011798941901056906
# 46
# Correlation matrix for column 0 and and column46: -0.0050210745164053746
# 47
# Correlation matrix for column 0 and and column47: 0.0658721850518985
# 48
# Correlation matrix for column 0 and and column48: -0.08298647144300962
# 49
# Correlation matrix for column 0 and and column49: -0.16992927610310252
# 50
# Correlation matrix for column 0 and and column50: -0.13414251613450348
# 51
# Correlation matrix for column 0 and and column51: 0.07159116821882801
# 52
# Correlation matrix for column 0 and and column52: 0.1534530762230239
# 53
# Correlation matrix for column 0 and and column53: -0.05559952616443729
# 54
# Correlation matrix for column 0 and and column54: -0.027893411880310224
# 55
# Correlation matrix for column 0 and and column55: 0.19873144449582647
# 56
# Correlation matrix for column 0 and and column56: -0.10121537619706315
# 57
# Correlation matrix for column 0 and and column57: -0.10463158324121699
# 58
# Correlation matrix for column 0 and and column58: 0.07085136744555956
# 59
# Correlation matrix for column 0 and and column59: 0.10902494494421841
# 60
# Correlation matrix for column 0 and and column60: -0.03523782861709758
# 61
# Correlation matrix for column 0 and and column61: -0.0906049399110793
# 62
# Correlation matrix for column 0 and and column62: 0.2649046994229487
# 63
# Correlation matrix for column 0 and and column63: -0.25351238110232155
# 64
# Correlation matrix for column 0 and and column64: -0.12616454482273423
# 65
# Correlation matrix for column 0 and and column65: 0.16074992163051274
# 66
# Correlation matrix for column 0 and and column66: -0.0626267346113504
# 67
# Correlation matrix for column 0 and and column67: 0.09041208267409835
# 68
# Correlation matrix for column 0 and and column68: 0.05301980437382226
# 69
# Correlation matrix for column 0 and and column69: -0.006641305929366129
# 70
# Correlation matrix for column 0 and and column70: -0.012173631157082506
# 71
# Correlation matrix for column 0 and and column71: -0.14471158994334818
# 72
# Correlation matrix for column 0 and and column72: 0.1142190673345428
# 73
# Correlation matrix for column 0 and and column73: -0.019896659768649457
# 74
# Correlation matrix for column 0 and and column74: 0.06503127265640904
# 75
# Correlation matrix for column 0 and and column75: -0.05968332646689311
# 76
# Correlation matrix for column 0 and and column76: -0.07295186010399028
# 77
# Correlation matrix for column 0 and and column77: 0.09909282409626578
# 78
# Correlation matrix for column 0 and and column78: -0.18347983591791112
# 79
# Correlation matrix for column 0 and and column79: -0.019872585732571422
# 80
# Correlation matrix for column 0 and and column80: -0.09229711716344698
# 81
# Correlation matrix for column 0 and and column81: -0.1754699505277163
# 82
# Correlation matrix for column 0 and and column82: 0.03424275618352836
# 83
# Correlation matrix for column 0 and and column83: 0.03996905745833019
# 84
# Correlation matrix for column 0 and and column84: -0.28836063478329144
# 85
# Correlation matrix for column 0 and and column85: -0.111159760498456
# 86
# Correlation matrix for column 0 and and column86: 0.20278237117225156
# 87
# Correlation matrix for column 0 and and column87: -0.09385245394660814
# 88
# Correlation matrix for column 0 and and column88: -0.07673533756541588
# 89
# Correlation matrix for column 0 and and column89: 0.01684750572761338
# 90
# Correlation matrix for column 0 and and column90: -0.0745802032211445
# 91
# Correlation matrix for column 0 and and column91: -0.06391679158378365
# 92
# Correlation matrix for column 0 and and column92: 0.09486680771480702
# 93
# Correlation matrix for column 0 and and column93: 0.1161852734944359
# 94
# Correlation matrix for column 0 and and column94: 0.07345012078227173
# 95
# Correlation matrix for column 0 and and column95: 0.046691905356191096
# 96
# Correlation matrix for column 0 and and column96: -0.05615193146221433
# 97
# Correlation matrix for column 0 and and column97: 0.07999553062552077
# 98
# Correlation matrix for column 0 and and column98: -0.012066310223840063
# 99
# Correlation matrix for column 0 and and column99: -0.26164393514691625
# 100
# Correlation matrix for column 0 and and column100: -0.127580212435417

# %% [markdown]
# We now compare which of the correlation lists has the highest numbers of every parameter

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df2)):
    if abs(list_corr_df2[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df2:",(b/len(list_corr_df2)*100),"%")
# Out:
# Percentage of correlations in df1: 30.0 %
# Percentage of correlations in df2: 92.0 %

# %% [markdown]
# Clearly it is seen that the lower the number of observations, the higher the frequency of spurious correlations. However the number of spurious correlations present in the bigger DataFrame is still very significant.

# %% [markdown]
# To counter spurious correlations, random projection can be used.

# %% [markdown]
# ## Random Projection eps = 0.1

# %%
# Pass df1 in the random projection to create a new reduced DataFrame
transformer = random_projection.GaussianRandomProjection(eps = 0.1)
df_new = pd.DataFrame(transformer.fit_transform(df))
df_new
# Out:
#           0         1         2         3         4         5         6     \
# 0     1.665789 -3.554306 -1.240858 -3.786952 -2.935615  0.233420  0.283468
# 1     3.474260  0.845563 -1.735496 -3.002755 -1.976022  3.304029  4.375962
# 2     1.339460 -2.198424  1.803141 -1.667702 -1.505442  0.723374  2.903003
# 3    -0.044174 -2.286818 -0.078582  1.016842 -0.050237 -0.277349  4.962141
# 4     2.814635 -3.639665 -0.655833 -0.117571 -0.656697 -0.939370  2.248766
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  3.707387 -2.256306 -1.837845 -2.468503 -1.237190  2.100843  2.454363
# 9996  2.999208 -3.585934 -1.306878 -2.595376 -0.452083  1.011241  4.348227
# 9997 -1.078753 -4.550946  0.707891 -3.783754 -0.752056  0.229308  1.558930
# 9998  2.281969 -1.226835 -2.589543 -1.899051  2.132335  1.292078  4.214326
# 9999  2.443857 -3.017123  3.223808 -2.888806 -2.560184  2.191837  1.029619
#
#           7         8         9     ...      7884      7885      7886  \
# 0    -4.858662  7.237866 -3.894009  ... -3.499727 -1.126407  2.414381
# 1    -5.918114  5.070523 -2.465235  ... -1.316234  2.219521 -0.557337
# 2    -1.965030  4.845087 -4.777778  ... -1.580486  3.429607 -1.767742
# 3    -6.193419  7.150366 -3.573952  ...  0.085174  2.158210 -0.872226
# 4    -6.310729  6.669675 -1.838556  ... -2.663974  1.213637  0.039754
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -4.152532  6.622466 -2.924955  ... -2.474402  4.707203 -0.352545
# 9996 -3.174340  4.742399 -1.288392  ... -2.214131  1.718321 -0.664068
# 9997 -4.949001  6.290678 -1.053820  ...  1.183180  4.180561 -0.496773
# 9998 -4.340628  8.145260  1.088984  ... -2.556302  3.414142  0.336312
# 9999 -6.380373  6.677547 -1.306109  ...  1.238662  1.755904 -1.003929
#
#           7887      7888      7889      7890      7891      7892      7893
# 0     0.495631  0.877327  1.131523 -7.087682 -0.958305 -0.188304 -1.878007
# 1    -0.463123  0.857663  1.160130 -6.644235 -0.986309  2.024641 -2.576079
# 2     0.211710  0.090567  1.467660 -5.304263 -2.845783  1.343019 -1.692814
# 3    -4.009695  0.457941 -0.323630 -7.199769 -0.567774  1.137293 -5.074202
# 4    -0.300678  2.569871 -0.458503 -5.106754 -4.865524 -1.285187 -2.188566
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.500105  0.220468  0.377716 -6.929371 -2.521950  1.127161 -1.742228
# 9996 -0.497274  1.421825  3.298005 -4.144344 -0.462896 -1.084247 -3.016438
# 9997  0.057437  1.343879  4.512358 -3.539726 -0.659936  1.149582 -4.336575
# 9998 -0.795036  2.057661  2.699765 -6.367952 -2.681310  0.637814 -3.265784
# 9999 -0.101434 -0.091748  1.046900 -3.029846 -0.866182  1.751941 -5.537256
#
# [10000 rows x 7894 columns]

# %%
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]
print(Y_df_new)

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    print(i)
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
# Out:
# 0       1.665789
# 1       3.474260
# 2       1.339460
# 3      -0.044174
# 4       2.814635
#           ...
# 9995    3.707387
# 9996    2.999208
# 9997   -1.078753
# 9998    2.281969
# 9999    2.443857
# Name: 0, Length: 10000, dtype: float64
# (10000, 7893) (10000,)
# 1
# Correlation matrix for column 0 and and column1: -0.010428947591750495
# 2
# Correlation matrix for column 0 and and column2: -0.010600514686739775
# 3
# Correlation matrix for column 0 and and column3: -0.007730092629386428
# 4
# Correlation matrix for column 0 and and column4: 0.006698938356208991
# 5
# Correlation matrix for column 0 and and column5: -0.002651923823496458
# 6
# Correlation matrix for column 0 and and column6: -0.0009149348411265851
# 7
# Correlation matrix for column 0 and and column7: -0.009437893853160042
# 8
# Correlation matrix for column 0 and and column8: 0.00813669351101188
# 9
# Correlation matrix for column 0 and and column9: -0.009679140316876916
# 10
# Correlation matrix for column 0 and and column10: -0.00754636822128765
# 11
# Correlation matrix for column 0 and and column11: 0.011015860235094564
# 12
# Correlation matrix for column 0 and and column12: 0.007676204903284375
# 13
# Correlation matrix for column 0 and and column13: -0.0020670374405956328
# 14
# Correlation matrix for column 0 and and column14: -0.005451879783684792
# 15
# Correlation matrix for column 0 and and column15: 0.0016117193195349356
# 16
# Correlation matrix for column 0 and and column16: -0.006892033605667569
# 17
# Correlation matrix for column 0 and and column17: -0.009810193423249743
# 18
# Correlation matrix for column 0 and and column18: 0.014185224172429482
# 19
# Correlation matrix for column 0 and and column19: 0.012455065016006099
# 20
# Correlation matrix for column 0 and and column20: -0.009112250843843133
# 21
# Correlation matrix for column 0 and and column21: 0.0032320622694863624
# 22
# Correlation matrix for column 0 and and column22: -0.0117368857134676
# 23
# Correlation matrix for column 0 and and column23: -0.005946137832546058
# 24
# Correlation matrix for column 0 and and column24: 0.013626177287505408
# 25
# Correlation matrix for column 0 and and column25: 0.003479551005786929
# 26
# Correlation matrix for column 0 and and column26: -0.011741641683131757
# 27
# Correlation matrix for column 0 and and column27: 0.00975072955691004
# 28
# Correlation matrix for column 0 and and column28: 0.019754023766717053
# 29
# Correlation matrix for column 0 and and column29: -0.002652621000778129
# 30
# Correlation matrix for column 0 and and column30: -0.014731985563093406
# 31
# Correlation matrix for column 0 and and column31: 0.01617623128490117
# 32
# Correlation matrix for column 0 and and column32: 0.004373412127299202
# 33
# Correlation matrix for column 0 and and column33: -0.010317442322756304
# 34
# Correlation matrix for column 0 and and column34: -0.0121271340143801
# 35
# Correlation matrix for column 0 and and column35: -0.0005291231094404031
# 36
# Correlation matrix for column 0 and and column36: 0.00414906897974958
# 37
# Correlation matrix for column 0 and and column37: -0.01448806447484028
# 38
# Correlation matrix for column 0 and and column38: 0.011518173314135132
# 39
# Correlation matrix for column 0 and and column39: -0.001839338874324136
# 40
# Correlation matrix for column 0 and and column40: 0.0017029858643345228
# 41
# Correlation matrix for column 0 and and column41: -0.0023790343782810466
# 42
# Correlation matrix for column 0 and and column42: 0.010513920625439023
# 43
# Correlation matrix for column 0 and and column43: -0.00519415657265936
# 44
# Correlation matrix for column 0 and and column44: 0.0013887196797707482
# 45
# Correlation matrix for column 0 and and column45: 0.012548200154330722
# 46
# Correlation matrix for column 0 and and column46: 0.0017232641334488188
# 47
# Correlation matrix for column 0 and and column47: 0.004025939977821773
# 48
# Correlation matrix for column 0 and and column48: -0.0022349141359748934
# 49
# Correlation matrix for column 0 and and column49: -0.01637052792767073
# 50
# Correlation matrix for column 0 and and column50: -0.007407575805053718
# 51
# Correlation matrix for column 0 and and column51: -0.006216707560917375
# 52
# Correlation matrix for column 0 and and column52: -0.00046485829498296765
# 53
# Correlation matrix for column 0 and and column53: -0.009586261487337287
# 54
# Correlation matrix for column 0 and and column54: -0.0016377873639455039
# 55
# Correlation matrix for column 0 and and column55: 0.004091886028701645
# 56
# Correlation matrix for column 0 and and column56: 0.0006649327955154785
# 57
# Correlation matrix for column 0 and and column57: -0.0036507135076146897
# 58
# Correlation matrix for column 0 and and column58: -0.002861972103435614
# 59
# Correlation matrix for column 0 and and column59: -0.008869368133438648
# 60
# Correlation matrix for column 0 and and column60: 0.01845607355963182
# 61
# Correlation matrix for column 0 and and column61: -0.003863724499833068
# 62
# Correlation matrix for column 0 and and column62: 0.009098746480793595
# 63
# Correlation matrix for column 0 and and column63: 0.0061572980530329585
# 64
# Correlation matrix for column 0 and and column64: 0.01925961623534997
# 65
# Correlation matrix for column 0 and and column65: 0.004875231007580707
# 66
# Correlation matrix for column 0 and and column66: 0.008862715384922826
# 67
# Correlation matrix for column 0 and and column67: -0.008834782082269182
# 68
# Correlation matrix for column 0 and and column68: -0.012899643066134153
# 69
# Correlation matrix for column 0 and and column69: -0.00027418994657775833
# 70
# Correlation matrix for column 0 and and column70: -0.02372080161866489
# 71
# Correlation matrix for column 0 and and column71: 0.01103863870373753
# 72
# Correlation matrix for column 0 and and column72: -0.004803774804273707
# 73
# Correlation matrix for column 0 and and column73: 0.018704693989808445
# 74
# Correlation matrix for column 0 and and column74: 0.00016425925348737173
# 75
# Correlation matrix for column 0 and and column75: 0.005548054806982428
# 76
# Correlation matrix for column 0 and and column76: -0.0066258399107858345
# 77
# Correlation matrix for column 0 and and column77: 0.007609977049189413
# 78
# Correlation matrix for column 0 and and column78: 0.002888759743296786
# 79
# Correlation matrix for column 0 and and column79: -0.011575051374210466
# 80
# Correlation matrix for column 0 and and column80: -0.024150596155755124
# 81
# Correlation matrix for column 0 and and column81: 0.008126922324412412
# 82
# Correlation matrix for column 0 and and column82: 0.004500068365470308
# 83
# Correlation matrix for column 0 and and column83: -0.01852915207418545
# 84
# Correlation matrix for column 0 and and column84: -0.010059143020115313
# 85
# Correlation matrix for column 0 and and column85: -0.018524328357217488
# 86
# Correlation matrix for column 0 and and column86: 0.010961050018902711
# 87
# Correlation matrix for column 0 and and column87: -0.002114749461518609
# 88
# Correlation matrix for column 0 and and column88: -0.01647239000992875
# 89
# Correlation matrix for column 0 and and column89: -0.003986032979322556
# 90
# Correlation matrix for column 0 and and column90: -0.012573772880459232
# 91
# Correlation matrix for column 0 and and column91: -0.002288011830905249
# 92
# Correlation matrix for column 0 and and column92: -0.016583004792559333
# 93
# Correlation matrix for column 0 and and column93: 0.01994393185216995
# 94
# Correlation matrix for column 0 and and column94: -0.0017231088866768486
# 95
# Correlation matrix for column 0 and and column95: -0.0028887632130337668
# 96
# Correlation matrix for column 0 and and column96: 0.004318554758156343
# 97
# Correlation matrix for column 0 and and column97: 0.003172465725287043
# 98
# Correlation matrix for column 0 and and column98: 0.00820866712167901
# 99
# Correlation matrix for column 0 and and column99: -0.0012337981250509571
# 100
# Correlation matrix for column 0 and and column100: 0.0006157702621400502
# 101
# Correlation matrix for column 0 and and column101: 0.000950753869578845
# 102
# Correlation matrix for column 0 and and column102: -0.01105081085914353
# 103
# Correlation matrix for column 0 and and column103: 0.001427112743623566
# 104
# Correlation matrix for column 0 and and column104: 0.010850465083799714
# 105
# Correlation matrix for column 0 and and column105: -0.0013354658716049628
# 106
# Correlation matrix for column 0 and and column106: 0.0009902250518791795
# 107
# Correlation matrix for column 0 and and column107: -0.005574735422665044
# 108
# Correlation matrix for column 0 and and column108: -0.0023633421799578794
# 109
# Correlation matrix for column 0 and and column109: -0.013229624122585602
# 110
# Correlation matrix for column 0 and and column110: 0.004749955734792462
# 111
# Correlation matrix for column 0 and and column111: 0.016114858221110185
# 112
# Correlation matrix for column 0 and and column112: -0.004469154681133578
# 113
# Correlation matrix for column 0 and and column113: -0.010985249106306978
# 114
# Correlation matrix for column 0 and and column114: -0.009624439862228981
# 115
# Correlation matrix for column 0 and and column115: 0.013187519016249562
# 116
# Correlation matrix for column 0 and and column116: -0.021154740601421997
# 117
# Correlation matrix for column 0 and and column117: -0.0018741438694209953
# 118
# Correlation matrix for column 0 and and column118: -0.001840380820860039
# 119
# Correlation matrix for column 0 and and column119: -2.5041600959985276e-05
# 120
# Correlation matrix for column 0 and and column120: 0.002282168954147689
# 121
# Correlation matrix for column 0 and and column121: 0.001860973553620033
# 122
# Correlation matrix for column 0 and and column122: 0.001555901078592621
# 123
# Correlation matrix for column 0 and and column123: 0.004076976546451297
# 124
# Correlation matrix for column 0 and and column124: 0.0010784442515906494
# 125
# Correlation matrix for column 0 and and column125: 0.0007349350031251609
# 126
# Correlation matrix for column 0 and and column126: 0.017916331704122487
# 127
# Correlation matrix for column 0 and and column127: 0.0011819748986629716
# 128
# Correlation matrix for column 0 and and column128: 0.004316033088712279
# 129
# Correlation matrix for column 0 and and column129: 0.0011198535042853796
# 130
# Correlation matrix for column 0 and and column130: -0.007652669381541421
# 131
# Correlation matrix for column 0 and and column131: -0.005582237329938362
# 132
# Correlation matrix for column 0 and and column132: 0.012073258777523353
# 133
# Correlation matrix for column 0 and and column133: -0.00858802779715943
# 134
# Correlation matrix for column 0 and and column134: -0.00514520189120109
# 135
# Correlation matrix for column 0 and and column135: 0.005222278193188845
# 136
# Correlation matrix for column 0 and and column136: 0.0008517535230110479
# 137
# Correlation matrix for column 0 and and column137: 0.012184608821633958
# 138
# Correlation matrix for column 0 and and column138: 0.0014873614490895756
# 139
# Correlation matrix for column 0 and and column139: 0.00012534060720431495
# 140
# Correlation matrix for column 0 and and column140: 0.004555603377289751
# 141
# Correlation matrix for column 0 and and column141: -0.006894873160729423
# 142
# Correlation matrix for column 0 and and column142: -0.0030598605865137718
# 143
# Correlation matrix for column 0 and and column143: -0.00537465272108351
# 144
# Correlation matrix for column 0 and and column144: 0.0018865503053610054
# 145
# Correlation matrix for column 0 and and column145: 0.0186983895311145
# 146
# Correlation matrix for column 0 and and column146: 0.005048407520333713
# 147
# Correlation matrix for column 0 and and column147: 0.00818567904273391
# 148
# Correlation matrix for column 0 and and column148: -0.0018552312821293103
# 149
# Correlation matrix for column 0 and and column149: -0.005176403540182361
# 150
# Correlation matrix for column 0 and and column150: 0.001533298642606314
# 151
# Correlation matrix for column 0 and and column151: -0.015707864763308193
# 152
# Correlation matrix for column 0 and and column152: -0.02397761721240963
# 153
# Correlation matrix for column 0 and and column153: 0.02115099946129253
# 154
# Correlation matrix for column 0 and and column154: -0.006429611079900391
# 155
# Correlation matrix for column 0 and and column155: -0.01586638936258232
# 156
# Correlation matrix for column 0 and and column156: -0.008498252338860134
# 157
# Correlation matrix for column 0 and and column157: 0.025819378472396078
# 158
# Correlation matrix for column 0 and and column158: -0.011193722002943033
# 159
# Correlation matrix for column 0 and and column159: 0.012990035830429379
# 160
# Correlation matrix for column 0 and and column160: -0.0061868205674288634
# 161
# Correlation matrix for column 0 and and column161: 0.013725946114888187
# 162
# Correlation matrix for column 0 and and column162: 0.008960880955747232
# 163
# Correlation matrix for column 0 and and column163: -0.003783185591916896
# 164
# Correlation matrix for column 0 and and column164: -0.000985538377795205
# 165
# Correlation matrix for column 0 and and column165: -0.0067250196745747125
# 166
# Correlation matrix for column 0 and and column166: -0.005885426822983605
# 167
# Correlation matrix for column 0 and and column167: 0.006117526176889291
# 168
# Correlation matrix for column 0 and and column168: 0.005428799219031312
# 169
# Correlation matrix for column 0 and and column169: 0.005027431396356255
# 170
# Correlation matrix for column 0 and and column170: 0.00014730407258115778
# 171
# Correlation matrix for column 0 and and column171: -0.0007782375789015524
# 172
# Correlation matrix for column 0 and and column172: -0.003546872970190816
# 173
# Correlation matrix for column 0 and and column173: 0.00553656324781008
# 174
# Correlation matrix for column 0 and and column174: -0.020151119319399242
# 175
# Correlation matrix for column 0 and and column175: 0.008610786047313537
# 176
# Correlation matrix for column 0 and and column176: 0.012754524965405549
# 177
# Correlation matrix for column 0 and and column177: -0.004523105486090942
# 178
# Correlation matrix for column 0 and and column178: 0.003045823892735893
# 179
# Correlation matrix for column 0 and and column179: -0.008662586723120163
# 180
# Correlation matrix for column 0 and and column180: 0.0006060420472763944
# 181
# Correlation matrix for column 0 and and column181: -0.007488443349135254
# 182
# Correlation matrix for column 0 and and column182: 0.005363514342748413
# 183
# Correlation matrix for column 0 and and column183: -0.007254044284971663
# 184
# Correlation matrix for column 0 and and column184: -0.0030317478849013445
# 185
# Correlation matrix for column 0 and and column185: 0.005623453081385219
# 186
# Correlation matrix for column 0 and and column186: -0.00604128573996447
# 187
# Correlation matrix for column 0 and and column187: 0.009401076547096177
# 188
# Correlation matrix for column 0 and and column188: -0.02159306583074377
# 189
# Correlation matrix for column 0 and and column189: -0.002126047107654052
# 190
# Correlation matrix for column 0 and and column190: 0.004475319086993919
# 191
# Correlation matrix for column 0 and and column191: 0.008474111974237876
# 192
# Correlation matrix for column 0 and and column192: -0.008851967058277151
# 193
# Correlation matrix for column 0 and and column193: -0.00519742373811674
# 194
# Correlation matrix for column 0 and and column194: 0.018815400046556855
# 195
# Correlation matrix for column 0 and and column195: -0.004185595897325517
# 196
# Correlation matrix for column 0 and and column196: -0.015373493228741137
# 197
# Correlation matrix for column 0 and and column197: -0.004183349639644331
# 198
# Correlation matrix for column 0 and and column198: -0.0021824236290987078
# 199
# Correlation matrix for column 0 and and column199: 0.009342247989292814
# 200
# Correlation matrix for column 0 and and column200: -0.0036054726019820295
# 201
# Correlation matrix for column 0 and and column201: -0.0012027996460247778
# 202
# Correlation matrix for column 0 and and column202: 0.007312925792764159
# 203
# Correlation matrix for column 0 and and column203: -0.0076935629479697116
# 204
# Correlation matrix for column 0 and and column204: 0.0073061464979196225
# 205
# Correlation matrix for column 0 and and column205: 0.019873408828541134
# 206
# Correlation matrix for column 0 and and column206: -0.001826471911118482
# 207
# Correlation matrix for column 0 and and column207: 0.013016920945173427
# 208
# Correlation matrix for column 0 and and column208: 0.012286383894855675
# 209
# Correlation matrix for column 0 and and column209: 0.010533854904309022
# 210
# Correlation matrix for column 0 and and column210: -0.0005932392746290744
# 211
# Correlation matrix for column 0 and and column211: 0.0010124685120392596
# 212
# Correlation matrix for column 0 and and column212: 0.012136232982748935
# 213
# Correlation matrix for column 0 and and column213: 0.0263030192367644
# 214
# Correlation matrix for column 0 and and column214: 0.014237001828915704
# 215
# Correlation matrix for column 0 and and column215: -0.00031137271902798795
# 216
# Correlation matrix for column 0 and and column216: -0.02073209523152731
# 217
# Correlation matrix for column 0 and and column217: 0.0036955754020736825
# 218
# Correlation matrix for column 0 and and column218: 0.005728775641607696
# 219
# Correlation matrix for column 0 and and column219: 0.009723758869321199
# 220
# Correlation matrix for column 0 and and column220: -0.0015545824016428213
# 221
# Correlation matrix for column 0 and and column221: 0.009006647558662565
# 222
# Correlation matrix for column 0 and and column222: 0.005627385672373476
# 223
# Correlation matrix for column 0 and and column223: 0.0073031888424625255
# 224
# Correlation matrix for column 0 and and column224: -0.0009979671123133554
# 225
# Correlation matrix for column 0 and and column225: 0.0008649002544977613
# 226
# Correlation matrix for column 0 and and column226: 0.008250751888915024
# 227
# Correlation matrix for column 0 and and column227: 0.016321061952156237
# 228
# Correlation matrix for column 0 and and column228: 0.006010484993919468
# 229
# Correlation matrix for column 0 and and column229: 0.0066961424540144115
# 230
# Correlation matrix for column 0 and and column230: 0.011923940900886384
# 231
# Correlation matrix for column 0 and and column231: 0.005289197281237678
# 232
# Correlation matrix for column 0 and and column232: -0.011033022678461889
# 233
# Correlation matrix for column 0 and and column233: -0.011728756779406836
# 234
# Correlation matrix for column 0 and and column234: -0.0032208874482331485
# 235
# Correlation matrix for column 0 and and column235: 0.011044163476229989
# 236
# Correlation matrix for column 0 and and column236: -0.014144894838949236
# 237
# Correlation matrix for column 0 and and column237: -0.002733668309597045
# 238
# Correlation matrix for column 0 and and column238: 0.0004975018596087695
# 239
# Correlation matrix for column 0 and and column239: 0.002331694349462512
# 240
# Correlation matrix for column 0 and and column240: -0.009279582967110242
# 241
# Correlation matrix for column 0 and and column241: -0.0014235079132484455
# 242
# Correlation matrix for column 0 and and column242: 0.00024996767383983997
# 243
# Correlation matrix for column 0 and and column243: -0.014026188657123717
# 244
# Correlation matrix for column 0 and and column244: 0.004279126280917009
# 245
# Correlation matrix for column 0 and and column245: -0.0030299056883036487
# 246
# Correlation matrix for column 0 and and column246: -0.019008125715669677
# 247
# Correlation matrix for column 0 and and column247: 0.00021811339462172517
# 248
# Correlation matrix for column 0 and and column248: -0.0037169638233581852
# 249
# Correlation matrix for column 0 and and column249: -0.0011417568071882549
# 250
# Correlation matrix for column 0 and and column250: -0.004584583979089078
# 251
# Correlation matrix for column 0 and and column251: -0.012333119470662656
# 252
# Correlation matrix for column 0 and and column252: -0.007037226415947008
# 253
# Correlation matrix for column 0 and and column253: -0.0021706240797460257
# 254
# Correlation matrix for column 0 and and column254: -0.012138467043697988
# 255
# Correlation matrix for column 0 and and column255: -0.0036863500614599466
# 256
# Correlation matrix for column 0 and and column256: 0.009274109010106954
# 257
# Correlation matrix for column 0 and and column257: -0.010167150347564203
# 258
# Correlation matrix for column 0 and and column258: 0.014919523890132498
# 259
# Correlation matrix for column 0 and and column259: 0.005764254732316639
# 260
# Correlation matrix for column 0 and and column260: 0.0051946331931026395
# 261
# Correlation matrix for column 0 and and column261: -0.00853277975061311
# 262
# Correlation matrix for column 0 and and column262: -0.0005827836903432086
# 263
# Correlation matrix for column 0 and and column263: -0.019313438433921245
# 264
# Correlation matrix for column 0 and and column264: -6.153075517119172e-05
# 265
# Correlation matrix for column 0 and and column265: -0.0025640374196652937
# 266
# Correlation matrix for column 0 and and column266: -0.002426037957877724
# 267
# Correlation matrix for column 0 and and column267: 0.018506261272627708
# 268
# Correlation matrix for column 0 and and column268: -0.0004602557170401151
# 269
# Correlation matrix for column 0 and and column269: -0.003915314481288872
# 270
# Correlation matrix for column 0 and and column270: -0.010974388366057922
# 271
# Correlation matrix for column 0 and and column271: -0.006176975505568878
# 272
# Correlation matrix for column 0 and and column272: -0.003842302066044069
# 273
# Correlation matrix for column 0 and and column273: -0.012408556633171045
# 274
# Correlation matrix for column 0 and and column274: -0.014713841820865317
# 275
# Correlation matrix for column 0 and and column275: 0.005069976067769991
# 276
# Correlation matrix for column 0 and and column276: 0.0025028899503687185
# 277
# Correlation matrix for column 0 and and column277: 0.016345138503976637
# 278
# Correlation matrix for column 0 and and column278: 0.007701386485252394
# 279
# Correlation matrix for column 0 and and column279: -0.0012876192110892956
# 280
# Correlation matrix for column 0 and and column280: -0.007203561719661293
# 281
# Correlation matrix for column 0 and and column281: -0.03307194605573537
# 282
# Correlation matrix for column 0 and and column282: 0.0019150739613325832
# 283
# Correlation matrix for column 0 and and column283: -0.01632928005027354
# 284
# Correlation matrix for column 0 and and column284: 0.007828920418116893
# 285
# Correlation matrix for column 0 and and column285: -0.000612630413146856
# 286
# Correlation matrix for column 0 and and column286: -0.008403298018072948
# 287
# Correlation matrix for column 0 and and column287: -0.006557956945580763
# 288
# Correlation matrix for column 0 and and column288: -0.006017664785478459
# 289
# Correlation matrix for column 0 and and column289: -0.009761205255248618
# 290
# Correlation matrix for column 0 and and column290: 0.01340939264778806
# 291
# Correlation matrix for column 0 and and column291: 0.009043940303409418
# 292
# Correlation matrix for column 0 and and column292: 0.000760186685338011
# 293
# Correlation matrix for column 0 and and column293: -0.003139140821189967
# 294
# Correlation matrix for column 0 and and column294: -0.001288249104157079
# 295
# Correlation matrix for column 0 and and column295: 0.008353467921581838
# 296
# Correlation matrix for column 0 and and column296: 0.004432946441964299
# 297
# Correlation matrix for column 0 and and column297: -0.0014250335099515717
# 298
# Correlation matrix for column 0 and and column298: 0.008673367872887937
# 299
# Correlation matrix for column 0 and and column299: -0.00018811400207238216
# 300
# Correlation matrix for column 0 and and column300: 0.012859596871805597
# 301
# Correlation matrix for column 0 and and column301: 0.0095291756346732
# 302
# Correlation matrix for column 0 and and column302: 0.006632640566535608
# 303
# Correlation matrix for column 0 and and column303: 0.01336768151335014
# 304
# Correlation matrix for column 0 and and column304: -0.005753242103443209
# 305
# Correlation matrix for column 0 and and column305: 0.0015207043416031504
# 306
# Correlation matrix for column 0 and and column306: 0.00607369514745495
# 307
# Correlation matrix for column 0 and and column307: 0.0007326784153180729
# 308
# Correlation matrix for column 0 and and column308: -0.017509399145462484
# 309
# Correlation matrix for column 0 and and column309: -0.009726951246305597
# 310
# Correlation matrix for column 0 and and column310: -0.010469458678196968
# 311
# Correlation matrix for column 0 and and column311: 0.01279124178802495
# 312
# Correlation matrix for column 0 and and column312: 0.026269747721904147
# 313
# Correlation matrix for column 0 and and column313: -0.009037057798720079
# 314
# Correlation matrix for column 0 and and column314: -0.007201709657006398
# 315
# Correlation matrix for column 0 and and column315: -0.003697054348781762
# 316
# Correlation matrix for column 0 and and column316: 0.009710586950828659
# 317
# Correlation matrix for column 0 and and column317: -0.015829372009209745
# 318
# Correlation matrix for column 0 and and column318: 0.007380269306187795
# 319
# Correlation matrix for column 0 and and column319: -0.002706576351366509
# 320
# Correlation matrix for column 0 and and column320: -0.007847043147026047
# 321
# Correlation matrix for column 0 and and column321: -0.010028027515691424
# 322
# Correlation matrix for column 0 and and column322: 0.01657038136384907
# 323
# Correlation matrix for column 0 and and column323: 0.0029574983825979085
# 324
# Correlation matrix for column 0 and and column324: -0.022277081739278656
# 325
# Correlation matrix for column 0 and and column325: 0.0030065192885304396
# 326
# Correlation matrix for column 0 and and column326: -0.007713536298223425
# 327
# Correlation matrix for column 0 and and column327: 0.0016037172161830029
# 328
# Correlation matrix for column 0 and and column328: 0.002642843198962303
# 329
# Correlation matrix for column 0 and and column329: 0.007281483536855684
# 330
# Correlation matrix for column 0 and and column330: -0.016819504993303192
# 331
# Correlation matrix for column 0 and and column331: -0.010731773694913543
# 332
# Correlation matrix for column 0 and and column332: -0.005194398396112193
# 333
# Correlation matrix for column 0 and and column333: -0.005843632427573442
# 334
# Correlation matrix for column 0 and and column334: 0.0041228907362479755
# 335
# Correlation matrix for column 0 and and column335: -0.0033739594534478593
# 336
# Correlation matrix for column 0 and and column336: 0.004195167425526669
# 337
# Correlation matrix for column 0 and and column337: -0.0006671787552417984
# 338
# Correlation matrix for column 0 and and column338: -0.004707258900773221
# 339
# Correlation matrix for column 0 and and column339: 6.628534542055878e-05
# 340
# Correlation matrix for column 0 and and column340: -0.0033000772203077553
# 341
# Correlation matrix for column 0 and and column341: -0.005687287971841721
# 342
# Correlation matrix for column 0 and and column342: -0.007365333835148407
# 343
# Correlation matrix for column 0 and and column343: 0.014429082459924292
# 344
# Correlation matrix for column 0 and and column344: 0.005372997999811506
# 345
# Correlation matrix for column 0 and and column345: -0.00910446061688093
# 346
# Correlation matrix for column 0 and and column346: -0.011662052450582662
# 347
# Correlation matrix for column 0 and and column347: -0.016665796757362558
# 348
# Correlation matrix for column 0 and and column348: -0.008322215516982928
# 349
# Correlation matrix for column 0 and and column349: -0.00699728362583943
# 350
# Correlation matrix for column 0 and and column350: 0.02267762047888347
# 351
# Correlation matrix for column 0 and and column351: 0.009018122301364733
# 352
# Correlation matrix for column 0 and and column352: 0.024210559276463154
# 353
# Correlation matrix for column 0 and and column353: -0.009843660070749004
# 354
# Correlation matrix for column 0 and and column354: 0.01565496529278684
# 355
# Correlation matrix for column 0 and and column355: -0.012589524444084179
# 356
# Correlation matrix for column 0 and and column356: 0.0014381912073502666
# 357
# Correlation matrix for column 0 and and column357: 0.014835563634644222
# 358
# Correlation matrix for column 0 and and column358: -0.016958154026058617
# 359
# Correlation matrix for column 0 and and column359: 0.010153962086873854
# 360
# Correlation matrix for column 0 and and column360: 0.004511125704597099
# 361
# Correlation matrix for column 0 and and column361: 0.0042083808702888265
# 362
# Correlation matrix for column 0 and and column362: -0.011471074526177827
# 363
# Correlation matrix for column 0 and and column363: 0.008758473228264417
# 364
# Correlation matrix for column 0 and and column364: -0.01003302900304919
# 365
# Correlation matrix for column 0 and and column365: -0.012969366514464994
# 366
# Correlation matrix for column 0 and and column366: -0.0010041782622353566
# 367
# Correlation matrix for column 0 and and column367: -0.00440836166669946
# 368
# Correlation matrix for column 0 and and column368: 0.0008889063509935489
# 369
# Correlation matrix for column 0 and and column369: 0.003409838034261946
# 370
# Correlation matrix for column 0 and and column370: -0.0009722684517461515
# 371
# Correlation matrix for column 0 and and column371: 0.0072418542648483445
# 372
# Correlation matrix for column 0 and and column372: 0.001237550465137825
# 373
# Correlation matrix for column 0 and and column373: 0.010108185692172202
# 374
# Correlation matrix for column 0 and and column374: -0.007241390944488647
# 375
# Correlation matrix for column 0 and and column375: 0.014552971830911919
# 376
# Correlation matrix for column 0 and and column376: 0.010629620086639847
# 377
# Correlation matrix for column 0 and and column377: 0.021893249311596766
# 378
# Correlation matrix for column 0 and and column378: 0.0087111599578626
# 379
# Correlation matrix for column 0 and and column379: 0.0029231479966001085
# 380
# Correlation matrix for column 0 and and column380: 0.007342144774692658
# 381
# Correlation matrix for column 0 and and column381: 0.002120615640345982
# 382
# Correlation matrix for column 0 and and column382: -0.005744257645391907
# 383
# Correlation matrix for column 0 and and column383: 0.003378896645862099
# 384
# Correlation matrix for column 0 and and column384: 0.00489067291972733
# 385
# Correlation matrix for column 0 and and column385: -0.001666192528813619
# 386
# Correlation matrix for column 0 and and column386: -0.0006361549888788886
# 387
# Correlation matrix for column 0 and and column387: 0.01123064735937601
# 388
# Correlation matrix for column 0 and and column388: 6.414050947788493e-05
# 389
# Correlation matrix for column 0 and and column389: 0.0016592764107378713
# 390
# Correlation matrix for column 0 and and column390: -0.010725629973605223
# 391
# Correlation matrix for column 0 and and column391: 0.014596819284768178
# 392
# Correlation matrix for column 0 and and column392: -0.006968639595395809
# 393
# Correlation matrix for column 0 and and column393: -0.014832606034369358
# 394
# Correlation matrix for column 0 and and column394: -0.0002260871672122853
# 395
# Correlation matrix for column 0 and and column395: 0.00981960574995108
# 396
# Correlation matrix for column 0 and and column396: 0.0028472206143072233
# 397
# Correlation matrix for column 0 and and column397: 0.0014646094139510706
# 398
# Correlation matrix for column 0 and and column398: 0.0043054912571447385
# 399
# Correlation matrix for column 0 and and column399: -0.004338423878260066
# 400
# Correlation matrix for column 0 and and column400: 0.0005445037763046
# 401
# Correlation matrix for column 0 and and column401: 0.014945733439314678
# 402
# Correlation matrix for column 0 and and column402: -0.0181975175264862
# 403
# Correlation matrix for column 0 and and column403: -0.003434388232205104
# 404
# Correlation matrix for column 0 and and column404: -0.01800956405914223
# 405
# Correlation matrix for column 0 and and column405: 0.0025251451543410494
# 406
# Correlation matrix for column 0 and and column406: 0.005785157662756282
# 407
# Correlation matrix for column 0 and and column407: 0.01358631536828574
# 408
# Correlation matrix for column 0 and and column408: -0.0006706291248408348
# 409
# Correlation matrix for column 0 and and column409: -0.00042401348999778713
# 410
# Correlation matrix for column 0 and and column410: 0.0022946974268725356
# 411
# Correlation matrix for column 0 and and column411: -0.0046089407258811145
# 412
# Correlation matrix for column 0 and and column412: 0.0027668104180583646
# 413
# Correlation matrix for column 0 and and column413: -0.015469229084372867
# 414
# Correlation matrix for column 0 and and column414: -0.014395768768027542
# 415
# Correlation matrix for column 0 and and column415: -0.003157309580913472
# 416
# Correlation matrix for column 0 and and column416: 0.012684130947449145
# 417
# Correlation matrix for column 0 and and column417: 0.005606169970866437
# 418
# Correlation matrix for column 0 and and column418: -0.00041928934542054773
# 419
# Correlation matrix for column 0 and and column419: -0.003328075354423119
# 420
# Correlation matrix for column 0 and and column420: -0.009227815832743767
# 421
# Correlation matrix for column 0 and and column421: 0.003565117973439183
# 422
# Correlation matrix for column 0 and and column422: -0.011362499187034698
# 423
# Correlation matrix for column 0 and and column423: -0.007626573425938719
# 424
# Correlation matrix for column 0 and and column424: 0.009489217539391895
# 425
# Correlation matrix for column 0 and and column425: -0.015905515491476462
# 426
# Correlation matrix for column 0 and and column426: -0.014582970741001643
# 427
# Correlation matrix for column 0 and and column427: 0.0019335352556484654
# 428
# Correlation matrix for column 0 and and column428: -0.008478833293627811
# 429
# Correlation matrix for column 0 and and column429: 0.006211811762743107
# 430
# Correlation matrix for column 0 and and column430: -0.0007087243629752648
# 431
# Correlation matrix for column 0 and and column431: -0.001417452480733973
# 432
# Correlation matrix for column 0 and and column432: 0.001587715563096869
# 433
# Correlation matrix for column 0 and and column433: 0.013204884500442327
# 434
# Correlation matrix for column 0 and and column434: -0.01157087842667927
# 435
# Correlation matrix for column 0 and and column435: -0.0008052242716351599
# 436
# Correlation matrix for column 0 and and column436: -0.0017709593062981777
# 437
# Correlation matrix for column 0 and and column437: 0.004138271677815451
# 438
# Correlation matrix for column 0 and and column438: 0.011073970604492014
# 439
# Correlation matrix for column 0 and and column439: 0.006025834307920326
# 440
# Correlation matrix for column 0 and and column440: 0.007750546989837787
# 441
# Correlation matrix for column 0 and and column441: 0.0016347606706246529
# 442
# Correlation matrix for column 0 and and column442: 0.00675561585632171
# 443
# Correlation matrix for column 0 and and column443: 0.011546376832243075
# 444
# Correlation matrix for column 0 and and column444: 0.020557391642396027
# 445
# Correlation matrix for column 0 and and column445: -0.003576495069691791
# 446
# Correlation matrix for column 0 and and column446: 0.0001198801202640149
# 447
# Correlation matrix for column 0 and and column447: -0.0017630108780197287
# 448
# Correlation matrix for column 0 and and column448: -0.015159091578432317
# 449
# Correlation matrix for column 0 and and column449: 0.008698015968191752
# 450
# Correlation matrix for column 0 and and column450: -0.013195446230609701
# 451
# Correlation matrix for column 0 and and column451: 0.006151811836801727
# 452
# Correlation matrix for column 0 and and column452: 0.009150615881623369
# 453
# Correlation matrix for column 0 and and column453: 0.013342849052589457
# 454
# Correlation matrix for column 0 and and column454: 0.0018692755889216125
# 455
# Correlation matrix for column 0 and and column455: -0.0025895718519700307
# 456
# Correlation matrix for column 0 and and column456: 0.0024962407907255938
# 457
# Correlation matrix for column 0 and and column457: -0.00958645515966529
# 458
# Correlation matrix for column 0 and and column458: 0.008021394921422894
# 459
# Correlation matrix for column 0 and and column459: -0.011870269254882737
# 460
# Correlation matrix for column 0 and and column460: 0.00918792597829042
# 461
# Correlation matrix for column 0 and and column461: -0.0037627904026825347
# 462
# Correlation matrix for column 0 and and column462: 0.009468704111308374
# 463
# Correlation matrix for column 0 and and column463: 0.0049928412342697525
# 464
# Correlation matrix for column 0 and and column464: 0.0021759098413136825
# 465
# Correlation matrix for column 0 and and column465: 0.010328020989823317
# 466
# Correlation matrix for column 0 and and column466: -0.015878959184233116
# 467
# Correlation matrix for column 0 and and column467: 0.015578685565888711
# 468
# Correlation matrix for column 0 and and column468: 0.013100017216083417
# 469
# Correlation matrix for column 0 and and column469: 0.011953726145331791
# 470
# Correlation matrix for column 0 and and column470: 0.009349773978216075
# 471
# Correlation matrix for column 0 and and column471: 0.01745002517497324
# 472
# Correlation matrix for column 0 and and column472: -0.00820432808957194
# 473
# Correlation matrix for column 0 and and column473: -0.002635182779675502
# 474
# Correlation matrix for column 0 and and column474: -0.014765714891282668
# 475
# Correlation matrix for column 0 and and column475: -0.005388707389660271
# 476
# Correlation matrix for column 0 and and column476: 0.0002464528371042844
# 477
# Correlation matrix for column 0 and and column477: 0.0029524574253370897
# 478
# Correlation matrix for column 0 and and column478: -0.009504667381171162
# 479
# Correlation matrix for column 0 and and column479: 0.0031008747064081485
# 480
# Correlation matrix for column 0 and and column480: 0.006233519021233163
# 481
# Correlation matrix for column 0 and and column481: -0.004021018961456655
# 482
# Correlation matrix for column 0 and and column482: 0.00011988371308079635
# 483
# Correlation matrix for column 0 and and column483: -0.0232574179704293
# 484
# Correlation matrix for column 0 and and column484: -0.010988503134357556
# 485
# Correlation matrix for column 0 and and column485: 0.004484906533349985
# 486
# Correlation matrix for column 0 and and column486: -0.011216402269487008
# 487
# Correlation matrix for column 0 and and column487: -0.018861992071214032
# 488
# Correlation matrix for column 0 and and column488: -0.008637187663943065
# 489
# Correlation matrix for column 0 and and column489: -0.007950662207821963
# 490
# Correlation matrix for column 0 and and column490: 0.00821729170082383
# 491
# Correlation matrix for column 0 and and column491: -0.007840707178414261
# 492
# Correlation matrix for column 0 and and column492: 0.005888073727688
# 493
# Correlation matrix for column 0 and and column493: -0.010889320873043808
# 494
# Correlation matrix for column 0 and and column494: 0.000841797976633972
# 495
# Correlation matrix for column 0 and and column495: -0.003214572421629123
# 496
# Correlation matrix for column 0 and and column496: -0.007799141147760431
# 497
# Correlation matrix for column 0 and and column497: 0.0035913051728056096
# 498
# Correlation matrix for column 0 and and column498: -0.004115057782257418
# 499
# Correlation matrix for column 0 and and column499: -0.007243755405649171
# 500
# Correlation matrix for column 0 and and column500: 0.025240475872500997
# 501
# Correlation matrix for column 0 and and column501: -0.014948175259069213
# 502
# Correlation matrix for column 0 and and column502: -0.014019238590459743
# 503
# Correlation matrix for column 0 and and column503: -0.004897941164964629
# 504
# Correlation matrix for column 0 and and column504: 0.0002663538587383509
# 505
# Correlation matrix for column 0 and and column505: -0.002730913837715406
# 506
# Correlation matrix for column 0 and and column506: -0.023948629026986298
# 507
# Correlation matrix for column 0 and and column507: 0.029738489530279643
# 508
# Correlation matrix for column 0 and and column508: -0.0013127173820665586
# 509
# Correlation matrix for column 0 and and column509: -0.011136457010977515
# 510
# Correlation matrix for column 0 and and column510: 0.028746365632738156
# 511
# Correlation matrix for column 0 and and column511: -0.002573773177832464
# 512
# Correlation matrix for column 0 and and column512: 0.02413653897688993
# 513
# Correlation matrix for column 0 and and column513: -0.011518017647622275
# 514
# Correlation matrix for column 0 and and column514: 0.007708875602212111
# 515
# Correlation matrix for column 0 and and column515: -0.01813747415035547
# 516
# Correlation matrix for column 0 and and column516: -0.002494681807234193
# 517
# Correlation matrix for column 0 and and column517: 0.003773737664472344
# 518
# Correlation matrix for column 0 and and column518: 0.011554114950154654
# 519
# Correlation matrix for column 0 and and column519: 0.014061399056228881
# 520
# Correlation matrix for column 0 and and column520: 0.0038219920605736995
# 521
# Correlation matrix for column 0 and and column521: 0.0098951833603095
# 522
# Correlation matrix for column 0 and and column522: -0.004898954654599017
# 523
# Correlation matrix for column 0 and and column523: -0.004227074261817092
# 524
# Correlation matrix for column 0 and and column524: 0.01256582886011978
# 525
# Correlation matrix for column 0 and and column525: 0.011570727022206989
# 526
# Correlation matrix for column 0 and and column526: 0.009621704958544464
# 527
# Correlation matrix for column 0 and and column527: 0.020035240788654023
# 528
# Correlation matrix for column 0 and and column528: -0.008585151460162392
# 529
# Correlation matrix for column 0 and and column529: 0.0011506699684163079
# 530
# Correlation matrix for column 0 and and column530: 0.011944855640344925
# 531
# Correlation matrix for column 0 and and column531: -0.013692415781567874
# 532
# Correlation matrix for column 0 and and column532: 0.001095427351862677
# 533
# Correlation matrix for column 0 and and column533: 0.0015898111706870862
# 534
# Correlation matrix for column 0 and and column534: -0.0256907447872471
# 535
# Correlation matrix for column 0 and and column535: -0.004723507286621373
# 536
# Correlation matrix for column 0 and and column536: -0.005636066651641643
# 537
# Correlation matrix for column 0 and and column537: 0.020871353599972726
# 538
# Correlation matrix for column 0 and and column538: 0.011352492833028131
# 539
# Correlation matrix for column 0 and and column539: -0.002377194352064047
# 540
# Correlation matrix for column 0 and and column540: -0.006339517340582621
# 541
# Correlation matrix for column 0 and and column541: -0.014464384471887736
# 542
# Correlation matrix for column 0 and and column542: 0.016242607304805378
# 543
# Correlation matrix for column 0 and and column543: -0.013891094273995885
# 544
# Correlation matrix for column 0 and and column544: -0.011330072740367738
# 545
# Correlation matrix for column 0 and and column545: -0.008355025174775618
# 546
# Correlation matrix for column 0 and and column546: -0.01792818799098165
# 547
# Correlation matrix for column 0 and and column547: -0.0024266126850420937
# 548
# Correlation matrix for column 0 and and column548: 0.00998963174181786
# 549
# Correlation matrix for column 0 and and column549: -0.009159639876849474
# 550
# Correlation matrix for column 0 and and column550: -7.119766898717771e-05
# 551
# Correlation matrix for column 0 and and column551: 0.011700749204800706
# 552
# Correlation matrix for column 0 and and column552: -0.011273891522344455
# 553
# Correlation matrix for column 0 and and column553: -0.007109548121192668
# 554
# Correlation matrix for column 0 and and column554: 0.015174446353111097
# 555
# Correlation matrix for column 0 and and column555: 0.01241139427825572
# 556
# Correlation matrix for column 0 and and column556: 0.002401213589171417
# 557
# Correlation matrix for column 0 and and column557: -0.025611212430188827
# 558
# Correlation matrix for column 0 and and column558: -0.003947160612398983
# 559
# Correlation matrix for column 0 and and column559: -0.005160566276987699
# 560
# Correlation matrix for column 0 and and column560: -0.010597067100463289
# 561
# Correlation matrix for column 0 and and column561: -0.01089972573433975
# 562
# Correlation matrix for column 0 and and column562: 0.009887655432141663
# 563
# Correlation matrix for column 0 and and column563: 0.004799199665547398
# 564
# Correlation matrix for column 0 and and column564: 0.0006066772070042432
# 565
# Correlation matrix for column 0 and and column565: 0.010941580247440902
# 566
# Correlation matrix for column 0 and and column566: -0.0028718465181987586
# 567
# Correlation matrix for column 0 and and column567: 0.008318702859145927
# 568
# Correlation matrix for column 0 and and column568: -0.009594697876968197
# 569
# Correlation matrix for column 0 and and column569: -0.012971808482871253
# 570
# Correlation matrix for column 0 and and column570: -0.009495423676638042
# 571
# Correlation matrix for column 0 and and column571: -0.014551620096265896
# 572
# Correlation matrix for column 0 and and column572: 0.0063265074158071625
# 573
# Correlation matrix for column 0 and and column573: -0.005328173659239716
# 574
# Correlation matrix for column 0 and and column574: -0.002042519625887419
# 575
# Correlation matrix for column 0 and and column575: 0.01292390498295248
# 576
# Correlation matrix for column 0 and and column576: 0.009517793019647098
# 577
# Correlation matrix for column 0 and and column577: -0.00467787801507951
# 578
# Correlation matrix for column 0 and and column578: -0.006312003773485397
# 579
# Correlation matrix for column 0 and and column579: 0.01313301068206812
# 580
# Correlation matrix for column 0 and and column580: -0.00369142397306114
# 581
# Correlation matrix for column 0 and and column581: -0.007664482445708186
# 582
# Correlation matrix for column 0 and and column582: 0.005663254751700945
# 583
# Correlation matrix for column 0 and and column583: -0.0060744402506568524
# 584
# Correlation matrix for column 0 and and column584: 0.015172166872438256
# 585
# Correlation matrix for column 0 and and column585: 0.009017938460392573
# 586
# Correlation matrix for column 0 and and column586: -0.013829962667969648
# 587
# Correlation matrix for column 0 and and column587: -0.024621656688941597
# 588
# Correlation matrix for column 0 and and column588: 0.01095598546194281
# 589
# Correlation matrix for column 0 and and column589: -0.0019701154022262186
# 590
# Correlation matrix for column 0 and and column590: 0.0032796511525108253
# 591
# Correlation matrix for column 0 and and column591: 0.0019854414661455125
# 592
# Correlation matrix for column 0 and and column592: -0.018149248843524996
# 593
# Correlation matrix for column 0 and and column593: 0.0017495727271794159
# 594
# Correlation matrix for column 0 and and column594: 0.0023372458171397248
# 595
# Correlation matrix for column 0 and and column595: -0.007075614355232043
# 596
# Correlation matrix for column 0 and and column596: -0.007282095885060207
# 597
# Correlation matrix for column 0 and and column597: 0.008839815444571616
# 598
# Correlation matrix for column 0 and and column598: 0.009224874618371137
# 599
# Correlation matrix for column 0 and and column599: 6.47202065037043e-05
# 600
# Correlation matrix for column 0 and and column600: 0.004332783933953035
# 601
# Correlation matrix for column 0 and and column601: -0.008784448731749779
# 602
# Correlation matrix for column 0 and and column602: -0.0016486414693791449
# 603
# Correlation matrix for column 0 and and column603: -0.0015518433155404193
# 604
# Correlation matrix for column 0 and and column604: -0.002766295402754216
# 605
# Correlation matrix for column 0 and and column605: 0.0014148082777119782
# 606
# Correlation matrix for column 0 and and column606: 0.01396097651686897
# 607
# Correlation matrix for column 0 and and column607: -0.002796578457632104
# 608
# Correlation matrix for column 0 and and column608: 0.01064285999172572
# 609
# Correlation matrix for column 0 and and column609: -0.027331911701890466
# 610
# Correlation matrix for column 0 and and column610: -0.002513214539687856
# 611
# Correlation matrix for column 0 and and column611: 0.015240843704466938
# 612
# Correlation matrix for column 0 and and column612: -0.012485012299926377
# 613
# Correlation matrix for column 0 and and column613: -0.011879928759534501
# 614
# Correlation matrix for column 0 and and column614: -0.007657431049722949
# 615
# Correlation matrix for column 0 and and column615: -0.003927359781808996
# 616
# Correlation matrix for column 0 and and column616: 0.01799659751050781
# 617
# Correlation matrix for column 0 and and column617: -0.008310759730265621
# 618
# Correlation matrix for column 0 and and column618: 0.0021319993623249924
# 619
# Correlation matrix for column 0 and and column619: -0.01448016513253266
# 620
# Correlation matrix for column 0 and and column620: -0.014715924383044721
# 621
# Correlation matrix for column 0 and and column621: -0.000907851010119959
# 622
# Correlation matrix for column 0 and and column622: 0.0030150964868905917
# 623
# Correlation matrix for column 0 and and column623: -0.0023013876093947055
# 624
# Correlation matrix for column 0 and and column624: -0.004597302635762427
# 625
# Correlation matrix for column 0 and and column625: 0.013754448867937214
# 626
# Correlation matrix for column 0 and and column626: 0.00657748444432935
# ...
# 7691
# Correlation matrix for column 0 and and column7691: -0.010580440480738662
# 7692
# Correlation matrix for column 0 and and column7692: -0.0027063608860256605
# 7693
# Correlation matrix for column 0 and and column7693: 0.0020584151570511543
# 7694
# Correlation matrix for column 0 and and column7694: -0.0011469072004546166
# 7695
# Correlation matrix for column 0 and and column7695: -0.0003316985101513195
# 7696
# Correlation matrix for column 0 and and column7696: 0.02351302415413657
# 7697
# Correlation matrix for column 0 and and column7697: 0.005717347432001742
# 7698
# Correlation matrix for column 0 and and column7698: 0.006425328141584773
# 7699
# Correlation matrix for column 0 and and column7699: -0.0019523609055065727
# 7700
# Correlation matrix for column 0 and and column7700: -0.001512254700061072
# 7701
# Correlation matrix for column 0 and and column7701: -0.01278217060105355
# 7702
# Correlation matrix for column 0 and and column7702: -0.0050850464778953944
# 7703
# Correlation matrix for column 0 and and column7703: 0.0026047760936682546
# 7704
# Correlation matrix for column 0 and and column7704: 0.009141841222139211
# 7705
# Correlation matrix for column 0 and and column7705: 0.006531299409204119
# 7706
# Correlation matrix for column 0 and and column7706: 0.0012868194705382048
# 7707
# Correlation matrix for column 0 and and column7707: 0.003068547265874591
# 7708
# Correlation matrix for column 0 and and column7708: -0.0019005540472901083
# 7709
# Correlation matrix for column 0 and and column7709: 0.005951058934989218
# 7710
# Correlation matrix for column 0 and and column7710: 0.010933472912753562
# 7711
# Correlation matrix for column 0 and and column7711: -0.0017763920783888123
# 7712
# Correlation matrix for column 0 and and column7712: -0.0005717026162490306
# 7713
# Correlation matrix for column 0 and and column7713: 0.006848121352074848
# 7714
# Correlation matrix for column 0 and and column7714: -0.010111550095929062
# 7715
# Correlation matrix for column 0 and and column7715: 0.004506232219535504
# 7716
# Correlation matrix for column 0 and and column7716: 0.001419169069643425
# 7717
# Correlation matrix for column 0 and and column7717: -0.005820001521199216
# 7718
# Correlation matrix for column 0 and and column7718: -0.004350173856616504
# 7719
# Correlation matrix for column 0 and and column7719: 0.0074447239194882124
# 7720
# Correlation matrix for column 0 and and column7720: 0.02067301540307214
# 7721
# Correlation matrix for column 0 and and column7721: -0.0047940705320219
# 7722
# Correlation matrix for column 0 and and column7722: 0.017757126629768288
# 7723
# Correlation matrix for column 0 and and column7723: 0.0064299494374424546
# 7724
# Correlation matrix for column 0 and and column7724: -0.0045216954269318614
# 7725
# Correlation matrix for column 0 and and column7725: -0.00023037233577072848
# 7726
# Correlation matrix for column 0 and and column7726: -0.0036695987956073305
# 7727
# Correlation matrix for column 0 and and column7727: 0.006704692765356838
# 7728
# Correlation matrix for column 0 and and column7728: 0.013697317745029141
# 7729
# Correlation matrix for column 0 and and column7729: 0.0053924564089581906
# 7730
# Correlation matrix for column 0 and and column7730: -0.0096562418555786
# 7731
# Correlation matrix for column 0 and and column7731: 0.002249226483208556
# 7732
# Correlation matrix for column 0 and and column7732: -0.015022560748868994
# 7733
# Correlation matrix for column 0 and and column7733: 0.003145000776672463
# 7734
# Correlation matrix for column 0 and and column7734: -0.0006721741022615074
# 7735
# Correlation matrix for column 0 and and column7735: -0.000553491552113827
# 7736
# Correlation matrix for column 0 and and column7736: -0.00648567658001526
# 7737
# Correlation matrix for column 0 and and column7737: -0.009594334990183574
# 7738
# Correlation matrix for column 0 and and column7738: 0.021798434984849503
# 7739
# Correlation matrix for column 0 and and column7739: 0.0038508551855001177
# 7740
# Correlation matrix for column 0 and and column7740: 0.0010700828982558115
# 7741
# Correlation matrix for column 0 and and column7741: -0.0049475883265938615
# 7742
# Correlation matrix for column 0 and and column7742: -0.007621149525235466
# 7743
# Correlation matrix for column 0 and and column7743: -0.007477285342077774
# 7744
# Correlation matrix for column 0 and and column7744: -0.0022268540511854486
# 7745
# Correlation matrix for column 0 and and column7745: 0.011858826819131448
# 7746
# Correlation matrix for column 0 and and column7746: 0.0183715593576531
# 7747
# Correlation matrix for column 0 and and column7747: 0.009708189216314654
# 7748
# Correlation matrix for column 0 and and column7748: 0.009188383908518293
# 7749
# Correlation matrix for column 0 and and column7749: 0.002261682844973865
# 7750
# Correlation matrix for column 0 and and column7750: 0.001064505753561369
# 7751
# Correlation matrix for column 0 and and column7751: -0.015307187829571297
# 7752
# Correlation matrix for column 0 and and column7752: 0.004222604218688854
# 7753
# Correlation matrix for column 0 and and column7753: -0.008170978522134938
# 7754
# Correlation matrix for column 0 and and column7754: -0.004008350424286375
# 7755
# Correlation matrix for column 0 and and column7755: 0.0051931990574212265
# 7756
# Correlation matrix for column 0 and and column7756: 0.008684927954034144
# 7757
# Correlation matrix for column 0 and and column7757: 0.010845053253753371
# 7758
# Correlation matrix for column 0 and and column7758: 0.01340333827205017
# 7759
# Correlation matrix for column 0 and and column7759: 0.01061040297144235
# 7760
# Correlation matrix for column 0 and and column7760: -0.005947749362599186
# 7761
# Correlation matrix for column 0 and and column7761: -0.002168518330678015
# 7762
# Correlation matrix for column 0 and and column7762: -0.007050747414623113
# 7763
# Correlation matrix for column 0 and and column7763: 0.010523591608012228
# 7764
# Correlation matrix for column 0 and and column7764: 0.005786650915869365
# 7765
# Correlation matrix for column 0 and and column7765: 0.008675814959753971
# 7766
# Correlation matrix for column 0 and and column7766: -0.010368345284305795
# 7767
# Correlation matrix for column 0 and and column7767: 0.0020154860248899065
# 7768
# Correlation matrix for column 0 and and column7768: -0.0017182188962452628
# 7769
# Correlation matrix for column 0 and and column7769: -0.011891701369897884
# 7770
# Correlation matrix for column 0 and and column7770: 0.003744596024697497
# 7771
# Correlation matrix for column 0 and and column7771: -0.01310778641400601
# 7772
# Correlation matrix for column 0 and and column7772: -0.014018690471148763
# 7773
# Correlation matrix for column 0 and and column7773: 0.009103863411950335
# 7774
# Correlation matrix for column 0 and and column7774: -0.022884928676193277
# 7775
# Correlation matrix for column 0 and and column7775: 0.009902574723919665
# 7776
# Correlation matrix for column 0 and and column7776: 0.008395253936430825
# 7777
# Correlation matrix for column 0 and and column7777: -0.0016116456064879726
# 7778
# Correlation matrix for column 0 and and column7778: -0.013725320821866087
# 7779
# Correlation matrix for column 0 and and column7779: -0.008382828060710133
# 7780
# Correlation matrix for column 0 and and column7780: -0.0020074896241986423
# 7781
# Correlation matrix for column 0 and and column7781: -0.007992300222645146
# 7782
# Correlation matrix for column 0 and and column7782: -0.002613318684561852
# 7783
# Correlation matrix for column 0 and and column7783: -0.021941868525330442
# 7784
# Correlation matrix for column 0 and and column7784: 0.013554466213053262
# 7785
# Correlation matrix for column 0 and and column7785: 0.01145465919522122
# 7786
# Correlation matrix for column 0 and and column7786: 0.002791490021762805
# 7787
# Correlation matrix for column 0 and and column7787: 0.0030901357814834157
# 7788
# Correlation matrix for column 0 and and column7788: -0.004234645657872007
# 7789
# Correlation matrix for column 0 and and column7789: -0.0006228919948987124
# 7790
# Correlation matrix for column 0 and and column7790: -0.0002732742078115804
# 7791
# Correlation matrix for column 0 and and column7791: -0.004678061290972541
# 7792
# Correlation matrix for column 0 and and column7792: 0.003172162832278459
# 7793
# Correlation matrix for column 0 and and column7793: -0.0081200032786271
# 7794
# Correlation matrix for column 0 and and column7794: 0.0256513535470786
# 7795
# Correlation matrix for column 0 and and column7795: -0.01944967934978247
# 7796
# Correlation matrix for column 0 and and column7796: 0.0015442916227130323
# 7797
# Correlation matrix for column 0 and and column7797: -0.009434563730061367
# 7798
# Correlation matrix for column 0 and and column7798: 0.014198439611767892
# 7799
# Correlation matrix for column 0 and and column7799: 0.002185563556812046
# 7800
# Correlation matrix for column 0 and and column7800: -0.00959738188603856
# 7801
# Correlation matrix for column 0 and and column7801: 0.024162662569757243
# 7802
# Correlation matrix for column 0 and and column7802: 0.012075829464126803
# 7803
# Correlation matrix for column 0 and and column7803: -0.00928038144403143
# 7804
# Correlation matrix for column 0 and and column7804: 0.0011751500205714493
# 7805
# Correlation matrix for column 0 and and column7805: -0.007725249095606533
# 7806
# Correlation matrix for column 0 and and column7806: -0.01220620510209427
# 7807
# Correlation matrix for column 0 and and column7807: 0.0004664008326072123
# 7808
# Correlation matrix for column 0 and and column7808: -0.017770226646517322
# 7809
# Correlation matrix for column 0 and and column7809: -0.009864605197499977
# 7810
# Correlation matrix for column 0 and and column7810: -0.016056535854765807
# 7811
# Correlation matrix for column 0 and and column7811: -0.00640011974299249
# 7812
# Correlation matrix for column 0 and and column7812: -0.003765366289399876
# 7813
# Correlation matrix for column 0 and and column7813: -0.007329719722148025
# 7814
# Correlation matrix for column 0 and and column7814: -0.008708476683715298
# 7815
# Correlation matrix for column 0 and and column7815: -0.004504294262555162
# 7816
# Correlation matrix for column 0 and and column7816: 0.023733951234377337
# 7817
# Correlation matrix for column 0 and and column7817: -0.0012444725288888305
# 7818
# Correlation matrix for column 0 and and column7818: -0.014727181169248184
# 7819
# Correlation matrix for column 0 and and column7819: 0.014992918118231887
# 7820
# Correlation matrix for column 0 and and column7820: -0.018069761547745294
# 7821
# Correlation matrix for column 0 and and column7821: 0.003982546336986556
# 7822
# Correlation matrix for column 0 and and column7822: -0.0013314476447514273
# 7823
# Correlation matrix for column 0 and and column7823: 0.012315699683438994
# 7824
# Correlation matrix for column 0 and and column7824: 0.007447090688230886
# 7825
# Correlation matrix for column 0 and and column7825: 0.00874264062421166
# 7826
# Correlation matrix for column 0 and and column7826: 0.0032815929168205833
# 7827
# Correlation matrix for column 0 and and column7827: -0.0009340343299059983
# 7828
# Correlation matrix for column 0 and and column7828: -0.008731303155582135
# 7829
# Correlation matrix for column 0 and and column7829: -0.008124307177189998
# 7830
# Correlation matrix for column 0 and and column7830: -0.0097928738881026
# 7831
# Correlation matrix for column 0 and and column7831: 0.0036259104468197912
# 7832
# Correlation matrix for column 0 and and column7832: -0.007018390064160951
# 7833
# Correlation matrix for column 0 and and column7833: -0.01975770820031919
# 7834
# Correlation matrix for column 0 and and column7834: 0.00832304634454548
# 7835
# Correlation matrix for column 0 and and column7835: 0.0020678790166408535
# 7836
# Correlation matrix for column 0 and and column7836: 0.004587317794381352
# 7837
# Correlation matrix for column 0 and and column7837: -0.010477197118518654
# 7838
# Correlation matrix for column 0 and and column7838: 0.011906396138598757
# 7839
# Correlation matrix for column 0 and and column7839: -0.0016583775104273904
# 7840
# Correlation matrix for column 0 and and column7840: 0.002101517932000482
# 7841
# Correlation matrix for column 0 and and column7841: -0.0016749545218063264
# 7842
# Correlation matrix for column 0 and and column7842: -0.016507652683866003
# 7843
# Correlation matrix for column 0 and and column7843: 0.0005987568292272147
# 7844
# Correlation matrix for column 0 and and column7844: -0.0068472225311569605
# 7845
# Correlation matrix for column 0 and and column7845: -0.013059916159122033
# 7846
# Correlation matrix for column 0 and and column7846: 0.0010737056398478606
# 7847
# Correlation matrix for column 0 and and column7847: 0.0069156396984684934
# 7848
# Correlation matrix for column 0 and and column7848: 0.00913687757469743
# 7849
# Correlation matrix for column 0 and and column7849: -0.002970963969821489
# 7850
# Correlation matrix for column 0 and and column7850: 0.00711812167557766
# 7851
# Correlation matrix for column 0 and and column7851: -0.00027024756944649846
# 7852
# Correlation matrix for column 0 and and column7852: -0.005718339482839574
# 7853
# Correlation matrix for column 0 and and column7853: -0.0016239944940327768
# 7854
# Correlation matrix for column 0 and and column7854: 0.020055832642610894
# 7855
# Correlation matrix for column 0 and and column7855: 0.002795655667488763
# 7856
# Correlation matrix for column 0 and and column7856: 0.012810167732708114
# 7857
# Correlation matrix for column 0 and and column7857: 0.005834528623883139
# 7858
# Correlation matrix for column 0 and and column7858: -0.009367694684030764
# 7859
# Correlation matrix for column 0 and and column7859: 0.01918611583222977
# 7860
# Correlation matrix for column 0 and and column7860: -0.0039558978474919715
# 7861
# Correlation matrix for column 0 and and column7861: 0.0017587200729740958
# 7862
# Correlation matrix for column 0 and and column7862: 0.01554000093945257
# 7863
# Correlation matrix for column 0 and and column7863: -0.0011861113266055682
# 7864
# Correlation matrix for column 0 and and column7864: 0.0064345765690761005
# 7865
# Correlation matrix for column 0 and and column7865: 0.00013615565459934416
# 7866
# Correlation matrix for column 0 and and column7866: -0.005733226338792518
# 7867
# Correlation matrix for column 0 and and column7867: -0.009911165531562663
# 7868
# Correlation matrix for column 0 and and column7868: 0.013519521310361908
# 7869
# Correlation matrix for column 0 and and column7869: -0.015522330100670445
# 7870
# Correlation matrix for column 0 and and column7870: -0.00247117461336109
# 7871
# Correlation matrix for column 0 and and column7871: 0.009342400158759619
# 7872
# Correlation matrix for column 0 and and column7872: -0.005529771829790852
# 7873
# Correlation matrix for column 0 and and column7873: 0.006207019169189256
# 7874
# Correlation matrix for column 0 and and column7874: -0.00011992931567238172
# 7875
# Correlation matrix for column 0 and and column7875: 3.8263940450660865e-05
# 7876
# Correlation matrix for column 0 and and column7876: 0.012766304546710254
# 7877
# Correlation matrix for column 0 and and column7877: 0.007174135507218999
# 7878
# Correlation matrix for column 0 and and column7878: -0.004300167977845828
# 7879
# Correlation matrix for column 0 and and column7879: 0.00669632739456876
# 7880
# Correlation matrix for column 0 and and column7880: -0.014744472797980879
# 7881
# Correlation matrix for column 0 and and column7881: 0.01587476927205693
# 7882
# Correlation matrix for column 0 and and column7882: 0.00433456843138814
# 7883
# Correlation matrix for column 0 and and column7883: -0.01565843656401452
# 7884
# Correlation matrix for column 0 and and column7884: 0.00016722712385211792
# 7885
# Correlation matrix for column 0 and and column7885: -0.01850298237839525
# 7886
# Correlation matrix for column 0 and and column7886: 0.005363189914873221
# 7887
# Correlation matrix for column 0 and and column7887: -0.0001234535826480385
# 7888
# Correlation matrix for column 0 and and column7888: 0.007446279401645438
# 7889
# Correlation matrix for column 0 and and column7889: -0.0013668826048593623
# 7890
# Correlation matrix for column 0 and and column7890: -0.01985995711155637
# 7891
# Correlation matrix for column 0 and and column7891: 0.010497194673408256
# 7892
# Correlation matrix for column 0 and and column7892: 0.010569274193287514
# 7893
# Correlation matrix for column 0 and and column7893: -0.014214571849914093

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")
# Out:
# Percentage of correlations in df1: 30.0 %
# Percentage of correlations in df_new: 33.39668060306601 %
