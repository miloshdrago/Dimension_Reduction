# %% [markdown]
# # Spurious Correlations of Highly Dimensional Big Data

# %% [markdown]
# This Notebook aims at showing how PCA and random projection can solve the problem of spurious correlations in Big Data.

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import random_projection
from sklearn.utils import shuffle

# %% [markdown]
# ## DataFrame Creation

# %%
# User defined parameters

# Number of rows for df1
x = 10000

# Number of columns for df1
y = 50000

# Number of rows for df2
z = 100

# %%
# Creating a dataframe with x number of rows and y number of columns
df = pd.DataFrame(np.random.random_sample((x,y)))
df
# Out:
#          0         1         2         3         4         5         6      \
# 0     0.161537  0.230152  0.321752  0.045548  0.327331  0.265337  0.356719
# 1     0.557257  0.843707  0.482685  0.585022  0.270943  0.016193  0.235657
# 2     0.243034  0.549041  0.639664  0.128769  0.210019  0.041539  0.708618
# 3     0.539145  0.975516  0.095903  0.760185  0.021810  0.797899  0.631584
# 4     0.128277  0.586222  0.063367  0.192537  0.331533  0.691179  0.432043
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.816988  0.131492  0.639235  0.903606  0.356882  0.648416  0.683233
# 9996  0.723330  0.612552  0.888813  0.437515  0.159240  0.865794  0.094839
# 9997  0.600350  0.769686  0.563229  0.564364  0.552433  0.222196  0.501446
# 9998  0.102388  0.010534  0.772276  0.446890  0.822528  0.979337  0.162932
# 9999  0.037191  0.799993  0.072799  0.925804  0.656771  0.288096  0.967713
#
#          7         8         9      ...     49990     49991     49992  \
# 0     0.181036  0.133112  0.892356  ...  0.208107  0.441717  0.608767
# 1     0.930825  0.195350  0.233330  ...  0.599279  0.172883  0.704992
# 2     0.597223  0.526631  0.597928  ...  0.145090  0.353259  0.669502
# 3     0.686302  0.673548  0.367420  ...  0.326220  0.007284  0.049699
# 4     0.518492  0.845520  0.473112  ...  0.249087  0.507572  0.560249
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.135722  0.800951  0.171311  ...  0.251131  0.807302  0.741644
# 9996  0.461963  0.772761  0.769893  ...  0.958675  0.500838  0.004107
# 9997  0.647164  0.282689  0.792739  ...  0.179703  0.090657  0.811865
# 9998  0.717912  0.473390  0.923075  ...  0.970725  0.506415  0.088609
# 9999  0.416168  0.665987  0.697960  ...  0.974012  0.177831  0.986796
#
#          49993     49994     49995     49996     49997     49998     49999
# 0     0.385151  0.581127  0.271514  0.120596  0.853516  0.823199  0.061428
# 1     0.047608  0.841132  0.903959  0.236117  0.533104  0.999573  0.447933
# 2     0.298060  0.031005  0.163447  0.559883  0.803802  0.088355  0.313765
# 3     0.198102  0.572368  0.219680  0.702008  0.463793  0.490226  0.826699
# 4     0.577554  0.133067  0.569029  0.100523  0.772878  0.822328  0.358362
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.756896  0.466128  0.307997  0.816628  0.117002  0.687615  0.250306
# 9996  0.494311  0.703526  0.710676  0.077824  0.878658  0.489834  0.648380
# 9997  0.121310  0.588515  0.898713  0.470621  0.941536  0.215674  0.965661
# 9998  0.853411  0.044284  0.640800  0.745037  0.691888  0.560997  0.577608
# 9999  0.326757  0.856377  0.399480  0.016868  0.033961  0.558259  0.548205
#
# [10000 rows x 50000 columns]

# %% [markdown]
# In order to assess the correlations of the different parameters, correlations between the column with index 0 and the 999 other first columns is assessed.

# %%
# Assigning X to all columns except 0
X_df = df.drop(columns=0)
X_df.head()

# Assigning Y to column 0
Y_df = df[0]
print(Y_df)

# The following line makes Y become a list
Y_df = np.array(Y_df).reshape(-1)
print(X_df.shape,Y_df.shape)

list_titles = X_df.columns
list_corr_df1 = []
for i in list_titles[0:z]:
    print(i)
    list_corr_df1.append(abs(np.corrcoef(Y_df, X_df[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df, X_df[i])[0][1]))
# Out:
# 0       0.161537
# 1       0.557257
# 2       0.243034
# 3       0.539145
# 4       0.128277
#           ...
# 9995    0.816988
# 9996    0.723330
# 9997    0.600350
# 9998    0.102388
# 9999    0.037191
# Name: 0, Length: 10000, dtype: float64
# (10000, 49999) (10000,)
# 1
# Correlation matrix for column 0 and and column1: 0.006891744923251544
# 2
# Correlation matrix for column 0 and and column2: 0.03328065914942067
# 3
# Correlation matrix for column 0 and and column3: -0.007796333177111809
# 4
# Correlation matrix for column 0 and and column4: 0.0019189236567749499
# 5
# Correlation matrix for column 0 and and column5: -0.010565412930646109
# 6
# Correlation matrix for column 0 and and column6: -0.005832976545159553
# 7
# Correlation matrix for column 0 and and column7: -0.0016449554541346054
# 8
# Correlation matrix for column 0 and and column8: 0.005014668693843067
# 9
# Correlation matrix for column 0 and and column9: 0.01077355571985353
# 10
# Correlation matrix for column 0 and and column10: -0.0058919494376162606
# 11
# Correlation matrix for column 0 and and column11: -0.003335626548549062
# 12
# Correlation matrix for column 0 and and column12: -0.01650267430499016
# 13
# Correlation matrix for column 0 and and column13: -0.0045556079617094175
# 14
# Correlation matrix for column 0 and and column14: -0.0031814536315796864
# 15
# Correlation matrix for column 0 and and column15: -0.006900425521036463
# 16
# Correlation matrix for column 0 and and column16: 0.003683354367024942
# 17
# Correlation matrix for column 0 and and column17: 0.0029085444272273614
# 18
# Correlation matrix for column 0 and and column18: -0.006598149916826849
# 19
# Correlation matrix for column 0 and and column19: 0.012708167355289917
# 20
# Correlation matrix for column 0 and and column20: -0.009047356447305026
# 21
# Correlation matrix for column 0 and and column21: 0.00473952921087749
# 22
# Correlation matrix for column 0 and and column22: -0.0037260868647267732
# 23
# Correlation matrix for column 0 and and column23: 0.002826845569267698
# 24
# Correlation matrix for column 0 and and column24: 0.006002459809118484
# 25
# Correlation matrix for column 0 and and column25: 0.004041244369976499
# 26
# Correlation matrix for column 0 and and column26: -0.0027453851563994493
# 27
# Correlation matrix for column 0 and and column27: -0.007742449013498449
# 28
# Correlation matrix for column 0 and and column28: -0.0061397123759032385
# 29
# Correlation matrix for column 0 and and column29: -0.006361745860553337
# 30
# Correlation matrix for column 0 and and column30: -0.0013604247813085784
# 31
# Correlation matrix for column 0 and and column31: 0.0078368964989552
# 32
# Correlation matrix for column 0 and and column32: -0.007919870122721837
# 33
# Correlation matrix for column 0 and and column33: 0.0071121571358818214
# 34
# Correlation matrix for column 0 and and column34: 0.005692568040919701
# 35
# Correlation matrix for column 0 and and column35: -0.0016422050892582454
# 36
# Correlation matrix for column 0 and and column36: -0.021773376865266064
# 37
# Correlation matrix for column 0 and and column37: -0.005014266234964547
# 38
# Correlation matrix for column 0 and and column38: 0.005378178813108433
# 39
# Correlation matrix for column 0 and and column39: -0.009519127775375823
# 40
# Correlation matrix for column 0 and and column40: 0.011155053790913602
# 41
# Correlation matrix for column 0 and and column41: 6.508882617560425e-05
# 42
# Correlation matrix for column 0 and and column42: -0.01304093963627511
# 43
# Correlation matrix for column 0 and and column43: 0.00595444944044046
# 44
# Correlation matrix for column 0 and and column44: 0.005791166386975515
# 45
# Correlation matrix for column 0 and and column45: -0.006249828345290938
# 46
# Correlation matrix for column 0 and and column46: -0.00650706900345038
# 47
# Correlation matrix for column 0 and and column47: -0.007470031367500813
# 48
# Correlation matrix for column 0 and and column48: -0.006831020686019317
# 49
# Correlation matrix for column 0 and and column49: -0.009117419742229418
# 50
# Correlation matrix for column 0 and and column50: 0.015694095952468595
# 51
# Correlation matrix for column 0 and and column51: -0.007625054923406602
# 52
# Correlation matrix for column 0 and and column52: 0.017518749376986765
# 53
# Correlation matrix for column 0 and and column53: 0.0012617327021832241
# 54
# Correlation matrix for column 0 and and column54: 0.02413702102488933
# 55
# Correlation matrix for column 0 and and column55: -0.012594035804193958
# 56
# Correlation matrix for column 0 and and column56: 0.0030540607777459292
# 57
# Correlation matrix for column 0 and and column57: -0.009672940135577976
# 58
# Correlation matrix for column 0 and and column58: -0.007613110096488038
# 59
# Correlation matrix for column 0 and and column59: 0.004223020044055625
# 60
# Correlation matrix for column 0 and and column60: 0.009647323394474772
# 61
# Correlation matrix for column 0 and and column61: 0.0031796233077602595
# 62
# Correlation matrix for column 0 and and column62: 0.005114435099490028
# 63
# Correlation matrix for column 0 and and column63: 0.0062953234360335255
# 64
# Correlation matrix for column 0 and and column64: -0.01961043685248703
# 65
# Correlation matrix for column 0 and and column65: 0.0015864924340889578
# 66
# Correlation matrix for column 0 and and column66: -0.003529403104087311
# 67
# Correlation matrix for column 0 and and column67: -0.0056410453855417824
# 68
# Correlation matrix for column 0 and and column68: 0.0051074769483554746
# 69
# Correlation matrix for column 0 and and column69: -0.009052088647319264
# 70
# Correlation matrix for column 0 and and column70: -0.003131196421383532
# 71
# Correlation matrix for column 0 and and column71: 0.005956016353704546
# 72
# Correlation matrix for column 0 and and column72: 0.003403660743647717
# 73
# Correlation matrix for column 0 and and column73: 0.020689575597687505
# 74
# Correlation matrix for column 0 and and column74: 0.005121609787315941
# 75
# Correlation matrix for column 0 and and column75: 0.0008696577162488891
# 76
# Correlation matrix for column 0 and and column76: -0.005919733733428868
# 77
# Correlation matrix for column 0 and and column77: 0.004072099668860348
# 78
# Correlation matrix for column 0 and and column78: -0.00258909794532572
# 79
# Correlation matrix for column 0 and and column79: 0.0037711562978003338
# 80
# Correlation matrix for column 0 and and column80: 0.0007372450569717014
# 81
# Correlation matrix for column 0 and and column81: 0.016783226704804
# 82
# Correlation matrix for column 0 and and column82: 0.016669421167588367
# 83
# Correlation matrix for column 0 and and column83: -0.016779484275150046
# 84
# Correlation matrix for column 0 and and column84: 0.0019273535376596448
# 85
# Correlation matrix for column 0 and and column85: 0.007292036201634861
# 86
# Correlation matrix for column 0 and and column86: -0.02206985592653787
# 87
# Correlation matrix for column 0 and and column87: -0.005589287214739731
# 88
# Correlation matrix for column 0 and and column88: -0.0022175492031716332
# 89
# Correlation matrix for column 0 and and column89: 0.004796248560306722
# 90
# Correlation matrix for column 0 and and column90: 0.005224391652055899
# 91
# Correlation matrix for column 0 and and column91: -0.0017734635435399232
# 92
# Correlation matrix for column 0 and and column92: -0.0029159871016203646
# 93
# Correlation matrix for column 0 and and column93: 0.014239917235604086
# 94
# Correlation matrix for column 0 and and column94: -0.002249747773254186
# 95
# Correlation matrix for column 0 and and column95: -0.009925317409763901
# 96
# Correlation matrix for column 0 and and column96: 0.003283057695227157
# 97
# Correlation matrix for column 0 and and column97: -0.014058678596864103
# 98
# Correlation matrix for column 0 and and column98: -0.001685464126611984
# 99
# Correlation matrix for column 0 and and column99: 0.0063739487129194725
# 100
# Correlation matrix for column 0 and and column100: 0.006454437673318129

# %% [markdown]
# To see if indeed the correlations between the different parameters increases with the data size, the original dataframe is compared to a sub-set dataframe which only takes the first z rows of the original dataframe. If the correlations in the original dataframe are higher than in the smaller dataframe this would prove that the bigger the data size the more frequent the number of spurious correlations.

# %%
# Creating smaller dataframe taking z number of rows from original dataframe
df2 = df.iloc[:z]
df2
# Out:
#        0         1         2         3         4         5         6      \
# 0   0.161537  0.230152  0.321752  0.045548  0.327331  0.265337  0.356719
# 1   0.557257  0.843707  0.482685  0.585022  0.270943  0.016193  0.235657
# 2   0.243034  0.549041  0.639664  0.128769  0.210019  0.041539  0.708618
# 3   0.539145  0.975516  0.095903  0.760185  0.021810  0.797899  0.631584
# 4   0.128277  0.586222  0.063367  0.192537  0.331533  0.691179  0.432043
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.280421  0.986907  0.497736  0.880855  0.939793  0.247863  0.796791
# 96  0.223540  0.291521  0.317973  0.195673  0.173532  0.814563  0.952182
# 97  0.230217  0.173699  0.542043  0.667667  0.518045  0.278231  0.505344
# 98  0.941921  0.923734  0.826760  0.845088  0.413349  0.148162  0.004406
# 99  0.710526  0.959654  0.232930  0.040109  0.779806  0.409682  0.416732
#
#        7         8         9      ...     49990     49991     49992     49993  \
# 0   0.181036  0.133112  0.892356  ...  0.208107  0.441717  0.608767  0.385151
# 1   0.930825  0.195350  0.233330  ...  0.599279  0.172883  0.704992  0.047608
# 2   0.597223  0.526631  0.597928  ...  0.145090  0.353259  0.669502  0.298060
# 3   0.686302  0.673548  0.367420  ...  0.326220  0.007284  0.049699  0.198102
# 4   0.518492  0.845520  0.473112  ...  0.249087  0.507572  0.560249  0.577554
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.724937  0.596731  0.247469  ...  0.667566  0.685691  0.819112  0.870467
# 96  0.864320  0.135453  0.066538  ...  0.551059  0.027357  0.897877  0.808150
# 97  0.180041  0.654546  0.917526  ...  0.929777  0.352107  0.290135  0.228847
# 98  0.056507  0.292354  0.668705  ...  0.399467  0.833844  0.967222  0.496735
# 99  0.418819  0.484250  0.110166  ...  0.468582  0.245553  0.617280  0.809490
#
#        49994     49995     49996     49997     49998     49999
# 0   0.581127  0.271514  0.120596  0.853516  0.823199  0.061428
# 1   0.841132  0.903959  0.236117  0.533104  0.999573  0.447933
# 2   0.031005  0.163447  0.559883  0.803802  0.088355  0.313765
# 3   0.572368  0.219680  0.702008  0.463793  0.490226  0.826699
# 4   0.133067  0.569029  0.100523  0.772878  0.822328  0.358362
# ..       ...       ...       ...       ...       ...       ...
# 95  0.694627  0.133612  0.131162  0.802321  0.934586  0.350758
# 96  0.703954  0.662664  0.402813  0.223452  0.737472  0.645273
# 97  0.013647  0.136668  0.297595  0.322706  0.718453  0.069571
# 98  0.720909  0.775346  0.669418  0.398019  0.671973  0.809187
# 99  0.856965  0.445381  0.281761  0.802704  0.639877  0.808723
#
# [100 rows x 50000 columns]

# %%
# Assigning X to all columns except 0
X_df2 = df2.drop(columns=0)
X_df2.head()

# Assigning Y to column 0
Y_df2 = df2[0]
print(Y_df2)

# The following line makes Y become a list
Y_df2 = np.array(Y_df2).reshape(-1)
print(X_df2.shape,Y_df2.shape)

list_titles = X_df2.columns

list_corr_df2 = []
for i in list_titles[0:z]:
    print(i)
    list_corr_df2.append(abs(np.corrcoef(Y_df2, X_df2[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df2, X_df2[i])[0][1]))
# Out:
# 0     0.161537
# 1     0.557257
# 2     0.243034
# 3     0.539145
# 4     0.128277
#         ...
# 95    0.280421
# 96    0.223540
# 97    0.230217
# 98    0.941921
# 99    0.710526
# Name: 0, Length: 100, dtype: float64
# (100, 49999) (100,)
# 1
# Correlation matrix for column 0 and and column1: 0.049109240538850296
# 2
# Correlation matrix for column 0 and and column2: 0.058403232911537144
# 3
# Correlation matrix for column 0 and and column3: -0.04978529074082224
# 4
# Correlation matrix for column 0 and and column4: 0.22743750013933656
# 5
# Correlation matrix for column 0 and and column5: 0.0386677183320128
# 6
# Correlation matrix for column 0 and and column6: -0.0217181151279665
# 7
# Correlation matrix for column 0 and and column7: -0.020979746234635426
# 8
# Correlation matrix for column 0 and and column8: 0.15337850821315688
# 9
# Correlation matrix for column 0 and and column9: 0.0802920399415619
# 10
# Correlation matrix for column 0 and and column10: -0.034810539275110686
# 11
# Correlation matrix for column 0 and and column11: -0.09130792598043523
# 12
# Correlation matrix for column 0 and and column12: 0.06890520590533585
# 13
# Correlation matrix for column 0 and and column13: 0.060998409487484063
# 14
# Correlation matrix for column 0 and and column14: -0.1875332739109498
# 15
# Correlation matrix for column 0 and and column15: 0.16479599106449103
# 16
# Correlation matrix for column 0 and and column16: -0.1455119380164473
# 17
# Correlation matrix for column 0 and and column17: 0.1543399489687455
# 18
# Correlation matrix for column 0 and and column18: -0.04604929263658494
# 19
# Correlation matrix for column 0 and and column19: 0.15255824264956203
# 20
# Correlation matrix for column 0 and and column20: -0.11367984616184723
# 21
# Correlation matrix for column 0 and and column21: 0.0785213324826693
# 22
# Correlation matrix for column 0 and and column22: -0.08476080372911947
# 23
# Correlation matrix for column 0 and and column23: 0.004178375959899557
# 24
# Correlation matrix for column 0 and and column24: 0.10358539986480918
# 25
# Correlation matrix for column 0 and and column25: 0.28686124115056644
# 26
# Correlation matrix for column 0 and and column26: 0.05801825447910559
# 27
# Correlation matrix for column 0 and and column27: -0.04767420076466623
# 28
# Correlation matrix for column 0 and and column28: 5.062796560741737e-05
# 29
# Correlation matrix for column 0 and and column29: 0.19221682031477125
# 30
# Correlation matrix for column 0 and and column30: -0.152136237868376
# 31
# Correlation matrix for column 0 and and column31: 0.1089073218951717
# 32
# Correlation matrix for column 0 and and column32: -0.18385546934968966
# 33
# Correlation matrix for column 0 and and column33: 0.19819745160865015
# 34
# Correlation matrix for column 0 and and column34: 0.15523599243719094
# 35
# Correlation matrix for column 0 and and column35: 0.019862493811756435
# 36
# Correlation matrix for column 0 and and column36: -0.02408348063402566
# 37
# Correlation matrix for column 0 and and column37: 0.18156179854466703
# 38
# Correlation matrix for column 0 and and column38: 0.06395372247863625
# 39
# Correlation matrix for column 0 and and column39: 0.05055103991986156
# 40
# Correlation matrix for column 0 and and column40: 0.13058446591262862
# 41
# Correlation matrix for column 0 and and column41: 0.04550822616314957
# 42
# Correlation matrix for column 0 and and column42: -0.0561700429259563
# 43
# Correlation matrix for column 0 and and column43: -0.0277281729429575
# 44
# Correlation matrix for column 0 and and column44: 0.06927049348067789
# 45
# Correlation matrix for column 0 and and column45: -0.03424123918417691
# 46
# Correlation matrix for column 0 and and column46: 0.053721422033496516
# 47
# Correlation matrix for column 0 and and column47: 0.007764640456279142
# 48
# Correlation matrix for column 0 and and column48: -0.10582093522398073
# 49
# Correlation matrix for column 0 and and column49: -0.019483771704133145
# 50
# Correlation matrix for column 0 and and column50: -0.08024292764588183
# 51
# Correlation matrix for column 0 and and column51: -0.1517114110957523
# 52
# Correlation matrix for column 0 and and column52: 0.05095912923775485
# 53
# Correlation matrix for column 0 and and column53: -0.08883249280487576
# 54
# Correlation matrix for column 0 and and column54: -0.057772592446157935
# 55
# Correlation matrix for column 0 and and column55: -0.0017341705506544178
# 56
# Correlation matrix for column 0 and and column56: -0.04039942905121472
# 57
# Correlation matrix for column 0 and and column57: -0.04341166276413757
# 58
# Correlation matrix for column 0 and and column58: -0.029589902252424582
# 59
# Correlation matrix for column 0 and and column59: -0.0004934612114073532
# 60
# Correlation matrix for column 0 and and column60: 0.13996495355573363
# 61
# Correlation matrix for column 0 and and column61: -0.02853656024327873
# 62
# Correlation matrix for column 0 and and column62: -0.15928532656674416
# 63
# Correlation matrix for column 0 and and column63: -0.13809662811905726
# 64
# Correlation matrix for column 0 and and column64: -0.06223136093803869
# 65
# Correlation matrix for column 0 and and column65: -0.014545975629289042
# 66
# Correlation matrix for column 0 and and column66: 0.006573590920398828
# 67
# Correlation matrix for column 0 and and column67: -0.04187271168920191
# 68
# Correlation matrix for column 0 and and column68: -0.09720507778414082
# 69
# Correlation matrix for column 0 and and column69: 0.10083333694324001
# 70
# Correlation matrix for column 0 and and column70: 0.08964774192849476
# 71
# Correlation matrix for column 0 and and column71: 0.06084166009863642
# 72
# Correlation matrix for column 0 and and column72: 0.06877660510191087
# 73
# Correlation matrix for column 0 and and column73: 0.08823449817739996
# 74
# Correlation matrix for column 0 and and column74: -0.15696648791841816
# 75
# Correlation matrix for column 0 and and column75: 0.15095215524329125
# 76
# Correlation matrix for column 0 and and column76: 0.00021806786629908575
# 77
# Correlation matrix for column 0 and and column77: 0.06072398384865727
# 78
# Correlation matrix for column 0 and and column78: -0.11874603612894932
# 79
# Correlation matrix for column 0 and and column79: 0.10780980724038879
# 80
# Correlation matrix for column 0 and and column80: -0.002265264054451661
# 81
# Correlation matrix for column 0 and and column81: 0.17286370833765016
# 82
# Correlation matrix for column 0 and and column82: -0.006787296678977807
# 83
# Correlation matrix for column 0 and and column83: -0.04344401747315336
# 84
# Correlation matrix for column 0 and and column84: -0.03889046985207828
# 85
# Correlation matrix for column 0 and and column85: -0.1643051046170858
# 86
# Correlation matrix for column 0 and and column86: -0.0352592312133244
# 87
# Correlation matrix for column 0 and and column87: -0.050100291902886306
# 88
# Correlation matrix for column 0 and and column88: 0.08518543672303762
# 89
# Correlation matrix for column 0 and and column89: 0.08922237399062471
# 90
# Correlation matrix for column 0 and and column90: -0.02838378285086332
# 91
# Correlation matrix for column 0 and and column91: -0.09709887770528441
# 92
# Correlation matrix for column 0 and and column92: 0.08000527120170696
# 93
# Correlation matrix for column 0 and and column93: 0.13751848652882825
# 94
# Correlation matrix for column 0 and and column94: 0.13257648237305017
# 95
# Correlation matrix for column 0 and and column95: 0.09448586845586587
# 96
# Correlation matrix for column 0 and and column96: -0.06349213201676553
# 97
# Correlation matrix for column 0 and and column97: -0.074025986427649
# 98
# Correlation matrix for column 0 and and column98: 0.16229616699546193
# 99
# Correlation matrix for column 0 and and column99: 0.09349109060869845
# 100
# Correlation matrix for column 0 and and column100: 0.01557555268295461

# %% [markdown]
# We now compare which of the correlation lists has the highest numbers of every parameter

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df2)):
    if abs(list_corr_df2[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df2:",(b/len(list_corr_df2)*100),"%")
# Out:
# Percentage of correlations in df1: 20.0 %
# Percentage of correlations in df2: 91.0 %

# %% [markdown]
# Clearly it is seen that the lower the number of observations, the higher the frequency of spurious correlations. However the number of spurious correlations present in the bigger DataFrame is still very significant.

# %% [markdown]
# To counter spurious correlations, random projection can be used.

# %% [markdown]
# ## Random Projection eps = 0.1

# %%
# Pass df1 in the random projection to create a new reduced DataFrame
transformer = random_projection.GaussianRandomProjection(eps = 0.1)
df_new = pd.DataFrame(transformer.fit_transform(df))
df_new
# Out:
#           0         1         2         3         4         5         6     \
# 0    -1.601732 -0.117326  1.731682 -0.557385  0.384392  1.538381 -0.630234
# 1    -3.195321 -0.114936  1.255496 -0.201712 -0.942520  0.720171 -0.432147
# 2    -3.813890  0.729645  1.916631 -0.878726  0.434454  1.016661  0.142003
# 3    -3.855565  0.036564  1.219008 -0.759713 -0.734632  1.805569  0.290390
# 4    -3.355035 -0.471131  0.316235  0.412976 -0.475891  0.759204  0.224968
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -2.547534  1.594297 -0.210897 -0.502058 -1.273753  3.022238  0.653387
# 9996 -2.396189 -0.562915  1.633030  0.381063 -0.255825  2.193516  0.695160
# 9997 -1.732713  0.422424  1.888830 -0.108934 -0.369378  3.066845  0.955237
# 9998 -3.849580 -0.152087  1.358796  1.528268  0.069003  1.364937  0.427461
# 9999 -3.477791  0.164211  0.177355 -0.812537 -0.610848  1.572782  0.447431
#
#           7         8         9     ...      7884      7885      7886  \
# 0     0.951603 -0.510984 -0.494942  ... -0.876267 -2.427731 -0.203645
# 1    -0.101867 -1.486084 -0.366703  ... -2.255950 -1.161699  1.445758
# 2    -0.007094 -0.907188 -0.327160  ... -2.361016 -2.075941  0.934862
# 3     0.313628 -1.463906  0.672448  ... -1.481216 -2.516646  1.263283
# 4    -0.025547 -1.931189 -0.323641  ... -2.250351 -0.707209  1.053165
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.803869 -0.573208 -0.457313  ... -2.816756 -1.644069 -0.414990
# 9996  1.587520 -2.248228  0.657587  ... -2.759514 -1.746728  1.771137
# 9997  0.000566 -2.658843  0.468938  ... -1.762118 -0.203111  0.236213
# 9998  0.065768 -2.868598 -1.026894  ... -3.111286 -1.116850  1.000644
# 9999  0.610808 -2.053716  0.385609  ... -1.739865 -1.570900  1.316369
#
#           7887      7888      7889      7890      7891      7892      7893
# 0    -0.486127  0.699491  2.700707  1.513709  1.897580  0.817330 -0.424708
# 1    -1.427781  0.485550  2.149990  1.142450  1.999056  1.526511  0.428079
# 2     0.444871  2.463131  2.783620  1.198301  1.446284  0.175103 -0.148120
# 3    -1.069465  1.295054  1.660904  1.856010  2.079585 -0.553049 -0.908647
# 4    -0.275399  0.419091  1.838221  1.396086  1.474282  0.435951 -1.598815
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -1.660281  1.380047  1.466222  2.685329  1.441267  1.296043 -0.647897
# 9996 -3.063567  1.053948  1.722525  2.520127  0.327139  0.374060 -0.367632
# 9997 -1.091203  1.723195  2.600651  2.847139  1.026241  1.092549  0.221897
# 9998 -0.774440 -0.339171  2.090069  0.819278  1.014915  1.709084  0.949513
# 9999 -0.680217  2.092822  0.741767  1.446167  0.319811  0.966258 -0.277912
#
# [10000 rows x 7894 columns]

# %%
# Assigning X to all columns except 0
X_df_new = df_new.drop(columns=0)

# Assigning Y to column 0
Y_df_new = df_new[0]
print(Y_df_new)

# The following line makes Y become a list
Y_df_new = np.array(Y_df_new).reshape(-1)
print(X_df_new.shape,Y_df_new.shape)

list_titles = X_df_new.columns

list_corr_df_new = []
for i in list_titles[0:len(list_titles)]:
    print(i)
    list_corr_df_new.append(abs(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
    print('Correlation matrix for column 0 and and column' + str(i) + ': ' + str(np.corrcoef(Y_df_new, X_df_new[i])[0][1]))
# Out:
# 0      -1.601732
# 1      -3.195321
# 2      -3.813890
# 3      -3.855565
# 4      -3.355035
#           ...
# 9995   -2.547534
# 9996   -2.396189
# 9997   -1.732713
# 9998   -3.849580
# 9999   -3.477791
# Name: 0, Length: 10000, dtype: float64
# (10000, 7893) (10000,)
# 1
# Correlation matrix for column 0 and and column1: 0.0005176990980160398
# 2
# Correlation matrix for column 0 and and column2: -0.00556144106544075
# 3
# Correlation matrix for column 0 and and column3: 0.003499757813513752
# 4
# Correlation matrix for column 0 and and column4: 0.0010449406279790011
# 5
# Correlation matrix for column 0 and and column5: -0.0035053315344585746
# 6
# Correlation matrix for column 0 and and column6: 0.015105521257329635
# 7
# Correlation matrix for column 0 and and column7: 0.0020341466141781065
# 8
# Correlation matrix for column 0 and and column8: 0.011044819787193167
# 9
# Correlation matrix for column 0 and and column9: 0.011269057708892806
# 10
# Correlation matrix for column 0 and and column10: 0.00037917269155893983
# 11
# Correlation matrix for column 0 and and column11: -0.00039856277159571493
# 12
# Correlation matrix for column 0 and and column12: -0.020289019761205583
# 13
# Correlation matrix for column 0 and and column13: 0.0014943083348316272
# 14
# Correlation matrix for column 0 and and column14: -0.00961364700537817
# 15
# Correlation matrix for column 0 and and column15: -0.0001651431686466014
# 16
# Correlation matrix for column 0 and and column16: 0.0018288039669941125
# 17
# Correlation matrix for column 0 and and column17: -0.012030177171273238
# 18
# Correlation matrix for column 0 and and column18: 0.003170856987560837
# 19
# Correlation matrix for column 0 and and column19: 0.001885009029437734
# 20
# Correlation matrix for column 0 and and column20: 0.0014119015868052556
# 21
# Correlation matrix for column 0 and and column21: -0.013069785400787818
# 22
# Correlation matrix for column 0 and and column22: 0.011058792182677614
# 23
# Correlation matrix for column 0 and and column23: -0.01705663594405778
# 24
# Correlation matrix for column 0 and and column24: -0.01584715375742827
# 25
# Correlation matrix for column 0 and and column25: -0.015095020583844628
# 26
# Correlation matrix for column 0 and and column26: 0.0015963283656195851
# 27
# Correlation matrix for column 0 and and column27: -0.0172064013582183
# 28
# Correlation matrix for column 0 and and column28: 0.018962814811638348
# 29
# Correlation matrix for column 0 and and column29: -0.010403938853381933
# 30
# Correlation matrix for column 0 and and column30: 0.009375256830576443
# 31
# Correlation matrix for column 0 and and column31: 0.0010325067272817195
# 32
# Correlation matrix for column 0 and and column32: -0.00230067729542743
# 33
# Correlation matrix for column 0 and and column33: -0.013393714776186266
# 34
# Correlation matrix for column 0 and and column34: -0.014763914957004973
# 35
# Correlation matrix for column 0 and and column35: 0.022489999100017394
# 36
# Correlation matrix for column 0 and and column36: 0.017326611095206994
# 37
# Correlation matrix for column 0 and and column37: -0.0067879743301309985
# 38
# Correlation matrix for column 0 and and column38: 0.005398032144546996
# 39
# Correlation matrix for column 0 and and column39: 0.009610270520608168
# 40
# Correlation matrix for column 0 and and column40: 0.012397011954173344
# 41
# Correlation matrix for column 0 and and column41: -0.008979861854933735
# 42
# Correlation matrix for column 0 and and column42: 0.007093989686129479
# 43
# Correlation matrix for column 0 and and column43: 0.006063756546667069
# 44
# Correlation matrix for column 0 and and column44: -0.006597447760539737
# 45
# Correlation matrix for column 0 and and column45: -0.014948403030968479
# 46
# Correlation matrix for column 0 and and column46: 0.00594228825596986
# 47
# Correlation matrix for column 0 and and column47: 0.00425862413924837
# 48
# Correlation matrix for column 0 and and column48: 0.03965968366360681
# 49
# Correlation matrix for column 0 and and column49: -0.006939598052242396
# 50
# Correlation matrix for column 0 and and column50: 0.009976025288517607
# 51
# Correlation matrix for column 0 and and column51: -0.0033773636705604253
# 52
# Correlation matrix for column 0 and and column52: 0.01861193468165354
# 53
# Correlation matrix for column 0 and and column53: 0.0024993492917114906
# 54
# Correlation matrix for column 0 and and column54: 0.002729923824018866
# 55
# Correlation matrix for column 0 and and column55: -0.013274443433840457
# 56
# Correlation matrix for column 0 and and column56: 0.006890607605928422
# 57
# Correlation matrix for column 0 and and column57: 0.007527273724809734
# 58
# Correlation matrix for column 0 and and column58: 0.022871785164003212
# 59
# Correlation matrix for column 0 and and column59: -0.027645002094255074
# 60
# Correlation matrix for column 0 and and column60: 0.005438923307284049
# 61
# Correlation matrix for column 0 and and column61: -0.01616811398402719
# 62
# Correlation matrix for column 0 and and column62: 0.009979093990007524
# 63
# Correlation matrix for column 0 and and column63: 0.01697882881082628
# 64
# Correlation matrix for column 0 and and column64: -0.0061296462366123355
# 65
# Correlation matrix for column 0 and and column65: 0.008013644380371474
# 66
# Correlation matrix for column 0 and and column66: 0.006825039318637156
# 67
# Correlation matrix for column 0 and and column67: -0.022803979497889555
# 68
# Correlation matrix for column 0 and and column68: -0.006968157070442907
# 69
# Correlation matrix for column 0 and and column69: -0.0026251986266899417
# 70
# Correlation matrix for column 0 and and column70: 0.0073248556954127846
# 71
# Correlation matrix for column 0 and and column71: -0.006946236128235917
# 72
# Correlation matrix for column 0 and and column72: 0.001039009416149465
# 73
# Correlation matrix for column 0 and and column73: 0.010806536286922405
# 74
# Correlation matrix for column 0 and and column74: 0.001535372234257089
# 75
# Correlation matrix for column 0 and and column75: -0.01729283349446781
# 76
# Correlation matrix for column 0 and and column76: 0.01228699449487199
# 77
# Correlation matrix for column 0 and and column77: -0.022630396124483327
# 78
# Correlation matrix for column 0 and and column78: -0.015267435160437949
# 79
# Correlation matrix for column 0 and and column79: 0.0025475952807402984
# 80
# Correlation matrix for column 0 and and column80: 0.018859917708948227
# 81
# Correlation matrix for column 0 and and column81: 0.02487814286776858
# 82
# Correlation matrix for column 0 and and column82: 0.01495415788131798
# 83
# Correlation matrix for column 0 and and column83: -0.007407727507882288
# 84
# Correlation matrix for column 0 and and column84: -0.005522213969457531
# 85
# Correlation matrix for column 0 and and column85: 0.006779310965947751
# 86
# Correlation matrix for column 0 and and column86: 0.019790303655821965
# 87
# Correlation matrix for column 0 and and column87: 0.010882455459272794
# 88
# Correlation matrix for column 0 and and column88: -0.004743306363781881
# 89
# Correlation matrix for column 0 and and column89: -0.021133523352326336
# 90
# Correlation matrix for column 0 and and column90: -0.007918740729908487
# 91
# Correlation matrix for column 0 and and column91: 0.0037238004705196464
# 92
# Correlation matrix for column 0 and and column92: -0.006445283596910332
# 93
# Correlation matrix for column 0 and and column93: 0.0036648178686929382
# 94
# Correlation matrix for column 0 and and column94: 0.013468306474151263
# 95
# Correlation matrix for column 0 and and column95: -0.030340174971919903
# 96
# Correlation matrix for column 0 and and column96: 0.0031932906143660217
# 97
# Correlation matrix for column 0 and and column97: -0.008867752291690246
# 98
# Correlation matrix for column 0 and and column98: -0.021742909797203034
# 99
# Correlation matrix for column 0 and and column99: 0.003175044745059011
# 100
# Correlation matrix for column 0 and and column100: -0.004840581968652811
# 101
# Correlation matrix for column 0 and and column101: 0.006039957959135029
# 102
# Correlation matrix for column 0 and and column102: -0.002267927338293231
# 103
# Correlation matrix for column 0 and and column103: 0.020118754581170416
# 104
# Correlation matrix for column 0 and and column104: 0.006835460751281112
# 105
# Correlation matrix for column 0 and and column105: -0.010357965935549296
# 106
# Correlation matrix for column 0 and and column106: 0.007479949890047307
# 107
# Correlation matrix for column 0 and and column107: -0.0029827053373498716
# 108
# Correlation matrix for column 0 and and column108: -0.005557695729862412
# 109
# Correlation matrix for column 0 and and column109: 0.01709426034518586
# 110
# Correlation matrix for column 0 and and column110: -0.008113025309805741
# 111
# Correlation matrix for column 0 and and column111: 0.01123476416878218
# 112
# Correlation matrix for column 0 and and column112: -0.00974153180623272
# 113
# Correlation matrix for column 0 and and column113: 0.01912437110743632
# 114
# Correlation matrix for column 0 and and column114: -0.006105094453511452
# 115
# Correlation matrix for column 0 and and column115: 0.004305540067279303
# 116
# Correlation matrix for column 0 and and column116: 0.01644841259343098
# 117
# Correlation matrix for column 0 and and column117: -0.007809175338057805
# 118
# Correlation matrix for column 0 and and column118: -0.009169281353554779
# 119
# Correlation matrix for column 0 and and column119: -0.0011609878684468908
# 120
# Correlation matrix for column 0 and and column120: -0.003237919241135982
# 121
# Correlation matrix for column 0 and and column121: -0.001815192317034953
# 122
# Correlation matrix for column 0 and and column122: 0.008412394902541389
# 123
# Correlation matrix for column 0 and and column123: 0.007714649808125514
# 124
# Correlation matrix for column 0 and and column124: 0.024918311223681495
# 125
# Correlation matrix for column 0 and and column125: 0.003578905500003986
# 126
# Correlation matrix for column 0 and and column126: 0.00012133622344379015
# 127
# Correlation matrix for column 0 and and column127: 0.005924592587266631
# 128
# Correlation matrix for column 0 and and column128: 0.013870321472627307
# 129
# Correlation matrix for column 0 and and column129: -0.013016780248324094
# 130
# Correlation matrix for column 0 and and column130: 0.006940879043642404
# 131
# Correlation matrix for column 0 and and column131: -0.009014640505336936
# 132
# Correlation matrix for column 0 and and column132: -0.010423698946598305
# 133
# Correlation matrix for column 0 and and column133: -0.0032889641413103095
# 134
# Correlation matrix for column 0 and and column134: -0.0037579953476884424
# 135
# Correlation matrix for column 0 and and column135: -0.00045867607387672677
# 136
# Correlation matrix for column 0 and and column136: 0.01997064977312413
# 137
# Correlation matrix for column 0 and and column137: -0.009385952816167772
# 138
# Correlation matrix for column 0 and and column138: 0.004576006080917514
# 139
# Correlation matrix for column 0 and and column139: 0.0032189488681284924
# 140
# Correlation matrix for column 0 and and column140: 0.02340928773100384
# 141
# Correlation matrix for column 0 and and column141: -0.01831383186716177
# 142
# Correlation matrix for column 0 and and column142: -0.011360898862406859
# 143
# Correlation matrix for column 0 and and column143: 0.013505689276647808
# 144
# Correlation matrix for column 0 and and column144: -0.010754612190412077
# 145
# Correlation matrix for column 0 and and column145: 0.009631082529568425
# 146
# Correlation matrix for column 0 and and column146: -0.003918639434295761
# 147
# Correlation matrix for column 0 and and column147: -0.021315405173323903
# 148
# Correlation matrix for column 0 and and column148: 0.004515139968505367
# 149
# Correlation matrix for column 0 and and column149: -0.0006525219856899337
# 150
# Correlation matrix for column 0 and and column150: 0.01058066561199809
# 151
# Correlation matrix for column 0 and and column151: 0.008672584969147797
# 152
# Correlation matrix for column 0 and and column152: 0.0032127935720268857
# 153
# Correlation matrix for column 0 and and column153: -0.0001792730646276867
# 154
# Correlation matrix for column 0 and and column154: 0.00016645547254804283
# 155
# Correlation matrix for column 0 and and column155: 0.002958433166947233
# 156
# Correlation matrix for column 0 and and column156: -0.01329974318188829
# 157
# Correlation matrix for column 0 and and column157: 0.0013494505332726327
# 158
# Correlation matrix for column 0 and and column158: -0.0012556681752572763
# 159
# Correlation matrix for column 0 and and column159: 0.01087723021430157
# 160
# Correlation matrix for column 0 and and column160: -0.016282946544846376
# 161
# Correlation matrix for column 0 and and column161: -0.017031563446849116
# 162
# Correlation matrix for column 0 and and column162: 0.005918206965302044
# 163
# Correlation matrix for column 0 and and column163: 0.004935029170140567
# 164
# Correlation matrix for column 0 and and column164: -0.011873864166633562
# 165
# Correlation matrix for column 0 and and column165: -0.009558595589376237
# 166
# Correlation matrix for column 0 and and column166: 0.0021207586756094277
# 167
# Correlation matrix for column 0 and and column167: 0.005781517630000651
# 168
# Correlation matrix for column 0 and and column168: -0.0014697832351675975
# 169
# Correlation matrix for column 0 and and column169: -0.004635080263595163
# 170
# Correlation matrix for column 0 and and column170: -0.024015561552015632
# 171
# Correlation matrix for column 0 and and column171: 0.009338790315785533
# 172
# Correlation matrix for column 0 and and column172: 0.001244825790908599
# 173
# Correlation matrix for column 0 and and column173: 0.011713403694721559
# 174
# Correlation matrix for column 0 and and column174: -0.013299867065900303
# 175
# Correlation matrix for column 0 and and column175: -0.01248459867976311
# 176
# Correlation matrix for column 0 and and column176: -0.002384389898598156
# 177
# Correlation matrix for column 0 and and column177: -0.00923163185073243
# 178
# Correlation matrix for column 0 and and column178: 0.01257915231431468
# 179
# Correlation matrix for column 0 and and column179: -0.013452921402236436
# 180
# Correlation matrix for column 0 and and column180: -0.02601689514996851
# 181
# Correlation matrix for column 0 and and column181: 0.014693077767746556
# 182
# Correlation matrix for column 0 and and column182: -0.000526115553588686
# 183
# Correlation matrix for column 0 and and column183: 0.01749893824341508
# 184
# Correlation matrix for column 0 and and column184: 0.011543536598989127
# 185
# Correlation matrix for column 0 and and column185: 0.007199892081372626
# 186
# Correlation matrix for column 0 and and column186: 0.012930865350827537
# 187
# Correlation matrix for column 0 and and column187: -0.017216749380822814
# 188
# Correlation matrix for column 0 and and column188: 0.00471817443401621
# 189
# Correlation matrix for column 0 and and column189: -0.009856526859349775
# 190
# Correlation matrix for column 0 and and column190: 0.004187872021289221
# 191
# Correlation matrix for column 0 and and column191: -0.013696867672108487
# 192
# Correlation matrix for column 0 and and column192: 0.017143831694905607
# 193
# Correlation matrix for column 0 and and column193: -0.00033872839022239417
# 194
# Correlation matrix for column 0 and and column194: -0.009905465662039231
# 195
# Correlation matrix for column 0 and and column195: -0.011940749081449728
# 196
# Correlation matrix for column 0 and and column196: 0.005397058155249517
# 197
# Correlation matrix for column 0 and and column197: 0.01688391157377743
# 198
# Correlation matrix for column 0 and and column198: 0.0042997236316204375
# 199
# Correlation matrix for column 0 and and column199: -0.021060744220135208
# 200
# Correlation matrix for column 0 and and column200: 0.023272972255498705
# 201
# Correlation matrix for column 0 and and column201: -0.010413418955740092
# 202
# Correlation matrix for column 0 and and column202: -0.012711557897403507
# 203
# Correlation matrix for column 0 and and column203: -0.011134084548382085
# 204
# Correlation matrix for column 0 and and column204: 0.007602170189042656
# 205
# Correlation matrix for column 0 and and column205: -0.023142473027523473
# 206
# Correlation matrix for column 0 and and column206: -0.013865836338545991
# 207
# Correlation matrix for column 0 and and column207: 0.01296912617667456
# 208
# Correlation matrix for column 0 and and column208: 0.0071318801385364065
# 209
# Correlation matrix for column 0 and and column209: -0.00026318663270416364
# 210
# Correlation matrix for column 0 and and column210: -0.0014163049341182029
# 211
# Correlation matrix for column 0 and and column211: -0.00710389549118388
# 212
# Correlation matrix for column 0 and and column212: 0.0011633540189155444
# 213
# Correlation matrix for column 0 and and column213: -0.011746373968395103
# 214
# Correlation matrix for column 0 and and column214: -0.01666079686286169
# 215
# Correlation matrix for column 0 and and column215: -0.009443971680445104
# 216
# Correlation matrix for column 0 and and column216: -0.006112574954866124
# 217
# Correlation matrix for column 0 and and column217: 0.005843020979679185
# 218
# Correlation matrix for column 0 and and column218: -0.003549544828386648
# 219
# Correlation matrix for column 0 and and column219: 0.00837039079511688
# 220
# Correlation matrix for column 0 and and column220: -0.005783384410277529
# 221
# Correlation matrix for column 0 and and column221: 0.006781712264699496
# 222
# Correlation matrix for column 0 and and column222: 0.019387275905327225
# 223
# Correlation matrix for column 0 and and column223: -0.00670207391696707
# 224
# Correlation matrix for column 0 and and column224: 0.0049615102242381755
# 225
# Correlation matrix for column 0 and and column225: -0.014810555371698664
# 226
# Correlation matrix for column 0 and and column226: 0.0026424065261900875
# 227
# Correlation matrix for column 0 and and column227: -0.004511391927271546
# 228
# Correlation matrix for column 0 and and column228: 0.0017418874316343044
# 229
# Correlation matrix for column 0 and and column229: 0.011838335992605014
# 230
# Correlation matrix for column 0 and and column230: -0.006578900341568563
# 231
# Correlation matrix for column 0 and and column231: 0.005960221736713107
# 232
# Correlation matrix for column 0 and and column232: -0.006399900604500439
# 233
# Correlation matrix for column 0 and and column233: -0.00015682858797575012
# 234
# Correlation matrix for column 0 and and column234: -0.003372778300271943
# 235
# Correlation matrix for column 0 and and column235: -0.00011558360593147455
# 236
# Correlation matrix for column 0 and and column236: 0.012884452792267107
# 237
# Correlation matrix for column 0 and and column237: 0.011666882072670763
# 238
# Correlation matrix for column 0 and and column238: -0.0011506987372450655
# 239
# Correlation matrix for column 0 and and column239: 0.004652600265998743
# 240
# Correlation matrix for column 0 and and column240: -0.0008690403424374235
# 241
# Correlation matrix for column 0 and and column241: 0.004101698054295188
# 242
# Correlation matrix for column 0 and and column242: 0.0007218730819387377
# 243
# Correlation matrix for column 0 and and column243: -0.015604381078067091
# 244
# Correlation matrix for column 0 and and column244: 0.006766195549125126
# 245
# Correlation matrix for column 0 and and column245: -0.000999425458162097
# 246
# Correlation matrix for column 0 and and column246: -0.01908500625837235
# 247
# Correlation matrix for column 0 and and column247: 0.01361223295699531
# 248
# Correlation matrix for column 0 and and column248: -0.017783187321468233
# 249
# Correlation matrix for column 0 and and column249: -0.00587006297377485
# 250
# Correlation matrix for column 0 and and column250: 0.004542669655705162
# 251
# Correlation matrix for column 0 and and column251: 0.012676257191078032
# 252
# Correlation matrix for column 0 and and column252: -0.0022202547557816825
# 253
# Correlation matrix for column 0 and and column253: 0.0003724763642187074
# 254
# Correlation matrix for column 0 and and column254: 0.03418232308115822
# 255
# Correlation matrix for column 0 and and column255: -0.004794827453077668
# 256
# Correlation matrix for column 0 and and column256: 0.014283794791753186
# 257
# Correlation matrix for column 0 and and column257: 0.0059090317516758
# 258
# Correlation matrix for column 0 and and column258: -0.004417769181844343
# 259
# Correlation matrix for column 0 and and column259: 0.018076334045073177
# 260
# Correlation matrix for column 0 and and column260: 0.00631626551768258
# 261
# Correlation matrix for column 0 and and column261: -0.0034755850636741673
# 262
# Correlation matrix for column 0 and and column262: 0.0055468114956423635
# 263
# Correlation matrix for column 0 and and column263: -0.007436997516112209
# 264
# Correlation matrix for column 0 and and column264: -0.003221028375366183
# 265
# Correlation matrix for column 0 and and column265: -0.0014038393770305488
# 266
# Correlation matrix for column 0 and and column266: -0.005086088998230748
# 267
# Correlation matrix for column 0 and and column267: 0.004324031304591845
# 268
# Correlation matrix for column 0 and and column268: -0.00244283762853463
# 269
# Correlation matrix for column 0 and and column269: 0.003522278667528081
# 270
# Correlation matrix for column 0 and and column270: 0.0035306034091489033
# 271
# Correlation matrix for column 0 and and column271: -0.005124291730109983
# 272
# Correlation matrix for column 0 and and column272: -0.02447805849092867
# 273
# Correlation matrix for column 0 and and column273: -0.00587761808607719
# 274
# Correlation matrix for column 0 and and column274: -0.01811196333899382
# 275
# Correlation matrix for column 0 and and column275: 0.0077701889133326195
# 276
# Correlation matrix for column 0 and and column276: -0.00020082296112410182
# 277
# Correlation matrix for column 0 and and column277: 0.00664778123397492
# 278
# Correlation matrix for column 0 and and column278: -0.0033954909703362616
# 279
# Correlation matrix for column 0 and and column279: 0.0032220426166201434
# 280
# Correlation matrix for column 0 and and column280: -0.007808884841443428
# 281
# Correlation matrix for column 0 and and column281: 0.005295430299062604
# 282
# Correlation matrix for column 0 and and column282: -0.01342944484871713
# 283
# Correlation matrix for column 0 and and column283: 0.01015798732021663
# 284
# Correlation matrix for column 0 and and column284: -0.008054340342313336
# 285
# Correlation matrix for column 0 and and column285: -0.005303898659946942
# 286
# Correlation matrix for column 0 and and column286: -0.00731718187557845
# 287
# Correlation matrix for column 0 and and column287: -0.0049859661211032295
# 288
# Correlation matrix for column 0 and and column288: 0.025525298900057874
# 289
# Correlation matrix for column 0 and and column289: 0.007574778259834259
# 290
# Correlation matrix for column 0 and and column290: -0.012565811253726189
# 291
# Correlation matrix for column 0 and and column291: 0.00033882663573204895
# 292
# Correlation matrix for column 0 and and column292: 0.010428732141752602
# 293
# Correlation matrix for column 0 and and column293: -0.0013539903499999381
# 294
# Correlation matrix for column 0 and and column294: 0.020313542058554745
# 295
# Correlation matrix for column 0 and and column295: 0.007660894537188885
# 296
# Correlation matrix for column 0 and and column296: -0.004891460136197833
# 297
# Correlation matrix for column 0 and and column297: -0.004259986434980309
# 298
# Correlation matrix for column 0 and and column298: -0.01870939550337453
# 299
# Correlation matrix for column 0 and and column299: 0.029074584867340724
# 300
# Correlation matrix for column 0 and and column300: 0.0011971420770041468
# 301
# Correlation matrix for column 0 and and column301: -0.006593658174402411
# 302
# Correlation matrix for column 0 and and column302: 0.000132458527658457
# 303
# Correlation matrix for column 0 and and column303: -0.010940743334238508
# 304
# Correlation matrix for column 0 and and column304: -0.005404488706056094
# 305
# Correlation matrix for column 0 and and column305: 0.017679226481655156
# 306
# Correlation matrix for column 0 and and column306: 0.012028808245563866
# 307
# Correlation matrix for column 0 and and column307: 0.00038580832234081
# 308
# Correlation matrix for column 0 and and column308: -0.004493475538434031
# 309
# Correlation matrix for column 0 and and column309: 0.00022582914661010173
# 310
# Correlation matrix for column 0 and and column310: 0.00718147624029504
# 311
# Correlation matrix for column 0 and and column311: 0.0015294800826863018
# 312
# Correlation matrix for column 0 and and column312: -0.0173213490194671
# 313
# Correlation matrix for column 0 and and column313: -0.0010358833154630307
# 314
# Correlation matrix for column 0 and and column314: 0.016055765859249407
# 315
# Correlation matrix for column 0 and and column315: -0.001415833461216715
# 316
# Correlation matrix for column 0 and and column316: -0.010935369716486704
# 317
# Correlation matrix for column 0 and and column317: -0.010129838137159284
# 318
# Correlation matrix for column 0 and and column318: 0.0026023179527430752
# 319
# Correlation matrix for column 0 and and column319: -0.014105209974516407
# 320
# Correlation matrix for column 0 and and column320: -0.0025840676304710736
# 321
# Correlation matrix for column 0 and and column321: 0.005013435490142427
# 322
# Correlation matrix for column 0 and and column322: -0.01910196391049664
# 323
# Correlation matrix for column 0 and and column323: 0.00906810498780726
# 324
# Correlation matrix for column 0 and and column324: 0.008593253027326308
# 325
# Correlation matrix for column 0 and and column325: -0.006253996695882095
# 326
# Correlation matrix for column 0 and and column326: 0.0021838434557598443
# 327
# Correlation matrix for column 0 and and column327: 6.194046964748992e-05
# 328
# Correlation matrix for column 0 and and column328: -0.00952230628841344
# 329
# Correlation matrix for column 0 and and column329: 0.004234627471660154
# 330
# Correlation matrix for column 0 and and column330: 0.0056618271672370015
# 331
# Correlation matrix for column 0 and and column331: -0.011408849762894092
# 332
# Correlation matrix for column 0 and and column332: 0.006182700109029302
# 333
# Correlation matrix for column 0 and and column333: -0.003178559422015266
# 334
# Correlation matrix for column 0 and and column334: 0.0017424012909218272
# 335
# Correlation matrix for column 0 and and column335: -0.0012854780118921817
# 336
# Correlation matrix for column 0 and and column336: 0.0065643968851601606
# 337
# Correlation matrix for column 0 and and column337: -7.71738645196958e-05
# 338
# Correlation matrix for column 0 and and column338: 0.007847031973365023
# 339
# Correlation matrix for column 0 and and column339: -0.03893477577485212
# 340
# Correlation matrix for column 0 and and column340: -0.00797618536177642
# 341
# Correlation matrix for column 0 and and column341: -0.02163100672511698
# 342
# Correlation matrix for column 0 and and column342: 0.004992438580491392
# 343
# Correlation matrix for column 0 and and column343: -0.0070793374940560224
# 344
# Correlation matrix for column 0 and and column344: 0.009806882321700044
# 345
# Correlation matrix for column 0 and and column345: 0.005647290665346247
# 346
# Correlation matrix for column 0 and and column346: -0.02141196537270177
# 347
# Correlation matrix for column 0 and and column347: -0.0015075696415375974
# 348
# Correlation matrix for column 0 and and column348: 0.0034477419254736142
# 349
# Correlation matrix for column 0 and and column349: -0.0006899819772262938
# 350
# Correlation matrix for column 0 and and column350: 0.011401720892838177
# 351
# Correlation matrix for column 0 and and column351: -0.00652892734651242
# 352
# Correlation matrix for column 0 and and column352: 0.005582189852064004
# 353
# Correlation matrix for column 0 and and column353: 0.005922900908676833
# 354
# Correlation matrix for column 0 and and column354: 0.01890621085414251
# 355
# Correlation matrix for column 0 and and column355: 0.003935470055988877
# 356
# Correlation matrix for column 0 and and column356: -0.016994704432389016
# 357
# Correlation matrix for column 0 and and column357: -0.009373594344327794
# 358
# Correlation matrix for column 0 and and column358: -0.01245521987037071
# 359
# Correlation matrix for column 0 and and column359: -0.017971991610146166
# 360
# Correlation matrix for column 0 and and column360: 0.01446970431692686
# 361
# Correlation matrix for column 0 and and column361: -0.01293545623429995
# 362
# Correlation matrix for column 0 and and column362: 0.0019506293787999794
# 363
# Correlation matrix for column 0 and and column363: 0.013127570306855048
# 364
# Correlation matrix for column 0 and and column364: 0.009997474991356423
# 365
# Correlation matrix for column 0 and and column365: -0.004140079706914392
# 366
# Correlation matrix for column 0 and and column366: 0.01712922768721704
# 367
# Correlation matrix for column 0 and and column367: 0.009117339845870523
# 368
# Correlation matrix for column 0 and and column368: 0.007099946879255508
# 369
# Correlation matrix for column 0 and and column369: -0.00852462166044513
# 370
# Correlation matrix for column 0 and and column370: -0.01168579289000614
# 371
# Correlation matrix for column 0 and and column371: 0.014248703742021038
# 372
# Correlation matrix for column 0 and and column372: 0.016548682462335835
# 373
# Correlation matrix for column 0 and and column373: -0.0015290049123481211
# 374
# Correlation matrix for column 0 and and column374: -0.027689942102976477
# 375
# Correlation matrix for column 0 and and column375: 0.008283699714749881
# 376
# Correlation matrix for column 0 and and column376: -0.004328050722885651
# 377
# Correlation matrix for column 0 and and column377: 0.0013768911668817104
# 378
# Correlation matrix for column 0 and and column378: 0.019000881173622534
# 379
# Correlation matrix for column 0 and and column379: -0.009595884942294752
# 380
# Correlation matrix for column 0 and and column380: -0.008311202573967709
# 381
# Correlation matrix for column 0 and and column381: 0.01006787679156075
# 382
# Correlation matrix for column 0 and and column382: 0.00873653456058829
# 383
# Correlation matrix for column 0 and and column383: -0.012197132317425323
# 384
# Correlation matrix for column 0 and and column384: -0.016666015163979968
# 385
# Correlation matrix for column 0 and and column385: 0.008419550333773711
# 386
# Correlation matrix for column 0 and and column386: 0.0039421675909656825
# 387
# Correlation matrix for column 0 and and column387: 0.00479523889015575
# 388
# Correlation matrix for column 0 and and column388: -0.0048595953835744495
# 389
# Correlation matrix for column 0 and and column389: -0.005400404617016422
# 390
# Correlation matrix for column 0 and and column390: -0.008899134740520443
# 391
# Correlation matrix for column 0 and and column391: 0.014261226185663152
# 392
# Correlation matrix for column 0 and and column392: -0.005070492146643352
# 393
# Correlation matrix for column 0 and and column393: -0.010514110887643223
# 394
# Correlation matrix for column 0 and and column394: -0.018933689856445536
# 395
# Correlation matrix for column 0 and and column395: 0.006988471214168515
# 396
# Correlation matrix for column 0 and and column396: 0.01064421863714063
# 397
# Correlation matrix for column 0 and and column397: 0.0059739040439834605
# 398
# Correlation matrix for column 0 and and column398: -0.01033358277782425
# 399
# Correlation matrix for column 0 and and column399: -0.005074610289650965
# 400
# Correlation matrix for column 0 and and column400: 0.011077901962781266
# 401
# Correlation matrix for column 0 and and column401: -0.016983192561973438
# 402
# Correlation matrix for column 0 and and column402: -0.0017267503047198414
# 403
# Correlation matrix for column 0 and and column403: -0.008772964026201903
# 404
# Correlation matrix for column 0 and and column404: 0.0009655992114647323
# 405
# Correlation matrix for column 0 and and column405: 0.013230664682635694
# 406
# Correlation matrix for column 0 and and column406: 1.3045304654529461e-05
# 407
# Correlation matrix for column 0 and and column407: 0.013616352908773584
# 408
# Correlation matrix for column 0 and and column408: -0.01342879868545224
# 409
# Correlation matrix for column 0 and and column409: -0.015325321614489174
# 410
# Correlation matrix for column 0 and and column410: 0.0059200556464411936
# 411
# Correlation matrix for column 0 and and column411: -0.011301305294400306
# 412
# Correlation matrix for column 0 and and column412: 0.0002045661657499781
# 413
# Correlation matrix for column 0 and and column413: -0.0034869811813068763
# 414
# Correlation matrix for column 0 and and column414: -0.0035718670550227297
# 415
# Correlation matrix for column 0 and and column415: 0.006732314359451422
# 416
# Correlation matrix for column 0 and and column416: 0.0035372407983929976
# 417
# Correlation matrix for column 0 and and column417: -0.007677156073285735
# 418
# Correlation matrix for column 0 and and column418: 0.004998763706470777
# 419
# Correlation matrix for column 0 and and column419: -0.006179216983047688
# 420
# Correlation matrix for column 0 and and column420: -0.0009758098823365406
# 421
# Correlation matrix for column 0 and and column421: 0.002176065083843532
# 422
# Correlation matrix for column 0 and and column422: -0.005974268174700188
# 423
# Correlation matrix for column 0 and and column423: -0.00019545650604845262
# 424
# Correlation matrix for column 0 and and column424: 0.01059090309970712
# 425
# Correlation matrix for column 0 and and column425: 0.0014553194969127053
# 426
# Correlation matrix for column 0 and and column426: -0.00039470108116847365
# 427
# Correlation matrix for column 0 and and column427: -0.019879684873205773
# 428
# Correlation matrix for column 0 and and column428: 0.010983595577784095
# 429
# Correlation matrix for column 0 and and column429: -0.01591348112122866
# 430
# Correlation matrix for column 0 and and column430: 0.006082478085780262
# 431
# Correlation matrix for column 0 and and column431: -0.0006708437408593444
# 432
# Correlation matrix for column 0 and and column432: -0.0015213688108077226
# 433
# Correlation matrix for column 0 and and column433: 0.021907115316581224
# 434
# Correlation matrix for column 0 and and column434: -0.0038415984583139375
# 435
# Correlation matrix for column 0 and and column435: 0.010201034527536209
# 436
# Correlation matrix for column 0 and and column436: -0.019314032389382802
# 437
# Correlation matrix for column 0 and and column437: 0.0016815019724982848
# 438
# Correlation matrix for column 0 and and column438: 0.011550139078567683
# 439
# Correlation matrix for column 0 and and column439: 0.015700831801572782
# 440
# Correlation matrix for column 0 and and column440: 0.008470907752927673
# 441
# Correlation matrix for column 0 and and column441: 0.010969467792245701
# 442
# Correlation matrix for column 0 and and column442: 0.003982794737252303
# 443
# Correlation matrix for column 0 and and column443: 0.003999737134191221
# 444
# Correlation matrix for column 0 and and column444: 0.006769823386040524
# 445
# Correlation matrix for column 0 and and column445: 0.003385999175974439
# 446
# Correlation matrix for column 0 and and column446: 0.004034216688820814
# 447
# Correlation matrix for column 0 and and column447: 0.0020458921609101746
# 448
# Correlation matrix for column 0 and and column448: -0.014140736001683949
# 449
# Correlation matrix for column 0 and and column449: -0.005911676465456681
# 450
# Correlation matrix for column 0 and and column450: -0.0006733557318371488
# 451
# Correlation matrix for column 0 and and column451: 0.005312306375137902
# 452
# Correlation matrix for column 0 and and column452: -0.010979903699222793
# 453
# Correlation matrix for column 0 and and column453: 0.01326015139810423
# 454
# Correlation matrix for column 0 and and column454: -0.00860197787259906
# 455
# Correlation matrix for column 0 and and column455: -0.021035188239742656
# 456
# Correlation matrix for column 0 and and column456: 0.0035930181641066934
# 457
# Correlation matrix for column 0 and and column457: -0.003178450104453263
# 458
# Correlation matrix for column 0 and and column458: -0.003178347396823137
# 459
# Correlation matrix for column 0 and and column459: -0.0007862464665308252
# 460
# Correlation matrix for column 0 and and column460: -0.008027903535773843
# 461
# Correlation matrix for column 0 and and column461: -0.0158585112235369
# 462
# Correlation matrix for column 0 and and column462: -0.0011666788756852795
# 463
# Correlation matrix for column 0 and and column463: 0.021840156419803653
# 464
# Correlation matrix for column 0 and and column464: 0.012115580456762313
# 465
# Correlation matrix for column 0 and and column465: 0.017928881694275648
# 466
# Correlation matrix for column 0 and and column466: -0.006585938764261065
# 467
# Correlation matrix for column 0 and and column467: -0.0029140824659902634
# 468
# Correlation matrix for column 0 and and column468: -0.0163200886838086
# 469
# Correlation matrix for column 0 and and column469: -0.005201788839216397
# 470
# Correlation matrix for column 0 and and column470: 0.011780497427612894
# 471
# Correlation matrix for column 0 and and column471: -0.008843183494934903
# 472
# Correlation matrix for column 0 and and column472: -0.009388096230715605
# 473
# Correlation matrix for column 0 and and column473: -0.009441632143471925
# 474
# Correlation matrix for column 0 and and column474: 0.020934456080414075
# 475
# Correlation matrix for column 0 and and column475: 0.002167716657175088
# 476
# Correlation matrix for column 0 and and column476: -0.0027835070072190185
# 477
# Correlation matrix for column 0 and and column477: -0.0016740030881483778
# 478
# Correlation matrix for column 0 and and column478: 0.0029120495446929963
# 479
# Correlation matrix for column 0 and and column479: -0.009124503643040198
# 480
# Correlation matrix for column 0 and and column480: 0.004265384628622801
# 481
# Correlation matrix for column 0 and and column481: -0.009454793490056424
# 482
# Correlation matrix for column 0 and and column482: -0.0009123333160052399
# 483
# Correlation matrix for column 0 and and column483: 0.0035531003082076534
# 484
# Correlation matrix for column 0 and and column484: 0.011293428182236722
# 485
# Correlation matrix for column 0 and and column485: -0.008789405542043473
# 486
# Correlation matrix for column 0 and and column486: 0.014474530276914303
# 487
# Correlation matrix for column 0 and and column487: -6.954174561641291e-05
# 488
# Correlation matrix for column 0 and and column488: -0.007138617050453911
# 489
# Correlation matrix for column 0 and and column489: -0.011484330771847335
# 490
# Correlation matrix for column 0 and and column490: -0.026360584959746927
# 491
# Correlation matrix for column 0 and and column491: -0.001132598749803102
# 492
# Correlation matrix for column 0 and and column492: 0.0011005278663639873
# 493
# Correlation matrix for column 0 and and column493: -0.010251321119505493
# 494
# Correlation matrix for column 0 and and column494: 9.803517277158227e-05
# 495
# Correlation matrix for column 0 and and column495: -0.0078028649867782
# 496
# Correlation matrix for column 0 and and column496: 0.011501248868536762
# 497
# Correlation matrix for column 0 and and column497: -0.006850966876735554
# 498
# Correlation matrix for column 0 and and column498: 0.007696467229314925
# 499
# Correlation matrix for column 0 and and column499: 0.014420019767732677
# 500
# Correlation matrix for column 0 and and column500: -0.001798126050754076
# 501
# Correlation matrix for column 0 and and column501: -0.005030901423883089
# 502
# Correlation matrix for column 0 and and column502: -0.024582532058261823
# 503
# Correlation matrix for column 0 and and column503: -0.0018301347213207238
# 504
# Correlation matrix for column 0 and and column504: 0.006243949175382035
# 505
# Correlation matrix for column 0 and and column505: 0.0039017030418718977
# 506
# Correlation matrix for column 0 and and column506: 0.01262464838018007
# 507
# Correlation matrix for column 0 and and column507: -0.006281378082367879
# 508
# Correlation matrix for column 0 and and column508: 0.009068533186571932
# 509
# Correlation matrix for column 0 and and column509: -0.009314451500371695
# 510
# Correlation matrix for column 0 and and column510: -0.005851573157027126
# 511
# Correlation matrix for column 0 and and column511: 0.008393189033017084
# 512
# Correlation matrix for column 0 and and column512: -0.013664548143016327
# 513
# Correlation matrix for column 0 and and column513: 0.000574459273747883
# 514
# Correlation matrix for column 0 and and column514: 0.007810358075849355
# 515
# Correlation matrix for column 0 and and column515: 0.023153040563327607
# 516
# Correlation matrix for column 0 and and column516: 0.01976246228769203
# 517
# Correlation matrix for column 0 and and column517: 0.02263211912021961
# 518
# Correlation matrix for column 0 and and column518: 0.00039967835748949855
# 519
# Correlation matrix for column 0 and and column519: 0.004490838033965463
# 520
# Correlation matrix for column 0 and and column520: -0.002954649692279978
# 521
# Correlation matrix for column 0 and and column521: 0.00031265012197755033
# 522
# Correlation matrix for column 0 and and column522: 0.025124000163004506
# 523
# Correlation matrix for column 0 and and column523: 0.005696108964265093
# 524
# Correlation matrix for column 0 and and column524: 0.0078368313582357
# 525
# Correlation matrix for column 0 and and column525: 0.002507406886647612
# 526
# Correlation matrix for column 0 and and column526: 0.007846674794824869
# 527
# Correlation matrix for column 0 and and column527: 0.01686504569038886
# 528
# Correlation matrix for column 0 and and column528: -0.003107086729273392
# 529
# Correlation matrix for column 0 and and column529: -0.019063312500565133
# 530
# Correlation matrix for column 0 and and column530: 0.004100450021010438
# 531
# Correlation matrix for column 0 and and column531: 0.009714070061389576
# 532
# Correlation matrix for column 0 and and column532: 0.0051514216452840985
# 533
# Correlation matrix for column 0 and and column533: -0.0015826754683845444
# 534
# Correlation matrix for column 0 and and column534: 0.012612626846782228
# 535
# Correlation matrix for column 0 and and column535: 0.006251525872905637
# 536
# Correlation matrix for column 0 and and column536: -0.011382621698265259
# 537
# Correlation matrix for column 0 and and column537: -0.014052565896230218
# 538
# Correlation matrix for column 0 and and column538: 0.02949119401327962
# 539
# Correlation matrix for column 0 and and column539: -0.002854892719701248
# 540
# Correlation matrix for column 0 and and column540: 0.006013469485488123
# 541
# Correlation matrix for column 0 and and column541: -0.014674324964471224
# 542
# Correlation matrix for column 0 and and column542: -0.0017562246267077426
# 543
# Correlation matrix for column 0 and and column543: 0.010181842604050622
# 544
# Correlation matrix for column 0 and and column544: -0.016813644550561137
# 545
# Correlation matrix for column 0 and and column545: -0.008658843288231244
# 546
# Correlation matrix for column 0 and and column546: 0.014618437287329072
# 547
# Correlation matrix for column 0 and and column547: 0.007157792091333794
# 548
# Correlation matrix for column 0 and and column548: -0.00830612203737784
# 549
# Correlation matrix for column 0 and and column549: -0.00794028325939499
# 550
# Correlation matrix for column 0 and and column550: -0.0046148634038283
# 551
# Correlation matrix for column 0 and and column551: -0.006500093195483853
# 552
# Correlation matrix for column 0 and and column552: -0.017029074769399476
# 553
# Correlation matrix for column 0 and and column553: -0.005433607592272084
# 554
# Correlation matrix for column 0 and and column554: -0.004424100702121491
# 555
# Correlation matrix for column 0 and and column555: 0.008132920320872976
# 556
# Correlation matrix for column 0 and and column556: 0.009089924492678064
# 557
# Correlation matrix for column 0 and and column557: -0.011028310212566433
# 558
# Correlation matrix for column 0 and and column558: 0.007609553553793726
# 559
# Correlation matrix for column 0 and and column559: 0.011782832137406146
# 560
# Correlation matrix for column 0 and and column560: 0.010994050964503335
# 561
# Correlation matrix for column 0 and and column561: -0.01465515742020086
# 562
# Correlation matrix for column 0 and and column562: 0.009167966189780262
# 563
# Correlation matrix for column 0 and and column563: 0.017823123688522676
# 564
# Correlation matrix for column 0 and and column564: 0.0044316300548249135
# 565
# Correlation matrix for column 0 and and column565: -0.005777178567729028
# 566
# Correlation matrix for column 0 and and column566: 0.0030174915852770557
# 567
# Correlation matrix for column 0 and and column567: -0.0018218808368890194
# 568
# Correlation matrix for column 0 and and column568: 0.00024390014321597683
# 569
# Correlation matrix for column 0 and and column569: 0.011489614488674388
# 570
# Correlation matrix for column 0 and and column570: 0.010771995026548548
# 571
# Correlation matrix for column 0 and and column571: -0.006249574193274593
# 572
# Correlation matrix for column 0 and and column572: 0.0035650689861897486
# 573
# Correlation matrix for column 0 and and column573: 0.0009877145249420412
# 574
# Correlation matrix for column 0 and and column574: 0.01480041753707265
# 575
# Correlation matrix for column 0 and and column575: -0.014305698183162678
# 576
# Correlation matrix for column 0 and and column576: -0.014491524139252006
# 577
# Correlation matrix for column 0 and and column577: -0.000802956753438387
# 578
# Correlation matrix for column 0 and and column578: 0.019761837985598673
# 579
# Correlation matrix for column 0 and and column579: 0.00828110415798022
# 580
# Correlation matrix for column 0 and and column580: -0.007080721349038296
# 581
# Correlation matrix for column 0 and and column581: -0.003768887276318902
# 582
# Correlation matrix for column 0 and and column582: 0.0037896661658417255
# 583
# Correlation matrix for column 0 and and column583: 0.0038656596646951618
# 584
# Correlation matrix for column 0 and and column584: -0.0012870621105247689
# 585
# Correlation matrix for column 0 and and column585: -0.00033062849231503815
# 586
# Correlation matrix for column 0 and and column586: -0.013735186702995145
# 587
# Correlation matrix for column 0 and and column587: -6.424390735127312e-05
# 588
# Correlation matrix for column 0 and and column588: -0.006372796026284368
# 589
# Correlation matrix for column 0 and and column589: -0.008957622927219659
# 590
# Correlation matrix for column 0 and and column590: -0.009774898181428912
# 591
# Correlation matrix for column 0 and and column591: -0.001649349079489051
# 592
# Correlation matrix for column 0 and and column592: -0.003689837725530988
# 593
# Correlation matrix for column 0 and and column593: 0.0024495309909040963
# 594
# Correlation matrix for column 0 and and column594: -0.006610038602163901
# 595
# Correlation matrix for column 0 and and column595: 0.004827834232896756
# 596
# Correlation matrix for column 0 and and column596: -0.013465384749091184
# 597
# Correlation matrix for column 0 and and column597: 0.004864468559562373
# 598
# Correlation matrix for column 0 and and column598: 0.015031177121020879
# 599
# Correlation matrix for column 0 and and column599: 0.002600514039741425
# 600
# Correlation matrix for column 0 and and column600: 0.0012042959579892018
# 601
# Correlation matrix for column 0 and and column601: 0.0032250195449783424
# 602
# Correlation matrix for column 0 and and column602: -0.0016463886424655247
# 603
# Correlation matrix for column 0 and and column603: -0.006357231145415012
# 604
# Correlation matrix for column 0 and and column604: -0.001279410909492874
# 605
# Correlation matrix for column 0 and and column605: -0.007631613788714019
# 606
# Correlation matrix for column 0 and and column606: -0.011020099622479258
# 607
# Correlation matrix for column 0 and and column607: 0.01453947019192587
# 608
# Correlation matrix for column 0 and and column608: -0.009638036073408152
# 609
# Correlation matrix for column 0 and and column609: 0.0040606083742873635
# 610
# Correlation matrix for column 0 and and column610: -0.005797184281721751
# 611
# Correlation matrix for column 0 and and column611: -0.024779164844405982
# 612
# Correlation matrix for column 0 and and column612: -0.01195339896060248
# 613
# Correlation matrix for column 0 and and column613: -0.0007847135551048847
# 614
# Correlation matrix for column 0 and and column614: 0.010592340044892304
# 615
# Correlation matrix for column 0 and and column615: 0.014866397781277381
# 616
# Correlation matrix for column 0 and and column616: 0.006419262082134714
# 617
# Correlation matrix for column 0 and and column617: 0.009754354479514104
# 618
# Correlation matrix for column 0 and and column618: -0.025639335340085605
# 619
# Correlation matrix for column 0 and and column619: -0.007250357111472007
# 620
# Correlation matrix for column 0 and and column620: 0.005539021028200947
# 621
# Correlation matrix for column 0 and and column621: -0.00938089765924467
# 622
# Correlation matrix for column 0 and and column622: -0.009507664006675826
# 623
# Correlation matrix for column 0 and and column623: 0.013256463598905055
# 624
# Correlation matrix for column 0 and and column624: -0.021045951251654486
# 625
# Correlation matrix for column 0 and and column625: -0.0028474369593958796
# 626
# Correlation matrix for column 0 and and column626: -0.008227343830428585
# 627
# ...
# 7691
# Correlation matrix for column 0 and and column7691: -0.011249346489809986
# 7692
# Correlation matrix for column 0 and and column7692: 0.022055616411840687
# 7693
# Correlation matrix for column 0 and and column7693: 0.0060175290521006595
# 7694
# Correlation matrix for column 0 and and column7694: 0.0046532611652460145
# 7695
# Correlation matrix for column 0 and and column7695: -0.0015402770437967243
# 7696
# Correlation matrix for column 0 and and column7696: -0.013801184602727303
# 7697
# Correlation matrix for column 0 and and column7697: 0.002144727223398335
# 7698
# Correlation matrix for column 0 and and column7698: -0.006381112207892351
# 7699
# Correlation matrix for column 0 and and column7699: -0.00016680777485500562
# 7700
# Correlation matrix for column 0 and and column7700: 0.0082520604996676
# 7701
# Correlation matrix for column 0 and and column7701: 0.03138377513927342
# 7702
# Correlation matrix for column 0 and and column7702: 0.015689970675174178
# 7703
# Correlation matrix for column 0 and and column7703: 0.0005379811095319508
# 7704
# Correlation matrix for column 0 and and column7704: 0.02889059673286187
# 7705
# Correlation matrix for column 0 and and column7705: -0.007588895317919093
# 7706
# Correlation matrix for column 0 and and column7706: 0.006572494918173236
# 7707
# Correlation matrix for column 0 and and column7707: -0.01092284097615577
# 7708
# Correlation matrix for column 0 and and column7708: -0.009811171648699888
# 7709
# Correlation matrix for column 0 and and column7709: 0.011065708801287013
# 7710
# Correlation matrix for column 0 and and column7710: -0.020720031536444118
# 7711
# Correlation matrix for column 0 and and column7711: -0.0003332710384575994
# 7712
# Correlation matrix for column 0 and and column7712: -0.0044676435327406245
# 7713
# Correlation matrix for column 0 and and column7713: 0.015375478886416596
# 7714
# Correlation matrix for column 0 and and column7714: 0.007973132751813357
# 7715
# Correlation matrix for column 0 and and column7715: -0.0006072694627532882
# 7716
# Correlation matrix for column 0 and and column7716: 0.008098409520271731
# 7717
# Correlation matrix for column 0 and and column7717: -0.010109555933140628
# 7718
# Correlation matrix for column 0 and and column7718: 0.0017983549899772335
# 7719
# Correlation matrix for column 0 and and column7719: 0.005825004634609025
# 7720
# Correlation matrix for column 0 and and column7720: 0.002341020610084557
# 7721
# Correlation matrix for column 0 and and column7721: 0.002719346089606696
# 7722
# Correlation matrix for column 0 and and column7722: -0.00013364148420474977
# 7723
# Correlation matrix for column 0 and and column7723: -0.001131232529738737
# 7724
# Correlation matrix for column 0 and and column7724: -0.009782564303969022
# 7725
# Correlation matrix for column 0 and and column7725: -0.0010778578954809728
# 7726
# Correlation matrix for column 0 and and column7726: -0.028198227153702047
# 7727
# Correlation matrix for column 0 and and column7727: 0.006723647158899466
# 7728
# Correlation matrix for column 0 and and column7728: 0.007423805106880302
# 7729
# Correlation matrix for column 0 and and column7729: 0.020024006939580657
# 7730
# Correlation matrix for column 0 and and column7730: -0.010968450610477428
# 7731
# Correlation matrix for column 0 and and column7731: 0.009766171936984619
# 7732
# Correlation matrix for column 0 and and column7732: -0.0002036954168246272
# 7733
# Correlation matrix for column 0 and and column7733: -0.012430683735496374
# 7734
# Correlation matrix for column 0 and and column7734: 0.001054959747170056
# 7735
# Correlation matrix for column 0 and and column7735: 0.00469082438418387
# 7736
# Correlation matrix for column 0 and and column7736: 0.022250379263116796
# 7737
# Correlation matrix for column 0 and and column7737: 0.001525623300331279
# 7738
# Correlation matrix for column 0 and and column7738: 0.004767637015647269
# 7739
# Correlation matrix for column 0 and and column7739: -0.01664005913468621
# 7740
# Correlation matrix for column 0 and and column7740: -0.011294552346422288
# 7741
# Correlation matrix for column 0 and and column7741: -0.020144405029868764
# 7742
# Correlation matrix for column 0 and and column7742: 0.016643486558864082
# 7743
# Correlation matrix for column 0 and and column7743: -0.012685298549501043
# 7744
# Correlation matrix for column 0 and and column7744: -0.0009117882300606126
# 7745
# Correlation matrix for column 0 and and column7745: 0.0025759244000325204
# 7746
# Correlation matrix for column 0 and and column7746: -0.0007734319565136736
# 7747
# Correlation matrix for column 0 and and column7747: 0.0010616856254607764
# 7748
# Correlation matrix for column 0 and and column7748: -0.0020473704192278757
# 7749
# Correlation matrix for column 0 and and column7749: -0.0016029242428233126
# 7750
# Correlation matrix for column 0 and and column7750: 0.013900197356697008
# 7751
# Correlation matrix for column 0 and and column7751: -0.011362255755807937
# 7752
# Correlation matrix for column 0 and and column7752: 0.00746174703012963
# 7753
# Correlation matrix for column 0 and and column7753: -0.008694688884912765
# 7754
# Correlation matrix for column 0 and and column7754: 0.0004831434946064142
# 7755
# Correlation matrix for column 0 and and column7755: 0.011342479015580267
# 7756
# Correlation matrix for column 0 and and column7756: 0.013616925364869529
# 7757
# Correlation matrix for column 0 and and column7757: 0.002031392241645838
# 7758
# Correlation matrix for column 0 and and column7758: 0.010879197252056631
# 7759
# Correlation matrix for column 0 and and column7759: -0.019297216329203636
# 7760
# Correlation matrix for column 0 and and column7760: -0.004613281002963192
# 7761
# Correlation matrix for column 0 and and column7761: 0.0018181611459281697
# 7762
# Correlation matrix for column 0 and and column7762: -0.020004431087277227
# 7763
# Correlation matrix for column 0 and and column7763: 0.011615405942545428
# 7764
# Correlation matrix for column 0 and and column7764: 0.020017533015249115
# 7765
# Correlation matrix for column 0 and and column7765: 0.00998441370231138
# 7766
# Correlation matrix for column 0 and and column7766: -0.001381120769929284
# 7767
# Correlation matrix for column 0 and and column7767: 0.008458622872303511
# 7768
# Correlation matrix for column 0 and and column7768: -0.011553950902941264
# 7769
# Correlation matrix for column 0 and and column7769: 0.008246053075997413
# 7770
# Correlation matrix for column 0 and and column7770: -0.0013433077391553478
# 7771
# Correlation matrix for column 0 and and column7771: -0.00046330316288718495
# 7772
# Correlation matrix for column 0 and and column7772: -0.01049133887711909
# 7773
# Correlation matrix for column 0 and and column7773: 0.01742150971654008
# 7774
# Correlation matrix for column 0 and and column7774: 0.017886827471441
# 7775
# Correlation matrix for column 0 and and column7775: -0.003765592204727974
# 7776
# Correlation matrix for column 0 and and column7776: 0.006936812340574923
# 7777
# Correlation matrix for column 0 and and column7777: -0.01861736564099206
# 7778
# Correlation matrix for column 0 and and column7778: -0.001846335883148749
# 7779
# Correlation matrix for column 0 and and column7779: -0.01499695215264061
# 7780
# Correlation matrix for column 0 and and column7780: 0.0013616685503879756
# 7781
# Correlation matrix for column 0 and and column7781: 0.00291000423008463
# 7782
# Correlation matrix for column 0 and and column7782: 0.019167032614361076
# 7783
# Correlation matrix for column 0 and and column7783: 0.006355737971613437
# 7784
# Correlation matrix for column 0 and and column7784: -0.004767947848768509
# 7785
# Correlation matrix for column 0 and and column7785: -0.013963794773798084
# 7786
# Correlation matrix for column 0 and and column7786: 0.007758526221614372
# 7787
# Correlation matrix for column 0 and and column7787: 0.004102981674038241
# 7788
# Correlation matrix for column 0 and and column7788: 0.0041048594134546834
# 7789
# Correlation matrix for column 0 and and column7789: 0.001807638506421384
# 7790
# Correlation matrix for column 0 and and column7790: -0.008512594068004588
# 7791
# Correlation matrix for column 0 and and column7791: 0.0030043088830879142
# 7792
# Correlation matrix for column 0 and and column7792: 0.022947045447515878
# 7793
# Correlation matrix for column 0 and and column7793: -0.012840221918692236
# 7794
# Correlation matrix for column 0 and and column7794: -0.006114582399668422
# 7795
# Correlation matrix for column 0 and and column7795: 0.00216651000888482
# 7796
# Correlation matrix for column 0 and and column7796: -0.0013340589623297094
# 7797
# Correlation matrix for column 0 and and column7797: -0.012444315314338792
# 7798
# Correlation matrix for column 0 and and column7798: 0.0026002991959925056
# 7799
# Correlation matrix for column 0 and and column7799: -0.00043916009306577906
# 7800
# Correlation matrix for column 0 and and column7800: -0.00810384085000887
# 7801
# Correlation matrix for column 0 and and column7801: 0.002208492917645409
# 7802
# Correlation matrix for column 0 and and column7802: 0.013530100368120596
# 7803
# Correlation matrix for column 0 and and column7803: -0.009496658283263246
# 7804
# Correlation matrix for column 0 and and column7804: 0.01191775584320327
# 7805
# Correlation matrix for column 0 and and column7805: -0.0011938464596523198
# 7806
# Correlation matrix for column 0 and and column7806: 0.028669043446498295
# 7807
# Correlation matrix for column 0 and and column7807: -0.00575555029098457
# 7808
# Correlation matrix for column 0 and and column7808: -0.0025805523368172202
# 7809
# Correlation matrix for column 0 and and column7809: 0.0009337306590364527
# 7810
# Correlation matrix for column 0 and and column7810: 0.009243078233533387
# 7811
# Correlation matrix for column 0 and and column7811: -0.0017441806943342484
# 7812
# Correlation matrix for column 0 and and column7812: -0.0031116886825135336
# 7813
# Correlation matrix for column 0 and and column7813: 0.0017346966634569447
# 7814
# Correlation matrix for column 0 and and column7814: 0.0058598126292253964
# 7815
# Correlation matrix for column 0 and and column7815: -0.006045201688091846
# 7816
# Correlation matrix for column 0 and and column7816: 0.004536389953906925
# 7817
# Correlation matrix for column 0 and and column7817: -0.0023402643933574173
# 7818
# Correlation matrix for column 0 and and column7818: -0.004030120610000801
# 7819
# Correlation matrix for column 0 and and column7819: 0.006020573820565041
# 7820
# Correlation matrix for column 0 and and column7820: -0.013090189933955484
# 7821
# Correlation matrix for column 0 and and column7821: -0.008335482263976743
# 7822
# Correlation matrix for column 0 and and column7822: 0.0027145413885459302
# 7823
# Correlation matrix for column 0 and and column7823: 0.01949283804241179
# 7824
# Correlation matrix for column 0 and and column7824: 0.001893948644397516
# 7825
# Correlation matrix for column 0 and and column7825: -0.004983513596909524
# 7826
# Correlation matrix for column 0 and and column7826: 0.008954389461012305
# 7827
# Correlation matrix for column 0 and and column7827: 0.013343388674710901
# 7828
# Correlation matrix for column 0 and and column7828: -0.0025478565728834428
# 7829
# Correlation matrix for column 0 and and column7829: 0.003890840079275691
# 7830
# Correlation matrix for column 0 and and column7830: -0.005191592211171714
# 7831
# Correlation matrix for column 0 and and column7831: -0.007352336830178573
# 7832
# Correlation matrix for column 0 and and column7832: -0.009234437948309101
# 7833
# Correlation matrix for column 0 and and column7833: -0.006600888950063831
# 7834
# Correlation matrix for column 0 and and column7834: -0.008002709273219697
# 7835
# Correlation matrix for column 0 and and column7835: 0.011530606061213599
# 7836
# Correlation matrix for column 0 and and column7836: 0.004540021149570023
# 7837
# Correlation matrix for column 0 and and column7837: 0.005902961096801881
# 7838
# Correlation matrix for column 0 and and column7838: -0.0168744148835022
# 7839
# Correlation matrix for column 0 and and column7839: 0.021418905167714764
# 7840
# Correlation matrix for column 0 and and column7840: 0.004678006266988935
# 7841
# Correlation matrix for column 0 and and column7841: 0.016598745046210533
# 7842
# Correlation matrix for column 0 and and column7842: 0.0052485081450931
# 7843
# Correlation matrix for column 0 and and column7843: -0.0027894119726654593
# 7844
# Correlation matrix for column 0 and and column7844: -0.004387276053808981
# 7845
# Correlation matrix for column 0 and and column7845: -0.006958193845300903
# 7846
# Correlation matrix for column 0 and and column7846: 0.0008872134063944457
# 7847
# Correlation matrix for column 0 and and column7847: -0.002368188607377769
# 7848
# Correlation matrix for column 0 and and column7848: -0.01537865768098831
# 7849
# Correlation matrix for column 0 and and column7849: -0.016219738153599426
# 7850
# Correlation matrix for column 0 and and column7850: -0.029253620028242326
# 7851
# Correlation matrix for column 0 and and column7851: -0.008049607204038425
# 7852
# Correlation matrix for column 0 and and column7852: 0.01248740884013775
# 7853
# Correlation matrix for column 0 and and column7853: -0.0013202103261915035
# 7854
# Correlation matrix for column 0 and and column7854: -0.013401231457156604
# 7855
# Correlation matrix for column 0 and and column7855: -0.001313793715644558
# 7856
# Correlation matrix for column 0 and and column7856: -0.020289527716169303
# 7857
# Correlation matrix for column 0 and and column7857: -0.007849010496312904
# 7858
# Correlation matrix for column 0 and and column7858: 0.00405846472514971
# 7859
# Correlation matrix for column 0 and and column7859: -0.00044306662452353487
# 7860
# Correlation matrix for column 0 and and column7860: 0.004054738810505026
# 7861
# Correlation matrix for column 0 and and column7861: -0.0017861686791677807
# 7862
# Correlation matrix for column 0 and and column7862: 0.0069435908251603475
# 7863
# Correlation matrix for column 0 and and column7863: 3.759894040709358e-05
# 7864
# Correlation matrix for column 0 and and column7864: 0.0012866536748090268
# 7865
# Correlation matrix for column 0 and and column7865: 0.014535136580030346
# 7866
# Correlation matrix for column 0 and and column7866: 0.016317239396303015
# 7867
# Correlation matrix for column 0 and and column7867: -0.0003588133387470527
# 7868
# Correlation matrix for column 0 and and column7868: -0.0035146473930662233
# 7869
# Correlation matrix for column 0 and and column7869: 0.009811387485368755
# 7870
# Correlation matrix for column 0 and and column7870: 0.004237732691156227
# 7871
# Correlation matrix for column 0 and and column7871: -0.030180432366412692
# 7872
# Correlation matrix for column 0 and and column7872: -0.0052059339709709185
# 7873
# Correlation matrix for column 0 and and column7873: -0.01678548051264531
# 7874
# Correlation matrix for column 0 and and column7874: -0.008799426667517995
# 7875
# Correlation matrix for column 0 and and column7875: -0.02377280075278015
# 7876
# Correlation matrix for column 0 and and column7876: -0.006707846403027002
# 7877
# Correlation matrix for column 0 and and column7877: 0.0012345201232744148
# 7878
# Correlation matrix for column 0 and and column7878: -0.009170204715746928
# 7879
# Correlation matrix for column 0 and and column7879: -0.00048376585437255576
# 7880
# Correlation matrix for column 0 and and column7880: -0.015851405391056214
# 7881
# Correlation matrix for column 0 and and column7881: -0.003784675888737733
# 7882
# Correlation matrix for column 0 and and column7882: -0.0036248996623864252
# 7883
# Correlation matrix for column 0 and and column7883: 0.000902035815103339
# 7884
# Correlation matrix for column 0 and and column7884: 0.01714394278099295
# 7885
# Correlation matrix for column 0 and and column7885: 0.01115971816573797
# 7886
# Correlation matrix for column 0 and and column7886: -0.008781452589925638
# 7887
# Correlation matrix for column 0 and and column7887: -0.003706505880877442
# 7888
# Correlation matrix for column 0 and and column7888: 0.013611202156067485
# 7889
# Correlation matrix for column 0 and and column7889: 0.0025717301148526386
# 7890
# Correlation matrix for column 0 and and column7890: -0.01356512195532454
# 7891
# Correlation matrix for column 0 and and column7891: 0.0055313540336795084
# 7892
# Correlation matrix for column 0 and and column7892: -0.01286119054259446
# 7893
# Correlation matrix for column 0 and and column7893: -0.005168880731769488

# %%
a = 0
b = 0
for i in range(0,len(list_corr_df1)):
    if abs(list_corr_df1[i]) > 0.01:
        a+=1
    else:
        pass
        
for i in range(0,len(list_corr_df_new)):
    if abs(list_corr_df_new[i]) > 0.01:
        b+=1
    else:
        pass

print("Percentage of correlations in df1:",(a/len(list_corr_df1)*100),"%")

print("Percentage of correlations in df_new:",(b/len(list_corr_df_new)*100),"%")
# Out:
# Percentage of correlations in df1: 20.0 %
# Percentage of correlations in df_new: 35.58849613581654 %
